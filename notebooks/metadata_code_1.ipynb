# %%
import numpy as np 
import pandas as pd
import re

# %%
def clean_text(text):
    if isinstance(text, str): 
        return re.sub(r'\s+', ' ', text).strip()
    return text

# %%
def summary(df):
    print(f'data shape: {df.shape}')  
    summ = pd.DataFrame(df.dtypes, columns=['data type'])
    summ['#missing'] = df.isnull().sum().values 
    summ['%missing'] = df.isnull().sum().values / len(df)
    summ['#unique'] = df.nunique().values
    desc = pd.DataFrame(df.describe(include='all').transpose())
#     summ['min'] = desc['min'].values
#     summ['max'] = desc['max'].values
    return summ

# %%
file_path = '../metadata/hierarchy_topic_by_sheet.xlsx' 
xls = pd.ExcelFile(file_path)


dfs = {}

for sheet_name in xls.sheet_names:
    first_word = sheet_name.split()[0].lower() 
    df = pd.read_excel(xls, sheet_name=sheet_name)  
    dfs[first_word] = df  


for name, df in dfs.items():
    print(f"{name}")
# Out:
# economic
# education
# environment
# financial
# gender
# health
# infrastructure
# poverty
# private
# public
# social
# trade

# %%
dfs['education']
# Out:
#                   Code                                     Indicator Name  \
# 0       SE.PRM.PRS5.ZS        Persistence to grade 5, total (% of cohort)
# 1       SE.PRM.GINT.ZS  Gross intake ratio in first grade of primary e...
# 2       SE.PRM.NINT.ZS  Net intake rate in grade 1 (% of official scho...
# 3    SE.PRM.OENR.MA.ZS  Over-age students, primary, male (% of male en...
# 4    SE.PRM.PRS5.MA.ZS         Persistence to grade 5, male (% of cohort)
# ..                 ...                                                ...
# 151  SE.ENR.PRIM.FM.ZS  School enrollment, primary (gross), gender par...
# 152        SE.PRM.NENR                 School enrollment, primary (% net)
# 153     SE.PRE.ENRR.MA      School enrollment, preprimary, male (% gross)
# 154     SE.PRM.PRIV.ZS  School enrollment, primary, private (% of tota...
# 155  SE.ENR.TERT.FM.ZS  School enrollment, tertiary (gross), gender pa...
#
#                 General Topic      Topic      SubTopic1  SubTopic2  SubTopic3
# 0       Education: Efficiency  Education     Efficiency        NaN        NaN
# 1       Education: Efficiency  Education     Efficiency        NaN        NaN
# 2       Education: Efficiency  Education     Efficiency        NaN        NaN
# 3       Education: Efficiency  Education     Efficiency        NaN        NaN
# 4       Education: Efficiency  Education     Efficiency        NaN        NaN
# ..                        ...        ...            ...        ...        ...
# 151  Education: Participation  Education  Participation        NaN        NaN
# 152  Education: Participation  Education  Participation        NaN        NaN
# 153  Education: Participation  Education  Participation        NaN        NaN
# 154  Education: Participation  Education  Participation        NaN        NaN
# 155  Education: Participation  Education  Participation        NaN        NaN
#
# [156 rows x 7 columns]

# %%
example_education = dfs['education'].copy()

# %%
example_education['code3'] = example_education['Code'].str.split('.').str[:3].str.join('.')

# %%
grouped_counts = example_education['code3'].value_counts()
grouped_counts.head()
# Out:
# code3
# SE.TER.CUAT    12
# SE.SEC.CUAT     9
# SE.LPV.PRIM     9
# SE.SEC.TCAQ     9
# SE.SEC.ENRL     9
# Name: count, dtype: int64

# %%
with pd.option_context('display.max_colwidth', 200):

    display(example_education[example_education['code3'] == 'SE.TER.CUAT'])
# Out:
#                     Code  \
# 68  SE.TER.CUAT.BA.FE.ZS
# 69  SE.TER.CUAT.DO.FE.ZS
# 70  SE.TER.CUAT.BA.MA.ZS
# 71  SE.TER.CUAT.DO.MA.ZS
# 73  SE.TER.CUAT.ST.FE.ZS
# 76  SE.TER.CUAT.ST.MA.ZS
# 77     SE.TER.CUAT.MS.ZS
# 78     SE.TER.CUAT.BA.ZS
# 80     SE.TER.CUAT.DO.ZS
# 81  SE.TER.CUAT.MS.MA.ZS
# 82  SE.TER.CUAT.MS.FE.ZS
# 83     SE.TER.CUAT.ST.ZS
#
#                                                                                               Indicator Name  \
# 68        Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)
# 69                   Educational attainment, Doctoral or equivalent, population 25+, female (%) (cumulative)
# 70          Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)
# 71                     Educational attainment, Doctoral or equivalent, population 25+, male (%) (cumulative)
# 73  Educational attainment, at least completed short-cycle tertiary, population 25+, female (%) (cumulative)
# 76    Educational attainment, at least completed short-cycle tertiary, population 25+, male (%) (cumulative)
# 77           Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)
# 78         Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)
# 80                    Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)
# 81            Educational attainment, at least Master's or equivalent, population 25+, male (%) (cumulative)
# 82          Educational attainment, at least Master's or equivalent, population 25+, female (%) (cumulative)
# 83   Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)
#
#           General Topic      Topic SubTopic1  SubTopic2  SubTopic3  \
# 68  Education: Outcomes  Education  Outcomes        NaN        NaN
# 69  Education: Outcomes  Education  Outcomes        NaN        NaN
# 70  Education: Outcomes  Education  Outcomes        NaN        NaN
# 71  Education: Outcomes  Education  Outcomes        NaN        NaN
# 73  Education: Outcomes  Education  Outcomes        NaN        NaN
# 76  Education: Outcomes  Education  Outcomes        NaN        NaN
# 77  Education: Outcomes  Education  Outcomes        NaN        NaN
# 78  Education: Outcomes  Education  Outcomes        NaN        NaN
# 80  Education: Outcomes  Education  Outcomes        NaN        NaN
# 81  Education: Outcomes  Education  Outcomes        NaN        NaN
# 82  Education: Outcomes  Education  Outcomes        NaN        NaN
# 83  Education: Outcomes  Education  Outcomes        NaN        NaN
#
#           code3
# 68  SE.TER.CUAT
# 69  SE.TER.CUAT
# 70  SE.TER.CUAT
# 71  SE.TER.CUAT
# 73  SE.TER.CUAT
# 76  SE.TER.CUAT
# 77  SE.TER.CUAT
# 78  SE.TER.CUAT
# 80  SE.TER.CUAT
# 81  SE.TER.CUAT
# 82  SE.TER.CUAT
# 83  SE.TER.CUAT

# %% [markdown]
# In this eample of education outcomes, we observe that indicator codes beginning with **SE.TER.CUAT** can be further subdivided to populate relevant subtopics.
#
# To achieve this, we will:
# 1. **Read the WDI Indicators file** to examine the full list of codes and their corresponding descriptions.
# 2. **Identify patterns** within the codes that allow for classification into subtopics.
# 3. **Extract meaningful subtopic information** from the code structure and descriptions.
#
# By implementing this approach, we aim to enhance the granularity of our dataset and improve analytical insights into education outcomes.

# %%
wdi_codes = pd.read_excel('../metadata/WDI_Indicators.xlsx', sheet_name="Coding")

# %%
wdi_codes
# Out:
#      Topic                                Topic description General subject  \
# 0       AG                                      Agriculture             ACS
# 1       BG                       Balance of payments: gross             ADJ
# 2       BM  Balance of payments: imports, payments (credit)             ADM
# 3       BN                         Balance of payments: net             ADO
# 4       BX   Balance of payments: exports, receipts (debit)             ADT
# ...    ...                                              ...             ...
# 1057   NaN                                              NaN             NaN
# 1058   NaN                                              NaN             NaN
# 1059   NaN                                              NaN             NaN
# 1060   NaN                                              NaN             NaN
# 1061   NaN                                              NaN             NaN
#
#      General subject description Specific subject  \
# 0                         Access             0003
# 1               Adjusted savings             0004
# 2                      Admission             0014
# 3                     Adolescent             0324
# 4                          Adult             0306
# ...                          ...              ...
# 1057                         NaN             XOKA
# 1058                         NaN             XPND
# 1059                         NaN             XPRT
# 1060                         NaN             XTHR
# 1061                         NaN             YPKG
#
#               Specific subject description Extensions Extensions description
# 0                                  Age 0-3         05             2005 (PPP)
# 1                                  Age 0-4         10                 Decile
# 2                                 Age 0-14         14               Age 0-14
# 3                                 Age 0-24         20               Quintile
# 4                                  Age 3-6         90   % changes since 1990
# ...                                    ...        ...                    ...
# 1057  Excluding official capital transfers        NaN                    NaN
# 1058                           Expenditure        NaN                    NaN
# 1059                               Exports        NaN                    NaN
# 1060            Other manufactures (trade)        NaN                    NaN
# 1061     Income, profits and capital gains        NaN                    NaN
#
# [1062 rows x 8 columns]

# %% [markdown]
# ### Understanding the Code Structure using `wdi_codes`
#
# Based on our analysis, we have identified a general pattern in the structure of the codes formatted as **XX.XX.XX...**. While this does not apply to all cases, the common breakdown is as follows:
#
# 1. **Topic Column**: Corresponds to the `Topic` and `SubTopic1` of the dataset as the values for that column are **name : name**.
# 2. **General subject Column**: Represents the `SubTopic2`.
# 3. **Specific subject Column**: Defines the `SubTopic3`.
# 4. **Extension (the rest)**: Any additional components following the third part can be considered as **Extensions**, which provide further granularity or variations within the specific subject. Note we dont have a column for taht yet and we will find a way to add informations of extension if they are important to our work
#
# By leveraging this structure, we can systematically extract hierarchical information from the codes and use it for improved classification and mapping in our analysis.

# %% [markdown]
# We will delete the topic and topic description as we already has the topic metadata filled

# %%
wdi_codes.drop(columns=['Topic', 'Topic description'], inplace=True)
wdi_codes.head()
# Out:
#   General subject General subject description Specific subject  \
# 0             ACS                      Access             0003
# 1             ADJ            Adjusted savings             0004
# 2             ADM                   Admission             0014
# 3             ADO                  Adolescent             0324
# 4             ADT                       Adult             0306
#
#   Specific subject description Extensions Extensions description
# 0                      Age 0-3         05             2005 (PPP)
# 1                      Age 0-4         10                 Decile
# 2                     Age 0-14         14               Age 0-14
# 3                     Age 0-24         20               Quintile
# 4                      Age 3-6         90   % changes since 1990

# %%
for col in ['General subject', 'Specific subject', 'Extensions']:
    redundant = wdi_codes[col].dropna()[wdi_codes[col].dropna().duplicated()]
    if not redundant.empty:
        print(f"Redundant values in column '{col}':")
        print(redundant)
    else:
        print(f"No redundant values in column '{col}'.")
# Out:
# No redundant values in column 'General subject'.
# No redundant values in column 'Specific subject'.
# No redundant values in column 'Extensions'.

# %%
import pandas as pd

wdi_codes['has_match'] = wdi_codes.apply(
    lambda row: (
        (pd.notna(row['General subject']) and row['General subject'] in [row['Specific subject'], row['Extensions']]) or
        (pd.notna(row['Specific subject']) and row['Specific subject'] in [row['General subject'], row['Extensions']]) or
        (pd.notna(row['Extensions']) and row['Extensions'] in [row['General subject'], row['Specific subject']])
    ), axis=1
)

matching_rows = wdi_codes[wdi_codes['has_match']]
print("Rows with matching values between columns:")
print(matching_rows[['General subject', 'Specific subject', 'Extensions']])


wdi_codes.drop(columns=['has_match'], inplace=True)
# Out:
# Rows with matching values between columns:
# Empty DataFrame
# Columns: [General subject, Specific subject, Extensions]
# Index: []

# %%
# df_melted = pd.melt(wdi_codes, 
#                     value_vars=['General subject', 'Specific subject', 'Extensions'], 
#                     var_name='Key_Type', value_name='Key')

# df_melted['Value'] = pd.melt(wdi_codes, 
#                              value_vars=['General subject description', 'Specific subject description', 'Extensions description'], 
#                              var_name='Value_Type', value_name='Value')['Value']

# df_melted.dropna(subset=['Key', 'Value'], how='any', inplace=True)

# %%
# df_melted

# %% [markdown]
# ## Testing in the example of education `example_education`

# %%
print(example_education['SubTopic2'].notna().any())
print(example_education['SubTopic3'].notna().any())
# Out:
# False
# False

# %% [markdown]
# # This is the main function we will be using to assign the subtopics

# %%
def extract_and_match(row, df2):

    parts = row['Code'].split('.')
    if len(parts) < 3:
        first_desc, second_desc = None, None
    else:
        first_desc = df2.loc[df2['General subject'] == parts[1], 'General subject description'].values
        second_desc = df2.loc[df2['Specific subject'] == parts[2], 'Specific subject description'].values

        first_desc = first_desc[0] if first_desc.size > 0 else None
        second_desc = second_desc[0] if second_desc.size > 0 else None


    if pd.notna(row['SubTopic2']):


        if first_desc != None and row['SubTopic2'] != first_desc: 

            row['SubTopic2'] = [row['SubTopic2'], first_desc]            
    else:

        row['SubTopic2'] = first_desc

    if pd.notna(row['SubTopic3']):

        if row['SubTopic3'] != second_desc:
            row['SubTopic3'] = [row['SubTopic3'], second_desc]
    else:

        row['SubTopic3'] = second_desc

    return row

# %%
example_education = example_education.apply(extract_and_match, axis=1, df2=wdi_codes)

# %%
example_education
# Out:
#                   Code                                     Indicator Name  \
# 0       SE.PRM.PRS5.ZS        Persistence to grade 5, total (% of cohort)
# 1       SE.PRM.GINT.ZS  Gross intake ratio in first grade of primary e...
# 2       SE.PRM.NINT.ZS  Net intake rate in grade 1 (% of official scho...
# 3    SE.PRM.OENR.MA.ZS  Over-age students, primary, male (% of male en...
# 4    SE.PRM.PRS5.MA.ZS         Persistence to grade 5, male (% of cohort)
# ..                 ...                                                ...
# 151  SE.ENR.PRIM.FM.ZS  School enrollment, primary (gross), gender par...
# 152        SE.PRM.NENR                 School enrollment, primary (% net)
# 153     SE.PRE.ENRR.MA      School enrollment, preprimary, male (% gross)
# 154     SE.PRM.PRIV.ZS  School enrollment, primary, private (% of tota...
# 155  SE.ENR.TERT.FM.ZS  School enrollment, tertiary (gross), gender pa...
#
#                 General Topic      Topic      SubTopic1             SubTopic2  \
# 0       Education: Efficiency  Education     Efficiency     Primary education
# 1       Education: Efficiency  Education     Efficiency     Primary education
# 2       Education: Efficiency  Education     Efficiency     Primary education
# 3       Education: Efficiency  Education     Efficiency     Primary education
# 4       Education: Efficiency  Education     Efficiency     Primary education
# ..                        ...        ...            ...                   ...
# 151  Education: Participation  Education  Participation            Enrollment
# 152  Education: Participation  Education  Participation     Primary education
# 153  Education: Participation  Education  Participation  Preprimary education
# 154  Education: Participation  Education  Participation     Primary education
# 155  Education: Participation  Education  Participation            Enrollment
#
#                   SubTopic3        code3
# 0    Persistence to grade 5  SE.PRM.PRS5
# 1              Gross intake  SE.PRM.GINT
# 2                Net intake  SE.PRM.NINT
# 3       Over-age enrollment  SE.PRM.OENR
# 4    Persistence to grade 5  SE.PRM.PRS5
# ..                      ...          ...
# 151       Primary education  SE.ENR.PRIM
# 152          Net enrollment  SE.PRM.NENR
# 153          Enrolment rate  SE.PRE.ENRR
# 154                 Private  SE.PRM.PRIV
# 155      Tertiary education  SE.ENR.TERT
#
# [156 rows x 8 columns]

# %%
summary(example_education).style.background_gradient(cmap='Blues')
# Out:
# data shape: (156, 8)
# <style type="text/css">
# #T_8b250_row0_col1, #T_8b250_row0_col2, #T_8b250_row1_col1, #T_8b250_row1_col2, #T_8b250_row2_col1, #T_8b250_row2_col2, #T_8b250_row3_col1, #T_8b250_row3_col2, #T_8b250_row3_col3, #T_8b250_row4_col1, #T_8b250_row4_col2, #T_8b250_row6_col1, #T_8b250_row6_col2, #T_8b250_row7_col1, #T_8b250_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8b250_row0_col3, #T_8b250_row1_col3, #T_8b250_row5_col1, #T_8b250_row5_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8b250_row2_col3, #T_8b250_row4_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_8b250_row5_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_8b250_row6_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_8b250_row7_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# </style>
# <table id="T_8b250">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b250_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_8b250_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_8b250_level0_col2" class="col_heading level0 col2" >%missing</th>
#       <th id="T_8b250_level0_col3" class="col_heading level0 col3" >#unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b250_level0_row0" class="row_heading level0 row0" >Code</th>
#       <td id="T_8b250_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_8b250_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_8b250_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_8b250_row0_col3" class="data row0 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_8b250_level0_row1" class="row_heading level0 row1" >Indicator Name</th>
#       <td id="T_8b250_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_8b250_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_8b250_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_8b250_row1_col3" class="data row1 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_8b250_level0_row2" class="row_heading level0 row2" >General Topic</th>
#       <td id="T_8b250_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_8b250_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_8b250_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_8b250_row2_col3" class="data row2 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8b250_level0_row3" class="row_heading level0 row3" >Topic</th>
#       <td id="T_8b250_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_8b250_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_8b250_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_8b250_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8b250_level0_row4" class="row_heading level0 row4" >SubTopic1</th>
#       <td id="T_8b250_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_8b250_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_8b250_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_8b250_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8b250_level0_row5" class="row_heading level0 row5" >SubTopic2</th>
#       <td id="T_8b250_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_8b250_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_8b250_row5_col2" class="data row5 col2" >0.057692</td>
#       <td id="T_8b250_row5_col3" class="data row5 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_8b250_level0_row6" class="row_heading level0 row6" >SubTopic3</th>
#       <td id="T_8b250_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_8b250_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_8b250_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_8b250_row6_col3" class="data row6 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_8b250_level0_row7" class="row_heading level0 row7" >code3</th>
#       <td id="T_8b250_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_8b250_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_8b250_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_8b250_row7_col3" class="data row7 col3" >54</td>
#     </tr>
#   </tbody>
# </table>

# %%
with pd.option_context('display.max_colwidth', 200):

    display(example_education[example_education['SubTopic2'].isna()])
# Out:
#                   Code  \
# 75      SE.LPV.PRIM.SD
# 89      SE.LPV.PRIM.LD
# 94      SE.LPV.PRIM.MA
# 95      SE.LPV.PRIM.FE
# 101        SE.LPV.PRIM
# 104  SE.LPV.PRIM.LD.FE
# 105  SE.LPV.PRIM.SD.FE
# 106  SE.LPV.PRIM.SD.MA
# 109  SE.LPV.PRIM.LD.MA
#
#                                                                                                                                     Indicator Name  \
# 75                                                                                                   Primary school age children out-of-school (%)
# 89                                                              Pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 94     Learning poverty: Share of Male Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 95   Learning poverty: Share of Female Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 101         Learning poverty: Share of Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 104                                                      Female pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 105                                                                                           Female primary school age children out-of-school (%)
# 106                                                                                             Male primary school age children out-of-school (%)
# 109                                                        Male pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
#
#            General Topic      Topic SubTopic1 SubTopic2          SubTopic3  \
# 75   Education: Outcomes  Education  Outcomes      None  Primary education
# 89   Education: Outcomes  Education  Outcomes      None  Primary education
# 94   Education: Outcomes  Education  Outcomes      None  Primary education
# 95   Education: Outcomes  Education  Outcomes      None  Primary education
# 101  Education: Outcomes  Education  Outcomes      None  Primary education
# 104  Education: Outcomes  Education  Outcomes      None  Primary education
# 105  Education: Outcomes  Education  Outcomes      None  Primary education
# 106  Education: Outcomes  Education  Outcomes      None  Primary education
# 109  Education: Outcomes  Education  Outcomes      None  Primary education
#
#            code3
# 75   SE.LPV.PRIM
# 89   SE.LPV.PRIM
# 94   SE.LPV.PRIM
# 95   SE.LPV.PRIM
# 101  SE.LPV.PRIM
# 104  SE.LPV.PRIM
# 105  SE.LPV.PRIM
# 106  SE.LPV.PRIM
# 109  SE.LPV.PRIM

# %%
example_education['SubTopic2'] = example_education['SubTopic2'].fillna('Low Poverty Vulnerability')
summary(example_education).style.background_gradient(cmap='Blues')
# Out:
# data shape: (156, 8)
# <style type="text/css">
# #T_d1190_row0_col1, #T_d1190_row0_col2, #T_d1190_row1_col1, #T_d1190_row1_col2, #T_d1190_row2_col1, #T_d1190_row2_col2, #T_d1190_row3_col1, #T_d1190_row3_col2, #T_d1190_row3_col3, #T_d1190_row4_col1, #T_d1190_row4_col2, #T_d1190_row5_col1, #T_d1190_row5_col2, #T_d1190_row6_col1, #T_d1190_row6_col2, #T_d1190_row7_col1, #T_d1190_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d1190_row0_col3, #T_d1190_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d1190_row2_col3, #T_d1190_row4_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_d1190_row5_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_d1190_row6_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_d1190_row7_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# </style>
# <table id="T_d1190">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1190_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_d1190_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_d1190_level0_col2" class="col_heading level0 col2" >%missing</th>
#       <th id="T_d1190_level0_col3" class="col_heading level0 col3" >#unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1190_level0_row0" class="row_heading level0 row0" >Code</th>
#       <td id="T_d1190_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_d1190_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_d1190_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_d1190_row0_col3" class="data row0 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_d1190_level0_row1" class="row_heading level0 row1" >Indicator Name</th>
#       <td id="T_d1190_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_d1190_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_d1190_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_d1190_row1_col3" class="data row1 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_d1190_level0_row2" class="row_heading level0 row2" >General Topic</th>
#       <td id="T_d1190_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_d1190_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_d1190_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_d1190_row2_col3" class="data row2 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d1190_level0_row3" class="row_heading level0 row3" >Topic</th>
#       <td id="T_d1190_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_d1190_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_d1190_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_d1190_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d1190_level0_row4" class="row_heading level0 row4" >SubTopic1</th>
#       <td id="T_d1190_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_d1190_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_d1190_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_d1190_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d1190_level0_row5" class="row_heading level0 row5" >SubTopic2</th>
#       <td id="T_d1190_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_d1190_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_d1190_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_d1190_row5_col3" class="data row5 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_d1190_level0_row6" class="row_heading level0 row6" >SubTopic3</th>
#       <td id="T_d1190_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_d1190_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_d1190_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_d1190_row6_col3" class="data row6 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_d1190_level0_row7" class="row_heading level0 row7" >code3</th>
#       <td id="T_d1190_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_d1190_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_d1190_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_d1190_row7_col3" class="data row7 col3" >54</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## In this example
# As we can see, we were able to extend the granularity and hierarchy of the education metadata.
#
# There are missing values for subtopic1, and after further research, we can impute these with the value **LPV = 'Low Poverty Vulnerability'**.
#
# For now, this will be done manually for each sheet.

# %% [markdown]
# ## We apply our function to the entire df

# %%
for key, df in dfs.items():

    df = df.apply(extract_and_match, axis=1, df2=wdi_codes)  
    dfs[key] = df

# %%
for key, df in dfs.items():

    missing_subtopic2 = df['SubTopic2'].isnull().sum()
    missing_subtopic3 = df['SubTopic3'].isnull().sum()
    

    print(f"\n{'*' * 10} {key} {'*' * 10}")
    print(f"Missing subtopic2: {missing_subtopic2}")
    print(f"Missing subtopic3: {missing_subtopic3}")
    print("-" * 40)
# Out:
# ********** economic **********
# Missing subtopic2: 0
# Missing subtopic3: 15
# ----------------------------------------
#
# ********** education **********
# Missing subtopic2: 9
# Missing subtopic3: 0
# ----------------------------------------
#
# ********** environment **********
# Missing subtopic2: 43
# Missing subtopic3: 44
# ----------------------------------------
#
# ********** financial **********
# Missing subtopic2: 0
# Missing subtopic3: 0
# ----------------------------------------
#
# ********** gender **********
# Missing subtopic2: 1
# Missing subtopic3: 2
# ----------------------------------------
#
# ********** health **********
# Missing subtopic2: 12
# Missing subtopic3: 45
# ----------------------------------------
#
# ********** infrastructure **********
# Missing subtopic2: 0
# Missing subtopic3: 0
# ----------------------------------------
#
# ********** poverty **********
# Missing subtopic2: 0
# Missing subtopic3: 9
# ----------------------------------------
#
# ********** private **********
# Missing subtopic2: 6
# Missing subtopic3: 1
# ----------------------------------------
#
# ********** public **********
# Missing subtopic2: 51
# Missing subtopic3: 42
# ----------------------------------------
#
# ********** social **********
# Missing subtopic2: 27
# Missing subtopic3: 27
# ----------------------------------------
#
# ********** trade **********
# Missing subtopic2: 0
# Missing subtopic3: 0
# ----------------------------------------

# %% [markdown]
# ### For now i think the best way is to go throught each individually and handle missing and the different values in "list" subtopics (chatgpt + wdi documentation)

# %% [markdown]
# # Economic

# %%
economic = dfs["economic"]

# %% [markdown]
# **Notice we dont create a copy as we want the changes to reflect to dfs["economic"].**

# %%
with pd.option_context('display.max_colwidth', 200):

    display(economic[economic['SubTopic3'].isna()])
# Out:
#                  Code  \
# 269    DT.NFL.WITC.CD
# 286    DC.DAC.LTUL.CD
# 304    DT.NFL.CERF.CD
# 308  DT.NFL.UNCTAD.CD
# 311    DT.NFL.UNEP.CD
# 315    DT.NFL.UNID.CD
# 316   DT.NFL.UNIDO.CD
# 319    DT.NFL.UNWN.CD
# 320    DT.NFL.UNWT.CD
# 323    DT.NFL.UNCV.CD
# 324    DT.NFL.UNCD.CD
# 326    DT.NFL.SPRP.CD
# 329    DC.DAC.HUNL.CD
# 335    DC.DAC.ESTL.CD
# 337    DT.NFL.SDGF.CD
#
#                                                        Indicator Name  \
# 269        Net official flows from UN agencies, WTO-ITC (current US$)
# 286  Net bilateral aid flows from DAC donors, Lithuania (current US$)
# 304           Net official flows from UN agencies, CERF (current US$)
# 308         Net official flows from UN agencies, UNCTAD (current US$)
# 311           Net official flows from UN agencies, UNEP (current US$)
# 315         Net official flows from UN agencies, UNIDIR (current US$)
# 316          Net official flows from UN agencies, UNIDO (current US$)
# 319        Net official flows from UN agencies, UNWOMEN (current US$)
# 320          Net official flows from UN agencies, UNWTO (current US$)
# 323        Net official flows from UN agencies, UNCOVID (current US$)
# 324          Net official flows from UN agencies, UNCDF (current US$)
# 326           Net official flows from UN agencies, SPRP (current US$)
# 329    Net bilateral aid flows from DAC donors, Hungary (current US$)
# 335    Net bilateral aid flows from DAC donors, Estonia (current US$)
# 337        Net official flows from UN agencies, SDGFUND (current US$)
#
#                                                General Topic  \
# 269  Economic Policy & Debt: Official development assistance
# 286  Economic Policy & Debt: Official development assistance
# 304  Economic Policy & Debt: Official development assistance
# 308  Economic Policy & Debt: Official development assistance
# 311  Economic Policy & Debt: Official development assistance
# 315  Economic Policy & Debt: Official development assistance
# 316  Economic Policy & Debt: Official development assistance
# 319  Economic Policy & Debt: Official development assistance
# 320  Economic Policy & Debt: Official development assistance
# 323  Economic Policy & Debt: Official development assistance
# 324  Economic Policy & Debt: Official development assistance
# 326  Economic Policy & Debt: Official development assistance
# 329  Economic Policy & Debt: Official development assistance
# 335  Economic Policy & Debt: Official development assistance
# 337  Economic Policy & Debt: Official development assistance
#
#                       Topic                        SubTopic1  \
# 269  Economic Policy & Debt  Official development assistance
# 286  Economic Policy & Debt  Official development assistance
# 304  Economic Policy & Debt  Official development assistance
# 308  Economic Policy & Debt  Official development assistance
# 311  Economic Policy & Debt  Official development assistance
# 315  Economic Policy & Debt  Official development assistance
# 316  Economic Policy & Debt  Official development assistance
# 319  Economic Policy & Debt  Official development assistance
# 320  Economic Policy & Debt  Official development assistance
# 323  Economic Policy & Debt  Official development assistance
# 324  Economic Policy & Debt  Official development assistance
# 326  Economic Policy & Debt  Official development assistance
# 329  Economic Policy & Debt  Official development assistance
# 335  Economic Policy & Debt  Official development assistance
# 337  Economic Policy & Debt  Official development assistance
#
#                                    SubTopic2 SubTopic3
# 269                                Net flows      None
# 286  Development Assistance Committee (OECD)      None
# 304                                Net flows      None
# 308                                Net flows      None
# 311                                Net flows      None
# 315                                Net flows      None
# 316                                Net flows      None
# 319                                Net flows      None
# 320                                Net flows      None
# 323                                Net flows      None
# 324                                Net flows      None
# 326                                Net flows      None
# 329  Development Assistance Committee (OECD)      None
# 335  Development Assistance Committee (OECD)      None
# 337                                Net flows      None

# %%
economic_mapping = {
    "WITC": "World Integrated Trade Solution",
    "LTUL": "Long-Term Unemployment Level",
    "CERF": "Central Emergency Response Fund",
    "UNCTAD": "United Nations Conference on Trade and Development",
    "UNEP": "United Nations Environment Programme",
    "UNID": "United Nations Industrial Development Organization",
    "UNIDO": "United Nations Industrial Development Organization",
    "UNWN": "United Nations World Network (Unconfirmed)",
    "UNCV": "United Nations Convention",
    "SPRP": "Social Protection and Resilience Programs",
    "HUNL": "Hunger Levels (Unconfirmed)",
    "ESTL": "Estimated Labor Statistics",
    "SDGF": "Sustainable Development Goals Fund",
    "UNWT": "United Nations World Tourism Organization",
    "UNCD": "United Nations Conference on Disarmament"


}

economic.loc[economic["SubTopic3"].isna(), "SubTopic3"] = (
    economic["Code"].str.split(".").str[2].map(economic_mapping)
)

# %%
with pd.option_context('display.max_colwidth', 200):

    display(economic[economic['SubTopic3'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
def get_code_prefix(code):
    return ".".join(code.split(".")[:2])

filtered = economic[
    economic['SubTopic2'].apply(lambda x: isinstance(x, list)) | 
    economic['SubTopic3'].apply(lambda x: isinstance(x, list))
]

filtered = filtered.copy()
filtered.loc[:, "CodeGroup"] = filtered["Code"].apply(get_code_prefix)


grouped = filtered.groupby("CodeGroup")

# %%
group_keys = list(grouped.groups.keys())

index = 12  

selected_group_key = group_keys[index]
selected_group_df = grouped.get_group(selected_group_key)


with pd.option_context('display.max_colwidth', 200):

    display(selected_group_df)
# Out:
#               Code  \
# 4   BX.GSR.CMCP.ZS
# 5   BX.GSR.FCTY.CD
# 13  BX.GSR.GNFS.CD
# 15  BX.GSR.TRAN.ZS
# 17  BX.GSR.TOTL.CD
# 21  BX.GSR.INSF.ZS
# 24  BX.GSR.NFSV.CD
# 29  BX.GSR.ROYL.CD
# 38  BX.GSR.TRVL.ZS
# 49  BX.GSR.MRCH.CD
#
#                                                                Indicator Name  \
# 4                  Communications, computer, etc. (% of service exports, BoP)
# 5                                  Primary income receipts (BoP, current US$)
# 13                           Exports of goods and services (BoP, current US$)
# 15                             Transport services (% of service exports, BoP)
# 17           Exports of goods, services and primary income (BoP, current US$)
# 21               Insurance and financial services (% of service exports, BoP)
# 24                                         Service exports (BoP, current US$)
# 29  Charges for the use of intellectual property, receipts (BoP, current US$)
# 38                                Travel services (% of service exports, BoP)
# 49                                           Goods exports (BoP, current US$)
#
#                                                                              General Topic  \
# 4   Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 5   Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 13  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 15  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 17  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 21  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 24  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 29  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 38  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 49  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
#
#                      Topic            SubTopic1  \
# 4   Economic Policy & Debt  Balance of payments
# 5   Economic Policy & Debt  Balance of payments
# 13  Economic Policy & Debt  Balance of payments
# 15  Economic Policy & Debt  Balance of payments
# 17  Economic Policy & Debt  Balance of payments
# 21  Economic Policy & Debt  Balance of payments
# 24  Economic Policy & Debt  Balance of payments
# 29  Economic Policy & Debt  Balance of payments
# 38  Economic Policy & Debt  Balance of payments
# 49  Economic Policy & Debt  Balance of payments
#
#                                 SubTopic2  \
# 4   [Current account, Goods and services]
# 5   [Current account, Goods and services]
# 13  [Current account, Goods and services]
# 15  [Current account, Goods and services]
# 17  [Current account, Goods and services]
# 21  [Current account, Goods and services]
# 24  [Current account, Goods and services]
# 29  [Current account, Goods and services]
# 38  [Current account, Goods and services]
# 49  [Current account, Goods and services]
#
#                                                        SubTopic3 CodeGroup
# 4     [Goods, services & income, Communications, computer, etc.]    BX.GSR
# 5                      [Goods, services & income, Factor income]    BX.GSR
# 13    [Goods, services & income, Goods and (nonfactor) services]    BX.GSR
# 15                         [Goods, services & income, Transport]    BX.GSR
# 17                             [Goods, services & income, Total]    BX.GSR
# 21  [Goods, services & income, Insurance and financial services]    BX.GSR
# 24              [Goods, services & income, (Nonfactor) services]    BX.GSR
# 29          [Goods, services & income, Royalty and license fees]    BX.GSR
# 38                            [Goods, services & income, Travel]    BX.GSR
# 49               [Goods, services & income, Goods (merchandise)]    BX.GSR

# %% [markdown]
# ### For the various examples we analyzed, we concluded that selecting the values added from the WDI (World Development Indicators) dataset provides a more accurate representation. These values offer a finer level of granularity, enhancing our ability to analyze and interpret the data effectively.

# %%
def select_second_item(value):
    if isinstance(value, list) and len(value) > 1:
        return value[1]  
    return value

# %%
economic["SubTopic2"] = economic["SubTopic2"].apply(select_second_item)
economic["SubTopic3"] = economic["SubTopic3"].apply(select_second_item)

# %% [markdown]
# # Education

# %%
education = dfs['education']

# %%
with pd.option_context('display.max_colwidth', 200):

    display(education[education['SubTopic2'].isna()])
# Out:
#                   Code  \
# 75      SE.LPV.PRIM.SD
# 89      SE.LPV.PRIM.LD
# 94      SE.LPV.PRIM.MA
# 95      SE.LPV.PRIM.FE
# 101        SE.LPV.PRIM
# 104  SE.LPV.PRIM.LD.FE
# 105  SE.LPV.PRIM.SD.FE
# 106  SE.LPV.PRIM.SD.MA
# 109  SE.LPV.PRIM.LD.MA
#
#                                                                                                                                     Indicator Name  \
# 75                                                                                                   Primary school age children out-of-school (%)
# 89                                                              Pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 94     Learning poverty: Share of Male Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 95   Learning poverty: Share of Female Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 101         Learning poverty: Share of Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 104                                                      Female pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 105                                                                                           Female primary school age children out-of-school (%)
# 106                                                                                             Male primary school age children out-of-school (%)
# 109                                                        Male pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
#
#            General Topic      Topic SubTopic1 SubTopic2          SubTopic3
# 75   Education: Outcomes  Education  Outcomes      None  Primary education
# 89   Education: Outcomes  Education  Outcomes      None  Primary education
# 94   Education: Outcomes  Education  Outcomes      None  Primary education
# 95   Education: Outcomes  Education  Outcomes      None  Primary education
# 101  Education: Outcomes  Education  Outcomes      None  Primary education
# 104  Education: Outcomes  Education  Outcomes      None  Primary education
# 105  Education: Outcomes  Education  Outcomes      None  Primary education
# 106  Education: Outcomes  Education  Outcomes      None  Primary education
# 109  Education: Outcomes  Education  Outcomes      None  Primary education

# %%
education['SubTopic2'] = education['SubTopic2'].fillna('Low Poverty Vulnerability')

# %%
with pd.option_context('display.max_colwidth', 200):

    display(education[education['SubTopic3'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
has_list = education.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


education_with_lists = education[has_list]
print(education_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Environment

# %%
environment = dfs["environment"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(environment[(environment['SubTopic2'].isna())|(environment['SubTopic3'].isna())])
# Out:
#                            Code  \
# 65               ER.H2O.FWST.ZS
# 71      EN.GHG.ALL.LU.MT.CE.AR5
# 72         EN.GHG.ALL.PC.CE.AR5
# 73         EN.GHG.CO2.MT.CE.AR5
# 74   EN.GHG.CO2.LU.DF.MT.CE.AR5
# 75   EN.GHG.CO2.LU.OS.MT.CE.AR5
# 76     EN.GHG.FGAS.IP.MT.CE.AR5
# 77         EN.GHG.ALL.MT.CE.AR5
# 78            EN.GHG.CO2.ZG.AR5
# 79   EN.GHG.CO2.LU.OL.MT.CE.AR5
# 80      EN.GHG.CO2.RT.GDP.PP.KD
# 81         EN.GHG.CO2.RT.GDP.KD
# 82   EN.GHG.CO2.LU.FL.MT.CE.AR5
# 83      EN.GHG.CO2.LU.MT.CE.AR5
# 84            EN.GHG.TOT.ZG.AR5
# 85      EN.GHG.CO2.WA.MT.CE.AR5
# 86      EN.GHG.N2O.IC.MT.CE.AR5
# 87            EN.GHG.CH4.ZG.AR5
# 88            EN.GHG.N2O.ZG.AR5
# 89      EN.GHG.N2O.FE.MT.CE.AR5
# 90      EN.GHG.N2O.BU.MT.CE.AR5
# 91      EN.GHG.CH4.BU.MT.CE.AR5
# 92      EN.GHG.CH4.FE.MT.CE.AR5
# 93      EN.GHG.N2O.PI.MT.CE.AR5
# 94      EN.GHG.N2O.TR.MT.CE.AR5
# 95         EN.GHG.N2O.MT.CE.AR5
# 96      EN.GHG.N2O.WA.MT.CE.AR5
# 97         EN.GHG.CH4.MT.CE.AR5
# 98      EN.GHG.N2O.IP.MT.CE.AR5
# 99      EN.GHG.CH4.IC.MT.CE.AR5
# 100     EN.GHG.CH4.IP.MT.CE.AR5
# 101     EN.GHG.CH4.WA.MT.CE.AR5
# 102     EN.GHG.CH4.PI.MT.CE.AR5
# 103     EN.GHG.CH4.AG.MT.CE.AR5
# 104     EN.GHG.CO2.TR.MT.CE.AR5
# 105     EN.GHG.CO2.PI.MT.CE.AR5
# 106     EN.GHG.CO2.IP.MT.CE.AR5
# 107     EN.GHG.CH4.TR.MT.CE.AR5
# 108     EN.GHG.CO2.IC.MT.CE.AR5
# 109     EN.GHG.CO2.FE.MT.CE.AR5
# 110     EN.GHG.CO2.BU.MT.CE.AR5
# 111     EN.GHG.CO2.AG.MT.CE.AR5
# 112     EN.GHG.N2O.AG.MT.CE.AR5
# 113        EN.GHG.CO2.PC.CE.AR5
#
#                                                                                      Indicator Name  \
# 65   Level of water stress: freshwater withdrawal as a proportion of available freshwater resources
# 71                                        Total greenhouse gas emissions including LULUCF (Mt CO2e)
# 72                       Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)
# 73                                Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)
# 74                            Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e)
# 75                             Carbon dioxide (CO2) net fluxes from LULUCF - Organic Soil (Mt CO2e)
# 76             Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)
# 77                                        Total greenhouse gas emissions excluding LULUCF (Mt CO2e)
# 78                     Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990)
# 79                               Carbon dioxide (CO2) net fluxes from LULUCF - Other Land (Mt CO2e)
# 80                                                 Carbon intensity of GDP (kg CO2e per 2021 PPP $)
# 81                                   Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP)
# 82                              Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)
# 83       Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e)
# 84                             Total greenhouse gas emissions excluding LULUCF (% change from 1990)
# 85                                              Carbon dioxide (CO2) emissions from Waste (Mt CO2e)
# 86                      Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 87                            Methane (CH4) emissions (total) excluding LULUCF (% change from 1990)
# 88                      Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990)
# 89                         Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 90                                   Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)
# 91                                         Methane (CH4) emissions from Building (Energy) (Mt CO2e)
# 92                               Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 93                             Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)
# 94                                  Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)
# 95                                 Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)
# 96                                               Nitrous oxide (N2O) emissions from Waste (Mt CO2e)
# 97                                       Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)
# 98                                Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)
# 99                            Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 100                                     Methane (CH4) emissions from Industrial Processes (Mt CO2e)
# 101                                                    Methane (CH4) emissions from Waste (Mt CO2e)
# 102                                  Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)
# 103                                              Methane (CH4) emissions from Agriculture (Mt CO2e)
# 104                                Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)
# 105                           Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)
# 106                              Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)
# 107                                       Methane (CH4) emissions from Transport (Energy) (Mt CO2e)
# 108                    Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 109                       Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 110                                 Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)
# 111                                       Carbon dioxide (CO2) emissions from Agriculture (Mt CO2e)
# 112                                        Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)
# 113                      Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)
#
#                              General Topic        Topic  \
# 65                 Environment: Freshwater  Environment
# 71   Environment: Greenhouse Gas Emissions  Environment
# 72   Environment: Greenhouse Gas Emissions  Environment
# 73   Environment: Greenhouse Gas Emissions  Environment
# 74   Environment: Greenhouse Gas Emissions  Environment
# 75   Environment: Greenhouse Gas Emissions  Environment
# 76   Environment: Greenhouse Gas Emissions  Environment
# 77   Environment: Greenhouse Gas Emissions  Environment
# 78   Environment: Greenhouse Gas Emissions  Environment
# 79   Environment: Greenhouse Gas Emissions  Environment
# 80   Environment: Greenhouse Gas Emissions  Environment
# 81   Environment: Greenhouse Gas Emissions  Environment
# 82   Environment: Greenhouse Gas Emissions  Environment
# 83   Environment: Greenhouse Gas Emissions  Environment
# 84   Environment: Greenhouse Gas Emissions  Environment
# 85   Environment: Greenhouse Gas Emissions  Environment
# 86   Environment: Greenhouse Gas Emissions  Environment
# 87   Environment: Greenhouse Gas Emissions  Environment
# 88   Environment: Greenhouse Gas Emissions  Environment
# 89   Environment: Greenhouse Gas Emissions  Environment
# 90   Environment: Greenhouse Gas Emissions  Environment
# 91   Environment: Greenhouse Gas Emissions  Environment
# 92   Environment: Greenhouse Gas Emissions  Environment
# 93   Environment: Greenhouse Gas Emissions  Environment
# 94   Environment: Greenhouse Gas Emissions  Environment
# 95   Environment: Greenhouse Gas Emissions  Environment
# 96   Environment: Greenhouse Gas Emissions  Environment
# 97   Environment: Greenhouse Gas Emissions  Environment
# 98   Environment: Greenhouse Gas Emissions  Environment
# 99   Environment: Greenhouse Gas Emissions  Environment
# 100  Environment: Greenhouse Gas Emissions  Environment
# 101  Environment: Greenhouse Gas Emissions  Environment
# 102  Environment: Greenhouse Gas Emissions  Environment
# 103  Environment: Greenhouse Gas Emissions  Environment
# 104  Environment: Greenhouse Gas Emissions  Environment
# 105  Environment: Greenhouse Gas Emissions  Environment
# 106  Environment: Greenhouse Gas Emissions  Environment
# 107  Environment: Greenhouse Gas Emissions  Environment
# 108  Environment: Greenhouse Gas Emissions  Environment
# 109  Environment: Greenhouse Gas Emissions  Environment
# 110  Environment: Greenhouse Gas Emissions  Environment
# 111  Environment: Greenhouse Gas Emissions  Environment
# 112  Environment: Greenhouse Gas Emissions  Environment
# 113  Environment: Greenhouse Gas Emissions  Environment
#
#                     SubTopic1 SubTopic2 SubTopic3
# 65                 Freshwater     Water      None
# 71   Greenhouse Gas Emissions      None      None
# 72   Greenhouse Gas Emissions      None      None
# 73   Greenhouse Gas Emissions      None      None
# 74   Greenhouse Gas Emissions      None      None
# 75   Greenhouse Gas Emissions      None      None
# 76   Greenhouse Gas Emissions      None      None
# 77   Greenhouse Gas Emissions      None      None
# 78   Greenhouse Gas Emissions      None      None
# 79   Greenhouse Gas Emissions      None      None
# 80   Greenhouse Gas Emissions      None      None
# 81   Greenhouse Gas Emissions      None      None
# 82   Greenhouse Gas Emissions      None      None
# 83   Greenhouse Gas Emissions      None      None
# 84   Greenhouse Gas Emissions      None      None
# 85   Greenhouse Gas Emissions      None      None
# 86   Greenhouse Gas Emissions      None      None
# 87   Greenhouse Gas Emissions      None      None
# 88   Greenhouse Gas Emissions      None      None
# 89   Greenhouse Gas Emissions      None      None
# 90   Greenhouse Gas Emissions      None      None
# 91   Greenhouse Gas Emissions      None      None
# 92   Greenhouse Gas Emissions      None      None
# 93   Greenhouse Gas Emissions      None      None
# 94   Greenhouse Gas Emissions      None      None
# 95   Greenhouse Gas Emissions      None      None
# 96   Greenhouse Gas Emissions      None      None
# 97   Greenhouse Gas Emissions      None      None
# 98   Greenhouse Gas Emissions      None      None
# 99   Greenhouse Gas Emissions      None      None
# 100  Greenhouse Gas Emissions      None      None
# 101  Greenhouse Gas Emissions      None      None
# 102  Greenhouse Gas Emissions      None      None
# 103  Greenhouse Gas Emissions      None      None
# 104  Greenhouse Gas Emissions      None      None
# 105  Greenhouse Gas Emissions      None      None
# 106  Greenhouse Gas Emissions      None      None
# 107  Greenhouse Gas Emissions      None      None
# 108  Greenhouse Gas Emissions      None      None
# 109  Greenhouse Gas Emissions      None      None
# 110  Greenhouse Gas Emissions      None      None
# 111  Greenhouse Gas Emissions      None      None
# 112  Greenhouse Gas Emissions      None      None
# 113  Greenhouse Gas Emissions      None      None

# %%
# environment_mapping_subtopic3 = {
#     "FWST": "freshwater withdrawal"
# }

# %%
environment.loc[environment["Code"] == "ER.H2O.FWST.ZS", "SubTopic3"] = "Water stress: freshwater withdrawal"

# %%
environment_mapping = {
    "ALL": "All Greenhouse Gases",
    "FGAS": "Fluorinated Gases emissions",
    "CH4": "Methane emissions",
    "N2O": "Nitrous oxide emissions",
    "CO2": "Carbon dioxide emissions",
    "TOT": "Total"
}

environment.loc[environment["SubTopic2"].isna(), "SubTopic2"] = (
    environment["Code"].str.split(".").str[2].map(environment_mapping)
)

# %%
with pd.option_context('display.max_colwidth', 200):

    display(environment[environment['SubTopic2'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
with pd.option_context('display.max_colwidth', 200):

    display(environment[environment['SubTopic3'].isna()])
# Out:
#                      Code  \
# 72   EN.GHG.ALL.PC.CE.AR5
# 73   EN.GHG.CO2.MT.CE.AR5
# 77   EN.GHG.ALL.MT.CE.AR5
# 78      EN.GHG.CO2.ZG.AR5
# 84      EN.GHG.TOT.ZG.AR5
# 87      EN.GHG.CH4.ZG.AR5
# 88      EN.GHG.N2O.ZG.AR5
# 95   EN.GHG.N2O.MT.CE.AR5
# 97   EN.GHG.CH4.MT.CE.AR5
# 113  EN.GHG.CO2.PC.CE.AR5
#
#                                                                    Indicator Name  \
# 72     Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)
# 73              Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)
# 77                      Total greenhouse gas emissions excluding LULUCF (Mt CO2e)
# 78   Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990)
# 84           Total greenhouse gas emissions excluding LULUCF (% change from 1990)
# 87          Methane (CH4) emissions (total) excluding LULUCF (% change from 1990)
# 88    Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990)
# 95               Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)
# 97                     Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)
# 113    Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)
#
#                              General Topic        Topic  \
# 72   Environment: Greenhouse Gas Emissions  Environment
# 73   Environment: Greenhouse Gas Emissions  Environment
# 77   Environment: Greenhouse Gas Emissions  Environment
# 78   Environment: Greenhouse Gas Emissions  Environment
# 84   Environment: Greenhouse Gas Emissions  Environment
# 87   Environment: Greenhouse Gas Emissions  Environment
# 88   Environment: Greenhouse Gas Emissions  Environment
# 95   Environment: Greenhouse Gas Emissions  Environment
# 97   Environment: Greenhouse Gas Emissions  Environment
# 113  Environment: Greenhouse Gas Emissions  Environment
#
#                     SubTopic1                 SubTopic2 SubTopic3
# 72   Greenhouse Gas Emissions      All Greenhouse Gases       NaN
# 73   Greenhouse Gas Emissions  Carbon dioxide emissions       NaN
# 77   Greenhouse Gas Emissions      All Greenhouse Gases       NaN
# 78   Greenhouse Gas Emissions  Carbon dioxide emissions       NaN
# 84   Greenhouse Gas Emissions                     Total       NaN
# 87   Greenhouse Gas Emissions         Methane emissions       NaN
# 88   Greenhouse Gas Emissions   Nitrous oxide emissions       NaN
# 95   Greenhouse Gas Emissions   Nitrous oxide emissions       NaN
# 97   Greenhouse Gas Emissions         Methane emissions       NaN
# 113  Greenhouse Gas Emissions  Carbon dioxide emissions       NaN

# %%
environment_mapping_subtopic3 = {
    "LU": "Including Land Use and Land-Use Change (LULUC)",
    "RT": "Carbon intensity of GDP",
    "OS": "Other Sources",
    "OL": "Other Land Use",
    "WA": "Waste",
    "IC": "Industrial Combustion",
    "IP": "Industrial Processes",
    "BU": "Buildings",
    "AG": "Agriculture",
    "PI": "Power Industry",
    "TR": "Transport",
    "FE": "Fugitive Emissions",

}

environment.loc[environment["SubTopic3"].isna(), "SubTopic3"] = (
    environment["Code"].str.split(".").str[3].map(environment_mapping_subtopic3)
)

# %%
with pd.option_context('display.max_colwidth', 200):
    display(environment[environment['Code'].str.startswith('EN.GHG')])
# Out:
#                            Code  \
# 71      EN.GHG.ALL.LU.MT.CE.AR5
# 72         EN.GHG.ALL.PC.CE.AR5
# 73         EN.GHG.CO2.MT.CE.AR5
# 74   EN.GHG.CO2.LU.DF.MT.CE.AR5
# 75   EN.GHG.CO2.LU.OS.MT.CE.AR5
# 76     EN.GHG.FGAS.IP.MT.CE.AR5
# 77         EN.GHG.ALL.MT.CE.AR5
# 78            EN.GHG.CO2.ZG.AR5
# 79   EN.GHG.CO2.LU.OL.MT.CE.AR5
# 80      EN.GHG.CO2.RT.GDP.PP.KD
# 81         EN.GHG.CO2.RT.GDP.KD
# 82   EN.GHG.CO2.LU.FL.MT.CE.AR5
# 83      EN.GHG.CO2.LU.MT.CE.AR5
# 84            EN.GHG.TOT.ZG.AR5
# 85      EN.GHG.CO2.WA.MT.CE.AR5
# 86      EN.GHG.N2O.IC.MT.CE.AR5
# 87            EN.GHG.CH4.ZG.AR5
# 88            EN.GHG.N2O.ZG.AR5
# 89      EN.GHG.N2O.FE.MT.CE.AR5
# 90      EN.GHG.N2O.BU.MT.CE.AR5
# 91      EN.GHG.CH4.BU.MT.CE.AR5
# 92      EN.GHG.CH4.FE.MT.CE.AR5
# 93      EN.GHG.N2O.PI.MT.CE.AR5
# 94      EN.GHG.N2O.TR.MT.CE.AR5
# 95         EN.GHG.N2O.MT.CE.AR5
# 96      EN.GHG.N2O.WA.MT.CE.AR5
# 97         EN.GHG.CH4.MT.CE.AR5
# 98      EN.GHG.N2O.IP.MT.CE.AR5
# 99      EN.GHG.CH4.IC.MT.CE.AR5
# 100     EN.GHG.CH4.IP.MT.CE.AR5
# 101     EN.GHG.CH4.WA.MT.CE.AR5
# 102     EN.GHG.CH4.PI.MT.CE.AR5
# 103     EN.GHG.CH4.AG.MT.CE.AR5
# 104     EN.GHG.CO2.TR.MT.CE.AR5
# 105     EN.GHG.CO2.PI.MT.CE.AR5
# 106     EN.GHG.CO2.IP.MT.CE.AR5
# 107     EN.GHG.CH4.TR.MT.CE.AR5
# 108     EN.GHG.CO2.IC.MT.CE.AR5
# 109     EN.GHG.CO2.FE.MT.CE.AR5
# 110     EN.GHG.CO2.BU.MT.CE.AR5
# 111     EN.GHG.CO2.AG.MT.CE.AR5
# 112     EN.GHG.N2O.AG.MT.CE.AR5
# 113        EN.GHG.CO2.PC.CE.AR5
#
#                                                                                  Indicator Name  \
# 71                                    Total greenhouse gas emissions including LULUCF (Mt CO2e)
# 72                   Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)
# 73                            Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)
# 74                        Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e)
# 75                         Carbon dioxide (CO2) net fluxes from LULUCF - Organic Soil (Mt CO2e)
# 76         Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)
# 77                                    Total greenhouse gas emissions excluding LULUCF (Mt CO2e)
# 78                 Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990)
# 79                           Carbon dioxide (CO2) net fluxes from LULUCF - Other Land (Mt CO2e)
# 80                                             Carbon intensity of GDP (kg CO2e per 2021 PPP $)
# 81                               Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP)
# 82                          Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)
# 83   Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e)
# 84                         Total greenhouse gas emissions excluding LULUCF (% change from 1990)
# 85                                          Carbon dioxide (CO2) emissions from Waste (Mt CO2e)
# 86                  Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 87                        Methane (CH4) emissions (total) excluding LULUCF (% change from 1990)
# 88                  Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990)
# 89                     Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 90                               Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)
# 91                                     Methane (CH4) emissions from Building (Energy) (Mt CO2e)
# 92                           Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 93                         Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)
# 94                              Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)
# 95                             Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)
# 96                                           Nitrous oxide (N2O) emissions from Waste (Mt CO2e)
# 97                                   Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)
# 98                            Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)
# 99                        Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 100                                 Methane (CH4) emissions from Industrial Processes (Mt CO2e)
# 101                                                Methane (CH4) emissions from Waste (Mt CO2e)
# 102                              Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)
# 103                                          Methane (CH4) emissions from Agriculture (Mt CO2e)
# 104                            Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)
# 105                       Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)
# 106                          Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)
# 107                                   Methane (CH4) emissions from Transport (Energy) (Mt CO2e)
# 108                Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 109                   Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 110                             Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)
# 111                                   Carbon dioxide (CO2) emissions from Agriculture (Mt CO2e)
# 112                                    Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)
# 113                  Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)
#
#                              General Topic        Topic  \
# 71   Environment: Greenhouse Gas Emissions  Environment
# 72   Environment: Greenhouse Gas Emissions  Environment
# 73   Environment: Greenhouse Gas Emissions  Environment
# 74   Environment: Greenhouse Gas Emissions  Environment
# 75   Environment: Greenhouse Gas Emissions  Environment
# 76   Environment: Greenhouse Gas Emissions  Environment
# 77   Environment: Greenhouse Gas Emissions  Environment
# 78   Environment: Greenhouse Gas Emissions  Environment
# 79   Environment: Greenhouse Gas Emissions  Environment
# 80   Environment: Greenhouse Gas Emissions  Environment
# 81   Environment: Greenhouse Gas Emissions  Environment
# 82   Environment: Greenhouse Gas Emissions  Environment
# 83   Environment: Greenhouse Gas Emissions  Environment
# 84   Environment: Greenhouse Gas Emissions  Environment
# 85   Environment: Greenhouse Gas Emissions  Environment
# 86   Environment: Greenhouse Gas Emissions  Environment
# 87   Environment: Greenhouse Gas Emissions  Environment
# 88   Environment: Greenhouse Gas Emissions  Environment
# 89   Environment: Greenhouse Gas Emissions  Environment
# 90   Environment: Greenhouse Gas Emissions  Environment
# 91   Environment: Greenhouse Gas Emissions  Environment
# 92   Environment: Greenhouse Gas Emissions  Environment
# 93   Environment: Greenhouse Gas Emissions  Environment
# 94   Environment: Greenhouse Gas Emissions  Environment
# 95   Environment: Greenhouse Gas Emissions  Environment
# 96   Environment: Greenhouse Gas Emissions  Environment
# 97   Environment: Greenhouse Gas Emissions  Environment
# 98   Environment: Greenhouse Gas Emissions  Environment
# 99   Environment: Greenhouse Gas Emissions  Environment
# 100  Environment: Greenhouse Gas Emissions  Environment
# 101  Environment: Greenhouse Gas Emissions  Environment
# 102  Environment: Greenhouse Gas Emissions  Environment
# 103  Environment: Greenhouse Gas Emissions  Environment
# 104  Environment: Greenhouse Gas Emissions  Environment
# 105  Environment: Greenhouse Gas Emissions  Environment
# 106  Environment: Greenhouse Gas Emissions  Environment
# 107  Environment: Greenhouse Gas Emissions  Environment
# 108  Environment: Greenhouse Gas Emissions  Environment
# 109  Environment: Greenhouse Gas Emissions  Environment
# 110  Environment: Greenhouse Gas Emissions  Environment
# 111  Environment: Greenhouse Gas Emissions  Environment
# 112  Environment: Greenhouse Gas Emissions  Environment
# 113  Environment: Greenhouse Gas Emissions  Environment
#
#                     SubTopic1                 SubTopic2  \
# 71   Greenhouse Gas Emissions      All Greenhouse Gases
# 72   Greenhouse Gas Emissions      All Greenhouse Gases
# 73   Greenhouse Gas Emissions  Carbon dioxide emissions
# 74   Greenhouse Gas Emissions  Carbon dioxide emissions
# 75   Greenhouse Gas Emissions  Carbon dioxide emissions
# 76   Greenhouse Gas Emissions         Fluorinated Gases
# 77   Greenhouse Gas Emissions      All Greenhouse Gases
# 78   Greenhouse Gas Emissions  Carbon dioxide emissions
# 79   Greenhouse Gas Emissions  Carbon dioxide emissions
# 80   Greenhouse Gas Emissions  Carbon dioxide emissions
# 81   Greenhouse Gas Emissions  Carbon dioxide emissions
# 82   Greenhouse Gas Emissions  Carbon dioxide emissions
# 83   Greenhouse Gas Emissions  Carbon dioxide emissions
# 84   Greenhouse Gas Emissions                     Total
# 85   Greenhouse Gas Emissions  Carbon dioxide emissions
# 86   Greenhouse Gas Emissions   Nitrous oxide emissions
# 87   Greenhouse Gas Emissions         Methane emissions
# 88   Greenhouse Gas Emissions   Nitrous oxide emissions
# 89   Greenhouse Gas Emissions   Nitrous oxide emissions
# 90   Greenhouse Gas Emissions   Nitrous oxide emissions
# 91   Greenhouse Gas Emissions         Methane emissions
# 92   Greenhouse Gas Emissions         Methane emissions
# 93   Greenhouse Gas Emissions   Nitrous oxide emissions
# 94   Greenhouse Gas Emissions   Nitrous oxide emissions
# 95   Greenhouse Gas Emissions   Nitrous oxide emissions
# 96   Greenhouse Gas Emissions   Nitrous oxide emissions
# 97   Greenhouse Gas Emissions         Methane emissions
# 98   Greenhouse Gas Emissions   Nitrous oxide emissions
# 99   Greenhouse Gas Emissions         Methane emissions
# 100  Greenhouse Gas Emissions         Methane emissions
# 101  Greenhouse Gas Emissions         Methane emissions
# 102  Greenhouse Gas Emissions         Methane emissions
# 103  Greenhouse Gas Emissions         Methane emissions
# 104  Greenhouse Gas Emissions  Carbon dioxide emissions
# 105  Greenhouse Gas Emissions  Carbon dioxide emissions
# 106  Greenhouse Gas Emissions  Carbon dioxide emissions
# 107  Greenhouse Gas Emissions         Methane emissions
# 108  Greenhouse Gas Emissions  Carbon dioxide emissions
# 109  Greenhouse Gas Emissions  Carbon dioxide emissions
# 110  Greenhouse Gas Emissions  Carbon dioxide emissions
# 111  Greenhouse Gas Emissions  Carbon dioxide emissions
# 112  Greenhouse Gas Emissions   Nitrous oxide emissions
# 113  Greenhouse Gas Emissions  Carbon dioxide emissions
#
#                                           SubTopic3
# 71   Including Land Use and Land-Use Change (LULUC)
# 72                                              NaN
# 73                                              NaN
# 74   Including Land Use and Land-Use Change (LULUC)
# 75   Including Land Use and Land-Use Change (LULUC)
# 76                             Industrial Processes
# 77                                              NaN
# 78                                              NaN
# 79   Including Land Use and Land-Use Change (LULUC)
# 80                          Carbon intensity of GDP
# 81                          Carbon intensity of GDP
# 82   Including Land Use and Land-Use Change (LULUC)
# 83   Including Land Use and Land-Use Change (LULUC)
# 84                                              NaN
# 85                                            Waste
# 86                            Industrial Combustion
# 87                                              NaN
# 88                                              NaN
# 89                               Fugitive Emissions
# 90                                        Buildings
# 91                                        Buildings
# 92                               Fugitive Emissions
# 93                                   Power Industry
# 94                                        Transport
# 95                                              NaN
# 96                                            Waste
# 97                                              NaN
# 98                             Industrial Processes
# 99                            Industrial Combustion
# 100                            Industrial Processes
# 101                                           Waste
# 102                                  Power Industry
# 103                                     Agriculture
# 104                                       Transport
# 105                                  Power Industry
# 106                            Industrial Processes
# 107                                       Transport
# 108                           Industrial Combustion
# 109                              Fugitive Emissions
# 110                                       Buildings
# 111                                     Agriculture
# 112                                     Agriculture
# 113                                             NaN

# %%
environment.loc[environment["SubTopic3"].isna(), "SubTopic3"] = "Excluding  Land Use and Land-Use Change (LULUC)"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(environment[environment['Code'].str.startswith('EN.GHG')])
# Out:
#                            Code  \
# 71      EN.GHG.ALL.LU.MT.CE.AR5
# 72         EN.GHG.ALL.PC.CE.AR5
# 73         EN.GHG.CO2.MT.CE.AR5
# 74   EN.GHG.CO2.LU.DF.MT.CE.AR5
# 75   EN.GHG.CO2.LU.OS.MT.CE.AR5
# 76     EN.GHG.FGAS.IP.MT.CE.AR5
# 77         EN.GHG.ALL.MT.CE.AR5
# 78            EN.GHG.CO2.ZG.AR5
# 79   EN.GHG.CO2.LU.OL.MT.CE.AR5
# 80      EN.GHG.CO2.RT.GDP.PP.KD
# 81         EN.GHG.CO2.RT.GDP.KD
# 82   EN.GHG.CO2.LU.FL.MT.CE.AR5
# 83      EN.GHG.CO2.LU.MT.CE.AR5
# 84            EN.GHG.TOT.ZG.AR5
# 85      EN.GHG.CO2.WA.MT.CE.AR5
# 86      EN.GHG.N2O.IC.MT.CE.AR5
# 87            EN.GHG.CH4.ZG.AR5
# 88            EN.GHG.N2O.ZG.AR5
# 89      EN.GHG.N2O.FE.MT.CE.AR5
# 90      EN.GHG.N2O.BU.MT.CE.AR5
# 91      EN.GHG.CH4.BU.MT.CE.AR5
# 92      EN.GHG.CH4.FE.MT.CE.AR5
# 93      EN.GHG.N2O.PI.MT.CE.AR5
# 94      EN.GHG.N2O.TR.MT.CE.AR5
# 95         EN.GHG.N2O.MT.CE.AR5
# 96      EN.GHG.N2O.WA.MT.CE.AR5
# 97         EN.GHG.CH4.MT.CE.AR5
# 98      EN.GHG.N2O.IP.MT.CE.AR5
# 99      EN.GHG.CH4.IC.MT.CE.AR5
# 100     EN.GHG.CH4.IP.MT.CE.AR5
# 101     EN.GHG.CH4.WA.MT.CE.AR5
# 102     EN.GHG.CH4.PI.MT.CE.AR5
# 103     EN.GHG.CH4.AG.MT.CE.AR5
# 104     EN.GHG.CO2.TR.MT.CE.AR5
# 105     EN.GHG.CO2.PI.MT.CE.AR5
# 106     EN.GHG.CO2.IP.MT.CE.AR5
# 107     EN.GHG.CH4.TR.MT.CE.AR5
# 108     EN.GHG.CO2.IC.MT.CE.AR5
# 109     EN.GHG.CO2.FE.MT.CE.AR5
# 110     EN.GHG.CO2.BU.MT.CE.AR5
# 111     EN.GHG.CO2.AG.MT.CE.AR5
# 112     EN.GHG.N2O.AG.MT.CE.AR5
# 113        EN.GHG.CO2.PC.CE.AR5
#
#                                                                                  Indicator Name  \
# 71                                    Total greenhouse gas emissions including LULUCF (Mt CO2e)
# 72                   Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)
# 73                            Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)
# 74                        Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e)
# 75                         Carbon dioxide (CO2) net fluxes from LULUCF - Organic Soil (Mt CO2e)
# 76         Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)
# 77                                    Total greenhouse gas emissions excluding LULUCF (Mt CO2e)
# 78                 Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990)
# 79                           Carbon dioxide (CO2) net fluxes from LULUCF - Other Land (Mt CO2e)
# 80                                             Carbon intensity of GDP (kg CO2e per 2021 PPP $)
# 81                               Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP)
# 82                          Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)
# 83   Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e)
# 84                         Total greenhouse gas emissions excluding LULUCF (% change from 1990)
# 85                                          Carbon dioxide (CO2) emissions from Waste (Mt CO2e)
# 86                  Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 87                        Methane (CH4) emissions (total) excluding LULUCF (% change from 1990)
# 88                  Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990)
# 89                     Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 90                               Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)
# 91                                     Methane (CH4) emissions from Building (Energy) (Mt CO2e)
# 92                           Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 93                         Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)
# 94                              Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)
# 95                             Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)
# 96                                           Nitrous oxide (N2O) emissions from Waste (Mt CO2e)
# 97                                   Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)
# 98                            Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)
# 99                        Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 100                                 Methane (CH4) emissions from Industrial Processes (Mt CO2e)
# 101                                                Methane (CH4) emissions from Waste (Mt CO2e)
# 102                              Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)
# 103                                          Methane (CH4) emissions from Agriculture (Mt CO2e)
# 104                            Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)
# 105                       Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)
# 106                          Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)
# 107                                   Methane (CH4) emissions from Transport (Energy) (Mt CO2e)
# 108                Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 109                   Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 110                             Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)
# 111                                   Carbon dioxide (CO2) emissions from Agriculture (Mt CO2e)
# 112                                    Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)
# 113                  Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)
#
#                              General Topic        Topic  \
# 71   Environment: Greenhouse Gas Emissions  Environment
# 72   Environment: Greenhouse Gas Emissions  Environment
# 73   Environment: Greenhouse Gas Emissions  Environment
# 74   Environment: Greenhouse Gas Emissions  Environment
# 75   Environment: Greenhouse Gas Emissions  Environment
# 76   Environment: Greenhouse Gas Emissions  Environment
# 77   Environment: Greenhouse Gas Emissions  Environment
# 78   Environment: Greenhouse Gas Emissions  Environment
# 79   Environment: Greenhouse Gas Emissions  Environment
# 80   Environment: Greenhouse Gas Emissions  Environment
# 81   Environment: Greenhouse Gas Emissions  Environment
# 82   Environment: Greenhouse Gas Emissions  Environment
# 83   Environment: Greenhouse Gas Emissions  Environment
# 84   Environment: Greenhouse Gas Emissions  Environment
# 85   Environment: Greenhouse Gas Emissions  Environment
# 86   Environment: Greenhouse Gas Emissions  Environment
# 87   Environment: Greenhouse Gas Emissions  Environment
# 88   Environment: Greenhouse Gas Emissions  Environment
# 89   Environment: Greenhouse Gas Emissions  Environment
# 90   Environment: Greenhouse Gas Emissions  Environment
# 91   Environment: Greenhouse Gas Emissions  Environment
# 92   Environment: Greenhouse Gas Emissions  Environment
# 93   Environment: Greenhouse Gas Emissions  Environment
# 94   Environment: Greenhouse Gas Emissions  Environment
# 95   Environment: Greenhouse Gas Emissions  Environment
# 96   Environment: Greenhouse Gas Emissions  Environment
# 97   Environment: Greenhouse Gas Emissions  Environment
# 98   Environment: Greenhouse Gas Emissions  Environment
# 99   Environment: Greenhouse Gas Emissions  Environment
# 100  Environment: Greenhouse Gas Emissions  Environment
# 101  Environment: Greenhouse Gas Emissions  Environment
# 102  Environment: Greenhouse Gas Emissions  Environment
# 103  Environment: Greenhouse Gas Emissions  Environment
# 104  Environment: Greenhouse Gas Emissions  Environment
# 105  Environment: Greenhouse Gas Emissions  Environment
# 106  Environment: Greenhouse Gas Emissions  Environment
# 107  Environment: Greenhouse Gas Emissions  Environment
# 108  Environment: Greenhouse Gas Emissions  Environment
# 109  Environment: Greenhouse Gas Emissions  Environment
# 110  Environment: Greenhouse Gas Emissions  Environment
# 111  Environment: Greenhouse Gas Emissions  Environment
# 112  Environment: Greenhouse Gas Emissions  Environment
# 113  Environment: Greenhouse Gas Emissions  Environment
#
#                     SubTopic1                 SubTopic2  \
# 71   Greenhouse Gas Emissions      All Greenhouse Gases
# 72   Greenhouse Gas Emissions      All Greenhouse Gases
# 73   Greenhouse Gas Emissions  Carbon dioxide emissions
# 74   Greenhouse Gas Emissions  Carbon dioxide emissions
# 75   Greenhouse Gas Emissions  Carbon dioxide emissions
# 76   Greenhouse Gas Emissions         Fluorinated Gases
# 77   Greenhouse Gas Emissions      All Greenhouse Gases
# 78   Greenhouse Gas Emissions  Carbon dioxide emissions
# 79   Greenhouse Gas Emissions  Carbon dioxide emissions
# 80   Greenhouse Gas Emissions  Carbon dioxide emissions
# 81   Greenhouse Gas Emissions  Carbon dioxide emissions
# 82   Greenhouse Gas Emissions  Carbon dioxide emissions
# 83   Greenhouse Gas Emissions  Carbon dioxide emissions
# 84   Greenhouse Gas Emissions                     Total
# 85   Greenhouse Gas Emissions  Carbon dioxide emissions
# 86   Greenhouse Gas Emissions   Nitrous oxide emissions
# 87   Greenhouse Gas Emissions         Methane emissions
# 88   Greenhouse Gas Emissions   Nitrous oxide emissions
# 89   Greenhouse Gas Emissions   Nitrous oxide emissions
# 90   Greenhouse Gas Emissions   Nitrous oxide emissions
# 91   Greenhouse Gas Emissions         Methane emissions
# 92   Greenhouse Gas Emissions         Methane emissions
# 93   Greenhouse Gas Emissions   Nitrous oxide emissions
# 94   Greenhouse Gas Emissions   Nitrous oxide emissions
# 95   Greenhouse Gas Emissions   Nitrous oxide emissions
# 96   Greenhouse Gas Emissions   Nitrous oxide emissions
# 97   Greenhouse Gas Emissions         Methane emissions
# 98   Greenhouse Gas Emissions   Nitrous oxide emissions
# 99   Greenhouse Gas Emissions         Methane emissions
# 100  Greenhouse Gas Emissions         Methane emissions
# 101  Greenhouse Gas Emissions         Methane emissions
# 102  Greenhouse Gas Emissions         Methane emissions
# 103  Greenhouse Gas Emissions         Methane emissions
# 104  Greenhouse Gas Emissions  Carbon dioxide emissions
# 105  Greenhouse Gas Emissions  Carbon dioxide emissions
# 106  Greenhouse Gas Emissions  Carbon dioxide emissions
# 107  Greenhouse Gas Emissions         Methane emissions
# 108  Greenhouse Gas Emissions  Carbon dioxide emissions
# 109  Greenhouse Gas Emissions  Carbon dioxide emissions
# 110  Greenhouse Gas Emissions  Carbon dioxide emissions
# 111  Greenhouse Gas Emissions  Carbon dioxide emissions
# 112  Greenhouse Gas Emissions   Nitrous oxide emissions
# 113  Greenhouse Gas Emissions  Carbon dioxide emissions
#
#                                            SubTopic3
# 71    Including Land Use and Land-Use Change (LULUC)
# 72   Excluding  Land Use and Land-Use Change (LULUC)
# 73   Excluding  Land Use and Land-Use Change (LULUC)
# 74    Including Land Use and Land-Use Change (LULUC)
# 75    Including Land Use and Land-Use Change (LULUC)
# 76                              Industrial Processes
# 77   Excluding  Land Use and Land-Use Change (LULUC)
# 78   Excluding  Land Use and Land-Use Change (LULUC)
# 79    Including Land Use and Land-Use Change (LULUC)
# 80                           Carbon intensity of GDP
# 81                           Carbon intensity of GDP
# 82    Including Land Use and Land-Use Change (LULUC)
# 83    Including Land Use and Land-Use Change (LULUC)
# 84   Excluding  Land Use and Land-Use Change (LULUC)
# 85                                             Waste
# 86                             Industrial Combustion
# 87   Excluding  Land Use and Land-Use Change (LULUC)
# 88   Excluding  Land Use and Land-Use Change (LULUC)
# 89                                Fugitive Emissions
# 90                                         Buildings
# 91                                         Buildings
# 92                                Fugitive Emissions
# 93                                    Power Industry
# 94                                         Transport
# 95   Excluding  Land Use and Land-Use Change (LULUC)
# 96                                             Waste
# 97   Excluding  Land Use and Land-Use Change (LULUC)
# 98                              Industrial Processes
# 99                             Industrial Combustion
# 100                             Industrial Processes
# 101                                            Waste
# 102                                   Power Industry
# 103                                      Agriculture
# 104                                        Transport
# 105                                   Power Industry
# 106                             Industrial Processes
# 107                                        Transport
# 108                            Industrial Combustion
# 109                               Fugitive Emissions
# 110                                        Buildings
# 111                                      Agriculture
# 112                                      Agriculture
# 113  Excluding  Land Use and Land-Use Change (LULUC)

# %%
has_list = environment.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


environment_with_lists = environment[has_list]
print(environment_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Financial

# %%
financial  = dfs["financial"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(financial[financial['SubTopic2'].isna() | financial['SubTopic3'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
financial
# Out:
#                     Code                                     Indicator Name  \
# 0      FX.OWN.TOTL.SO.ZS  Account ownership at a financial institution o...
# 1         FB.ATM.TOTL.P5  Automated teller machines (ATMs) (per 100,000 ...
# 2      FX.OWN.TOTL.YG.ZS  Account ownership at a financial institution o...
# 3      FX.OWN.TOTL.60.ZS  Account ownership at a financial institution o...
# 4      FX.OWN.TOTL.MA.ZS  Account ownership at a financial institution o...
# 5      FX.OWN.TOTL.OL.ZS  Account ownership at a financial institution o...
# 6      FX.OWN.TOTL.40.ZS  Account ownership at a financial institution o...
# 7      SI.RMT.COST.IB.ZS  Average transaction cost of sending remittance...
# 8      SI.RMT.COST.OB.ZS  Average transaction cost of sending remittance...
# 9         FB.CBK.BRCH.P5      Commercial bank branches (per 100,000 adults)
# 10     FX.OWN.TOTL.PL.ZS  Account ownership at a financial institution o...
# 11        FB.CBK.DPTR.P3  Depositors with commercial banks (per 1,000 ad...
# 12        FX.OWN.TOTL.ZS  Account ownership at a financial institution o...
# 13     FX.OWN.TOTL.FE.ZS  Account ownership at a financial institution o...
# 14        FB.CBK.BRWR.P3  Borrowers from commercial banks (per 1,000 adu...
# 15     FM.AST.DOMO.ZG.M3  Claims on other sectors of the domestic econom...
# 16     FD.AST.PRVT.GD.ZS  Domestic credit to private sector by banks (% ...
# 17     FS.AST.PRVT.GD.ZS       Domestic credit to private sector (% of GDP)
# 18     FM.AST.PRVT.ZG.M3  Claims on private sector (annual growth as % o...
# 19     FD.RES.LIQU.AS.ZS      Bank liquid reserves to bank assets ratio (%)
# 20     FS.AST.DOMO.GD.ZS  Claims on other sectors of the domestic econom...
# 21     FM.AST.PRVT.GD.ZS   Monetary Sector credit to private sector (% GDP)
# 22        FM.AST.NFRG.CN                   Net foreign assets (current LCU)
# 23     FS.AST.DOMS.GD.ZS  Domestic credit provided by financial sector (...
# 24     FS.AST.CGOV.GD.ZS         Claims on central government, etc. (% GDP)
# 25     FM.AST.CGOV.ZG.M3  Claims on central government (annual growth as...
# 26        FB.BNK.CAPA.ZS                   Bank capital to assets ratio (%)
# 27        FM.AST.DOMS.CN                  Net domestic credit (current LCU)
# 28        FB.AST.NPER.ZS  Bank nonperforming loans to total gross loans (%)
# 29     CM.MKT.TRAD.GD.ZS              Stocks traded, total value (% of GDP)
# 30     CM.MKT.LCAP.GD.ZS  Market capitalization of listed domestic compa...
# 31        CM.MKT.TRAD.CD           Stocks traded, total value (current US$)
# 32        CM.MKT.LCAP.CD  Market capitalization of listed domestic compa...
# 33        CM.MKT.INDX.ZG        S&P Global Equity Indices (annual % change)
# 34        CM.MKT.LDOM.NO                   Listed domestic companies, total
# 35           CM.MKT.TRNR  Stocks traded, turnover ratio of domestic shar...
# 36        NY.GDP.DEFL.ZS         GDP deflator (base year varies by country)
# 37  NY.GDP.DEFL.KD.ZG.AD  Inflation, GDP deflator: linked series (annual %)
# 38        FP.CPI.TOTL.ZG              Inflation, consumer prices (annual %)
# 39           FP.CPI.TOTL                  Consumer price index (2010 = 100)
# 40           PA.NUS.FCRF  Official exchange rate (LCU per US$, period av...
# 41     NY.GDP.DEFL.KD.ZG                 Inflation, GDP deflator (annual %)
# 42           FP.WPI.TOTL                 Wholesale price index (2010 = 100)
# 43           PX.REX.REER    Real effective exchange rate index (2010 = 100)
# 44           PA.NUS.ATLS    DEC alternative conversion factor (LCU per US$)
# 45     NY.GDP.DEFL.ZS.AD  GDP deflator: linked series (base year varies ...
# 46           FR.INR.LNDP  Interest rate spread (lending rate minus depos...
# 47           FR.INR.RINR                             Real interest rate (%)
# 48           FR.INR.RISK  Risk premium on lending (lending rate minus tr...
# 49           FR.INR.DPST                          Deposit interest rate (%)
# 50           FR.INR.LEND                          Lending interest rate (%)
# 51     FM.LBL.BMNY.IR.ZS                Broad money to total reserves ratio
# 52     FM.LBL.BMNY.GD.ZS                             Broad money (% of GDP)
# 53        FM.LBL.BMNY.CN                          Broad money (current LCU)
# 54        FM.LBL.BMNY.ZG                      Broad money growth (annual %)
#
#                                         General Topic             Topic  \
# 0                            Financial Sector: Access  Financial Sector
# 1                            Financial Sector: Access  Financial Sector
# 2                            Financial Sector: Access  Financial Sector
# 3                            Financial Sector: Access  Financial Sector
# 4                            Financial Sector: Access  Financial Sector
# 5                            Financial Sector: Access  Financial Sector
# 6                            Financial Sector: Access  Financial Sector
# 7                            Financial Sector: Access  Financial Sector
# 8                            Financial Sector: Access  Financial Sector
# 9                            Financial Sector: Access  Financial Sector
# 10                           Financial Sector: Access  Financial Sector
# 11                           Financial Sector: Access  Financial Sector
# 12                           Financial Sector: Access  Financial Sector
# 13                           Financial Sector: Access  Financial Sector
# 14                           Financial Sector: Access  Financial Sector
# 15                           Financial Sector: Assets  Financial Sector
# 16                           Financial Sector: Assets  Financial Sector
# 17                           Financial Sector: Assets  Financial Sector
# 18                           Financial Sector: Assets  Financial Sector
# 19                           Financial Sector: Assets  Financial Sector
# 20                           Financial Sector: Assets  Financial Sector
# 21                           Financial Sector: Assets  Financial Sector
# 22                           Financial Sector: Assets  Financial Sector
# 23                           Financial Sector: Assets  Financial Sector
# 24                           Financial Sector: Assets  Financial Sector
# 25                           Financial Sector: Assets  Financial Sector
# 26                           Financial Sector: Assets  Financial Sector
# 27                           Financial Sector: Assets  Financial Sector
# 28                           Financial Sector: Assets  Financial Sector
# 29                  Financial Sector: Capital markets  Financial Sector
# 30                  Financial Sector: Capital markets  Financial Sector
# 31                  Financial Sector: Capital markets  Financial Sector
# 32                  Financial Sector: Capital markets  Financial Sector
# 33                  Financial Sector: Capital markets  Financial Sector
# 34                  Financial Sector: Capital markets  Financial Sector
# 35                  Financial Sector: Capital markets  Financial Sector
# 36          Financial Sector: Exchange rates & prices  Financial Sector
# 37          Financial Sector: Exchange rates & prices  Financial Sector
# 38          Financial Sector: Exchange rates & prices  Financial Sector
# 39          Financial Sector: Exchange rates & prices  Financial Sector
# 40          Financial Sector: Exchange rates & prices  Financial Sector
# 41          Financial Sector: Exchange rates & prices  Financial Sector
# 42          Financial Sector: Exchange rates & prices  Financial Sector
# 43          Financial Sector: Exchange rates & prices  Financial Sector
# 44          Financial Sector: Exchange rates & prices  Financial Sector
# 45          Financial Sector: Exchange rates & prices  Financial Sector
# 46                   Financial Sector: Interest rates  Financial Sector
# 47                   Financial Sector: Interest rates  Financial Sector
# 48                   Financial Sector: Interest rates  Financial Sector
# 49                   Financial Sector: Interest rates  Financial Sector
# 50                   Financial Sector: Interest rates  Financial Sector
# 51  Financial Sector: Monetary holdings (liabilities)  Financial Sector
# 52  Financial Sector: Monetary holdings (liabilities)  Financial Sector
# 53  Financial Sector: Monetary holdings (liabilities)  Financial Sector
# 54  Financial Sector: Monetary holdings (liabilities)  Financial Sector
#
#                           SubTopic1                                 SubTopic2  \
# 0                            Access                                 Ownership
# 1                            Access  Atmosphere (or automated teller machine)
# 2                            Access                                 Ownership
# 3                            Access                                 Ownership
# 4                            Access                                 Ownership
# 5                            Access                                 Ownership
# 6                            Access                                 Ownership
# 7                            Access                               Remittances
# 8                            Access                               Remittances
# 9                            Access                           Commercial bank
# 10                           Access                                 Ownership
# 11                           Access                           Commercial bank
# 12                           Access                                 Ownership
# 13                           Access                                 Ownership
# 14                           Access                           Commercial bank
# 15                           Assets                                     Asset
# 16                           Assets                                     Asset
# 17                           Assets                                     Asset
# 18                           Assets                                     Asset
# 19                           Assets                 Reserves (or residential)
# 20                           Assets                                     Asset
# 21                           Assets                                     Asset
# 22                           Assets                                     Asset
# 23                           Assets                                     Asset
# 24                           Assets                                     Asset
# 25                           Assets                                     Asset
# 26                           Assets                                      Bank
# 27                           Assets                                     Asset
# 28                           Assets                                     Asset
# 29                  Capital markets                           Markets (stock)
# 30                  Capital markets                           Markets (stock)
# 31                  Capital markets                           Markets (stock)
# 32                  Capital markets                           Markets (stock)
# 33                  Capital markets                           Markets (stock)
# 34                  Capital markets                           Markets (stock)
# 35                  Capital markets                           Markets (stock)
# 36          Exchange rates & prices                    Gross domestic product
# 37          Exchange rates & prices                    Gross domestic product
# 38          Exchange rates & prices                      Consumer price index
# 39          Exchange rates & prices                      Consumer price index
# 40          Exchange rates & prices               Local currency to US dollar
# 41          Exchange rates & prices                    Gross domestic product
# 42          Exchange rates & prices                     Wholesale price index
# 43          Exchange rates & prices                        Real exchange rate
# 44          Exchange rates & prices               Local currency to US dollar
# 45          Exchange rates & prices                    Gross domestic product
# 46                   Interest rates                             Interest rate
# 47                   Interest rates                             Interest rate
# 48                   Interest rates                             Interest rate
# 49                   Interest rates                             Interest rate
# 50                   Interest rates                             Interest rate
# 51  Monetary holdings (liabilities)                                 Liability
# 52  Monetary holdings (liabilities)                                 Liability
# 53  Monetary holdings (liabilities)                                 Liability
# 54  Monetary holdings (liabilities)                                 Liability
#
#                                     SubTopic3
# 0                                       Total
# 1                                       Total
# 2                                       Total
# 3                                       Total
# 4                                       Total
# 5                                       Total
# 6                                       Total
# 7                                        Cost
# 8                                        Cost
# 9                               Bank branches
# 10                                      Total
# 11                                 Depositors
# 12                                      Total
# 13                                      Total
# 14                                  Borrowers
# 15                     Other domestic sectors
# 16                                    Private
# 17                                    Private
# 18                                    Private
# 19                                     Liquid
# 20                     Other domestic sectors
# 21                                    Private
# 22                                Net foreign
# 23                                   Domestic
# 24                         Central government
# 25                         Central government
# 26                          Capital to assets
# 27                                   Domestic
# 28                              Nonperforming
# 29                                     Traded
# 30  Market capitalization of listed companies
# 31                                     Traded
# 32  Market capitalization of listed companies
# 33                                      Index
# 34                  Listed domestic companies
# 35     Transport receipts (or Turnover ratio)
# 36                                   Deflator
# 37                                   Deflator
# 38                                      Total
# 39                                      Total
# 40   IMF IFS code rf (official exchange rate)
# 41                                   Deflator
# 42                                      Total
# 43               Real effective exchange rate
# 44                               Atlas method
# 45                                   Deflator
# 46            Lending rate minus deposit rate
# 47                         Real interest rate
# 48                               Risk premium
# 49                                    Deposit
# 50                                    Lending
# 51                                Broad money
# 52                                Broad money
# 53                                Broad money
# 54                                Broad money

# %%
has_list = financial.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


financial_with_lists = financial[has_list]
print(financial_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Gender

# %%
gender  = dfs["gender"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(gender)
# Out:
#                  Code  \
# 0   SP.M18.2024.FE.ZS
# 1   SP.M15.2024.FE.ZS
# 2      SG.VAW.REAS.ZS
# 3      SG.VAW.ARGU.ZS
# 4      SG.VAW.1549.ZS
# 5      SG.VAW.BURN.ZS
# 6      SG.VAW.GOES.ZS
# 7      SG.VAW.NEGL.ZS
# 8      SG.VAW.REFU.ZS
# 9      SG.TIM.UWRK.MA
# 10     SG.TIM.UWRK.FE
# 11  SG.DMK.SRCR.FN.ZS
# 12        SG.LAW.INDX
# 13     SG.GEN.PARL.ZS
# 14  SG.DMK.ALLD.FN.ZS
#
#                                                                                                                                  Indicator Name  \
# 0                                                                                Women who were first married by age 18 (% of women ages 20-24)
# 1                                                                                Women who were first married by age 15 (% of women ages 20-24)
# 2                                                        Women who believe a husband is justified in beating his wife (any of five reasons) (%)
# 3                                                     Women who believe a husband is justified in beating his wife when she argues with him (%)
# 4                 Proportion of women subjected to physical and/or sexual violence in the last 12 months (% of ever-partnered women ages 15-49)
# 5                                                      Women who believe a husband is justified in beating his wife when she burns the food (%)
# 6                                        Women who believe a husband is justified in beating his wife when she goes out without telling him (%)
# 7                                               Women who believe a husband is justified in beating his wife when she neglects the children (%)
# 8                                                Women who believe a husband is justified in beating his wife when she refuses sex with him (%)
# 9                                                            Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)
# 10                                                         Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)
# 11  Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)
# 12                                                                                         Women Business and the Law Index Score (scale 1-100)
# 13                                                                                Proportion of seats held by women in national parliaments (%)
# 14          Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
#
#                             General Topic   Topic  \
# 0                          Gender: Agency  Gender
# 1                          Gender: Agency  Gender
# 2                          Gender: Health  Gender
# 3                          Gender: Health  Gender
# 4                          Gender: Health  Gender
# 5                          Gender: Health  Gender
# 6                          Gender: Health  Gender
# 7                          Gender: Health  Gender
# 8                          Gender: Health  Gender
# 9          Gender: Participation & access  Gender
# 10         Gender: Participation & access  Gender
# 11  Gender: Public life & decision making  Gender
# 12  Gender: Public life & decision making  Gender
# 13  Gender: Public life & decision making  Gender
# 14  Gender: Public life & decision making  Gender
#
#                         SubTopic1               SubTopic2  \
# 0                          Agency       Married by age 18
# 1                          Agency       Married by age 15
# 2                          Health  Violence against women
# 3                          Health  Violence against women
# 4                          Health  Violence against women
# 5                          Health  Violence against women
# 6                          Health  Violence against women
# 7                          Health  Violence against women
# 8                          Health  Violence against women
# 9          Participation & access                    Time
# 10         Participation & access                    Time
# 11  Public life & decision making         Decision making
# 12  Public life & decision making                     Law
# 13  Public life & decision making                  Gender
# 14  Public life & decision making         Decision making
#
#                                         SubTopic3
# 0                                       Age 20-24
# 1                                       Age 20-24
# 2                                          Reason
# 3                                           Argue
# 4                                            None
# 5                                      Burns food
# 6                                        Goes out
# 7                               Neglects children
# 8                                          Refuse
# 9                                     Unpaid work
# 10                                    Unpaid work
# 11                                           None
# 12                                          Index
# 13                           National parliaments
# 14  Total development assistance and official aid

# %%
with pd.option_context('display.max_colwidth', 200):

    display(gender[gender['SubTopic2'].isna()])
# Out:
#                 Code  \
# 1  SP.M15.2024.FE.ZS
#
#                                                    Indicator Name  \
# 1  Women who were first married by age 15 (% of women ages 20-24)
#
#     General Topic   Topic SubTopic1 SubTopic2  SubTopic3
# 1  Gender: Agency  Gender    Agency      None  Age 20-24

# %%
gender.loc[gender["Code"] == "SP.M15.2024.FE.ZS", "SubTopic2"] = "Married by age 15"

# %%
with pd.option_context('display.max_colwidth', 200):

    display(gender[gender['SubTopic3'].isna()])
# Out:
#                  Code  \
# 4      SG.VAW.1549.ZS
# 11  SG.DMK.SRCR.FN.ZS
#
#                                                                                                                                  Indicator Name  \
# 4                 Proportion of women subjected to physical and/or sexual violence in the last 12 months (% of ever-partnered women ages 15-49)
# 11  Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)
#
#                             General Topic   Topic  \
# 4                          Gender: Health  Gender
# 11  Gender: Public life & decision making  Gender
#
#                         SubTopic1               SubTopic2 SubTopic3
# 4                          Health  Violence against women      None
# 11  Public life & decision making         Decision making      None

# %%
gender.loc[gender["Code"] == "SG.VAW.1549.ZS", "SubTopic3"] = "Age 15-49"
gender.loc[gender["Code"] == "SG.DMK.SRCR.FN.ZS", "SubTopic3"] = "Age 15-49"

# %%
with pd.option_context('display.max_colwidth', 200):

    display(gender)
# Out:
#                  Code  \
# 0   SP.M18.2024.FE.ZS
# 1   SP.M15.2024.FE.ZS
# 2      SG.VAW.REAS.ZS
# 3      SG.VAW.ARGU.ZS
# 4      SG.VAW.1549.ZS
# 5      SG.VAW.BURN.ZS
# 6      SG.VAW.GOES.ZS
# 7      SG.VAW.NEGL.ZS
# 8      SG.VAW.REFU.ZS
# 9      SG.TIM.UWRK.MA
# 10     SG.TIM.UWRK.FE
# 11  SG.DMK.SRCR.FN.ZS
# 12        SG.LAW.INDX
# 13     SG.GEN.PARL.ZS
# 14  SG.DMK.ALLD.FN.ZS
#
#                                                                                                                                  Indicator Name  \
# 0                                                                                Women who were first married by age 18 (% of women ages 20-24)
# 1                                                                                Women who were first married by age 15 (% of women ages 20-24)
# 2                                                        Women who believe a husband is justified in beating his wife (any of five reasons) (%)
# 3                                                     Women who believe a husband is justified in beating his wife when she argues with him (%)
# 4                 Proportion of women subjected to physical and/or sexual violence in the last 12 months (% of ever-partnered women ages 15-49)
# 5                                                      Women who believe a husband is justified in beating his wife when she burns the food (%)
# 6                                        Women who believe a husband is justified in beating his wife when she goes out without telling him (%)
# 7                                               Women who believe a husband is justified in beating his wife when she neglects the children (%)
# 8                                                Women who believe a husband is justified in beating his wife when she refuses sex with him (%)
# 9                                                            Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)
# 10                                                         Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)
# 11  Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)
# 12                                                                                         Women Business and the Law Index Score (scale 1-100)
# 13                                                                                Proportion of seats held by women in national parliaments (%)
# 14          Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
#
#                             General Topic   Topic  \
# 0                          Gender: Agency  Gender
# 1                          Gender: Agency  Gender
# 2                          Gender: Health  Gender
# 3                          Gender: Health  Gender
# 4                          Gender: Health  Gender
# 5                          Gender: Health  Gender
# 6                          Gender: Health  Gender
# 7                          Gender: Health  Gender
# 8                          Gender: Health  Gender
# 9          Gender: Participation & access  Gender
# 10         Gender: Participation & access  Gender
# 11  Gender: Public life & decision making  Gender
# 12  Gender: Public life & decision making  Gender
# 13  Gender: Public life & decision making  Gender
# 14  Gender: Public life & decision making  Gender
#
#                         SubTopic1               SubTopic2  \
# 0                          Agency       Married by age 18
# 1                          Agency       Married by age 15
# 2                          Health  Violence against women
# 3                          Health  Violence against women
# 4                          Health  Violence against women
# 5                          Health  Violence against women
# 6                          Health  Violence against women
# 7                          Health  Violence against women
# 8                          Health  Violence against women
# 9          Participation & access                    Time
# 10         Participation & access                    Time
# 11  Public life & decision making         Decision making
# 12  Public life & decision making                     Law
# 13  Public life & decision making                  Gender
# 14  Public life & decision making         Decision making
#
#                                         SubTopic3
# 0                                       Age 20-24
# 1                                       Age 20-24
# 2                                          Reason
# 3                                           Argue
# 4                                       Age 15-49
# 5                                      Burns food
# 6                                        Goes out
# 7                               Neglects children
# 8                                          Refuse
# 9                                     Unpaid work
# 10                                    Unpaid work
# 11                                      Age 15-49
# 12                                          Index
# 13                           National parliaments
# 14  Total development assistance and official aid

# %%
has_list = gender.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


gender_with_lists = gender[has_list]
print(gender_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Health

# %%
health  = dfs["health"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(health)
# Out:
#                   Code  \
# 0       SH.MLR.NETS.ZS
# 1    SH.STA.SMSS.RU.ZS
# 2          SH.IMM.MEAS
# 3       SH.STA.SMSS.ZS
# 4    SH.H2O.SMDW.RU.ZS
# ..                 ...
# 243     SH.UHC.TOTR.ZS
# 244  SH.UHC.OOPC.25.ZS
# 245     SH.UHC.FBPR.ZS
# 246     SH.UHC.NOP1.ZS
# 247  SH.UHC.OOPC.10.ZS
#
#                                                                                                                               Indicator Name  \
# 0                                                                              Use of insecticide-treated bed nets (% of under-5 population)
# 1                                                             People using safely managed sanitation services, rural (% of rural population)
# 2                                                                                    Immunization, measles (% of children ages 12-23 months)
# 3                                                                          People using safely managed sanitation services (% of population)
# 4                                                         People using safely managed drinking water services, rural (% of rural population)
# ..                                                                                                                                       ...
# 243  Proportion of population pushed or further pushed below the 60% median consumption poverty line by out-of-pocket health expenditure (%)
# 244          Proportion of population spending more than 25% of household consumption or income on out-of-pocket health care expenditure (%)
# 245       Proportion of population pushed further below the 60% median consumption poverty line by out-of-pocket health care expenditure (%)
# 246                   Proportion of population pushed below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)
# 247          Proportion of population spending more than 10% of household consumption or income on out-of-pocket health care expenditure (%)
#
#                          General Topic   Topic                  SubTopic1  \
# 0           Health: Disease prevention  Health         Disease prevention
# 1           Health: Disease prevention  Health         Disease prevention
# 2           Health: Disease prevention  Health         Disease prevention
# 3           Health: Disease prevention  Health         Disease prevention
# 4           Health: Disease prevention  Health         Disease prevention
# ..                                 ...     ...                        ...
# 243  Health: Universal Health Coverage  Health  Universal Health Coverage
# 244  Health: Universal Health Coverage  Health  Universal Health Coverage
# 245  Health: Universal Health Coverage  Health  Universal Health Coverage
# 246  Health: Universal Health Coverage  Health  Universal Health Coverage
# 247  Health: Universal Health Coverage  Health  Universal Health Coverage
#
#                                          SubTopic2  \
# 0                                          Malaria
# 1                                       Stationary
# 2                                     Immunization
# 3                                       Stationary
# 4                                            Water
# ..                                             ...
# 243  Poverty Line (pushed or further pushed below)
# 244                   Poverty Line (spending more)
# 245            Poverty Line (pushed further below)
# 246                    Poverty Line (pushed below)
# 247                   Poverty Line (spending more)
#
#                                   SubTopic3
# 0              Insecticide-treated bed nets
# 1                                       NaN
# 2                                   Measles
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 243     60% median consumption poverty line
# 244  25% of household consumption or income
# 245     60% median consumption poverty line
# 246             2.15(2017 PPP) poverty line
# 247  10% of household consumption or income
#
# [248 rows x 7 columns]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(health[health['SubTopic2'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
health.loc[health["Code"] == "SH.UHC.SRVS.CV.XD", ["SubTopic2", "SubTopic3"]] = ["Service Coverage", "Index"]

# %%
health.loc[health["Code"] == "SH.UHC.NOP2.ZS",  "SubTopic3"] = ["3.65(2017 PPP) poverty line"]
health.loc[health["Code"] == "SH.UHC.NOP1.ZS",  "SubTopic3"] = ["2.15(2017 PPP) poverty line"]
health.loc[health["Code"] == "SH.UHC.OOPC.10.ZS",  "SubTopic3"] = ["10% of household consumption or income"]
health.loc[health["Code"] == "SH.UHC.OOPC.25.ZS",  "SubTopic3"] = ["25% of household consumption or income"]

# %%
health.loc[health['Code'].str.startswith('SH.UHC') & 
           health['Code'].str.contains('NOP1|NOP2|NOPR', regex=True), "SubTopic2"] = "Poverty Line (pushed below)"

health.loc[health['Code'].str.startswith('SH.UHC') & 
           health['Code'].str.contains('FBP1|FBP2|FBPR', regex=True), "SubTopic2"] = "Poverty Line (pushed further below)"

health.loc[health['Code'].str.startswith('SH.UHC') & 
           health['Code'].str.contains('TOT1|TOT2|TOTR', regex=True), "SubTopic2"] = "Poverty Line (pushed or further pushed below)"

health.loc[health['Code'].str.startswith('SH.UHC') & 
           health['Code'].str.contains('OOPC', regex=True), "SubTopic2"] = "Poverty Line (spending more)"

# %%
health_subtopic3_mapping = {
    "NOPR": "60% median consumption poverty line",
    "FBP1": "2.15(2017 PPP) poverty line",
    "FBP2": "3.65(2017 PPP) poverty line",
    "TOT1": "2.15(2017 PPP) poverty line",
    "TOT2": "3.65(2017 PPP) poverty line",
    "TOTR": "60% median consumption poverty line",
    "FBPR": "60% median consumption poverty line"
}
health.loc[health["SubTopic3"].isna(), "SubTopic3"] = (
    health["Code"].str.split(".").str[2].map(health_subtopic3_mapping)
)

# %%
health[health['Code'].str.startswith('SH.UHC')]
# Out:
#                   Code                                     Indicator Name  \
# 236  SH.UHC.SRVS.CV.XD                         UHC service coverage index
# 237     SH.UHC.NOP2.ZS  Proportion of population pushed below the $3.6...
# 238     SH.UHC.NOPR.ZS  Proportion of population pushed below the 60% ...
# 239     SH.UHC.FBP1.ZS  Proportion of population pushed further below ...
# 240     SH.UHC.FBP2.ZS  Proportion of population pushed further below ...
# 241     SH.UHC.TOT1.ZS  Proportion of population pushed or further pus...
# 242     SH.UHC.TOT2.ZS  Proportion of population pushed or further pus...
# 243     SH.UHC.TOTR.ZS  Proportion of population pushed or further pus...
# 244  SH.UHC.OOPC.25.ZS  Proportion of population spending more than 25...
# 245     SH.UHC.FBPR.ZS  Proportion of population pushed further below ...
# 246     SH.UHC.NOP1.ZS  Proportion of population pushed below the $2.1...
# 247  SH.UHC.OOPC.10.ZS  Proportion of population spending more than 10...
#
#                          General Topic   Topic                  SubTopic1  \
# 236  Health: Universal Health Coverage  Health  Universal Health Coverage
# 237  Health: Universal Health Coverage  Health  Universal Health Coverage
# 238  Health: Universal Health Coverage  Health  Universal Health Coverage
# 239  Health: Universal Health Coverage  Health  Universal Health Coverage
# 240  Health: Universal Health Coverage  Health  Universal Health Coverage
# 241  Health: Universal Health Coverage  Health  Universal Health Coverage
# 242  Health: Universal Health Coverage  Health  Universal Health Coverage
# 243  Health: Universal Health Coverage  Health  Universal Health Coverage
# 244  Health: Universal Health Coverage  Health  Universal Health Coverage
# 245  Health: Universal Health Coverage  Health  Universal Health Coverage
# 246  Health: Universal Health Coverage  Health  Universal Health Coverage
# 247  Health: Universal Health Coverage  Health  Universal Health Coverage
#
#                                          SubTopic2  \
# 236                               Service Coverage
# 237                    Poverty Line (pushed below)
# 238                    Poverty Line (pushed below)
# 239            Poverty Line (pushed further below)
# 240            Poverty Line (pushed further below)
# 241  Poverty Line (pushed or further pushed below)
# 242  Poverty Line (pushed or further pushed below)
# 243  Poverty Line (pushed or further pushed below)
# 244                   Poverty Line (spending more)
# 245            Poverty Line (pushed further below)
# 246                    Poverty Line (pushed below)
# 247                   Poverty Line (spending more)
#
#                                   SubTopic3
# 236                                   Index
# 237             3.65(2017 PPP) poverty line
# 238     60% median consumption poverty line
# 239             2.15(2017 PPP) poverty line
# 240             3.65(2017 PPP) poverty line
# 241             2.15(2017 PPP) poverty line
# 242             3.65(2017 PPP) poverty line
# 243     60% median consumption poverty line
# 244  25% of household consumption or income
# 245     60% median consumption poverty line
# 246             2.15(2017 PPP) poverty line
# 247  10% of household consumption or income

# %%
with pd.option_context('display.max_colwidth', 200):

    display(health[health['SubTopic3'].isna()])
# Out:
#                  Code  \
# 1   SH.STA.SMSS.RU.ZS
# 3      SH.STA.SMSS.ZS
# 4   SH.H2O.SMDW.RU.ZS
# 5   SH.STA.BASS.UR.ZS
# 6   SH.STA.BASS.RU.ZS
# 7      SH.STA.BASS.ZS
# 13  SH.STA.HYGN.UR.ZS
# 14     SH.STA.HYGN.ZS
# 16  SH.STA.SMSS.UR.ZS
# 18     SH.H2O.SMDW.ZS
# 19  SH.H2O.BASW.RU.ZS
# 20     SH.H2O.BASW.ZS
# 21  SH.STA.HYGN.RU.ZS
# 24  SH.H2O.BASW.UR.ZS
# 25  SH.H2O.SMDW.UR.ZS
# 27  SH.XPD.PVTD.CH.ZS
# 28  SH.XPD.GHED.GE.ZS
# 29  SH.XPD.EHEX.CH.ZS
# 30  SH.XPD.GHED.GD.ZS
# 31  SH.XPD.GHED.CH.ZS
# 34  SH.XPD.PVTD.PC.CD
# 35  SH.XPD.GHED.PC.CD
# 37  SH.XPD.CHEX.GD.ZS
# 42  SH.XPD.PVTD.PP.CD
# 43  SH.XPD.CHEX.PC.CD
# 44  SH.XPD.EHEX.PP.CD
# 46  SH.XPD.CHEX.PP.CD
# 47  SH.XPD.EHEX.PC.CD
# 49  SH.XPD.GHED.PP.CD
# 72  SH.STA.POIS.P5.MA
# 74  SH.STA.POIS.P5.FE
# 75     SH.STA.POIS.P5
# 76  SH.STA.AIRP.MA.P5
# 77  SH.STA.AIRP.FE.P5
# 78     SH.STA.AIRP.P5
# 82     SH.STA.WASH.P5
# 91     SN.ITK.SVFI.ZS
# 95     SN.ITK.MSFI.ZS
#
#                                                                                                                 Indicator Name  \
# 1                                               People using safely managed sanitation services, rural (% of rural population)
# 3                                                            People using safely managed sanitation services (% of population)
# 4                                           People using safely managed drinking water services, rural (% of rural population)
# 5                                               People using at least basic sanitation services, urban (% of urban population)
# 6                                               People using at least basic sanitation services, rural (% of rural population)
# 7                                                            People using at least basic sanitation services (% of population)
# 13                            People with basic handwashing facilities including soap and water, urban (% of urban population)
# 14                                         People with basic handwashing facilities including soap and water (% of population)
# 16                                              People using safely managed sanitation services, urban (% of urban population)
# 18                                                       People using safely managed drinking water services (% of population)
# 19                                          People using at least basic drinking water services, rural (% of rural population)
# 20                                                       People using at least basic drinking water services (% of population)
# 21                            People with basic handwashing facilities including soap and water, rural (% of rural population)
# 24                                          People using at least basic drinking water services, urban (% of urban population)
# 25                                          People using safely managed drinking water services, urban (% of urban population)
# 27                                                       Domestic private health expenditure (% of current health expenditure)
# 28                                        Domestic general government health expenditure (% of general government expenditure)
# 29                                                               External health expenditure (% of current health expenditure)
# 30                                                                   Domestic general government health expenditure (% of GDP)
# 31                                            Domestic general government health expenditure (% of current health expenditure)
# 34                                                                Domestic private health expenditure per capita (current US$)
# 35                                                     Domestic general government health expenditure per capita (current US$)
# 37                                                                                       Current health expenditure (% of GDP)
# 42                                               Domestic private health expenditure per capita, PPP (current international $)
# 43                                                                         Current health expenditure per capita (current US$)
# 44                                                       External health expenditure per capita, PPP (current international $)
# 46                                                        Current health expenditure per capita, PPP (current international $)
# 47                                                                        External health expenditure per capita (current US$)
# 49                                    Domestic general government health expenditure per capita, PPP (current international $)
# 72                                    Mortality rate attributed to unintentional poisoning, male (per 100,000 male population)
# 74                                Mortality rate attributed to unintentional poisoning, female (per 100,000 female population)
# 75                                               Mortality rate attributed to unintentional poisoning (per 100,000 population)
# 76      Mortality rate attributed to household and ambient air pollution, age-standardized, male (per 100,000 male population)
# 77  Mortality rate attributed to household and ambient air pollution, age-standardized, female (per 100,000 female population)
# 78                 Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)
# 82                   Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)
# 91                                                                  Prevalence of severe food insecurity in the population (%)
# 95                                                      Prevalence of moderate or severe food insecurity in the population (%)
#
#                  General Topic   Topic           SubTopic1    SubTopic2  \
# 1   Health: Disease prevention  Health  Disease prevention   Stationary
# 3   Health: Disease prevention  Health  Disease prevention   Stationary
# 4   Health: Disease prevention  Health  Disease prevention        Water
# 5   Health: Disease prevention  Health  Disease prevention   Stationary
# 6   Health: Disease prevention  Health  Disease prevention   Stationary
# 7   Health: Disease prevention  Health  Disease prevention   Stationary
# 13  Health: Disease prevention  Health  Disease prevention   Stationary
# 14  Health: Disease prevention  Health  Disease prevention   Stationary
# 16  Health: Disease prevention  Health  Disease prevention   Stationary
# 18  Health: Disease prevention  Health  Disease prevention        Water
# 19  Health: Disease prevention  Health  Disease prevention        Water
# 20  Health: Disease prevention  Health  Disease prevention        Water
# 21  Health: Disease prevention  Health  Disease prevention   Stationary
# 24  Health: Disease prevention  Health  Disease prevention        Water
# 25  Health: Disease prevention  Health  Disease prevention        Water
# 27      Health: Health systems  Health      Health systems  Expenditure
# 28      Health: Health systems  Health      Health systems  Expenditure
# 29      Health: Health systems  Health      Health systems  Expenditure
# 30      Health: Health systems  Health      Health systems  Expenditure
# 31      Health: Health systems  Health      Health systems  Expenditure
# 34      Health: Health systems  Health      Health systems  Expenditure
# 35      Health: Health systems  Health      Health systems  Expenditure
# 37      Health: Health systems  Health      Health systems  Expenditure
# 42      Health: Health systems  Health      Health systems  Expenditure
# 43      Health: Health systems  Health      Health systems  Expenditure
# 44      Health: Health systems  Health      Health systems  Expenditure
# 46      Health: Health systems  Health      Health systems  Expenditure
# 47      Health: Health systems  Health      Health systems  Expenditure
# 49      Health: Health systems  Health      Health systems  Expenditure
# 72           Health: Mortality  Health           Mortality   Stationary
# 74           Health: Mortality  Health           Mortality   Stationary
# 75           Health: Mortality  Health           Mortality   Stationary
# 76           Health: Mortality  Health           Mortality   Stationary
# 77           Health: Mortality  Health           Mortality   Stationary
# 78           Health: Mortality  Health           Mortality   Stationary
# 82           Health: Mortality  Health           Mortality   Stationary
# 91           Health: Nutrition  Health           Nutrition       Intake
# 95           Health: Nutrition  Health           Nutrition       Intake
#
#    SubTopic3
# 1        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 13       NaN
# 14       NaN
# 16       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 24       NaN
# 25       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 34       NaN
# 35       NaN
# 37       NaN
# 42       NaN
# 43       NaN
# 44       NaN
# 46       NaN
# 47       NaN
# 49       NaN
# 72       NaN
# 74       NaN
# 75       NaN
# 76       NaN
# 77       NaN
# 78       NaN
# 82       NaN
# 91       NaN
# 95       NaN

# %%
gender.loc[gender["Code"] == "SG.VAW.1549.ZS", "SubTopic3"] = "Age 15-49"
gender.loc[gender["Code"] == "SG.DMK.SRCR.FN.ZS", "SubTopic3"] = "Age 15-49"

# %%
with pd.option_context('display.max_colwidth', 200):

    display(gender)
# Out:
#                  Code  \
# 0   SP.M18.2024.FE.ZS
# 1   SP.M15.2024.FE.ZS
# 2      SG.VAW.REAS.ZS
# 3      SG.VAW.ARGU.ZS
# 4      SG.VAW.1549.ZS
# 5      SG.VAW.BURN.ZS
# 6      SG.VAW.GOES.ZS
# 7      SG.VAW.NEGL.ZS
# 8      SG.VAW.REFU.ZS
# 9      SG.TIM.UWRK.MA
# 10     SG.TIM.UWRK.FE
# 11  SG.DMK.SRCR.FN.ZS
# 12        SG.LAW.INDX
# 13     SG.GEN.PARL.ZS
# 14  SG.DMK.ALLD.FN.ZS
#
#                                                                                                                                  Indicator Name  \
# 0                                                                                Women who were first married by age 18 (% of women ages 20-24)
# 1                                                                                Women who were first married by age 15 (% of women ages 20-24)
# 2                                                        Women who believe a husband is justified in beating his wife (any of five reasons) (%)
# 3                                                     Women who believe a husband is justified in beating his wife when she argues with him (%)
# 4                 Proportion of women subjected to physical and/or sexual violence in the last 12 months (% of ever-partnered women ages 15-49)
# 5                                                      Women who believe a husband is justified in beating his wife when she burns the food (%)
# 6                                        Women who believe a husband is justified in beating his wife when she goes out without telling him (%)
# 7                                               Women who believe a husband is justified in beating his wife when she neglects the children (%)
# 8                                                Women who believe a husband is justified in beating his wife when she refuses sex with him (%)
# 9                                                            Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)
# 10                                                         Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)
# 11  Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)
# 12                                                                                         Women Business and the Law Index Score (scale 1-100)
# 13                                                                                Proportion of seats held by women in national parliaments (%)
# 14          Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
#
#                             General Topic   Topic  \
# 0                          Gender: Agency  Gender
# 1                          Gender: Agency  Gender
# 2                          Gender: Health  Gender
# 3                          Gender: Health  Gender
# 4                          Gender: Health  Gender
# 5                          Gender: Health  Gender
# 6                          Gender: Health  Gender
# 7                          Gender: Health  Gender
# 8                          Gender: Health  Gender
# 9          Gender: Participation & access  Gender
# 10         Gender: Participation & access  Gender
# 11  Gender: Public life & decision making  Gender
# 12  Gender: Public life & decision making  Gender
# 13  Gender: Public life & decision making  Gender
# 14  Gender: Public life & decision making  Gender
#
#                         SubTopic1               SubTopic2  \
# 0                          Agency       Married by age 18
# 1                          Agency       Married by age 15
# 2                          Health  Violence against women
# 3                          Health  Violence against women
# 4                          Health  Violence against women
# 5                          Health  Violence against women
# 6                          Health  Violence against women
# 7                          Health  Violence against women
# 8                          Health  Violence against women
# 9          Participation & access                    Time
# 10         Participation & access                    Time
# 11  Public life & decision making         Decision making
# 12  Public life & decision making                     Law
# 13  Public life & decision making                  Gender
# 14  Public life & decision making         Decision making
#
#                                         SubTopic3
# 0                                       Age 20-24
# 1                                       Age 20-24
# 2                                          Reason
# 3                                           Argue
# 4                                       Age 15-49
# 5                                      Burns food
# 6                                        Goes out
# 7                               Neglects children
# 8                                          Refuse
# 9                                     Unpaid work
# 10                                    Unpaid work
# 11                                      Age 15-49
# 12                                          Index
# 13                           National parliaments
# 14  Total development assistance and official aid

# %%
has_list = gender.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


gender_with_lists = gender[has_list]
print(gender_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []
