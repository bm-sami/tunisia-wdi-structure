# %%
import numpy as np 
import pandas as pd
import re

# %%
def clean_text(text):
    if isinstance(text, str): 
        return re.sub(r'\s+', ' ', text).strip()
    return text

# %%
def summary(df):
    print(f'data shape: {df.shape}')  
    summ = pd.DataFrame(df.dtypes, columns=['data type'])
    summ['#missing'] = df.isnull().sum().values 
    summ['%missing'] = df.isnull().sum().values / len(df)
    summ['#unique'] = df.nunique().values
    desc = pd.DataFrame(df.describe(include='all').transpose())
#     summ['min'] = desc['min'].values
#     summ['max'] = desc['max'].values
    return summ

# %%
file_path = '../metadata/hierarchy_topic_by_sheet.xlsx' 
xls = pd.ExcelFile(file_path)


dfs = {}

for sheet_name in xls.sheet_names:
    first_word = sheet_name.split()[0].lower() 
    df = pd.read_excel(xls, sheet_name=sheet_name)  
    dfs[first_word] = df  


for name, df in dfs.items():
    print(f"{name}")
# Out:
# economic
# education
# environment
# financial
# gender
# health
# infrastructure
# poverty
# private
# public
# social
# trade

# %%
dfs['education']
# Out:
#                   Code                                     Indicator Name  \
# 0       SE.PRM.PRS5.ZS        Persistence to grade 5, total (% of cohort)
# 1       SE.PRM.GINT.ZS  Gross intake ratio in first grade of primary e...
# 2       SE.PRM.NINT.ZS  Net intake rate in grade 1 (% of official scho...
# 3    SE.PRM.OENR.MA.ZS  Over-age students, primary, male (% of male en...
# 4    SE.PRM.PRS5.MA.ZS         Persistence to grade 5, male (% of cohort)
# ..                 ...                                                ...
# 151  SE.ENR.PRIM.FM.ZS  School enrollment, primary (gross), gender par...
# 152        SE.PRM.NENR                 School enrollment, primary (% net)
# 153     SE.PRE.ENRR.MA      School enrollment, preprimary, male (% gross)
# 154     SE.PRM.PRIV.ZS  School enrollment, primary, private (% of tota...
# 155  SE.ENR.TERT.FM.ZS  School enrollment, tertiary (gross), gender pa...
#
#                 General Topic      Topic      SubTopic1  SubTopic2  SubTopic3
# 0       Education: Efficiency  Education     Efficiency        NaN        NaN
# 1       Education: Efficiency  Education     Efficiency        NaN        NaN
# 2       Education: Efficiency  Education     Efficiency        NaN        NaN
# 3       Education: Efficiency  Education     Efficiency        NaN        NaN
# 4       Education: Efficiency  Education     Efficiency        NaN        NaN
# ..                        ...        ...            ...        ...        ...
# 151  Education: Participation  Education  Participation        NaN        NaN
# 152  Education: Participation  Education  Participation        NaN        NaN
# 153  Education: Participation  Education  Participation        NaN        NaN
# 154  Education: Participation  Education  Participation        NaN        NaN
# 155  Education: Participation  Education  Participation        NaN        NaN
#
# [156 rows x 7 columns]

# %%
example_education = dfs['education'].copy()

# %%
example_education['code3'] = example_education['Code'].str.split('.').str[:3].str.join('.')

# %%
grouped_counts = example_education['code3'].value_counts()
grouped_counts.head()
# Out:
# code3
# SE.TER.CUAT    12
# SE.SEC.CUAT     9
# SE.LPV.PRIM     9
# SE.SEC.TCAQ     9
# SE.SEC.ENRL     9
# Name: count, dtype: int64

# %%
with pd.option_context('display.max_colwidth', 200):

    display(example_education[example_education['code3'] == 'SE.TER.CUAT'])
# Out:
#                     Code  \
# 68  SE.TER.CUAT.BA.FE.ZS
# 69  SE.TER.CUAT.DO.FE.ZS
# 70  SE.TER.CUAT.BA.MA.ZS
# 71  SE.TER.CUAT.DO.MA.ZS
# 73  SE.TER.CUAT.ST.FE.ZS
# 76  SE.TER.CUAT.ST.MA.ZS
# 77     SE.TER.CUAT.MS.ZS
# 78     SE.TER.CUAT.BA.ZS
# 80     SE.TER.CUAT.DO.ZS
# 81  SE.TER.CUAT.MS.MA.ZS
# 82  SE.TER.CUAT.MS.FE.ZS
# 83     SE.TER.CUAT.ST.ZS
#
#                                                                                               Indicator Name  \
# 68        Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)
# 69                   Educational attainment, Doctoral or equivalent, population 25+, female (%) (cumulative)
# 70          Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)
# 71                     Educational attainment, Doctoral or equivalent, population 25+, male (%) (cumulative)
# 73  Educational attainment, at least completed short-cycle tertiary, population 25+, female (%) (cumulative)
# 76    Educational attainment, at least completed short-cycle tertiary, population 25+, male (%) (cumulative)
# 77           Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)
# 78         Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)
# 80                    Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)
# 81            Educational attainment, at least Master's or equivalent, population 25+, male (%) (cumulative)
# 82          Educational attainment, at least Master's or equivalent, population 25+, female (%) (cumulative)
# 83   Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)
#
#           General Topic      Topic SubTopic1  SubTopic2  SubTopic3  \
# 68  Education: Outcomes  Education  Outcomes        NaN        NaN
# 69  Education: Outcomes  Education  Outcomes        NaN        NaN
# 70  Education: Outcomes  Education  Outcomes        NaN        NaN
# 71  Education: Outcomes  Education  Outcomes        NaN        NaN
# 73  Education: Outcomes  Education  Outcomes        NaN        NaN
# 76  Education: Outcomes  Education  Outcomes        NaN        NaN
# 77  Education: Outcomes  Education  Outcomes        NaN        NaN
# 78  Education: Outcomes  Education  Outcomes        NaN        NaN
# 80  Education: Outcomes  Education  Outcomes        NaN        NaN
# 81  Education: Outcomes  Education  Outcomes        NaN        NaN
# 82  Education: Outcomes  Education  Outcomes        NaN        NaN
# 83  Education: Outcomes  Education  Outcomes        NaN        NaN
#
#           code3
# 68  SE.TER.CUAT
# 69  SE.TER.CUAT
# 70  SE.TER.CUAT
# 71  SE.TER.CUAT
# 73  SE.TER.CUAT
# 76  SE.TER.CUAT
# 77  SE.TER.CUAT
# 78  SE.TER.CUAT
# 80  SE.TER.CUAT
# 81  SE.TER.CUAT
# 82  SE.TER.CUAT
# 83  SE.TER.CUAT

# %% [markdown]
# In this eample of education outcomes, we observe that indicator codes beginning with **SE.TER.CUAT** can be further subdivided to populate relevant subtopics.
#
# To achieve this, we will:
# 1. **Read the WDI Indicators file** to examine the full list of codes and their corresponding descriptions.
# 2. **Identify patterns** within the codes that allow for classification into subtopics.
# 3. **Extract meaningful subtopic information** from the code structure and descriptions.
#
# By implementing this approach, we aim to enhance the granularity of our dataset and improve analytical insights into education outcomes.

# %%
wdi_codes = pd.read_excel('../metadata/WDI_Indicators.xlsx', sheet_name="Coding")

# %%
wdi_codes
# Out:
#      Topic                                Topic description General subject  \
# 0       AG                                      Agriculture             ACS
# 1       BG                       Balance of payments: gross             ADJ
# 2       BM  Balance of payments: imports, payments (credit)             ADM
# 3       BN                         Balance of payments: net             ADO
# 4       BX   Balance of payments: exports, receipts (debit)             ADT
# ...    ...                                              ...             ...
# 1057   NaN                                              NaN             NaN
# 1058   NaN                                              NaN             NaN
# 1059   NaN                                              NaN             NaN
# 1060   NaN                                              NaN             NaN
# 1061   NaN                                              NaN             NaN
#
#      General subject description Specific subject  \
# 0                         Access             0003
# 1               Adjusted savings             0004
# 2                      Admission             0014
# 3                     Adolescent             0324
# 4                          Adult             0306
# ...                          ...              ...
# 1057                         NaN             XOKA
# 1058                         NaN             XPND
# 1059                         NaN             XPRT
# 1060                         NaN             XTHR
# 1061                         NaN             YPKG
#
#               Specific subject description Extensions Extensions description
# 0                                  Age 0-3         05             2005 (PPP)
# 1                                  Age 0-4         10                 Decile
# 2                                 Age 0-14         14               Age 0-14
# 3                                 Age 0-24         20               Quintile
# 4                                  Age 3-6         90   % changes since 1990
# ...                                    ...        ...                    ...
# 1057  Excluding official capital transfers        NaN                    NaN
# 1058                           Expenditure        NaN                    NaN
# 1059                               Exports        NaN                    NaN
# 1060            Other manufactures (trade)        NaN                    NaN
# 1061     Income, profits and capital gains        NaN                    NaN
#
# [1062 rows x 8 columns]

# %% [markdown]
# ### Understanding the Code Structure using `wdi_codes`
#
# Based on our analysis, we have identified a general pattern in the structure of the codes formatted as **XX.XX.XX...**. While this does not apply to all cases, the common breakdown is as follows:
#
# 1. **Topic Column**: Corresponds to the `Topic` and `SubTopic1` of the dataset as the values for that column are **name : name**.
# 2. **General subject Column**: Represents the `SubTopic2`.
# 3. **Specific subject Column**: Defines the `SubTopic3`.
# 4. **Extension (the rest)**: Any additional components following the third part can be considered as **Extensions**, which provide further granularity or variations within the specific subject. Note we dont have a column for taht yet and we will find a way to add informations of extension if they are important to our work
#
# By leveraging this structure, we can systematically extract hierarchical information from the codes and use it for improved classification and mapping in our analysis.

# %% [markdown]
# We will delete the topic and topic description as we already has the topic metadata filled

# %%
wdi_codes.drop(columns=['Topic', 'Topic description'], inplace=True)
wdi_codes.head()
# Out:
#   General subject General subject description Specific subject  \
# 0             ACS                      Access             0003
# 1             ADJ            Adjusted savings             0004
# 2             ADM                   Admission             0014
# 3             ADO                  Adolescent             0324
# 4             ADT                       Adult             0306
#
#   Specific subject description Extensions Extensions description
# 0                      Age 0-3         05             2005 (PPP)
# 1                      Age 0-4         10                 Decile
# 2                     Age 0-14         14               Age 0-14
# 3                     Age 0-24         20               Quintile
# 4                      Age 3-6         90   % changes since 1990

# %%
for col in ['General subject', 'Specific subject', 'Extensions']:
    redundant = wdi_codes[col].dropna()[wdi_codes[col].dropna().duplicated()]
    if not redundant.empty:
        print(f"Redundant values in column '{col}':")
        print(redundant)
    else:
        print(f"No redundant values in column '{col}'.")
# Out:
# No redundant values in column 'General subject'.
# No redundant values in column 'Specific subject'.
# No redundant values in column 'Extensions'.

# %%
import pandas as pd

wdi_codes['has_match'] = wdi_codes.apply(
    lambda row: (
        (pd.notna(row['General subject']) and row['General subject'] in [row['Specific subject'], row['Extensions']]) or
        (pd.notna(row['Specific subject']) and row['Specific subject'] in [row['General subject'], row['Extensions']]) or
        (pd.notna(row['Extensions']) and row['Extensions'] in [row['General subject'], row['Specific subject']])
    ), axis=1
)

matching_rows = wdi_codes[wdi_codes['has_match']]
print("Rows with matching values between columns:")
print(matching_rows[['General subject', 'Specific subject', 'Extensions']])


wdi_codes.drop(columns=['has_match'], inplace=True)
# Out:
# Rows with matching values between columns:
# Empty DataFrame
# Columns: [General subject, Specific subject, Extensions]
# Index: []

# %%
# df_melted = pd.melt(wdi_codes, 
#                     value_vars=['General subject', 'Specific subject', 'Extensions'], 
#                     var_name='Key_Type', value_name='Key')

# df_melted['Value'] = pd.melt(wdi_codes, 
#                              value_vars=['General subject description', 'Specific subject description', 'Extensions description'], 
#                              var_name='Value_Type', value_name='Value')['Value']

# df_melted.dropna(subset=['Key', 'Value'], how='any', inplace=True)

# %%
# df_melted

# %% [markdown]
# ## Testing in the example of education `example_education`

# %%
print(example_education['SubTopic2'].notna().any())
print(example_education['SubTopic3'].notna().any())
# Out:
# False
# False

# %% [markdown]
# # This is the main function we will be using to assign the subtopics

# %%
def extract_and_match(row, df2):

    parts = row['Code'].split('.')

    first_desc = df2.loc[df2['General subject'] == parts[1], 'General subject description'].values
    second_desc = df2.loc[df2['Specific subject'] == parts[2], 'Specific subject description'].values

    first_desc = first_desc[0] if first_desc.size > 0 else None
    second_desc = second_desc[0] if second_desc.size > 0 else None

    # Check if there are existing values in SubTopic2 and SubTopic3
    if pd.notna(row['SubTopic2']):
        # If the new description is different, store both using list 
        if row['SubTopic2'] != first_desc:
            row['SubTopic2'] = [row['SubTopic2'], first_desc]
    else:

        row['SubTopic2'] = first_desc

    if pd.notna(row['SubTopic3']):

        if row['SubTopic3'] != second_desc:
            row['SubTopic3'] = [row['SubTopic3'], second_desc]
    else:
        # If SubTopic3 is empty  assign the value
        row['SubTopic3'] = second_desc

    return row

# %%
example_education = example_education.apply(extract_and_match, axis=1, df2=wdi_codes)

# %%
example_education
# Out:
#                   Code                                     Indicator Name  \
# 0       SE.PRM.PRS5.ZS        Persistence to grade 5, total (% of cohort)
# 1       SE.PRM.GINT.ZS  Gross intake ratio in first grade of primary e...
# 2       SE.PRM.NINT.ZS  Net intake rate in grade 1 (% of official scho...
# 3    SE.PRM.OENR.MA.ZS  Over-age students, primary, male (% of male en...
# 4    SE.PRM.PRS5.MA.ZS         Persistence to grade 5, male (% of cohort)
# ..                 ...                                                ...
# 151  SE.ENR.PRIM.FM.ZS  School enrollment, primary (gross), gender par...
# 152        SE.PRM.NENR                 School enrollment, primary (% net)
# 153     SE.PRE.ENRR.MA      School enrollment, preprimary, male (% gross)
# 154     SE.PRM.PRIV.ZS  School enrollment, primary, private (% of tota...
# 155  SE.ENR.TERT.FM.ZS  School enrollment, tertiary (gross), gender pa...
#
#                 General Topic      Topic      SubTopic1             SubTopic2  \
# 0       Education: Efficiency  Education     Efficiency     Primary education
# 1       Education: Efficiency  Education     Efficiency     Primary education
# 2       Education: Efficiency  Education     Efficiency     Primary education
# 3       Education: Efficiency  Education     Efficiency     Primary education
# 4       Education: Efficiency  Education     Efficiency     Primary education
# ..                        ...        ...            ...                   ...
# 151  Education: Participation  Education  Participation            Enrollment
# 152  Education: Participation  Education  Participation     Primary education
# 153  Education: Participation  Education  Participation  Preprimary education
# 154  Education: Participation  Education  Participation     Primary education
# 155  Education: Participation  Education  Participation            Enrollment
#
#                   SubTopic3        code3
# 0    Persistence to grade 5  SE.PRM.PRS5
# 1              Gross intake  SE.PRM.GINT
# 2                Net intake  SE.PRM.NINT
# 3       Over-age enrollment  SE.PRM.OENR
# 4    Persistence to grade 5  SE.PRM.PRS5
# ..                      ...          ...
# 151       Primary education  SE.ENR.PRIM
# 152          Net enrollment  SE.PRM.NENR
# 153          Enrolment rate  SE.PRE.ENRR
# 154                 Private  SE.PRM.PRIV
# 155      Tertiary education  SE.ENR.TERT
#
# [156 rows x 8 columns]

# %%
summary(example_education).style.background_gradient(cmap='Blues')
# Out:
# data shape: (156, 8)
# <style type="text/css">
# #T_8d134_row0_col1, #T_8d134_row0_col2, #T_8d134_row1_col1, #T_8d134_row1_col2, #T_8d134_row2_col1, #T_8d134_row2_col2, #T_8d134_row3_col1, #T_8d134_row3_col2, #T_8d134_row3_col3, #T_8d134_row4_col1, #T_8d134_row4_col2, #T_8d134_row6_col1, #T_8d134_row6_col2, #T_8d134_row7_col1, #T_8d134_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8d134_row0_col3, #T_8d134_row1_col3, #T_8d134_row5_col1, #T_8d134_row5_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8d134_row2_col3, #T_8d134_row4_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_8d134_row5_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_8d134_row6_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_8d134_row7_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# </style>
# <table id="T_8d134">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d134_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_8d134_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_8d134_level0_col2" class="col_heading level0 col2" >%missing</th>
#       <th id="T_8d134_level0_col3" class="col_heading level0 col3" >#unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d134_level0_row0" class="row_heading level0 row0" >Code</th>
#       <td id="T_8d134_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_8d134_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_8d134_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_8d134_row0_col3" class="data row0 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_8d134_level0_row1" class="row_heading level0 row1" >Indicator Name</th>
#       <td id="T_8d134_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_8d134_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_8d134_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_8d134_row1_col3" class="data row1 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_8d134_level0_row2" class="row_heading level0 row2" >General Topic</th>
#       <td id="T_8d134_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_8d134_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_8d134_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_8d134_row2_col3" class="data row2 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8d134_level0_row3" class="row_heading level0 row3" >Topic</th>
#       <td id="T_8d134_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_8d134_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_8d134_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_8d134_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8d134_level0_row4" class="row_heading level0 row4" >SubTopic1</th>
#       <td id="T_8d134_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_8d134_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_8d134_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_8d134_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8d134_level0_row5" class="row_heading level0 row5" >SubTopic2</th>
#       <td id="T_8d134_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_8d134_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_8d134_row5_col2" class="data row5 col2" >0.057692</td>
#       <td id="T_8d134_row5_col3" class="data row5 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_8d134_level0_row6" class="row_heading level0 row6" >SubTopic3</th>
#       <td id="T_8d134_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_8d134_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_8d134_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_8d134_row6_col3" class="data row6 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_8d134_level0_row7" class="row_heading level0 row7" >code3</th>
#       <td id="T_8d134_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_8d134_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_8d134_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_8d134_row7_col3" class="data row7 col3" >54</td>
#     </tr>
#   </tbody>
# </table>

# %%
with pd.option_context('display.max_colwidth', 200):

    display(example_education[example_education['SubTopic2'].isna()])
# Out:
#                   Code  \
# 75      SE.LPV.PRIM.SD
# 89      SE.LPV.PRIM.LD
# 94      SE.LPV.PRIM.MA
# 95      SE.LPV.PRIM.FE
# 101        SE.LPV.PRIM
# 104  SE.LPV.PRIM.LD.FE
# 105  SE.LPV.PRIM.SD.FE
# 106  SE.LPV.PRIM.SD.MA
# 109  SE.LPV.PRIM.LD.MA
#
#                                                                                                                                     Indicator Name  \
# 75                                                                                                   Primary school age children out-of-school (%)
# 89                                                              Pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 94     Learning poverty: Share of Male Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 95   Learning poverty: Share of Female Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 101         Learning poverty: Share of Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 104                                                      Female pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 105                                                                                           Female primary school age children out-of-school (%)
# 106                                                                                             Male primary school age children out-of-school (%)
# 109                                                        Male pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
#
#            General Topic      Topic SubTopic1 SubTopic2          SubTopic3  \
# 75   Education: Outcomes  Education  Outcomes      None  Primary education
# 89   Education: Outcomes  Education  Outcomes      None  Primary education
# 94   Education: Outcomes  Education  Outcomes      None  Primary education
# 95   Education: Outcomes  Education  Outcomes      None  Primary education
# 101  Education: Outcomes  Education  Outcomes      None  Primary education
# 104  Education: Outcomes  Education  Outcomes      None  Primary education
# 105  Education: Outcomes  Education  Outcomes      None  Primary education
# 106  Education: Outcomes  Education  Outcomes      None  Primary education
# 109  Education: Outcomes  Education  Outcomes      None  Primary education
#
#            code3
# 75   SE.LPV.PRIM
# 89   SE.LPV.PRIM
# 94   SE.LPV.PRIM
# 95   SE.LPV.PRIM
# 101  SE.LPV.PRIM
# 104  SE.LPV.PRIM
# 105  SE.LPV.PRIM
# 106  SE.LPV.PRIM
# 109  SE.LPV.PRIM

# %%
example_education['SubTopic2'] = example_education['SubTopic2'].fillna('Low Poverty Vulnerability')
summary(example_education).style.background_gradient(cmap='Blues')
# Out:
# data shape: (156, 8)
# <style type="text/css">
# #T_350f2_row0_col1, #T_350f2_row0_col2, #T_350f2_row1_col1, #T_350f2_row1_col2, #T_350f2_row2_col1, #T_350f2_row2_col2, #T_350f2_row3_col1, #T_350f2_row3_col2, #T_350f2_row3_col3, #T_350f2_row4_col1, #T_350f2_row4_col2, #T_350f2_row5_col1, #T_350f2_row5_col2, #T_350f2_row6_col1, #T_350f2_row6_col2, #T_350f2_row7_col1, #T_350f2_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_350f2_row0_col3, #T_350f2_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_350f2_row2_col3, #T_350f2_row4_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_350f2_row5_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_350f2_row6_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_350f2_row7_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# </style>
# <table id="T_350f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_350f2_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_350f2_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_350f2_level0_col2" class="col_heading level0 col2" >%missing</th>
#       <th id="T_350f2_level0_col3" class="col_heading level0 col3" >#unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_350f2_level0_row0" class="row_heading level0 row0" >Code</th>
#       <td id="T_350f2_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_350f2_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_350f2_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_350f2_row0_col3" class="data row0 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_350f2_level0_row1" class="row_heading level0 row1" >Indicator Name</th>
#       <td id="T_350f2_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_350f2_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_350f2_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_350f2_row1_col3" class="data row1 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_350f2_level0_row2" class="row_heading level0 row2" >General Topic</th>
#       <td id="T_350f2_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_350f2_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_350f2_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_350f2_row2_col3" class="data row2 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_350f2_level0_row3" class="row_heading level0 row3" >Topic</th>
#       <td id="T_350f2_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_350f2_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_350f2_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_350f2_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_350f2_level0_row4" class="row_heading level0 row4" >SubTopic1</th>
#       <td id="T_350f2_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_350f2_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_350f2_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_350f2_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_350f2_level0_row5" class="row_heading level0 row5" >SubTopic2</th>
#       <td id="T_350f2_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_350f2_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_350f2_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_350f2_row5_col3" class="data row5 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_350f2_level0_row6" class="row_heading level0 row6" >SubTopic3</th>
#       <td id="T_350f2_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_350f2_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_350f2_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_350f2_row6_col3" class="data row6 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_350f2_level0_row7" class="row_heading level0 row7" >code3</th>
#       <td id="T_350f2_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_350f2_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_350f2_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_350f2_row7_col3" class="data row7 col3" >54</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## In this example
# As we can see, we were able to extend the granularity and hierarchy of the education metadata.
#
# There are missing values for subtopic1, and after further research, we can impute these with the value **LPV = 'Low Poverty Vulnerability'**.
#
# For now, this will be done manually for each sheet.
