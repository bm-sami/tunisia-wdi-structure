# %%
import numpy as np 
import pandas as pd
import re

# %%
def clean_text(text):
    if isinstance(text, str): 
        return re.sub(r'\s+', ' ', text).strip()
    return text

# %%
def summary(df):
    print(f'data shape: {df.shape}')  
    summ = pd.DataFrame(df.dtypes, columns=['data type'])
    summ['#missing'] = df.isnull().sum().values 
    summ['%missing'] = df.isnull().sum().values / len(df)
    summ['#unique'] = df.nunique().values
    desc = pd.DataFrame(df.describe(include='all').transpose())
#     summ['min'] = desc['min'].values
#     summ['max'] = desc['max'].values
    return summ

# %%
def select_second_item(value):
    if isinstance(value, list) and len(value) > 1:
        return value[1]  
    return value 

def select_first_item(value):
    if isinstance(value, list) and len(value) > 1:
        return value[0]  
    return value

# %%
file_path = '../data/hierarchy/hierarchy_topic_by_sheet.xlsx' 
xls = pd.ExcelFile(file_path)


dfs = {}

for sheet_name in xls.sheet_names:
    first_word = sheet_name.split()[0].lower() 
    df = pd.read_excel(xls, sheet_name=sheet_name)  
    dfs[first_word] = df  


for name, df in dfs.items():
    print(f"{name}")
# Out:
# economic
# education
# environment
# financial
# gender
# health
# infrastructure
# poverty
# private
# public
# social
# trade

# %%
dfs['education']
# Out:
#                   Code                                     Indicator Name  \
# 0       SE.PRM.OENR.ZS       Over-age students, primary (% of enrollment)
# 1    SE.PRM.OENR.FE.ZS  Over-age students, primary, female (% of femal...
# 2    SE.PRM.OENR.MA.ZS  Over-age students, primary, male (% of male en...
# 3    SE.PRM.REPT.FE.ZS  Repeaters, primary, female (% of female enroll...
# 4    SE.PRM.REPT.MA.ZS    Repeaters, primary, male (% of male enrollment)
# ..                 ...                                                ...
# 151     SE.PRM.TENR.FE  Adjusted net enrollment rate, primary, female ...
# 152        SE.PRM.ENRR               School enrollment, primary (% gross)
# 153        SE.SEC.ENRR             School enrollment, secondary (% gross)
# 154        SE.TER.ENRR              School enrollment, tertiary (% gross)
# 155  SE.ENR.TERT.FM.ZS  School enrollment, tertiary (gross), gender pa...
#
#                 General Topic      Topic      SubTopic1  SubTopic2  SubTopic3
# 0       Education: Efficiency  Education     Efficiency        NaN        NaN
# 1       Education: Efficiency  Education     Efficiency        NaN        NaN
# 2       Education: Efficiency  Education     Efficiency        NaN        NaN
# 3       Education: Efficiency  Education     Efficiency        NaN        NaN
# 4       Education: Efficiency  Education     Efficiency        NaN        NaN
# ..                        ...        ...            ...        ...        ...
# 151  Education: Participation  Education  Participation        NaN        NaN
# 152  Education: Participation  Education  Participation        NaN        NaN
# 153  Education: Participation  Education  Participation        NaN        NaN
# 154  Education: Participation  Education  Participation        NaN        NaN
# 155  Education: Participation  Education  Participation        NaN        NaN
#
# [156 rows x 7 columns]

# %%
example_education = dfs['education'].copy()

# %%
example_education['code3'] = example_education['Code'].str.split('.').str[:3].str.join('.')

# %%
grouped_counts = example_education['code3'].value_counts()
grouped_counts.head()
# Out:
# code3
# SE.TER.CUAT    12
# SE.SEC.CUAT     9
# SE.LPV.PRIM     9
# SE.SEC.TCAQ     9
# SE.SEC.ENRL     9
# Name: count, dtype: int64

# %%
with pd.option_context('display.max_colwidth', 200):

    display(example_education[example_education['code3'] == 'SE.TER.CUAT'])
# Out:
#                      Code  \
# 83   SE.TER.CUAT.ST.FE.ZS
# 84   SE.TER.CUAT.ST.MA.ZS
# 85      SE.TER.CUAT.ST.ZS
# 88   SE.TER.CUAT.MS.FE.ZS
# 89   SE.TER.CUAT.MS.MA.ZS
# 90      SE.TER.CUAT.MS.ZS
# 91   SE.TER.CUAT.DO.FE.ZS
# 92   SE.TER.CUAT.DO.MA.ZS
# 94      SE.TER.CUAT.DO.ZS
# 96      SE.TER.CUAT.BA.ZS
# 102  SE.TER.CUAT.BA.FE.ZS
# 103  SE.TER.CUAT.BA.MA.ZS
#
#                                                                                                Indicator Name  \
# 83   Educational attainment, at least completed short-cycle tertiary, population 25+, female (%) (cumulative)
# 84     Educational attainment, at least completed short-cycle tertiary, population 25+, male (%) (cumulative)
# 85    Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)
# 88           Educational attainment, at least Master's or equivalent, population 25+, female (%) (cumulative)
# 89             Educational attainment, at least Master's or equivalent, population 25+, male (%) (cumulative)
# 90            Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)
# 91                    Educational attainment, Doctoral or equivalent, population 25+, female (%) (cumulative)
# 92                      Educational attainment, Doctoral or equivalent, population 25+, male (%) (cumulative)
# 94                     Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)
# 96          Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)
# 102        Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)
# 103          Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)
#
#            General Topic      Topic SubTopic1  SubTopic2  SubTopic3  \
# 83   Education: Outcomes  Education  Outcomes        NaN        NaN
# 84   Education: Outcomes  Education  Outcomes        NaN        NaN
# 85   Education: Outcomes  Education  Outcomes        NaN        NaN
# 88   Education: Outcomes  Education  Outcomes        NaN        NaN
# 89   Education: Outcomes  Education  Outcomes        NaN        NaN
# 90   Education: Outcomes  Education  Outcomes        NaN        NaN
# 91   Education: Outcomes  Education  Outcomes        NaN        NaN
# 92   Education: Outcomes  Education  Outcomes        NaN        NaN
# 94   Education: Outcomes  Education  Outcomes        NaN        NaN
# 96   Education: Outcomes  Education  Outcomes        NaN        NaN
# 102  Education: Outcomes  Education  Outcomes        NaN        NaN
# 103  Education: Outcomes  Education  Outcomes        NaN        NaN
#
#            code3
# 83   SE.TER.CUAT
# 84   SE.TER.CUAT
# 85   SE.TER.CUAT
# 88   SE.TER.CUAT
# 89   SE.TER.CUAT
# 90   SE.TER.CUAT
# 91   SE.TER.CUAT
# 92   SE.TER.CUAT
# 94   SE.TER.CUAT
# 96   SE.TER.CUAT
# 102  SE.TER.CUAT
# 103  SE.TER.CUAT

# %% [markdown]
# In this eample of education outcomes, we observe that indicator codes beginning with **SE.TER.CUAT** can be further subdivided to populate relevant subtopics.
#
# To achieve this, we will:
# 1. **Read the WDI Indicators file** to examine the full list of codes and their corresponding descriptions.
# 2. **Identify patterns** within the codes that allow for classification into subtopics.
# 3. **Extract meaningful subtopic information** from the code structure and descriptions.
#
# By implementing this approach, we aim to enhance the granularity of our dataset and improve analytical insights into education outcomes.

# %%
wdi_codes = pd.read_excel('../data/WDI_Indicators.xlsx', sheet_name="Coding")

# %%
wdi_codes
# Out:
#      Topic                                Topic description General subject  \
# 0       AG                                      Agriculture             ACS
# 1       BG                       Balance of payments: gross             ADJ
# 2       BM  Balance of payments: imports, payments (credit)             ADM
# 3       BN                         Balance of payments: net             ADO
# 4       BX   Balance of payments: exports, receipts (debit)             ADT
# ...    ...                                              ...             ...
# 1057   NaN                                              NaN             NaN
# 1058   NaN                                              NaN             NaN
# 1059   NaN                                              NaN             NaN
# 1060   NaN                                              NaN             NaN
# 1061   NaN                                              NaN             NaN
#
#      General subject description Specific subject  \
# 0                         Access             0003
# 1               Adjusted savings             0004
# 2                      Admission             0014
# 3                     Adolescent             0324
# 4                          Adult             0306
# ...                          ...              ...
# 1057                         NaN             XOKA
# 1058                         NaN             XPND
# 1059                         NaN             XPRT
# 1060                         NaN             XTHR
# 1061                         NaN             YPKG
#
#               Specific subject description Extensions Extensions description
# 0                                  Age 0-3         05             2005 (PPP)
# 1                                  Age 0-4         10                 Decile
# 2                                 Age 0-14         14               Age 0-14
# 3                                 Age 0-24         20               Quintile
# 4                                  Age 3-6         90   % changes since 1990
# ...                                    ...        ...                    ...
# 1057  Excluding official capital transfers        NaN                    NaN
# 1058                           Expenditure        NaN                    NaN
# 1059                               Exports        NaN                    NaN
# 1060            Other manufactures (trade)        NaN                    NaN
# 1061     Income, profits and capital gains        NaN                    NaN
#
# [1062 rows x 8 columns]

# %% [markdown]
# ### Understanding the Code Structure using `wdi_codes`
#
# Based on our analysis, we have identified a general pattern in the structure of the codes formatted as **XX.XX.XX...**. While this does not apply to all cases, the common breakdown is as follows:
#
# 1. **Topic Column**: Corresponds to the `Topic` and `SubTopic1` of the dataset as the values for that column are **name : name**.
# 2. **General subject Column**: Represents the `SubTopic2`.
# 3. **Specific subject Column**: Defines the `SubTopic3`.
# 4. **Extension (the rest)**: Any additional components following the third part can be considered as **Extensions**, which provide further granularity or variations within the specific subject. Note we dont have a column for taht yet and we will find a way to add informations of extension if they are important to our work
#
# By leveraging this structure, we can systematically extract hierarchical information from the codes and use it for improved classification and mapping in our analysis.

# %% [markdown]
# We will delete the topic and topic description as we already has the topic metadata filled

# %%
wdi_codes.drop(columns=['Topic', 'Topic description'], inplace=True)
wdi_codes.head()
# Out:
#   General subject General subject description Specific subject  \
# 0             ACS                      Access             0003
# 1             ADJ            Adjusted savings             0004
# 2             ADM                   Admission             0014
# 3             ADO                  Adolescent             0324
# 4             ADT                       Adult             0306
#
#   Specific subject description Extensions Extensions description
# 0                      Age 0-3         05             2005 (PPP)
# 1                      Age 0-4         10                 Decile
# 2                     Age 0-14         14               Age 0-14
# 3                     Age 0-24         20               Quintile
# 4                      Age 3-6         90   % changes since 1990

# %%
for col in ['General subject', 'Specific subject', 'Extensions']:
    redundant = wdi_codes[col].dropna()[wdi_codes[col].dropna().duplicated()]
    if not redundant.empty:
        print(f"Redundant values in column '{col}':")
        print(redundant)
    else:
        print(f"No redundant values in column '{col}'.")
# Out:
# No redundant values in column 'General subject'.
# No redundant values in column 'Specific subject'.
# No redundant values in column 'Extensions'.

# %%
import pandas as pd

wdi_codes['has_match'] = wdi_codes.apply(
    lambda row: (
        (pd.notna(row['General subject']) and row['General subject'] in [row['Specific subject'], row['Extensions']]) or
        (pd.notna(row['Specific subject']) and row['Specific subject'] in [row['General subject'], row['Extensions']]) or
        (pd.notna(row['Extensions']) and row['Extensions'] in [row['General subject'], row['Specific subject']])
    ), axis=1
)

matching_rows = wdi_codes[wdi_codes['has_match']]
print("Rows with matching values between columns:")
print(matching_rows[['General subject', 'Specific subject', 'Extensions']])


wdi_codes.drop(columns=['has_match'], inplace=True)
# Out:
# Rows with matching values between columns:
# Empty DataFrame
# Columns: [General subject, Specific subject, Extensions]
# Index: []

# %%
# df_melted = pd.melt(wdi_codes, 
#                     value_vars=['General subject', 'Specific subject', 'Extensions'], 
#                     var_name='Key_Type', value_name='Key')

# df_melted['Value'] = pd.melt(wdi_codes, 
#                              value_vars=['General subject description', 'Specific subject description', 'Extensions description'], 
#                              var_name='Value_Type', value_name='Value')['Value']

# df_melted.dropna(subset=['Key', 'Value'], how='any', inplace=True)

# %%
# df_melted

# %% [markdown]
# ## Testing in the example of education `example_education`

# %%
print(example_education['SubTopic2'].notna().any())
print(example_education['SubTopic3'].notna().any())
# Out:
# False
# False

# %% [markdown]
# # This is the main function we will be using to assign the subtopics

# %%
def extract_and_match(row, df2):

    parts = row['Code'].split('.')
    if len(parts) < 3:
        first_desc, second_desc = None, None
    else:
        first_desc = df2.loc[df2['General subject'] == parts[1], 'General subject description'].values
        second_desc = df2.loc[df2['Specific subject'] == parts[2], 'Specific subject description'].values

        first_desc = first_desc[0] if first_desc.size > 0 else None
        second_desc = second_desc[0] if second_desc.size > 0 else None


    if pd.notna(row['SubTopic2']):


        if first_desc != None and row['SubTopic2'] != first_desc: 

            row['SubTopic2'] = [row['SubTopic2'], first_desc]            
    else:

        row['SubTopic2'] = first_desc

    if pd.notna(row['SubTopic3']):

        if row['SubTopic3'] != second_desc:
            row['SubTopic3'] = [row['SubTopic3'], second_desc]
    else:

        row['SubTopic3'] = second_desc

    return row

# %%
example_education = example_education.apply(extract_and_match, axis=1, df2=wdi_codes)

# %%
example_education
# Out:
#                   Code                                     Indicator Name  \
# 0       SE.PRM.OENR.ZS       Over-age students, primary (% of enrollment)
# 1    SE.PRM.OENR.FE.ZS  Over-age students, primary, female (% of femal...
# 2    SE.PRM.OENR.MA.ZS  Over-age students, primary, male (% of male en...
# 3    SE.PRM.REPT.FE.ZS  Repeaters, primary, female (% of female enroll...
# 4    SE.PRM.REPT.MA.ZS    Repeaters, primary, male (% of male enrollment)
# ..                 ...                                                ...
# 151     SE.PRM.TENR.FE  Adjusted net enrollment rate, primary, female ...
# 152        SE.PRM.ENRR               School enrollment, primary (% gross)
# 153        SE.SEC.ENRR             School enrollment, secondary (% gross)
# 154        SE.TER.ENRR              School enrollment, tertiary (% gross)
# 155  SE.ENR.TERT.FM.ZS  School enrollment, tertiary (gross), gender pa...
#
#                 General Topic      Topic      SubTopic1            SubTopic2  \
# 0       Education: Efficiency  Education     Efficiency    Primary education
# 1       Education: Efficiency  Education     Efficiency    Primary education
# 2       Education: Efficiency  Education     Efficiency    Primary education
# 3       Education: Efficiency  Education     Efficiency    Primary education
# 4       Education: Efficiency  Education     Efficiency    Primary education
# ..                        ...        ...            ...                  ...
# 151  Education: Participation  Education  Participation    Primary education
# 152  Education: Participation  Education  Participation    Primary education
# 153  Education: Participation  Education  Participation  Secondary education
# 154  Education: Participation  Education  Participation             Tertiary
# 155  Education: Participation  Education  Participation           Enrollment
#
#                SubTopic3        code3
# 0    Over-age enrollment  SE.PRM.OENR
# 1    Over-age enrollment  SE.PRM.OENR
# 2    Over-age enrollment  SE.PRM.OENR
# 3              Repeaters  SE.PRM.REPT
# 4              Repeaters  SE.PRM.REPT
# ..                   ...          ...
# 151     Total enrollment  SE.PRM.TENR
# 152       Enrolment rate  SE.PRM.ENRR
# 153       Enrolment rate  SE.SEC.ENRR
# 154       Enrolment rate  SE.TER.ENRR
# 155   Tertiary education  SE.ENR.TERT
#
# [156 rows x 8 columns]

# %%
summary(example_education).style.background_gradient(cmap='Blues')
# Out:
# data shape: (156, 8)
# <style type="text/css">
# #T_3d4bd_row0_col1, #T_3d4bd_row0_col2, #T_3d4bd_row1_col1, #T_3d4bd_row1_col2, #T_3d4bd_row2_col1, #T_3d4bd_row2_col2, #T_3d4bd_row3_col1, #T_3d4bd_row3_col2, #T_3d4bd_row3_col3, #T_3d4bd_row4_col1, #T_3d4bd_row4_col2, #T_3d4bd_row6_col1, #T_3d4bd_row6_col2, #T_3d4bd_row7_col1, #T_3d4bd_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3d4bd_row0_col3, #T_3d4bd_row1_col3, #T_3d4bd_row5_col1, #T_3d4bd_row5_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3d4bd_row2_col3, #T_3d4bd_row4_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_3d4bd_row5_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_3d4bd_row6_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_3d4bd_row7_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# </style>
# <table id="T_3d4bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d4bd_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_3d4bd_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_3d4bd_level0_col2" class="col_heading level0 col2" >%missing</th>
#       <th id="T_3d4bd_level0_col3" class="col_heading level0 col3" >#unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d4bd_level0_row0" class="row_heading level0 row0" >Code</th>
#       <td id="T_3d4bd_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_3d4bd_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_3d4bd_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_3d4bd_row0_col3" class="data row0 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_3d4bd_level0_row1" class="row_heading level0 row1" >Indicator Name</th>
#       <td id="T_3d4bd_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_3d4bd_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_3d4bd_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_3d4bd_row1_col3" class="data row1 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_3d4bd_level0_row2" class="row_heading level0 row2" >General Topic</th>
#       <td id="T_3d4bd_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_3d4bd_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_3d4bd_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_3d4bd_row2_col3" class="data row2 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_3d4bd_level0_row3" class="row_heading level0 row3" >Topic</th>
#       <td id="T_3d4bd_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_3d4bd_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_3d4bd_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_3d4bd_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3d4bd_level0_row4" class="row_heading level0 row4" >SubTopic1</th>
#       <td id="T_3d4bd_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_3d4bd_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_3d4bd_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_3d4bd_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_3d4bd_level0_row5" class="row_heading level0 row5" >SubTopic2</th>
#       <td id="T_3d4bd_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_3d4bd_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_3d4bd_row5_col2" class="data row5 col2" >0.057692</td>
#       <td id="T_3d4bd_row5_col3" class="data row5 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_3d4bd_level0_row6" class="row_heading level0 row6" >SubTopic3</th>
#       <td id="T_3d4bd_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_3d4bd_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_3d4bd_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_3d4bd_row6_col3" class="data row6 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_3d4bd_level0_row7" class="row_heading level0 row7" >code3</th>
#       <td id="T_3d4bd_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_3d4bd_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_3d4bd_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_3d4bd_row7_col3" class="data row7 col3" >54</td>
#     </tr>
#   </tbody>
# </table>

# %%
with pd.option_context('display.max_colwidth', 200):

    display(example_education[example_education['SubTopic2'].isna()])
# Out:
#                   Code  \
# 68      SE.LPV.PRIM.MA
# 69      SE.LPV.PRIM.FE
# 71         SE.LPV.PRIM
# 73   SE.LPV.PRIM.LD.FE
# 74   SE.LPV.PRIM.SD.FE
# 76      SE.LPV.PRIM.LD
# 97      SE.LPV.PRIM.SD
# 106  SE.LPV.PRIM.LD.MA
# 107  SE.LPV.PRIM.SD.MA
#
#                                                                                                                                     Indicator Name  \
# 68     Learning poverty: Share of Male Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 69   Learning poverty: Share of Female Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 71          Learning poverty: Share of Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 73                                                       Female pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 74                                                                                            Female primary school age children out-of-school (%)
# 76                                                              Pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 97                                                                                                   Primary school age children out-of-school (%)
# 106                                                        Male pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 107                                                                                             Male primary school age children out-of-school (%)
#
#            General Topic      Topic SubTopic1 SubTopic2          SubTopic3  \
# 68   Education: Outcomes  Education  Outcomes      None  Primary education
# 69   Education: Outcomes  Education  Outcomes      None  Primary education
# 71   Education: Outcomes  Education  Outcomes      None  Primary education
# 73   Education: Outcomes  Education  Outcomes      None  Primary education
# 74   Education: Outcomes  Education  Outcomes      None  Primary education
# 76   Education: Outcomes  Education  Outcomes      None  Primary education
# 97   Education: Outcomes  Education  Outcomes      None  Primary education
# 106  Education: Outcomes  Education  Outcomes      None  Primary education
# 107  Education: Outcomes  Education  Outcomes      None  Primary education
#
#            code3
# 68   SE.LPV.PRIM
# 69   SE.LPV.PRIM
# 71   SE.LPV.PRIM
# 73   SE.LPV.PRIM
# 74   SE.LPV.PRIM
# 76   SE.LPV.PRIM
# 97   SE.LPV.PRIM
# 106  SE.LPV.PRIM
# 107  SE.LPV.PRIM

# %%
example_education['SubTopic2'] = example_education['SubTopic2'].fillna('Low Poverty Vulnerability')
summary(example_education).style.background_gradient(cmap='Blues')
# Out:
# data shape: (156, 8)
# <style type="text/css">
# #T_2f728_row0_col1, #T_2f728_row0_col2, #T_2f728_row1_col1, #T_2f728_row1_col2, #T_2f728_row2_col1, #T_2f728_row2_col2, #T_2f728_row3_col1, #T_2f728_row3_col2, #T_2f728_row3_col3, #T_2f728_row4_col1, #T_2f728_row4_col2, #T_2f728_row5_col1, #T_2f728_row5_col2, #T_2f728_row6_col1, #T_2f728_row6_col2, #T_2f728_row7_col1, #T_2f728_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2f728_row0_col3, #T_2f728_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2f728_row2_col3, #T_2f728_row4_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_2f728_row5_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_2f728_row6_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_2f728_row7_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# </style>
# <table id="T_2f728">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f728_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_2f728_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_2f728_level0_col2" class="col_heading level0 col2" >%missing</th>
#       <th id="T_2f728_level0_col3" class="col_heading level0 col3" >#unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f728_level0_row0" class="row_heading level0 row0" >Code</th>
#       <td id="T_2f728_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_2f728_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_2f728_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_2f728_row0_col3" class="data row0 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_2f728_level0_row1" class="row_heading level0 row1" >Indicator Name</th>
#       <td id="T_2f728_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_2f728_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_2f728_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_2f728_row1_col3" class="data row1 col3" >156</td>
#     </tr>
#     <tr>
#       <th id="T_2f728_level0_row2" class="row_heading level0 row2" >General Topic</th>
#       <td id="T_2f728_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_2f728_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_2f728_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_2f728_row2_col3" class="data row2 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2f728_level0_row3" class="row_heading level0 row3" >Topic</th>
#       <td id="T_2f728_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_2f728_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_2f728_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_2f728_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2f728_level0_row4" class="row_heading level0 row4" >SubTopic1</th>
#       <td id="T_2f728_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_2f728_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_2f728_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_2f728_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2f728_level0_row5" class="row_heading level0 row5" >SubTopic2</th>
#       <td id="T_2f728_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_2f728_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_2f728_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_2f728_row5_col3" class="data row5 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_2f728_level0_row6" class="row_heading level0 row6" >SubTopic3</th>
#       <td id="T_2f728_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_2f728_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_2f728_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_2f728_row6_col3" class="data row6 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_2f728_level0_row7" class="row_heading level0 row7" >code3</th>
#       <td id="T_2f728_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_2f728_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_2f728_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_2f728_row7_col3" class="data row7 col3" >54</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## In this example
# As we can see, we were able to extend the granularity and hierarchy of the education metadata.
#
# There are missing values for subtopic1, and after further research, we can impute these with the value **LPV = 'Low Poverty Vulnerability'**.
#
# For now, this will be done manually for each sheet.

# %% [markdown]
# ## We apply our function to the entire df

# %%
for key, df in dfs.items():

    df = df.apply(extract_and_match, axis=1, df2=wdi_codes)  
    dfs[key] = df

# %%
for key, df in dfs.items():

    missing_subtopic2 = df['SubTopic2'].isnull().sum()
    missing_subtopic3 = df['SubTopic3'].isnull().sum()
    

    print(f"\n{'*' * 10} {key} {'*' * 10}")
    print(f"Missing subtopic2: {missing_subtopic2}")
    print(f"Missing subtopic3: {missing_subtopic3}")
    print("-" * 40)
# Out:
# ********** economic **********
# Missing subtopic2: 0
# Missing subtopic3: 15
# ----------------------------------------
#
# ********** education **********
# Missing subtopic2: 9
# Missing subtopic3: 0
# ----------------------------------------
#
# ********** environment **********
# Missing subtopic2: 43
# Missing subtopic3: 44
# ----------------------------------------
#
# ********** financial **********
# Missing subtopic2: 0
# Missing subtopic3: 0
# ----------------------------------------
#
# ********** gender **********
# Missing subtopic2: 1
# Missing subtopic3: 2
# ----------------------------------------
#
# ********** health **********
# Missing subtopic2: 12
# Missing subtopic3: 45
# ----------------------------------------
#
# ********** infrastructure **********
# Missing subtopic2: 0
# Missing subtopic3: 0
# ----------------------------------------
#
# ********** poverty **********
# Missing subtopic2: 0
# Missing subtopic3: 9
# ----------------------------------------
#
# ********** private **********
# Missing subtopic2: 6
# Missing subtopic3: 1
# ----------------------------------------
#
# ********** public **********
# Missing subtopic2: 51
# Missing subtopic3: 42
# ----------------------------------------
#
# ********** social **********
# Missing subtopic2: 27
# Missing subtopic3: 27
# ----------------------------------------
#
# ********** trade **********
# Missing subtopic2: 0
# Missing subtopic3: 0
# ----------------------------------------

# %% [markdown]
# ## Another porblem when looking into the code description in wdi idnicators data there is some code parts that can describe both things as PO : Post (or plus other)
#
# ### This will cause a problem as the some subtiopics will have 2 descriptions seperated by (or)

# %%
#EXAMPLE FOR THE PROBLEM
with pd.option_context('display.max_colwidth', 200):
    display(dfs["economic"]["SubTopic2"][dfs["economic"]['SubTopic2'].str.contains(r'\(or', na=False)].iloc[0])
# Out:
# 'Consumption (or condom)'

# %% [markdown]
# ### For now i think the best way is to go throught each individually and handle missing and the different values in "list" subtopics (chatgpt + wdi documentation)

# %% [markdown]
# # Economic

# %%
economic = dfs["economic"]

# %% [markdown]
# **Notice we dont create a copy as we want the changes to reflect to dfs["economic"].**

# %%
with pd.option_context('display.max_colwidth', 200):

    display(economic[economic['SubTopic3'].isna()])
# Out:
#                  Code  \
# 284    DT.NFL.CERF.CD
# 303    DC.DAC.LTUL.CD
# 309    DC.DAC.HUNL.CD
# 315    DC.DAC.ESTL.CD
# 321    DT.NFL.SDGF.CD
# 322    DT.NFL.SPRP.CD
# 324    DT.NFL.UNCD.CD
# 325    DT.NFL.UNCV.CD
# 326  DT.NFL.UNCTAD.CD
# 329    DT.NFL.UNEP.CD
# 333    DT.NFL.UNID.CD
# 334   DT.NFL.UNIDO.CD
# 337    DT.NFL.UNWN.CD
# 338    DT.NFL.UNWT.CD
# 341    DT.NFL.WITC.CD
#
#                                                        Indicator Name  \
# 284           Net official flows from UN agencies, CERF (current US$)
# 303  Net bilateral aid flows from DAC donors, Lithuania (current US$)
# 309    Net bilateral aid flows from DAC donors, Hungary (current US$)
# 315    Net bilateral aid flows from DAC donors, Estonia (current US$)
# 321        Net official flows from UN agencies, SDGFUND (current US$)
# 322           Net official flows from UN agencies, SPRP (current US$)
# 324          Net official flows from UN agencies, UNCDF (current US$)
# 325        Net official flows from UN agencies, UNCOVID (current US$)
# 326         Net official flows from UN agencies, UNCTAD (current US$)
# 329           Net official flows from UN agencies, UNEP (current US$)
# 333         Net official flows from UN agencies, UNIDIR (current US$)
# 334          Net official flows from UN agencies, UNIDO (current US$)
# 337        Net official flows from UN agencies, UNWOMEN (current US$)
# 338          Net official flows from UN agencies, UNWTO (current US$)
# 341        Net official flows from UN agencies, WTO-ITC (current US$)
#
#                                                General Topic  \
# 284  Economic Policy & Debt: Official development assistance
# 303  Economic Policy & Debt: Official development assistance
# 309  Economic Policy & Debt: Official development assistance
# 315  Economic Policy & Debt: Official development assistance
# 321  Economic Policy & Debt: Official development assistance
# 322  Economic Policy & Debt: Official development assistance
# 324  Economic Policy & Debt: Official development assistance
# 325  Economic Policy & Debt: Official development assistance
# 326  Economic Policy & Debt: Official development assistance
# 329  Economic Policy & Debt: Official development assistance
# 333  Economic Policy & Debt: Official development assistance
# 334  Economic Policy & Debt: Official development assistance
# 337  Economic Policy & Debt: Official development assistance
# 338  Economic Policy & Debt: Official development assistance
# 341  Economic Policy & Debt: Official development assistance
#
#                       Topic                        SubTopic1  \
# 284  Economic Policy & Debt  Official development assistance
# 303  Economic Policy & Debt  Official development assistance
# 309  Economic Policy & Debt  Official development assistance
# 315  Economic Policy & Debt  Official development assistance
# 321  Economic Policy & Debt  Official development assistance
# 322  Economic Policy & Debt  Official development assistance
# 324  Economic Policy & Debt  Official development assistance
# 325  Economic Policy & Debt  Official development assistance
# 326  Economic Policy & Debt  Official development assistance
# 329  Economic Policy & Debt  Official development assistance
# 333  Economic Policy & Debt  Official development assistance
# 334  Economic Policy & Debt  Official development assistance
# 337  Economic Policy & Debt  Official development assistance
# 338  Economic Policy & Debt  Official development assistance
# 341  Economic Policy & Debt  Official development assistance
#
#                                    SubTopic2 SubTopic3
# 284                                Net flows      None
# 303  Development Assistance Committee (OECD)      None
# 309  Development Assistance Committee (OECD)      None
# 315  Development Assistance Committee (OECD)      None
# 321                                Net flows      None
# 322                                Net flows      None
# 324                                Net flows      None
# 325                                Net flows      None
# 326                                Net flows      None
# 329                                Net flows      None
# 333                                Net flows      None
# 334                                Net flows      None
# 337                                Net flows      None
# 338                                Net flows      None
# 341                                Net flows      None

# %%
economic_mapping = {
    "WITC": "World Integrated Trade Solution",
    "LTUL": "Long-Term Unemployment Level",
    "CERF": "Central Emergency Response Fund",
    "UNCTAD": "United Nations Conference on Trade and Development",
    "UNEP": "United Nations Environment Programme",
    "UNID": "United Nations Industrial Development Organization",
    "UNIDO": "United Nations Industrial Development Organization",
    "UNWN": "United Nations World Network (Unconfirmed)",
    "UNCV": "United Nations Convention",
    "SPRP": "Social Protection and Resilience Programs",
    "HUNL": "Hunger Levels (Unconfirmed)",
    "ESTL": "Estimated Labor Statistics",
    "SDGF": "Sustainable Development Goals Fund",
    "UNWT": "United Nations World Tourism Organization",
    "UNCD": "United Nations Conference on Disarmament"


}

economic.loc[economic["SubTopic3"].isna(), "SubTopic3"] = (
    economic["Code"].str.split(".").str[2].map(economic_mapping)
)

# %%
with pd.option_context('display.max_colwidth', 200):

    display(economic[economic['SubTopic3'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
def get_code_prefix(code):
    return ".".join(code.split(".")[:2])

filtered = economic[
    economic['SubTopic2'].apply(lambda x: isinstance(x, list)) | 
    economic['SubTopic3'].apply(lambda x: isinstance(x, list))
]

filtered = filtered.copy()
filtered.loc[:, "CodeGroup"] = filtered["Code"].apply(get_code_prefix)


grouped = filtered.groupby("CodeGroup")

# %%
group_keys = list(grouped.groups.keys())

index = 12  

selected_group_key = group_keys[index]
selected_group_df = grouped.get_group(selected_group_key)


with pd.option_context('display.max_colwidth', 200):

    display(selected_group_df)
# Out:
#               Code  \
# 16  BX.GSR.MRCH.CD
# 17  BX.GSR.TOTL.CD
# 18  BX.GSR.GNFS.CD
# 20  BX.GSR.FCTY.CD
# 22  BX.GSR.INSF.ZS
# 26  BX.GSR.NFSV.CD
# 28  BX.GSR.CMCP.ZS
# 30  BX.GSR.TRAN.ZS
# 32  BX.GSR.TRVL.ZS
# 34  BX.GSR.ROYL.CD
#
#                                                                Indicator Name  \
# 16                                           Goods exports (BoP, current US$)
# 17           Exports of goods, services and primary income (BoP, current US$)
# 18                           Exports of goods and services (BoP, current US$)
# 20                                 Primary income receipts (BoP, current US$)
# 22               Insurance and financial services (% of service exports, BoP)
# 26                                         Service exports (BoP, current US$)
# 28                 Communications, computer, etc. (% of service exports, BoP)
# 30                             Transport services (% of service exports, BoP)
# 32                                Travel services (% of service exports, BoP)
# 34  Charges for the use of intellectual property, receipts (BoP, current US$)
#
#                                                                              General Topic  \
# 16  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 17  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 18  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 20  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 22  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 26  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 28  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 30  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 32  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
# 34  Economic Policy & Debt: Balance of payments: Current account: Goods, services & income
#
#                      Topic            SubTopic1  \
# 16  Economic Policy & Debt  Balance of payments
# 17  Economic Policy & Debt  Balance of payments
# 18  Economic Policy & Debt  Balance of payments
# 20  Economic Policy & Debt  Balance of payments
# 22  Economic Policy & Debt  Balance of payments
# 26  Economic Policy & Debt  Balance of payments
# 28  Economic Policy & Debt  Balance of payments
# 30  Economic Policy & Debt  Balance of payments
# 32  Economic Policy & Debt  Balance of payments
# 34  Economic Policy & Debt  Balance of payments
#
#                                 SubTopic2  \
# 16  [Current account, Goods and services]
# 17  [Current account, Goods and services]
# 18  [Current account, Goods and services]
# 20  [Current account, Goods and services]
# 22  [Current account, Goods and services]
# 26  [Current account, Goods and services]
# 28  [Current account, Goods and services]
# 30  [Current account, Goods and services]
# 32  [Current account, Goods and services]
# 34  [Current account, Goods and services]
#
#                                                        SubTopic3 CodeGroup
# 16               [Goods, services & income, Goods (merchandise)]    BX.GSR
# 17                             [Goods, services & income, Total]    BX.GSR
# 18    [Goods, services & income, Goods and (nonfactor) services]    BX.GSR
# 20                     [Goods, services & income, Factor income]    BX.GSR
# 22  [Goods, services & income, Insurance and financial services]    BX.GSR
# 26              [Goods, services & income, (Nonfactor) services]    BX.GSR
# 28    [Goods, services & income, Communications, computer, etc.]    BX.GSR
# 30                         [Goods, services & income, Transport]    BX.GSR
# 32                            [Goods, services & income, Travel]    BX.GSR
# 34          [Goods, services & income, Royalty and license fees]    BX.GSR

# %% [markdown]
# ### For the various examples we analyzed, we concluded that selecting the values added from the WDI (World Development Indicators) dataset provides a more accurate representation. These values offer a finer level of granularity, enhancing our ability to analyze and interpret the data effectively.

# %%
economic["SubTopic2"] = economic["SubTopic2"].apply(select_second_item)
economic["SubTopic3"] = economic["SubTopic3"].apply(select_second_item)

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(economic[economic['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
#                      Code  \
# 8          BN.RES.INCL.CD
# 45         FI.RES.TOTL.CD
# 46         FI.RES.XGLD.CD
# 47         FI.RES.TOTL.MO
# 49      FI.RES.TOTL.DT.ZS
# 129     NE.CON.GOVT.KD.ZG
# 130  NE.CON.PRVT.PC.KD.ZG
# 131     NE.CON.PRVT.KD.ZG
# 135     NE.CON.TOTL.KD.ZG
# 136     NV.IND.TOTL.KD.ZG
# 138     NV.IND.MANF.KD.ZG
# 149        NY.TAX.NIND.KN
# 151        NE.CON.GOVT.KN
# 152        NE.CON.PRVT.KN
# 158        NE.CON.TOTL.KN
# 165        NV.IND.TOTL.KN
# 166        NV.IND.MANF.KN
# 179        NY.TAX.NIND.CN
# 182        NE.CON.GOVT.CN
# 183        NE.CON.PRVT.CN
# 190        NE.CON.TOTL.CN
# 192     NE.CON.PRVT.CN.AD
# 195        NV.IND.TOTL.CN
# 196        NV.IND.MANF.CN
# 199        NE.CON.GOVT.ZS
# 202        NE.CON.PRVT.ZS
# 210        NE.CON.TOTL.ZS
# 214        NV.IND.MANF.ZS
# 222        NV.IND.TOTL.ZS
# 230        NE.CON.GOVT.KD
# 231     NE.CON.PRVT.PC.KD
# 232        NE.CON.PRVT.KD
# 236        NE.CON.TOTL.KD
# 238        NV.IND.EMPL.KD
# 239        NV.IND.TOTL.KD
# 240        NV.IND.MANF.KD
# 252        NY.TAX.NIND.CD
# 255        NE.CON.GOVT.CD
# 256        NE.CON.PRVT.CD
# 261        NE.CON.TOTL.CD
# 264        NV.IND.TOTL.CD
# 265        NV.IND.MANF.CD
# 353     NE.CON.PRVT.PP.KD
# 354     NE.CON.PRVT.PP.CD
#
#                                                                                Indicator Name  \
# 8                                               Reserves and related items (BoP, current US$)
# 45                                                Total reserves (includes gold, current US$)
# 46                                                    Total reserves minus gold (current US$)
# 47                                                        Total reserves in months of imports
# 49                                                  Total reserves (% of total external debt)
# 129                        General government final consumption expenditure (annual % growth)
# 130                      Household final consumption expenditure per capita growth (annual %)
# 131                      Household and NPISHs Final consumption expenditure (annual % growth)
# 135                                           Final consumption expenditure (annual % growth)
# 136                          Industry (including construction), value added (annual % growth)
# 138                                              Manufacturing, value added (annual % growth)
# 149                                           Taxes less subsidies on products (constant LCU)
# 151                           General government final consumption expenditure (constant LCU)
# 152                         Household and NPISHs Final consumption expenditure (constant LCU)
# 158                                              Final consumption expenditure (constant LCU)
# 165                             Industry (including construction), value added (constant LCU)
# 166                                                 Manufacturing, value added (constant LCU)
# 179                                            Taxes less subsidies on products (current LCU)
# 182                            General government final consumption expenditure (current LCU)
# 183                          Household and NPISHs Final consumption expenditure (current LCU)
# 190                                               Final consumption expenditure (current LCU)
# 192          Households and NPISHs final consumption expenditure: linked series (current LCU)
# 195                              Industry (including construction), value added (current LCU)
# 196                                                  Manufacturing, value added (current LCU)
# 199                               General government final consumption expenditure (% of GDP)
# 202                            Households and NPISHs final consumption expenditure (% of GDP)
# 210                                                  Final consumption expenditure (% of GDP)
# 214                                                     Manufacturing, value added (% of GDP)
# 222                                 Industry (including construction), value added (% of GDP)
# 230                      General government final consumption expenditure (constant 2015 US$)
# 231        Households and NPISHs final consumption expenditure per capita (constant 2015 US$)
# 232                   Households and NPISHs Final consumption expenditure (constant 2015 US$)
# 236                                         Final consumption expenditure (constant 2015 US$)
# 238             Industry (including construction), value added per worker (constant 2015 US$)
# 239                        Industry (including construction), value added (constant 2015 US$)
# 240                                            Manufacturing, value added (constant 2015 US$)
# 252                                            Taxes less subsidies on products (current US$)
# 255                            General government final consumption expenditure (current US$)
# 256                          Household and NPISHs Final consumption expenditure (current US$)
# 261                                               Final consumption expenditure (current US$)
# 264                              Industry (including construction), value added (current US$)
# 265                                                  Manufacturing, value added (current US$)
# 353  Households and NPISHs Final consumption expenditure, PPP (constant 2021 international $)
# 354        Households and NPISHs Final consumption expenditure, PPP (current international $)
#
#                                                                                           General Topic  \
# 8                              Economic Policy & Debt: Balance of payments: Capital & financial account
# 45                                  Economic Policy & Debt: Balance of payments: Reserves & other items
# 46                                  Economic Policy & Debt: Balance of payments: Reserves & other items
# 47                                  Economic Policy & Debt: Balance of payments: Reserves & other items
# 49                                  Economic Policy & Debt: Balance of payments: Reserves & other items
# 129                                             Economic Policy & Debt: National accounts: Growth rates
# 130                                             Economic Policy & Debt: National accounts: Growth rates
# 131                                             Economic Policy & Debt: National accounts: Growth rates
# 135                                             Economic Policy & Debt: National accounts: Growth rates
# 136                                             Economic Policy & Debt: National accounts: Growth rates
# 138                                             Economic Policy & Debt: National accounts: Growth rates
# 149  Economic Policy & Debt: National accounts: Local currency at constant prices: Aggregate indicators
# 151    Economic Policy & Debt: National accounts: Local currency at constant prices: Expenditure on GDP
# 152    Economic Policy & Debt: National accounts: Local currency at constant prices: Expenditure on GDP
# 158    Economic Policy & Debt: National accounts: Local currency at constant prices: Expenditure on GDP
# 165           Economic Policy & Debt: National accounts: Local currency at constant prices: Value added
# 166           Economic Policy & Debt: National accounts: Local currency at constant prices: Value added
# 179   Economic Policy & Debt: National accounts: Local currency at current prices: Aggregate indicators
# 182     Economic Policy & Debt: National accounts: Local currency at current prices: Expenditure on GDP
# 183     Economic Policy & Debt: National accounts: Local currency at current prices: Expenditure on GDP
# 190     Economic Policy & Debt: National accounts: Local currency at current prices: Expenditure on GDP
# 192     Economic Policy & Debt: National accounts: Local currency at current prices: Expenditure on GDP
# 195            Economic Policy & Debt: National accounts: Local currency at current prices: Value added
# 196            Economic Policy & Debt: National accounts: Local currency at current prices: Value added
# 199                                    Economic Policy & Debt: National accounts: Shares of GDP & other
# 202                                    Economic Policy & Debt: National accounts: Shares of GDP & other
# 210                                    Economic Policy & Debt: National accounts: Shares of GDP & other
# 214                                    Economic Policy & Debt: National accounts: Shares of GDP & other
# 222                                    Economic Policy & Debt: National accounts: Shares of GDP & other
# 230          Economic Policy & Debt: National accounts: US$ at constant 2015 prices: Expenditure on GDP
# 231          Economic Policy & Debt: National accounts: US$ at constant 2015 prices: Expenditure on GDP
# 232          Economic Policy & Debt: National accounts: US$ at constant 2015 prices: Expenditure on GDP
# 236          Economic Policy & Debt: National accounts: US$ at constant 2015 prices: Expenditure on GDP
# 238                 Economic Policy & Debt: National accounts: US$ at constant 2015 prices: Value added
# 239                 Economic Policy & Debt: National accounts: US$ at constant 2015 prices: Value added
# 240                 Economic Policy & Debt: National accounts: US$ at constant 2015 prices: Value added
# 252              Economic Policy & Debt: National accounts: US$ at current prices: Aggregate indicators
# 255                Economic Policy & Debt: National accounts: US$ at current prices: Expenditure on GDP
# 256                Economic Policy & Debt: National accounts: US$ at current prices: Expenditure on GDP
# 261                Economic Policy & Debt: National accounts: US$ at current prices: Expenditure on GDP
# 264                       Economic Policy & Debt: National accounts: US$ at current prices: Value added
# 265                       Economic Policy & Debt: National accounts: US$ at current prices: Value added
# 353                                                     Economic Policy & Debt: Purchasing power parity
# 354                                                     Economic Policy & Debt: Purchasing power parity
#
#                       Topic                SubTopic1  \
# 8    Economic Policy & Debt      Balance of payments
# 45   Economic Policy & Debt      Balance of payments
# 46   Economic Policy & Debt      Balance of payments
# 47   Economic Policy & Debt      Balance of payments
# 49   Economic Policy & Debt      Balance of payments
# 129  Economic Policy & Debt        National accounts
# 130  Economic Policy & Debt        National accounts
# 131  Economic Policy & Debt        National accounts
# 135  Economic Policy & Debt        National accounts
# 136  Economic Policy & Debt        National accounts
# 138  Economic Policy & Debt        National accounts
# 149  Economic Policy & Debt        National accounts
# 151  Economic Policy & Debt        National accounts
# 152  Economic Policy & Debt        National accounts
# 158  Economic Policy & Debt        National accounts
# 165  Economic Policy & Debt        National accounts
# 166  Economic Policy & Debt        National accounts
# 179  Economic Policy & Debt        National accounts
# 182  Economic Policy & Debt        National accounts
# 183  Economic Policy & Debt        National accounts
# 190  Economic Policy & Debt        National accounts
# 192  Economic Policy & Debt        National accounts
# 195  Economic Policy & Debt        National accounts
# 196  Economic Policy & Debt        National accounts
# 199  Economic Policy & Debt        National accounts
# 202  Economic Policy & Debt        National accounts
# 210  Economic Policy & Debt        National accounts
# 214  Economic Policy & Debt        National accounts
# 222  Economic Policy & Debt        National accounts
# 230  Economic Policy & Debt        National accounts
# 231  Economic Policy & Debt        National accounts
# 232  Economic Policy & Debt        National accounts
# 236  Economic Policy & Debt        National accounts
# 238  Economic Policy & Debt        National accounts
# 239  Economic Policy & Debt        National accounts
# 240  Economic Policy & Debt        National accounts
# 252  Economic Policy & Debt        National accounts
# 255  Economic Policy & Debt        National accounts
# 256  Economic Policy & Debt        National accounts
# 261  Economic Policy & Debt        National accounts
# 264  Economic Policy & Debt        National accounts
# 265  Economic Policy & Debt        National accounts
# 353  Economic Policy & Debt  Purchasing power parity
# 354  Economic Policy & Debt  Purchasing power parity
#
#                                     SubTopic2  \
# 8                   Reserves (or residential)
# 45                  Reserves (or residential)
# 46                  Reserves (or residential)
# 47                  Reserves (or residential)
# 49                  Reserves (or residential)
# 129                   Consumption (or condom)
# 130                   Consumption (or condom)
# 131                   Consumption (or condom)
# 135                   Consumption (or condom)
# 136     Industry (or interest due) (or index)
# 138     Industry (or interest due) (or index)
# 149  Tax revenue (or tariff) (or tax related)
# 151                   Consumption (or condom)
# 152                   Consumption (or condom)
# 158                   Consumption (or condom)
# 165     Industry (or interest due) (or index)
# 166     Industry (or interest due) (or index)
# 179  Tax revenue (or tariff) (or tax related)
# 182                   Consumption (or condom)
# 183                   Consumption (or condom)
# 190                   Consumption (or condom)
# 192                   Consumption (or condom)
# 195     Industry (or interest due) (or index)
# 196     Industry (or interest due) (or index)
# 199                   Consumption (or condom)
# 202                   Consumption (or condom)
# 210                   Consumption (or condom)
# 214     Industry (or interest due) (or index)
# 222     Industry (or interest due) (or index)
# 230                   Consumption (or condom)
# 231                   Consumption (or condom)
# 232                   Consumption (or condom)
# 236                   Consumption (or condom)
# 238     Industry (or interest due) (or index)
# 239     Industry (or interest due) (or index)
# 240     Industry (or interest due) (or index)
# 252  Tax revenue (or tariff) (or tax related)
# 255                   Consumption (or condom)
# 256                   Consumption (or condom)
# 261                   Consumption (or condom)
# 264     Industry (or interest due) (or index)
# 265     Industry (or interest due) (or index)
# 353                   Consumption (or condom)
# 354                   Consumption (or condom)
#
#                                       SubTopic3
# 8                                     Including
# 45                                        Total
# 46                               Excluding gold
# 47                                        Total
# 49                                        Total
# 129                                  Government
# 130                                     Private
# 131                                     Private
# 135                                       Total
# 136                                       Total
# 138                               Manufacturing
# 149                          Net indirect taxes
# 151                                  Government
# 152                                     Private
# 158                                       Total
# 165                                       Total
# 166                               Manufacturing
# 179                          Net indirect taxes
# 182                                  Government
# 183                                     Private
# 190                                       Total
# 192                                     Private
# 195                                       Total
# 196                               Manufacturing
# 199                                  Government
# 202                                     Private
# 210                                       Total
# 214                               Manufacturing
# 222                                       Total
# 230                                  Government
# 231                                     Private
# 232                                     Private
# 236                                       Total
# 238  Economically active population (employees)
# 239                                       Total
# 240                               Manufacturing
# 252                          Net indirect taxes
# 255                                  Government
# 256                                     Private
# 261                                       Total
# 264                                       Total
# 265                               Manufacturing
# 353                                     Private
# 354                                     Private

# %%
economic.loc[economic['Code'].str.startswith('BN.RES') , "SubTopic2"] = "Reserves"
economic.loc[economic['Code'].str.startswith('FI.RES') , "SubTopic2"] = "Reserves"
economic.loc[economic['Code'].str.startswith('NE.CON'), "SubTopic2"] = "Consumption"
economic.loc[economic['Code'].str.startswith('NV.IND'), "SubTopic2"] = "Industry"
economic.loc[economic['Code'].str.startswith('NY.TAX'), "SubTopic2"] = "Tax revenue (or tax related)"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(economic[economic['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Education

# %%
education = dfs['education']

# %%
with pd.option_context('display.max_colwidth', 200):

    display(education[education['SubTopic2'].isna()])
# Out:
#                   Code  \
# 68      SE.LPV.PRIM.MA
# 69      SE.LPV.PRIM.FE
# 71         SE.LPV.PRIM
# 73   SE.LPV.PRIM.LD.FE
# 74   SE.LPV.PRIM.SD.FE
# 76      SE.LPV.PRIM.LD
# 97      SE.LPV.PRIM.SD
# 106  SE.LPV.PRIM.LD.MA
# 107  SE.LPV.PRIM.SD.MA
#
#                                                                                                                                     Indicator Name  \
# 68     Learning poverty: Share of Male Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 69   Learning poverty: Share of Female Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 71          Learning poverty: Share of Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)
# 73                                                       Female pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 74                                                                                            Female primary school age children out-of-school (%)
# 76                                                              Pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 97                                                                                                   Primary school age children out-of-school (%)
# 106                                                        Male pupils below minimum reading proficiency at end of primary (%). Low GAML threshold
# 107                                                                                             Male primary school age children out-of-school (%)
#
#            General Topic      Topic SubTopic1 SubTopic2          SubTopic3
# 68   Education: Outcomes  Education  Outcomes      None  Primary education
# 69   Education: Outcomes  Education  Outcomes      None  Primary education
# 71   Education: Outcomes  Education  Outcomes      None  Primary education
# 73   Education: Outcomes  Education  Outcomes      None  Primary education
# 74   Education: Outcomes  Education  Outcomes      None  Primary education
# 76   Education: Outcomes  Education  Outcomes      None  Primary education
# 97   Education: Outcomes  Education  Outcomes      None  Primary education
# 106  Education: Outcomes  Education  Outcomes      None  Primary education
# 107  Education: Outcomes  Education  Outcomes      None  Primary education

# %%
education['SubTopic2'] = education['SubTopic2'].fillna('Learning poverty')

# %%
with pd.option_context('display.max_colwidth', 200):

    display(education[education['SubTopic3'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
has_list = education.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


education_with_lists = education[has_list]
print(education_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(education[education['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
#            Code                          Indicator Name        General Topic  \
# 75  SE.COM.DURS  Compulsory education, duration (years)  Education: Outcomes
#
#         Topic SubTopic1                    SubTopic2 SubTopic3
# 75  Education  Outcomes  Commitments (or compulsory)  Duration

# %%
education.loc[education['Code'].str.startswith('SE.COM') , "SubTopic2"] = "Compulsory"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(education[education['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # More adjustments (personal)

# %%
education.loc[education['Code'].str.startswith('SE.ADT') , "SubTopic2"] = "Literacy rate"
education.loc[education['Code'].str.startswith('SE.ADT.1524') , "SubTopic3"] = "Youth (ages 15-24)"
education.loc[education['Code'].str.startswith('SE.ADT.LITR') , "SubTopic3"] = "Adult (ages 15 and above)"

# %% [markdown]
# # Environment

# %%
environment = dfs["environment"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(environment[(environment['SubTopic2'].isna())|(environment['SubTopic3'].isna())])
# Out:
#                            Code  \
# 66               ER.H2O.FWST.ZS
# 71      EN.GHG.CH4.TR.MT.CE.AR5
# 72      EN.GHG.CH4.PI.MT.CE.AR5
# 73      EN.GHG.CH4.WA.MT.CE.AR5
# 74      EN.GHG.CH4.IP.MT.CE.AR5
# 75      EN.GHG.N2O.AG.MT.CE.AR5
# 76      EN.GHG.CH4.IC.MT.CE.AR5
# 77      EN.GHG.CH4.AG.MT.CE.AR5
# 78         EN.GHG.CH4.MT.CE.AR5
# 79      EN.GHG.N2O.WA.MT.CE.AR5
# 80      EN.GHG.N2O.TR.MT.CE.AR5
# 81      EN.GHG.N2O.PI.MT.CE.AR5
# 82      EN.GHG.N2O.IP.MT.CE.AR5
# 83      EN.GHG.N2O.IC.MT.CE.AR5
# 84            EN.GHG.CH4.ZG.AR5
# 85            EN.GHG.N2O.ZG.AR5
# 86      EN.GHG.N2O.FE.MT.CE.AR5
# 87      EN.GHG.N2O.BU.MT.CE.AR5
# 88      EN.GHG.CH4.BU.MT.CE.AR5
# 89      EN.GHG.CH4.FE.MT.CE.AR5
# 90         EN.GHG.N2O.MT.CE.AR5
# 91            EN.GHG.TOT.ZG.AR5
# 92      EN.GHG.CO2.TR.MT.CE.AR5
# 93      EN.GHG.CO2.PI.MT.CE.AR5
# 94      EN.GHG.CO2.IP.MT.CE.AR5
# 95      EN.GHG.CO2.IC.MT.CE.AR5
# 96      EN.GHG.CO2.FE.MT.CE.AR5
# 97      EN.GHG.CO2.BU.MT.CE.AR5
# 98      EN.GHG.CO2.AG.MT.CE.AR5
# 99      EN.GHG.CO2.WA.MT.CE.AR5
# 100        EN.GHG.CO2.PC.CE.AR5
# 101        EN.GHG.CO2.MT.CE.AR5
# 102  EN.GHG.CO2.LU.DF.MT.CE.AR5
# 103  EN.GHG.CO2.LU.FL.MT.CE.AR5
# 104  EN.GHG.CO2.LU.OS.MT.CE.AR5
# 105    EN.GHG.FGAS.IP.MT.CE.AR5
# 106        EN.GHG.CO2.RT.GDP.KD
# 107     EN.GHG.CO2.RT.GDP.PP.KD
# 108     EN.GHG.CO2.LU.MT.CE.AR5
# 109  EN.GHG.CO2.LU.OL.MT.CE.AR5
# 110           EN.GHG.CO2.ZG.AR5
# 111        EN.GHG.ALL.MT.CE.AR5
# 112        EN.GHG.ALL.PC.CE.AR5
# 113     EN.GHG.ALL.LU.MT.CE.AR5
#
#                                                                                      Indicator Name  \
# 66   Level of water stress: freshwater withdrawal as a proportion of available freshwater resources
# 71                                        Methane (CH4) emissions from Transport (Energy) (Mt CO2e)
# 72                                   Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)
# 73                                                     Methane (CH4) emissions from Waste (Mt CO2e)
# 74                                      Methane (CH4) emissions from Industrial Processes (Mt CO2e)
# 75                                         Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)
# 76                            Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 77                                               Methane (CH4) emissions from Agriculture (Mt CO2e)
# 78                                       Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)
# 79                                               Nitrous oxide (N2O) emissions from Waste (Mt CO2e)
# 80                                  Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)
# 81                             Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)
# 82                                Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)
# 83                      Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 84                            Methane (CH4) emissions (total) excluding LULUCF (% change from 1990)
# 85                      Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990)
# 86                         Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 87                                   Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)
# 88                                         Methane (CH4) emissions from Building (Energy) (Mt CO2e)
# 89                               Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 90                                 Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)
# 91                             Total greenhouse gas emissions excluding LULUCF (% change from 1990)
# 92                                 Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)
# 93                            Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)
# 94                               Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)
# 95                     Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 96                        Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 97                                  Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)
# 98                                        Carbon dioxide (CO2) emissions from Agriculture (Mt CO2e)
# 99                                              Carbon dioxide (CO2) emissions from Waste (Mt CO2e)
# 100                      Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)
# 101                               Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)
# 102                           Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e)
# 103                             Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)
# 104                            Carbon dioxide (CO2) net fluxes from LULUCF - Organic Soil (Mt CO2e)
# 105            Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)
# 106                                  Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP)
# 107                                                Carbon intensity of GDP (kg CO2e per 2021 PPP $)
# 108      Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e)
# 109                              Carbon dioxide (CO2) net fluxes from LULUCF - Other Land (Mt CO2e)
# 110                    Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990)
# 111                                       Total greenhouse gas emissions excluding LULUCF (Mt CO2e)
# 112                      Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)
# 113                                       Total greenhouse gas emissions including LULUCF (Mt CO2e)
#
#                              General Topic        Topic  \
# 66                 Environment: Freshwater  Environment
# 71   Environment: Greenhouse Gas Emissions  Environment
# 72   Environment: Greenhouse Gas Emissions  Environment
# 73   Environment: Greenhouse Gas Emissions  Environment
# 74   Environment: Greenhouse Gas Emissions  Environment
# 75   Environment: Greenhouse Gas Emissions  Environment
# 76   Environment: Greenhouse Gas Emissions  Environment
# 77   Environment: Greenhouse Gas Emissions  Environment
# 78   Environment: Greenhouse Gas Emissions  Environment
# 79   Environment: Greenhouse Gas Emissions  Environment
# 80   Environment: Greenhouse Gas Emissions  Environment
# 81   Environment: Greenhouse Gas Emissions  Environment
# 82   Environment: Greenhouse Gas Emissions  Environment
# 83   Environment: Greenhouse Gas Emissions  Environment
# 84   Environment: Greenhouse Gas Emissions  Environment
# 85   Environment: Greenhouse Gas Emissions  Environment
# 86   Environment: Greenhouse Gas Emissions  Environment
# 87   Environment: Greenhouse Gas Emissions  Environment
# 88   Environment: Greenhouse Gas Emissions  Environment
# 89   Environment: Greenhouse Gas Emissions  Environment
# 90   Environment: Greenhouse Gas Emissions  Environment
# 91   Environment: Greenhouse Gas Emissions  Environment
# 92   Environment: Greenhouse Gas Emissions  Environment
# 93   Environment: Greenhouse Gas Emissions  Environment
# 94   Environment: Greenhouse Gas Emissions  Environment
# 95   Environment: Greenhouse Gas Emissions  Environment
# 96   Environment: Greenhouse Gas Emissions  Environment
# 97   Environment: Greenhouse Gas Emissions  Environment
# 98   Environment: Greenhouse Gas Emissions  Environment
# 99   Environment: Greenhouse Gas Emissions  Environment
# 100  Environment: Greenhouse Gas Emissions  Environment
# 101  Environment: Greenhouse Gas Emissions  Environment
# 102  Environment: Greenhouse Gas Emissions  Environment
# 103  Environment: Greenhouse Gas Emissions  Environment
# 104  Environment: Greenhouse Gas Emissions  Environment
# 105  Environment: Greenhouse Gas Emissions  Environment
# 106  Environment: Greenhouse Gas Emissions  Environment
# 107  Environment: Greenhouse Gas Emissions  Environment
# 108  Environment: Greenhouse Gas Emissions  Environment
# 109  Environment: Greenhouse Gas Emissions  Environment
# 110  Environment: Greenhouse Gas Emissions  Environment
# 111  Environment: Greenhouse Gas Emissions  Environment
# 112  Environment: Greenhouse Gas Emissions  Environment
# 113  Environment: Greenhouse Gas Emissions  Environment
#
#                     SubTopic1 SubTopic2 SubTopic3
# 66                 Freshwater     Water      None
# 71   Greenhouse Gas Emissions      None      None
# 72   Greenhouse Gas Emissions      None      None
# 73   Greenhouse Gas Emissions      None      None
# 74   Greenhouse Gas Emissions      None      None
# 75   Greenhouse Gas Emissions      None      None
# 76   Greenhouse Gas Emissions      None      None
# 77   Greenhouse Gas Emissions      None      None
# 78   Greenhouse Gas Emissions      None      None
# 79   Greenhouse Gas Emissions      None      None
# 80   Greenhouse Gas Emissions      None      None
# 81   Greenhouse Gas Emissions      None      None
# 82   Greenhouse Gas Emissions      None      None
# 83   Greenhouse Gas Emissions      None      None
# 84   Greenhouse Gas Emissions      None      None
# 85   Greenhouse Gas Emissions      None      None
# 86   Greenhouse Gas Emissions      None      None
# 87   Greenhouse Gas Emissions      None      None
# 88   Greenhouse Gas Emissions      None      None
# 89   Greenhouse Gas Emissions      None      None
# 90   Greenhouse Gas Emissions      None      None
# 91   Greenhouse Gas Emissions      None      None
# 92   Greenhouse Gas Emissions      None      None
# 93   Greenhouse Gas Emissions      None      None
# 94   Greenhouse Gas Emissions      None      None
# 95   Greenhouse Gas Emissions      None      None
# 96   Greenhouse Gas Emissions      None      None
# 97   Greenhouse Gas Emissions      None      None
# 98   Greenhouse Gas Emissions      None      None
# 99   Greenhouse Gas Emissions      None      None
# 100  Greenhouse Gas Emissions      None      None
# 101  Greenhouse Gas Emissions      None      None
# 102  Greenhouse Gas Emissions      None      None
# 103  Greenhouse Gas Emissions      None      None
# 104  Greenhouse Gas Emissions      None      None
# 105  Greenhouse Gas Emissions      None      None
# 106  Greenhouse Gas Emissions      None      None
# 107  Greenhouse Gas Emissions      None      None
# 108  Greenhouse Gas Emissions      None      None
# 109  Greenhouse Gas Emissions      None      None
# 110  Greenhouse Gas Emissions      None      None
# 111  Greenhouse Gas Emissions      None      None
# 112  Greenhouse Gas Emissions      None      None
# 113  Greenhouse Gas Emissions      None      None

# %%
# environment_mapping_subtopic3 = {
#     "FWST": "freshwater withdrawal"
# }

# %%
environment.loc[environment["Code"] == "ER.H2O.FWST.ZS", "SubTopic3"] = "Water stress: freshwater withdrawal"

# %%
environment_mapping = {
    "ALL": "All Greenhouse Gases",
    "FGAS": "Fluorinated Gases emissions",
    "CH4": "Methane emissions",
    "N2O": "Nitrous oxide emissions",
    "CO2": "Carbon dioxide emissions",
    "TOT": "Total"
}

environment.loc[environment["SubTopic2"].isna(), "SubTopic2"] = (
    environment["Code"].str.split(".").str[2].map(environment_mapping)
)

# %%
with pd.option_context('display.max_colwidth', 200):

    display(environment[environment['SubTopic2'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
with pd.option_context('display.max_colwidth', 200):

    display(environment[environment['SubTopic3'].isna()])
# Out:
#                            Code  \
# 71      EN.GHG.CH4.TR.MT.CE.AR5
# 72      EN.GHG.CH4.PI.MT.CE.AR5
# 73      EN.GHG.CH4.WA.MT.CE.AR5
# 74      EN.GHG.CH4.IP.MT.CE.AR5
# 75      EN.GHG.N2O.AG.MT.CE.AR5
# 76      EN.GHG.CH4.IC.MT.CE.AR5
# 77      EN.GHG.CH4.AG.MT.CE.AR5
# 78         EN.GHG.CH4.MT.CE.AR5
# 79      EN.GHG.N2O.WA.MT.CE.AR5
# 80      EN.GHG.N2O.TR.MT.CE.AR5
# 81      EN.GHG.N2O.PI.MT.CE.AR5
# 82      EN.GHG.N2O.IP.MT.CE.AR5
# 83      EN.GHG.N2O.IC.MT.CE.AR5
# 84            EN.GHG.CH4.ZG.AR5
# 85            EN.GHG.N2O.ZG.AR5
# 86      EN.GHG.N2O.FE.MT.CE.AR5
# 87      EN.GHG.N2O.BU.MT.CE.AR5
# 88      EN.GHG.CH4.BU.MT.CE.AR5
# 89      EN.GHG.CH4.FE.MT.CE.AR5
# 90         EN.GHG.N2O.MT.CE.AR5
# 91            EN.GHG.TOT.ZG.AR5
# 92      EN.GHG.CO2.TR.MT.CE.AR5
# 93      EN.GHG.CO2.PI.MT.CE.AR5
# 94      EN.GHG.CO2.IP.MT.CE.AR5
# 95      EN.GHG.CO2.IC.MT.CE.AR5
# 96      EN.GHG.CO2.FE.MT.CE.AR5
# 97      EN.GHG.CO2.BU.MT.CE.AR5
# 98      EN.GHG.CO2.AG.MT.CE.AR5
# 99      EN.GHG.CO2.WA.MT.CE.AR5
# 100        EN.GHG.CO2.PC.CE.AR5
# 101        EN.GHG.CO2.MT.CE.AR5
# 102  EN.GHG.CO2.LU.DF.MT.CE.AR5
# 103  EN.GHG.CO2.LU.FL.MT.CE.AR5
# 104  EN.GHG.CO2.LU.OS.MT.CE.AR5
# 105    EN.GHG.FGAS.IP.MT.CE.AR5
# 106        EN.GHG.CO2.RT.GDP.KD
# 107     EN.GHG.CO2.RT.GDP.PP.KD
# 108     EN.GHG.CO2.LU.MT.CE.AR5
# 109  EN.GHG.CO2.LU.OL.MT.CE.AR5
# 110           EN.GHG.CO2.ZG.AR5
# 111        EN.GHG.ALL.MT.CE.AR5
# 112        EN.GHG.ALL.PC.CE.AR5
# 113     EN.GHG.ALL.LU.MT.CE.AR5
#
#                                                                                  Indicator Name  \
# 71                                    Methane (CH4) emissions from Transport (Energy) (Mt CO2e)
# 72                               Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)
# 73                                                 Methane (CH4) emissions from Waste (Mt CO2e)
# 74                                  Methane (CH4) emissions from Industrial Processes (Mt CO2e)
# 75                                     Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)
# 76                        Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 77                                           Methane (CH4) emissions from Agriculture (Mt CO2e)
# 78                                   Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)
# 79                                           Nitrous oxide (N2O) emissions from Waste (Mt CO2e)
# 80                              Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)
# 81                         Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)
# 82                            Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)
# 83                  Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 84                        Methane (CH4) emissions (total) excluding LULUCF (% change from 1990)
# 85                  Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990)
# 86                     Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 87                               Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)
# 88                                     Methane (CH4) emissions from Building (Energy) (Mt CO2e)
# 89                           Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 90                             Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)
# 91                         Total greenhouse gas emissions excluding LULUCF (% change from 1990)
# 92                             Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)
# 93                        Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)
# 94                           Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)
# 95                 Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 96                    Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 97                              Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)
# 98                                    Carbon dioxide (CO2) emissions from Agriculture (Mt CO2e)
# 99                                          Carbon dioxide (CO2) emissions from Waste (Mt CO2e)
# 100                  Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)
# 101                           Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)
# 102                       Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e)
# 103                         Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)
# 104                        Carbon dioxide (CO2) net fluxes from LULUCF - Organic Soil (Mt CO2e)
# 105        Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)
# 106                              Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP)
# 107                                            Carbon intensity of GDP (kg CO2e per 2021 PPP $)
# 108  Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e)
# 109                          Carbon dioxide (CO2) net fluxes from LULUCF - Other Land (Mt CO2e)
# 110                Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990)
# 111                                   Total greenhouse gas emissions excluding LULUCF (Mt CO2e)
# 112                  Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)
# 113                                   Total greenhouse gas emissions including LULUCF (Mt CO2e)
#
#                              General Topic        Topic  \
# 71   Environment: Greenhouse Gas Emissions  Environment
# 72   Environment: Greenhouse Gas Emissions  Environment
# 73   Environment: Greenhouse Gas Emissions  Environment
# 74   Environment: Greenhouse Gas Emissions  Environment
# 75   Environment: Greenhouse Gas Emissions  Environment
# 76   Environment: Greenhouse Gas Emissions  Environment
# 77   Environment: Greenhouse Gas Emissions  Environment
# 78   Environment: Greenhouse Gas Emissions  Environment
# 79   Environment: Greenhouse Gas Emissions  Environment
# 80   Environment: Greenhouse Gas Emissions  Environment
# 81   Environment: Greenhouse Gas Emissions  Environment
# 82   Environment: Greenhouse Gas Emissions  Environment
# 83   Environment: Greenhouse Gas Emissions  Environment
# 84   Environment: Greenhouse Gas Emissions  Environment
# 85   Environment: Greenhouse Gas Emissions  Environment
# 86   Environment: Greenhouse Gas Emissions  Environment
# 87   Environment: Greenhouse Gas Emissions  Environment
# 88   Environment: Greenhouse Gas Emissions  Environment
# 89   Environment: Greenhouse Gas Emissions  Environment
# 90   Environment: Greenhouse Gas Emissions  Environment
# 91   Environment: Greenhouse Gas Emissions  Environment
# 92   Environment: Greenhouse Gas Emissions  Environment
# 93   Environment: Greenhouse Gas Emissions  Environment
# 94   Environment: Greenhouse Gas Emissions  Environment
# 95   Environment: Greenhouse Gas Emissions  Environment
# 96   Environment: Greenhouse Gas Emissions  Environment
# 97   Environment: Greenhouse Gas Emissions  Environment
# 98   Environment: Greenhouse Gas Emissions  Environment
# 99   Environment: Greenhouse Gas Emissions  Environment
# 100  Environment: Greenhouse Gas Emissions  Environment
# 101  Environment: Greenhouse Gas Emissions  Environment
# 102  Environment: Greenhouse Gas Emissions  Environment
# 103  Environment: Greenhouse Gas Emissions  Environment
# 104  Environment: Greenhouse Gas Emissions  Environment
# 105  Environment: Greenhouse Gas Emissions  Environment
# 106  Environment: Greenhouse Gas Emissions  Environment
# 107  Environment: Greenhouse Gas Emissions  Environment
# 108  Environment: Greenhouse Gas Emissions  Environment
# 109  Environment: Greenhouse Gas Emissions  Environment
# 110  Environment: Greenhouse Gas Emissions  Environment
# 111  Environment: Greenhouse Gas Emissions  Environment
# 112  Environment: Greenhouse Gas Emissions  Environment
# 113  Environment: Greenhouse Gas Emissions  Environment
#
#                     SubTopic1                    SubTopic2 SubTopic3
# 71   Greenhouse Gas Emissions            Methane emissions      None
# 72   Greenhouse Gas Emissions            Methane emissions      None
# 73   Greenhouse Gas Emissions            Methane emissions      None
# 74   Greenhouse Gas Emissions            Methane emissions      None
# 75   Greenhouse Gas Emissions      Nitrous oxide emissions      None
# 76   Greenhouse Gas Emissions            Methane emissions      None
# 77   Greenhouse Gas Emissions            Methane emissions      None
# 78   Greenhouse Gas Emissions            Methane emissions      None
# 79   Greenhouse Gas Emissions      Nitrous oxide emissions      None
# 80   Greenhouse Gas Emissions      Nitrous oxide emissions      None
# 81   Greenhouse Gas Emissions      Nitrous oxide emissions      None
# 82   Greenhouse Gas Emissions      Nitrous oxide emissions      None
# 83   Greenhouse Gas Emissions      Nitrous oxide emissions      None
# 84   Greenhouse Gas Emissions            Methane emissions      None
# 85   Greenhouse Gas Emissions      Nitrous oxide emissions      None
# 86   Greenhouse Gas Emissions      Nitrous oxide emissions      None
# 87   Greenhouse Gas Emissions      Nitrous oxide emissions      None
# 88   Greenhouse Gas Emissions            Methane emissions      None
# 89   Greenhouse Gas Emissions            Methane emissions      None
# 90   Greenhouse Gas Emissions      Nitrous oxide emissions      None
# 91   Greenhouse Gas Emissions                        Total      None
# 92   Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 93   Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 94   Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 95   Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 96   Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 97   Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 98   Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 99   Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 100  Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 101  Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 102  Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 103  Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 104  Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 105  Greenhouse Gas Emissions  Fluorinated Gases emissions      None
# 106  Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 107  Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 108  Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 109  Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 110  Greenhouse Gas Emissions     Carbon dioxide emissions      None
# 111  Greenhouse Gas Emissions         All Greenhouse Gases      None
# 112  Greenhouse Gas Emissions         All Greenhouse Gases      None
# 113  Greenhouse Gas Emissions         All Greenhouse Gases      None

# %%
environment_mapping_subtopic3 = {
    "LU": "Including Land Use and Land-Use Change (LULUC)",
    "RT": "Carbon intensity of GDP",
    "OS": "Other Sources",
    "OL": "Other Land Use",
    "WA": "Waste",
    "IC": "Industrial Combustion",
    "IP": "Industrial Processes",
    "BU": "Buildings",
    "AG": "Agriculture",
    "PI": "Power Industry",
    "TR": "Transport",
    "FE": "Fugitive Emissions",

}

environment.loc[environment["SubTopic3"].isna(), "SubTopic3"] = (
    environment["Code"].str.split(".").str[3].map(environment_mapping_subtopic3)
)

# %%
with pd.option_context('display.max_colwidth', 200):
    display(environment[environment['Code'].str.startswith('EN.GHG')])
# Out:
#                            Code  \
# 71      EN.GHG.CH4.TR.MT.CE.AR5
# 72      EN.GHG.CH4.PI.MT.CE.AR5
# 73      EN.GHG.CH4.WA.MT.CE.AR5
# 74      EN.GHG.CH4.IP.MT.CE.AR5
# 75      EN.GHG.N2O.AG.MT.CE.AR5
# 76      EN.GHG.CH4.IC.MT.CE.AR5
# 77      EN.GHG.CH4.AG.MT.CE.AR5
# 78         EN.GHG.CH4.MT.CE.AR5
# 79      EN.GHG.N2O.WA.MT.CE.AR5
# 80      EN.GHG.N2O.TR.MT.CE.AR5
# 81      EN.GHG.N2O.PI.MT.CE.AR5
# 82      EN.GHG.N2O.IP.MT.CE.AR5
# 83      EN.GHG.N2O.IC.MT.CE.AR5
# 84            EN.GHG.CH4.ZG.AR5
# 85            EN.GHG.N2O.ZG.AR5
# 86      EN.GHG.N2O.FE.MT.CE.AR5
# 87      EN.GHG.N2O.BU.MT.CE.AR5
# 88      EN.GHG.CH4.BU.MT.CE.AR5
# 89      EN.GHG.CH4.FE.MT.CE.AR5
# 90         EN.GHG.N2O.MT.CE.AR5
# 91            EN.GHG.TOT.ZG.AR5
# 92      EN.GHG.CO2.TR.MT.CE.AR5
# 93      EN.GHG.CO2.PI.MT.CE.AR5
# 94      EN.GHG.CO2.IP.MT.CE.AR5
# 95      EN.GHG.CO2.IC.MT.CE.AR5
# 96      EN.GHG.CO2.FE.MT.CE.AR5
# 97      EN.GHG.CO2.BU.MT.CE.AR5
# 98      EN.GHG.CO2.AG.MT.CE.AR5
# 99      EN.GHG.CO2.WA.MT.CE.AR5
# 100        EN.GHG.CO2.PC.CE.AR5
# 101        EN.GHG.CO2.MT.CE.AR5
# 102  EN.GHG.CO2.LU.DF.MT.CE.AR5
# 103  EN.GHG.CO2.LU.FL.MT.CE.AR5
# 104  EN.GHG.CO2.LU.OS.MT.CE.AR5
# 105    EN.GHG.FGAS.IP.MT.CE.AR5
# 106        EN.GHG.CO2.RT.GDP.KD
# 107     EN.GHG.CO2.RT.GDP.PP.KD
# 108     EN.GHG.CO2.LU.MT.CE.AR5
# 109  EN.GHG.CO2.LU.OL.MT.CE.AR5
# 110           EN.GHG.CO2.ZG.AR5
# 111        EN.GHG.ALL.MT.CE.AR5
# 112        EN.GHG.ALL.PC.CE.AR5
# 113     EN.GHG.ALL.LU.MT.CE.AR5
#
#                                                                                  Indicator Name  \
# 71                                    Methane (CH4) emissions from Transport (Energy) (Mt CO2e)
# 72                               Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)
# 73                                                 Methane (CH4) emissions from Waste (Mt CO2e)
# 74                                  Methane (CH4) emissions from Industrial Processes (Mt CO2e)
# 75                                     Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)
# 76                        Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 77                                           Methane (CH4) emissions from Agriculture (Mt CO2e)
# 78                                   Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)
# 79                                           Nitrous oxide (N2O) emissions from Waste (Mt CO2e)
# 80                              Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)
# 81                         Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)
# 82                            Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)
# 83                  Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 84                        Methane (CH4) emissions (total) excluding LULUCF (% change from 1990)
# 85                  Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990)
# 86                     Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 87                               Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)
# 88                                     Methane (CH4) emissions from Building (Energy) (Mt CO2e)
# 89                           Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 90                             Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)
# 91                         Total greenhouse gas emissions excluding LULUCF (% change from 1990)
# 92                             Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)
# 93                        Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)
# 94                           Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)
# 95                 Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 96                    Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 97                              Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)
# 98                                    Carbon dioxide (CO2) emissions from Agriculture (Mt CO2e)
# 99                                          Carbon dioxide (CO2) emissions from Waste (Mt CO2e)
# 100                  Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)
# 101                           Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)
# 102                       Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e)
# 103                         Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)
# 104                        Carbon dioxide (CO2) net fluxes from LULUCF - Organic Soil (Mt CO2e)
# 105        Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)
# 106                              Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP)
# 107                                            Carbon intensity of GDP (kg CO2e per 2021 PPP $)
# 108  Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e)
# 109                          Carbon dioxide (CO2) net fluxes from LULUCF - Other Land (Mt CO2e)
# 110                Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990)
# 111                                   Total greenhouse gas emissions excluding LULUCF (Mt CO2e)
# 112                  Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)
# 113                                   Total greenhouse gas emissions including LULUCF (Mt CO2e)
#
#                              General Topic        Topic  \
# 71   Environment: Greenhouse Gas Emissions  Environment
# 72   Environment: Greenhouse Gas Emissions  Environment
# 73   Environment: Greenhouse Gas Emissions  Environment
# 74   Environment: Greenhouse Gas Emissions  Environment
# 75   Environment: Greenhouse Gas Emissions  Environment
# 76   Environment: Greenhouse Gas Emissions  Environment
# 77   Environment: Greenhouse Gas Emissions  Environment
# 78   Environment: Greenhouse Gas Emissions  Environment
# 79   Environment: Greenhouse Gas Emissions  Environment
# 80   Environment: Greenhouse Gas Emissions  Environment
# 81   Environment: Greenhouse Gas Emissions  Environment
# 82   Environment: Greenhouse Gas Emissions  Environment
# 83   Environment: Greenhouse Gas Emissions  Environment
# 84   Environment: Greenhouse Gas Emissions  Environment
# 85   Environment: Greenhouse Gas Emissions  Environment
# 86   Environment: Greenhouse Gas Emissions  Environment
# 87   Environment: Greenhouse Gas Emissions  Environment
# 88   Environment: Greenhouse Gas Emissions  Environment
# 89   Environment: Greenhouse Gas Emissions  Environment
# 90   Environment: Greenhouse Gas Emissions  Environment
# 91   Environment: Greenhouse Gas Emissions  Environment
# 92   Environment: Greenhouse Gas Emissions  Environment
# 93   Environment: Greenhouse Gas Emissions  Environment
# 94   Environment: Greenhouse Gas Emissions  Environment
# 95   Environment: Greenhouse Gas Emissions  Environment
# 96   Environment: Greenhouse Gas Emissions  Environment
# 97   Environment: Greenhouse Gas Emissions  Environment
# 98   Environment: Greenhouse Gas Emissions  Environment
# 99   Environment: Greenhouse Gas Emissions  Environment
# 100  Environment: Greenhouse Gas Emissions  Environment
# 101  Environment: Greenhouse Gas Emissions  Environment
# 102  Environment: Greenhouse Gas Emissions  Environment
# 103  Environment: Greenhouse Gas Emissions  Environment
# 104  Environment: Greenhouse Gas Emissions  Environment
# 105  Environment: Greenhouse Gas Emissions  Environment
# 106  Environment: Greenhouse Gas Emissions  Environment
# 107  Environment: Greenhouse Gas Emissions  Environment
# 108  Environment: Greenhouse Gas Emissions  Environment
# 109  Environment: Greenhouse Gas Emissions  Environment
# 110  Environment: Greenhouse Gas Emissions  Environment
# 111  Environment: Greenhouse Gas Emissions  Environment
# 112  Environment: Greenhouse Gas Emissions  Environment
# 113  Environment: Greenhouse Gas Emissions  Environment
#
#                     SubTopic1                    SubTopic2  \
# 71   Greenhouse Gas Emissions            Methane emissions
# 72   Greenhouse Gas Emissions            Methane emissions
# 73   Greenhouse Gas Emissions            Methane emissions
# 74   Greenhouse Gas Emissions            Methane emissions
# 75   Greenhouse Gas Emissions      Nitrous oxide emissions
# 76   Greenhouse Gas Emissions            Methane emissions
# 77   Greenhouse Gas Emissions            Methane emissions
# 78   Greenhouse Gas Emissions            Methane emissions
# 79   Greenhouse Gas Emissions      Nitrous oxide emissions
# 80   Greenhouse Gas Emissions      Nitrous oxide emissions
# 81   Greenhouse Gas Emissions      Nitrous oxide emissions
# 82   Greenhouse Gas Emissions      Nitrous oxide emissions
# 83   Greenhouse Gas Emissions      Nitrous oxide emissions
# 84   Greenhouse Gas Emissions            Methane emissions
# 85   Greenhouse Gas Emissions      Nitrous oxide emissions
# 86   Greenhouse Gas Emissions      Nitrous oxide emissions
# 87   Greenhouse Gas Emissions      Nitrous oxide emissions
# 88   Greenhouse Gas Emissions            Methane emissions
# 89   Greenhouse Gas Emissions            Methane emissions
# 90   Greenhouse Gas Emissions      Nitrous oxide emissions
# 91   Greenhouse Gas Emissions                        Total
# 92   Greenhouse Gas Emissions     Carbon dioxide emissions
# 93   Greenhouse Gas Emissions     Carbon dioxide emissions
# 94   Greenhouse Gas Emissions     Carbon dioxide emissions
# 95   Greenhouse Gas Emissions     Carbon dioxide emissions
# 96   Greenhouse Gas Emissions     Carbon dioxide emissions
# 97   Greenhouse Gas Emissions     Carbon dioxide emissions
# 98   Greenhouse Gas Emissions     Carbon dioxide emissions
# 99   Greenhouse Gas Emissions     Carbon dioxide emissions
# 100  Greenhouse Gas Emissions     Carbon dioxide emissions
# 101  Greenhouse Gas Emissions     Carbon dioxide emissions
# 102  Greenhouse Gas Emissions     Carbon dioxide emissions
# 103  Greenhouse Gas Emissions     Carbon dioxide emissions
# 104  Greenhouse Gas Emissions     Carbon dioxide emissions
# 105  Greenhouse Gas Emissions  Fluorinated Gases emissions
# 106  Greenhouse Gas Emissions     Carbon dioxide emissions
# 107  Greenhouse Gas Emissions     Carbon dioxide emissions
# 108  Greenhouse Gas Emissions     Carbon dioxide emissions
# 109  Greenhouse Gas Emissions     Carbon dioxide emissions
# 110  Greenhouse Gas Emissions     Carbon dioxide emissions
# 111  Greenhouse Gas Emissions         All Greenhouse Gases
# 112  Greenhouse Gas Emissions         All Greenhouse Gases
# 113  Greenhouse Gas Emissions         All Greenhouse Gases
#
#                                           SubTopic3
# 71                                        Transport
# 72                                   Power Industry
# 73                                            Waste
# 74                             Industrial Processes
# 75                                      Agriculture
# 76                            Industrial Combustion
# 77                                      Agriculture
# 78                                              NaN
# 79                                            Waste
# 80                                        Transport
# 81                                   Power Industry
# 82                             Industrial Processes
# 83                            Industrial Combustion
# 84                                              NaN
# 85                                              NaN
# 86                               Fugitive Emissions
# 87                                        Buildings
# 88                                        Buildings
# 89                               Fugitive Emissions
# 90                                              NaN
# 91                                              NaN
# 92                                        Transport
# 93                                   Power Industry
# 94                             Industrial Processes
# 95                            Industrial Combustion
# 96                               Fugitive Emissions
# 97                                        Buildings
# 98                                      Agriculture
# 99                                            Waste
# 100                                             NaN
# 101                                             NaN
# 102  Including Land Use and Land-Use Change (LULUC)
# 103  Including Land Use and Land-Use Change (LULUC)
# 104  Including Land Use and Land-Use Change (LULUC)
# 105                            Industrial Processes
# 106                         Carbon intensity of GDP
# 107                         Carbon intensity of GDP
# 108  Including Land Use and Land-Use Change (LULUC)
# 109  Including Land Use and Land-Use Change (LULUC)
# 110                                             NaN
# 111                                             NaN
# 112                                             NaN
# 113  Including Land Use and Land-Use Change (LULUC)

# %%
environment.loc[environment["SubTopic3"].isna(), "SubTopic3"] = "Excluding  Land Use and Land-Use Change (LULUC)"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(environment[environment['Code'].str.startswith('EN.GHG')])
# Out:
#                            Code  \
# 71      EN.GHG.CH4.TR.MT.CE.AR5
# 72      EN.GHG.CH4.PI.MT.CE.AR5
# 73      EN.GHG.CH4.WA.MT.CE.AR5
# 74      EN.GHG.CH4.IP.MT.CE.AR5
# 75      EN.GHG.N2O.AG.MT.CE.AR5
# 76      EN.GHG.CH4.IC.MT.CE.AR5
# 77      EN.GHG.CH4.AG.MT.CE.AR5
# 78         EN.GHG.CH4.MT.CE.AR5
# 79      EN.GHG.N2O.WA.MT.CE.AR5
# 80      EN.GHG.N2O.TR.MT.CE.AR5
# 81      EN.GHG.N2O.PI.MT.CE.AR5
# 82      EN.GHG.N2O.IP.MT.CE.AR5
# 83      EN.GHG.N2O.IC.MT.CE.AR5
# 84            EN.GHG.CH4.ZG.AR5
# 85            EN.GHG.N2O.ZG.AR5
# 86      EN.GHG.N2O.FE.MT.CE.AR5
# 87      EN.GHG.N2O.BU.MT.CE.AR5
# 88      EN.GHG.CH4.BU.MT.CE.AR5
# 89      EN.GHG.CH4.FE.MT.CE.AR5
# 90         EN.GHG.N2O.MT.CE.AR5
# 91            EN.GHG.TOT.ZG.AR5
# 92      EN.GHG.CO2.TR.MT.CE.AR5
# 93      EN.GHG.CO2.PI.MT.CE.AR5
# 94      EN.GHG.CO2.IP.MT.CE.AR5
# 95      EN.GHG.CO2.IC.MT.CE.AR5
# 96      EN.GHG.CO2.FE.MT.CE.AR5
# 97      EN.GHG.CO2.BU.MT.CE.AR5
# 98      EN.GHG.CO2.AG.MT.CE.AR5
# 99      EN.GHG.CO2.WA.MT.CE.AR5
# 100        EN.GHG.CO2.PC.CE.AR5
# 101        EN.GHG.CO2.MT.CE.AR5
# 102  EN.GHG.CO2.LU.DF.MT.CE.AR5
# 103  EN.GHG.CO2.LU.FL.MT.CE.AR5
# 104  EN.GHG.CO2.LU.OS.MT.CE.AR5
# 105    EN.GHG.FGAS.IP.MT.CE.AR5
# 106        EN.GHG.CO2.RT.GDP.KD
# 107     EN.GHG.CO2.RT.GDP.PP.KD
# 108     EN.GHG.CO2.LU.MT.CE.AR5
# 109  EN.GHG.CO2.LU.OL.MT.CE.AR5
# 110           EN.GHG.CO2.ZG.AR5
# 111        EN.GHG.ALL.MT.CE.AR5
# 112        EN.GHG.ALL.PC.CE.AR5
# 113     EN.GHG.ALL.LU.MT.CE.AR5
#
#                                                                                  Indicator Name  \
# 71                                    Methane (CH4) emissions from Transport (Energy) (Mt CO2e)
# 72                               Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)
# 73                                                 Methane (CH4) emissions from Waste (Mt CO2e)
# 74                                  Methane (CH4) emissions from Industrial Processes (Mt CO2e)
# 75                                     Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)
# 76                        Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 77                                           Methane (CH4) emissions from Agriculture (Mt CO2e)
# 78                                   Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)
# 79                                           Nitrous oxide (N2O) emissions from Waste (Mt CO2e)
# 80                              Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)
# 81                         Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)
# 82                            Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)
# 83                  Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 84                        Methane (CH4) emissions (total) excluding LULUCF (% change from 1990)
# 85                  Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990)
# 86                     Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 87                               Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)
# 88                                     Methane (CH4) emissions from Building (Energy) (Mt CO2e)
# 89                           Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 90                             Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)
# 91                         Total greenhouse gas emissions excluding LULUCF (% change from 1990)
# 92                             Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)
# 93                        Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)
# 94                           Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)
# 95                 Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)
# 96                    Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# 97                              Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)
# 98                                    Carbon dioxide (CO2) emissions from Agriculture (Mt CO2e)
# 99                                          Carbon dioxide (CO2) emissions from Waste (Mt CO2e)
# 100                  Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)
# 101                           Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)
# 102                       Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e)
# 103                         Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)
# 104                        Carbon dioxide (CO2) net fluxes from LULUCF - Organic Soil (Mt CO2e)
# 105        Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)
# 106                              Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP)
# 107                                            Carbon intensity of GDP (kg CO2e per 2021 PPP $)
# 108  Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e)
# 109                          Carbon dioxide (CO2) net fluxes from LULUCF - Other Land (Mt CO2e)
# 110                Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990)
# 111                                   Total greenhouse gas emissions excluding LULUCF (Mt CO2e)
# 112                  Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)
# 113                                   Total greenhouse gas emissions including LULUCF (Mt CO2e)
#
#                              General Topic        Topic  \
# 71   Environment: Greenhouse Gas Emissions  Environment
# 72   Environment: Greenhouse Gas Emissions  Environment
# 73   Environment: Greenhouse Gas Emissions  Environment
# 74   Environment: Greenhouse Gas Emissions  Environment
# 75   Environment: Greenhouse Gas Emissions  Environment
# 76   Environment: Greenhouse Gas Emissions  Environment
# 77   Environment: Greenhouse Gas Emissions  Environment
# 78   Environment: Greenhouse Gas Emissions  Environment
# 79   Environment: Greenhouse Gas Emissions  Environment
# 80   Environment: Greenhouse Gas Emissions  Environment
# 81   Environment: Greenhouse Gas Emissions  Environment
# 82   Environment: Greenhouse Gas Emissions  Environment
# 83   Environment: Greenhouse Gas Emissions  Environment
# 84   Environment: Greenhouse Gas Emissions  Environment
# 85   Environment: Greenhouse Gas Emissions  Environment
# 86   Environment: Greenhouse Gas Emissions  Environment
# 87   Environment: Greenhouse Gas Emissions  Environment
# 88   Environment: Greenhouse Gas Emissions  Environment
# 89   Environment: Greenhouse Gas Emissions  Environment
# 90   Environment: Greenhouse Gas Emissions  Environment
# 91   Environment: Greenhouse Gas Emissions  Environment
# 92   Environment: Greenhouse Gas Emissions  Environment
# 93   Environment: Greenhouse Gas Emissions  Environment
# 94   Environment: Greenhouse Gas Emissions  Environment
# 95   Environment: Greenhouse Gas Emissions  Environment
# 96   Environment: Greenhouse Gas Emissions  Environment
# 97   Environment: Greenhouse Gas Emissions  Environment
# 98   Environment: Greenhouse Gas Emissions  Environment
# 99   Environment: Greenhouse Gas Emissions  Environment
# 100  Environment: Greenhouse Gas Emissions  Environment
# 101  Environment: Greenhouse Gas Emissions  Environment
# 102  Environment: Greenhouse Gas Emissions  Environment
# 103  Environment: Greenhouse Gas Emissions  Environment
# 104  Environment: Greenhouse Gas Emissions  Environment
# 105  Environment: Greenhouse Gas Emissions  Environment
# 106  Environment: Greenhouse Gas Emissions  Environment
# 107  Environment: Greenhouse Gas Emissions  Environment
# 108  Environment: Greenhouse Gas Emissions  Environment
# 109  Environment: Greenhouse Gas Emissions  Environment
# 110  Environment: Greenhouse Gas Emissions  Environment
# 111  Environment: Greenhouse Gas Emissions  Environment
# 112  Environment: Greenhouse Gas Emissions  Environment
# 113  Environment: Greenhouse Gas Emissions  Environment
#
#                     SubTopic1                    SubTopic2  \
# 71   Greenhouse Gas Emissions            Methane emissions
# 72   Greenhouse Gas Emissions            Methane emissions
# 73   Greenhouse Gas Emissions            Methane emissions
# 74   Greenhouse Gas Emissions            Methane emissions
# 75   Greenhouse Gas Emissions      Nitrous oxide emissions
# 76   Greenhouse Gas Emissions            Methane emissions
# 77   Greenhouse Gas Emissions            Methane emissions
# 78   Greenhouse Gas Emissions            Methane emissions
# 79   Greenhouse Gas Emissions      Nitrous oxide emissions
# 80   Greenhouse Gas Emissions      Nitrous oxide emissions
# 81   Greenhouse Gas Emissions      Nitrous oxide emissions
# 82   Greenhouse Gas Emissions      Nitrous oxide emissions
# 83   Greenhouse Gas Emissions      Nitrous oxide emissions
# 84   Greenhouse Gas Emissions            Methane emissions
# 85   Greenhouse Gas Emissions      Nitrous oxide emissions
# 86   Greenhouse Gas Emissions      Nitrous oxide emissions
# 87   Greenhouse Gas Emissions      Nitrous oxide emissions
# 88   Greenhouse Gas Emissions            Methane emissions
# 89   Greenhouse Gas Emissions            Methane emissions
# 90   Greenhouse Gas Emissions      Nitrous oxide emissions
# 91   Greenhouse Gas Emissions                        Total
# 92   Greenhouse Gas Emissions     Carbon dioxide emissions
# 93   Greenhouse Gas Emissions     Carbon dioxide emissions
# 94   Greenhouse Gas Emissions     Carbon dioxide emissions
# 95   Greenhouse Gas Emissions     Carbon dioxide emissions
# 96   Greenhouse Gas Emissions     Carbon dioxide emissions
# 97   Greenhouse Gas Emissions     Carbon dioxide emissions
# 98   Greenhouse Gas Emissions     Carbon dioxide emissions
# 99   Greenhouse Gas Emissions     Carbon dioxide emissions
# 100  Greenhouse Gas Emissions     Carbon dioxide emissions
# 101  Greenhouse Gas Emissions     Carbon dioxide emissions
# 102  Greenhouse Gas Emissions     Carbon dioxide emissions
# 103  Greenhouse Gas Emissions     Carbon dioxide emissions
# 104  Greenhouse Gas Emissions     Carbon dioxide emissions
# 105  Greenhouse Gas Emissions  Fluorinated Gases emissions
# 106  Greenhouse Gas Emissions     Carbon dioxide emissions
# 107  Greenhouse Gas Emissions     Carbon dioxide emissions
# 108  Greenhouse Gas Emissions     Carbon dioxide emissions
# 109  Greenhouse Gas Emissions     Carbon dioxide emissions
# 110  Greenhouse Gas Emissions     Carbon dioxide emissions
# 111  Greenhouse Gas Emissions         All Greenhouse Gases
# 112  Greenhouse Gas Emissions         All Greenhouse Gases
# 113  Greenhouse Gas Emissions         All Greenhouse Gases
#
#                                            SubTopic3
# 71                                         Transport
# 72                                    Power Industry
# 73                                             Waste
# 74                              Industrial Processes
# 75                                       Agriculture
# 76                             Industrial Combustion
# 77                                       Agriculture
# 78   Excluding  Land Use and Land-Use Change (LULUC)
# 79                                             Waste
# 80                                         Transport
# 81                                    Power Industry
# 82                              Industrial Processes
# 83                             Industrial Combustion
# 84   Excluding  Land Use and Land-Use Change (LULUC)
# 85   Excluding  Land Use and Land-Use Change (LULUC)
# 86                                Fugitive Emissions
# 87                                         Buildings
# 88                                         Buildings
# 89                                Fugitive Emissions
# 90   Excluding  Land Use and Land-Use Change (LULUC)
# 91   Excluding  Land Use and Land-Use Change (LULUC)
# 92                                         Transport
# 93                                    Power Industry
# 94                              Industrial Processes
# 95                             Industrial Combustion
# 96                                Fugitive Emissions
# 97                                         Buildings
# 98                                       Agriculture
# 99                                             Waste
# 100  Excluding  Land Use and Land-Use Change (LULUC)
# 101  Excluding  Land Use and Land-Use Change (LULUC)
# 102   Including Land Use and Land-Use Change (LULUC)
# 103   Including Land Use and Land-Use Change (LULUC)
# 104   Including Land Use and Land-Use Change (LULUC)
# 105                             Industrial Processes
# 106                          Carbon intensity of GDP
# 107                          Carbon intensity of GDP
# 108   Including Land Use and Land-Use Change (LULUC)
# 109   Including Land Use and Land-Use Change (LULUC)
# 110  Excluding  Land Use and Land-Use Change (LULUC)
# 111  Excluding  Land Use and Land-Use Change (LULUC)
# 112  Excluding  Land Use and Land-Use Change (LULUC)
# 113   Including Land Use and Land-Use Change (LULUC)

# %%
has_list = environment.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


environment_with_lists = environment[has_list]
print(environment_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(environment[environment['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
#                     Code  \
# 4         AG.CON.FERT.ZS
# 7      AG.CON.FERT.PT.ZS
# 30  EN.ATM.PM25.MC.T3.ZS
# 31  EN.ATM.PM25.MC.T2.ZS
# 32  EN.ATM.PM25.MC.T1.ZS
# 33     EN.ATM.PM25.MC.ZS
# 34     EN.ATM.PM25.MC.M3
#
#                                                                                      Indicator Name  \
# 4                                     Fertilizer consumption (kilograms per hectare of arable land)
# 7                                               Fertilizer consumption (% of fertilizer production)
# 30  PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-3 value (% of total)
# 31  PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-2 value (% of total)
# 32  PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-1 value (% of total)
# 33     PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)
# 34                           PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)
#
#                            General Topic        Topic  \
# 4   Environment: Agricultural production  Environment
# 7   Environment: Agricultural production  Environment
# 30                Environment: Emissions  Environment
# 31                Environment: Emissions  Environment
# 32                Environment: Emissions  Environment
# 33                Environment: Emissions  Environment
# 34                Environment: Emissions  Environment
#
#                   SubTopic1                                 SubTopic2  \
# 4   Agricultural production                   Consumption (or condom)
# 7   Agricultural production                   Consumption (or condom)
# 30                Emissions  Atmosphere (or automated teller machine)
# 31                Emissions  Atmosphere (or automated teller machine)
# 32                Emissions  Atmosphere (or automated teller machine)
# 33                Emissions  Atmosphere (or automated teller machine)
# 34                Emissions  Atmosphere (or automated teller machine)
#
#                SubTopic3
# 4             Fertilizer
# 7             Fertilizer
# 30  PM 2.5 air pollution
# 31  PM 2.5 air pollution
# 32  PM 2.5 air pollution
# 33  PM 2.5 air pollution
# 34  PM 2.5 air pollution

# %%
environment.loc[environment['Code'].str.startswith('AG.CON') , "SubTopic2"] = "Consumption"
environment.loc[environment['Code'].str.startswith('EN.ATM') , "SubTopic2"] = "Atmosphere"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(environment[environment['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Financial

# %%
financial  = dfs["financial"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(financial[financial['SubTopic2'].isna() | financial['SubTopic3'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
financial
# Out:
#                     Code                                     Indicator Name  \
# 0      FX.OWN.TOTL.SO.ZS  Account ownership at a financial institution o...
# 1         FB.CBK.DPTR.P3  Depositors with commercial banks (per 1,000 ad...
# 2      FX.OWN.TOTL.PL.ZS  Account ownership at a financial institution o...
# 3      FX.OWN.TOTL.40.ZS  Account ownership at a financial institution o...
# 4      FX.OWN.TOTL.OL.ZS  Account ownership at a financial institution o...
# 5      FX.OWN.TOTL.MA.ZS  Account ownership at a financial institution o...
# 6      FX.OWN.TOTL.60.ZS  Account ownership at a financial institution o...
# 7      FX.OWN.TOTL.YG.ZS  Account ownership at a financial institution o...
# 8         FB.CBK.BRCH.P5      Commercial bank branches (per 100,000 adults)
# 9         FX.OWN.TOTL.ZS  Account ownership at a financial institution o...
# 10     FX.OWN.TOTL.FE.ZS  Account ownership at a financial institution o...
# 11        FB.CBK.BRWR.P3  Borrowers from commercial banks (per 1,000 adu...
# 12     SI.RMT.COST.OB.ZS  Average transaction cost of sending remittance...
# 13     SI.RMT.COST.IB.ZS  Average transaction cost of sending remittance...
# 14        FB.ATM.TOTL.P5  Automated teller machines (ATMs) (per 100,000 ...
# 15     FS.AST.DOMS.GD.ZS  Domestic credit provided by financial sector (...
# 16        FM.AST.DOMS.CN                  Net domestic credit (current LCU)
# 17        FB.BNK.CAPA.ZS                   Bank capital to assets ratio (%)
# 18     FM.AST.CGOV.ZG.M3  Claims on central government (annual growth as...
# 19     FS.AST.CGOV.GD.ZS         Claims on central government, etc. (% GDP)
# 20     FM.AST.PRVT.GD.ZS   Monetary Sector credit to private sector (% GDP)
# 21        FM.AST.NFRG.CN                   Net foreign assets (current LCU)
# 22     FM.AST.PRVT.ZG.M3  Claims on private sector (annual growth as % o...
# 23     FS.AST.PRVT.GD.ZS       Domestic credit to private sector (% of GDP)
# 24     FD.AST.PRVT.GD.ZS  Domestic credit to private sector by banks (% ...
# 25     FS.AST.DOMO.GD.ZS  Claims on other sectors of the domestic econom...
# 26     FM.AST.DOMO.ZG.M3  Claims on other sectors of the domestic econom...
# 27     FD.RES.LIQU.AS.ZS      Bank liquid reserves to bank assets ratio (%)
# 28        FB.AST.NPER.ZS  Bank nonperforming loans to total gross loans (%)
# 29     CM.MKT.TRAD.GD.ZS              Stocks traded, total value (% of GDP)
# 30        CM.MKT.TRAD.CD           Stocks traded, total value (current US$)
# 31           CM.MKT.TRNR  Stocks traded, turnover ratio of domestic shar...
# 32        CM.MKT.LDOM.NO                   Listed domestic companies, total
# 33        CM.MKT.INDX.ZG        S&P Global Equity Indices (annual % change)
# 34     CM.MKT.LCAP.GD.ZS  Market capitalization of listed domestic compa...
# 35        CM.MKT.LCAP.CD  Market capitalization of listed domestic compa...
# 36           FP.CPI.TOTL                  Consumer price index (2010 = 100)
# 37           PA.NUS.FCRF  Official exchange rate (LCU per US$, period av...
# 38           PA.NUS.ATLS    DEC alternative conversion factor (LCU per US$)
# 39           PX.REX.REER    Real effective exchange rate index (2010 = 100)
# 40           FP.WPI.TOTL                 Wholesale price index (2010 = 100)
# 41     NY.GDP.DEFL.KD.ZG                 Inflation, GDP deflator (annual %)
# 42        FP.CPI.TOTL.ZG              Inflation, consumer prices (annual %)
# 43     NY.GDP.DEFL.ZS.AD  GDP deflator: linked series (base year varies ...
# 44        NY.GDP.DEFL.ZS         GDP deflator (base year varies by country)
# 45  NY.GDP.DEFL.KD.ZG.AD  Inflation, GDP deflator: linked series (annual %)
# 46           FR.INR.LEND                          Lending interest rate (%)
# 47           FR.INR.DPST                          Deposit interest rate (%)
# 48           FR.INR.RINR                             Real interest rate (%)
# 49           FR.INR.RISK  Risk premium on lending (lending rate minus tr...
# 50           FR.INR.LNDP  Interest rate spread (lending rate minus depos...
# 51     FM.LBL.BMNY.GD.ZS                             Broad money (% of GDP)
# 52     FM.LBL.BMNY.IR.ZS                Broad money to total reserves ratio
# 53        FM.LBL.BMNY.CN                          Broad money (current LCU)
# 54        FM.LBL.BMNY.ZG                      Broad money growth (annual %)
#
#                                         General Topic             Topic  \
# 0                            Financial Sector: Access  Financial Sector
# 1                            Financial Sector: Access  Financial Sector
# 2                            Financial Sector: Access  Financial Sector
# 3                            Financial Sector: Access  Financial Sector
# 4                            Financial Sector: Access  Financial Sector
# 5                            Financial Sector: Access  Financial Sector
# 6                            Financial Sector: Access  Financial Sector
# 7                            Financial Sector: Access  Financial Sector
# 8                            Financial Sector: Access  Financial Sector
# 9                            Financial Sector: Access  Financial Sector
# 10                           Financial Sector: Access  Financial Sector
# 11                           Financial Sector: Access  Financial Sector
# 12                           Financial Sector: Access  Financial Sector
# 13                           Financial Sector: Access  Financial Sector
# 14                           Financial Sector: Access  Financial Sector
# 15                           Financial Sector: Assets  Financial Sector
# 16                           Financial Sector: Assets  Financial Sector
# 17                           Financial Sector: Assets  Financial Sector
# 18                           Financial Sector: Assets  Financial Sector
# 19                           Financial Sector: Assets  Financial Sector
# 20                           Financial Sector: Assets  Financial Sector
# 21                           Financial Sector: Assets  Financial Sector
# 22                           Financial Sector: Assets  Financial Sector
# 23                           Financial Sector: Assets  Financial Sector
# 24                           Financial Sector: Assets  Financial Sector
# 25                           Financial Sector: Assets  Financial Sector
# 26                           Financial Sector: Assets  Financial Sector
# 27                           Financial Sector: Assets  Financial Sector
# 28                           Financial Sector: Assets  Financial Sector
# 29                  Financial Sector: Capital markets  Financial Sector
# 30                  Financial Sector: Capital markets  Financial Sector
# 31                  Financial Sector: Capital markets  Financial Sector
# 32                  Financial Sector: Capital markets  Financial Sector
# 33                  Financial Sector: Capital markets  Financial Sector
# 34                  Financial Sector: Capital markets  Financial Sector
# 35                  Financial Sector: Capital markets  Financial Sector
# 36          Financial Sector: Exchange rates & prices  Financial Sector
# 37          Financial Sector: Exchange rates & prices  Financial Sector
# 38          Financial Sector: Exchange rates & prices  Financial Sector
# 39          Financial Sector: Exchange rates & prices  Financial Sector
# 40          Financial Sector: Exchange rates & prices  Financial Sector
# 41          Financial Sector: Exchange rates & prices  Financial Sector
# 42          Financial Sector: Exchange rates & prices  Financial Sector
# 43          Financial Sector: Exchange rates & prices  Financial Sector
# 44          Financial Sector: Exchange rates & prices  Financial Sector
# 45          Financial Sector: Exchange rates & prices  Financial Sector
# 46                   Financial Sector: Interest rates  Financial Sector
# 47                   Financial Sector: Interest rates  Financial Sector
# 48                   Financial Sector: Interest rates  Financial Sector
# 49                   Financial Sector: Interest rates  Financial Sector
# 50                   Financial Sector: Interest rates  Financial Sector
# 51  Financial Sector: Monetary holdings (liabilities)  Financial Sector
# 52  Financial Sector: Monetary holdings (liabilities)  Financial Sector
# 53  Financial Sector: Monetary holdings (liabilities)  Financial Sector
# 54  Financial Sector: Monetary holdings (liabilities)  Financial Sector
#
#                           SubTopic1                                 SubTopic2  \
# 0                            Access                                 Ownership
# 1                            Access                           Commercial bank
# 2                            Access                                 Ownership
# 3                            Access                                 Ownership
# 4                            Access                                 Ownership
# 5                            Access                                 Ownership
# 6                            Access                                 Ownership
# 7                            Access                                 Ownership
# 8                            Access                           Commercial bank
# 9                            Access                                 Ownership
# 10                           Access                                 Ownership
# 11                           Access                           Commercial bank
# 12                           Access                               Remittances
# 13                           Access                               Remittances
# 14                           Access  Atmosphere (or automated teller machine)
# 15                           Assets                                     Asset
# 16                           Assets                                     Asset
# 17                           Assets                                      Bank
# 18                           Assets                                     Asset
# 19                           Assets                                     Asset
# 20                           Assets                                     Asset
# 21                           Assets                                     Asset
# 22                           Assets                                     Asset
# 23                           Assets                                     Asset
# 24                           Assets                                     Asset
# 25                           Assets                                     Asset
# 26                           Assets                                     Asset
# 27                           Assets                 Reserves (or residential)
# 28                           Assets                                     Asset
# 29                  Capital markets                           Markets (stock)
# 30                  Capital markets                           Markets (stock)
# 31                  Capital markets                           Markets (stock)
# 32                  Capital markets                           Markets (stock)
# 33                  Capital markets                           Markets (stock)
# 34                  Capital markets                           Markets (stock)
# 35                  Capital markets                           Markets (stock)
# 36          Exchange rates & prices                      Consumer price index
# 37          Exchange rates & prices               Local currency to US dollar
# 38          Exchange rates & prices               Local currency to US dollar
# 39          Exchange rates & prices                        Real exchange rate
# 40          Exchange rates & prices                     Wholesale price index
# 41          Exchange rates & prices                    Gross domestic product
# 42          Exchange rates & prices                      Consumer price index
# 43          Exchange rates & prices                    Gross domestic product
# 44          Exchange rates & prices                    Gross domestic product
# 45          Exchange rates & prices                    Gross domestic product
# 46                   Interest rates                             Interest rate
# 47                   Interest rates                             Interest rate
# 48                   Interest rates                             Interest rate
# 49                   Interest rates                             Interest rate
# 50                   Interest rates                             Interest rate
# 51  Monetary holdings (liabilities)                                 Liability
# 52  Monetary holdings (liabilities)                                 Liability
# 53  Monetary holdings (liabilities)                                 Liability
# 54  Monetary holdings (liabilities)                                 Liability
#
#                                     SubTopic3
# 0                                       Total
# 1                                  Depositors
# 2                                       Total
# 3                                       Total
# 4                                       Total
# 5                                       Total
# 6                                       Total
# 7                                       Total
# 8                               Bank branches
# 9                                       Total
# 10                                      Total
# 11                                  Borrowers
# 12                                       Cost
# 13                                       Cost
# 14                                      Total
# 15                                   Domestic
# 16                                   Domestic
# 17                          Capital to assets
# 18                         Central government
# 19                         Central government
# 20                                    Private
# 21                                Net foreign
# 22                                    Private
# 23                                    Private
# 24                                    Private
# 25                     Other domestic sectors
# 26                     Other domestic sectors
# 27                                     Liquid
# 28                              Nonperforming
# 29                                     Traded
# 30                                     Traded
# 31     Transport receipts (or Turnover ratio)
# 32                  Listed domestic companies
# 33                                      Index
# 34  Market capitalization of listed companies
# 35  Market capitalization of listed companies
# 36                                      Total
# 37   IMF IFS code rf (official exchange rate)
# 38                               Atlas method
# 39               Real effective exchange rate
# 40                                      Total
# 41                                   Deflator
# 42                                      Total
# 43                                   Deflator
# 44                                   Deflator
# 45                                   Deflator
# 46                                    Lending
# 47                                    Deposit
# 48                         Real interest rate
# 49                               Risk premium
# 50            Lending rate minus deposit rate
# 51                                Broad money
# 52                                Broad money
# 53                                Broad money
# 54                                Broad money

# %%
has_list = financial.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


financial_with_lists = financial[has_list]
print(financial_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(financial[financial['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
#                  Code                                         Indicator Name  \
# 14     FB.ATM.TOTL.P5  Automated teller machines (ATMs) (per 100,000 adults)
# 27  FD.RES.LIQU.AS.ZS          Bank liquid reserves to bank assets ratio (%)
#
#                General Topic             Topic SubTopic1  \
# 14  Financial Sector: Access  Financial Sector    Access
# 27  Financial Sector: Assets  Financial Sector    Assets
#
#                                    SubTopic2 SubTopic3
# 14  Atmosphere (or automated teller machine)     Total
# 27                 Reserves (or residential)    Liquid

# %%
financial.loc[financial['Code'].str.startswith('FB.ATM') , "SubTopic2"] = "Automated teller machines"
financial.loc[financial['Code'].str.startswith('FD.RES') , "SubTopic2"] = "Reserves"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(financial[financial['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
#            Code                                        Indicator Name  \
# 31  CM.MKT.TRNR  Stocks traded, turnover ratio of domestic shares (%)
#
#                         General Topic             Topic        SubTopic1  \
# 31  Financial Sector: Capital markets  Financial Sector  Capital markets
#
#           SubTopic2                               SubTopic3
# 31  Markets (stock)  Transport receipts (or Turnover ratio)

# %%
financial.loc[financial['Code'].str.startswith('CM.MKT.TRNR') , "SubTopic3"] = "Turnover ratio"

# %% [markdown]
# # More adjustments (personal)

# %%
financial.loc[financial['Code'].str.contains('FM.AST') , "SubTopic2"] = "Monetary Survey"
financial.loc[financial['Code'].str.contains('FS.FS') , "SubTopic2"] = "Bank Survey"
financial.loc[financial['Code'].str.contains('FB.AST') , "SubTopic2"] = "Bank (miscellaneous)"
financial.loc[financial['Code'].str.contains('FD.AST') , "SubTopic2"] = "Deposit money banks"

# %% [markdown]
# # Gender

# %%
gender  = dfs["gender"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(gender)
# Out:
#                  Code  \
# 0   SP.M18.2024.FE.ZS
# 1   SP.M15.2024.FE.ZS
# 2      SG.VAW.REAS.ZS
# 3      SG.VAW.ARGU.ZS
# 4      SG.VAW.1549.ZS
# 5      SG.VAW.BURN.ZS
# 6      SG.VAW.GOES.ZS
# 7      SG.VAW.NEGL.ZS
# 8      SG.VAW.REFU.ZS
# 9      SG.TIM.UWRK.MA
# 10     SG.TIM.UWRK.FE
# 11  SG.DMK.SRCR.FN.ZS
# 12        SG.LAW.INDX
# 13     SG.GEN.PARL.ZS
# 14  SG.DMK.ALLD.FN.ZS
#
#                                                                                                                                  Indicator Name  \
# 0                                                                                Women who were first married by age 18 (% of women ages 20-24)
# 1                                                                                Women who were first married by age 15 (% of women ages 20-24)
# 2                                                        Women who believe a husband is justified in beating his wife (any of five reasons) (%)
# 3                                                     Women who believe a husband is justified in beating his wife when she argues with him (%)
# 4                 Proportion of women subjected to physical and/or sexual violence in the last 12 months (% of ever-partnered women ages 15-49)
# 5                                                      Women who believe a husband is justified in beating his wife when she burns the food (%)
# 6                                        Women who believe a husband is justified in beating his wife when she goes out without telling him (%)
# 7                                               Women who believe a husband is justified in beating his wife when she neglects the children (%)
# 8                                                Women who believe a husband is justified in beating his wife when she refuses sex with him (%)
# 9                                                            Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)
# 10                                                         Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)
# 11  Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)
# 12                                                                                         Women Business and the Law Index Score (scale 1-100)
# 13                                                                                Proportion of seats held by women in national parliaments (%)
# 14          Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
#
#                             General Topic   Topic  \
# 0                          Gender: Agency  Gender
# 1                          Gender: Agency  Gender
# 2                          Gender: Health  Gender
# 3                          Gender: Health  Gender
# 4                          Gender: Health  Gender
# 5                          Gender: Health  Gender
# 6                          Gender: Health  Gender
# 7                          Gender: Health  Gender
# 8                          Gender: Health  Gender
# 9          Gender: Participation & access  Gender
# 10         Gender: Participation & access  Gender
# 11  Gender: Public life & decision making  Gender
# 12  Gender: Public life & decision making  Gender
# 13  Gender: Public life & decision making  Gender
# 14  Gender: Public life & decision making  Gender
#
#                         SubTopic1               SubTopic2  \
# 0                          Agency       Married by age 18
# 1                          Agency                    None
# 2                          Health  Violence against women
# 3                          Health  Violence against women
# 4                          Health  Violence against women
# 5                          Health  Violence against women
# 6                          Health  Violence against women
# 7                          Health  Violence against women
# 8                          Health  Violence against women
# 9          Participation & access                    Time
# 10         Participation & access                    Time
# 11  Public life & decision making         Decision making
# 12  Public life & decision making                     Law
# 13  Public life & decision making                  Gender
# 14  Public life & decision making         Decision making
#
#                                         SubTopic3
# 0                                       Age 20-24
# 1                                       Age 20-24
# 2                                          Reason
# 3                                           Argue
# 4                                            None
# 5                                      Burns food
# 6                                        Goes out
# 7                               Neglects children
# 8                                          Refuse
# 9                                     Unpaid work
# 10                                    Unpaid work
# 11                                           None
# 12                                          Index
# 13                           National parliaments
# 14  Total development assistance and official aid

# %%
with pd.option_context('display.max_colwidth', 200):

    display(gender[gender['SubTopic2'].isna()])
# Out:
#                 Code  \
# 1  SP.M15.2024.FE.ZS
#
#                                                    Indicator Name  \
# 1  Women who were first married by age 15 (% of women ages 20-24)
#
#     General Topic   Topic SubTopic1 SubTopic2  SubTopic3
# 1  Gender: Agency  Gender    Agency      None  Age 20-24

# %%
gender.loc[gender["Code"] == "SP.M15.2024.FE.ZS", "SubTopic2"] = "Married by age 15"

# %%
with pd.option_context('display.max_colwidth', 200):

    display(gender[gender['SubTopic3'].isna()])
# Out:
#                  Code  \
# 4      SG.VAW.1549.ZS
# 11  SG.DMK.SRCR.FN.ZS
#
#                                                                                                                                  Indicator Name  \
# 4                 Proportion of women subjected to physical and/or sexual violence in the last 12 months (% of ever-partnered women ages 15-49)
# 11  Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)
#
#                             General Topic   Topic  \
# 4                          Gender: Health  Gender
# 11  Gender: Public life & decision making  Gender
#
#                         SubTopic1               SubTopic2 SubTopic3
# 4                          Health  Violence against women      None
# 11  Public life & decision making         Decision making      None

# %%
gender.loc[gender["Code"] == "SG.VAW.1549.ZS", "SubTopic3"] = "Age 15-49"
gender.loc[gender["Code"] == "SG.DMK.SRCR.FN.ZS", "SubTopic3"] = "Age 15-49"

# %%
with pd.option_context('display.max_colwidth', 200):

    display(gender)
# Out:
#                  Code  \
# 0   SP.M18.2024.FE.ZS
# 1   SP.M15.2024.FE.ZS
# 2      SG.VAW.REAS.ZS
# 3      SG.VAW.ARGU.ZS
# 4      SG.VAW.1549.ZS
# 5      SG.VAW.BURN.ZS
# 6      SG.VAW.GOES.ZS
# 7      SG.VAW.NEGL.ZS
# 8      SG.VAW.REFU.ZS
# 9      SG.TIM.UWRK.MA
# 10     SG.TIM.UWRK.FE
# 11  SG.DMK.SRCR.FN.ZS
# 12        SG.LAW.INDX
# 13     SG.GEN.PARL.ZS
# 14  SG.DMK.ALLD.FN.ZS
#
#                                                                                                                                  Indicator Name  \
# 0                                                                                Women who were first married by age 18 (% of women ages 20-24)
# 1                                                                                Women who were first married by age 15 (% of women ages 20-24)
# 2                                                        Women who believe a husband is justified in beating his wife (any of five reasons) (%)
# 3                                                     Women who believe a husband is justified in beating his wife when she argues with him (%)
# 4                 Proportion of women subjected to physical and/or sexual violence in the last 12 months (% of ever-partnered women ages 15-49)
# 5                                                      Women who believe a husband is justified in beating his wife when she burns the food (%)
# 6                                        Women who believe a husband is justified in beating his wife when she goes out without telling him (%)
# 7                                               Women who believe a husband is justified in beating his wife when she neglects the children (%)
# 8                                                Women who believe a husband is justified in beating his wife when she refuses sex with him (%)
# 9                                                            Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)
# 10                                                         Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)
# 11  Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)
# 12                                                                                         Women Business and the Law Index Score (scale 1-100)
# 13                                                                                Proportion of seats held by women in national parliaments (%)
# 14          Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
#
#                             General Topic   Topic  \
# 0                          Gender: Agency  Gender
# 1                          Gender: Agency  Gender
# 2                          Gender: Health  Gender
# 3                          Gender: Health  Gender
# 4                          Gender: Health  Gender
# 5                          Gender: Health  Gender
# 6                          Gender: Health  Gender
# 7                          Gender: Health  Gender
# 8                          Gender: Health  Gender
# 9          Gender: Participation & access  Gender
# 10         Gender: Participation & access  Gender
# 11  Gender: Public life & decision making  Gender
# 12  Gender: Public life & decision making  Gender
# 13  Gender: Public life & decision making  Gender
# 14  Gender: Public life & decision making  Gender
#
#                         SubTopic1               SubTopic2  \
# 0                          Agency       Married by age 18
# 1                          Agency       Married by age 15
# 2                          Health  Violence against women
# 3                          Health  Violence against women
# 4                          Health  Violence against women
# 5                          Health  Violence against women
# 6                          Health  Violence against women
# 7                          Health  Violence against women
# 8                          Health  Violence against women
# 9          Participation & access                    Time
# 10         Participation & access                    Time
# 11  Public life & decision making         Decision making
# 12  Public life & decision making                     Law
# 13  Public life & decision making                  Gender
# 14  Public life & decision making         Decision making
#
#                                         SubTopic3
# 0                                       Age 20-24
# 1                                       Age 20-24
# 2                                          Reason
# 3                                           Argue
# 4                                       Age 15-49
# 5                                      Burns food
# 6                                        Goes out
# 7                               Neglects children
# 8                                          Refuse
# 9                                     Unpaid work
# 10                                    Unpaid work
# 11                                      Age 15-49
# 12                                          Index
# 13                           National parliaments
# 14  Total development assistance and official aid

# %%
has_list = gender.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


gender_with_lists = gender[has_list]
print(gender_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(gender[gender['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
with pd.option_context('display.max_colwidth', 200):
    display(gender[gender['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Health

# %%
health  = dfs["health"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(health)
# Out:
#                   Code  \
# 0       SH.MLR.NETS.ZS
# 1       SH.TBS.CURE.ZS
# 2       SH.STA.BASS.ZS
# 3    SH.STA.BASS.RU.ZS
# 4    SH.STA.BASS.UR.ZS
# ..                 ...
# 243     SH.UHC.FBP1.ZS
# 244     SH.UHC.NOPR.ZS
# 245     SH.UHC.NOP2.ZS
# 246     SH.UHC.NOP1.ZS
# 247  SH.UHC.SRVS.CV.XD
#
#                                                                                                                      Indicator Name  \
# 0                                                                     Use of insecticide-treated bed nets (% of under-5 population)
# 1                                                                              Tuberculosis treatment success rate (% of new cases)
# 2                                                                 People using at least basic sanitation services (% of population)
# 3                                                    People using at least basic sanitation services, rural (% of rural population)
# 4                                                    People using at least basic sanitation services, urban (% of urban population)
# ..                                                                                                                              ...
# 243  Proportion of population pushed further below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)
# 244           Proportion of population pushed below the 60% median consumption poverty line by out-of-pocket health expenditure (%)
# 245          Proportion of population pushed below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)
# 246          Proportion of population pushed below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)
# 247                                                                                                      UHC service coverage index
#
#                          General Topic   Topic                  SubTopic1  \
# 0           Health: Disease prevention  Health         Disease prevention
# 1           Health: Disease prevention  Health         Disease prevention
# 2           Health: Disease prevention  Health         Disease prevention
# 3           Health: Disease prevention  Health         Disease prevention
# 4           Health: Disease prevention  Health         Disease prevention
# ..                                 ...     ...                        ...
# 243  Health: Universal Health Coverage  Health  Universal Health Coverage
# 244  Health: Universal Health Coverage  Health  Universal Health Coverage
# 245  Health: Universal Health Coverage  Health  Universal Health Coverage
# 246  Health: Universal Health Coverage  Health  Universal Health Coverage
# 247  Health: Universal Health Coverage  Health  Universal Health Coverage
#
#         SubTopic2                      SubTopic3
# 0         Malaria   Insecticide-treated bed nets
# 1    Tuberculosis               Cure (treatment)
# 2      Stationary                           None
# 3      Stationary                           None
# 4      Stationary                           None
# ..            ...                            ...
# 243          None                           None
# 244          None                           None
# 245          None  Number of poor at $3.10 a day
# 246          None  Number of poor at $1.90 a day
# 247          None                       Services
#
# [248 rows x 7 columns]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(health[health['SubTopic2'].isna()])
# Out:
#                   Code  \
# 236     SH.UHC.FBPR.ZS
# 237  SH.UHC.OOPC.25.ZS
# 238  SH.UHC.OOPC.10.ZS
# 239     SH.UHC.TOTR.ZS
# 240     SH.UHC.TOT2.ZS
# 241     SH.UHC.TOT1.ZS
# 242     SH.UHC.FBP2.ZS
# 243     SH.UHC.FBP1.ZS
# 244     SH.UHC.NOPR.ZS
# 245     SH.UHC.NOP2.ZS
# 246     SH.UHC.NOP1.ZS
# 247  SH.UHC.SRVS.CV.XD
#
#                                                                                                                                Indicator Name  \
# 236        Proportion of population pushed further below the 60% median consumption poverty line by out-of-pocket health care expenditure (%)
# 237           Proportion of population spending more than 25% of household consumption or income on out-of-pocket health care expenditure (%)
# 238           Proportion of population spending more than 10% of household consumption or income on out-of-pocket health care expenditure (%)
# 239   Proportion of population pushed or further pushed below the 60% median consumption poverty line by out-of-pocket health expenditure (%)
# 240  Proportion of population pushed or further pushed below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)
# 241  Proportion of population pushed or further pushed below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)
# 242            Proportion of population pushed further below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)
# 243            Proportion of population pushed further below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)
# 244                     Proportion of population pushed below the 60% median consumption poverty line by out-of-pocket health expenditure (%)
# 245                    Proportion of population pushed below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)
# 246                    Proportion of population pushed below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)
# 247                                                                                                                UHC service coverage index
#
#                          General Topic   Topic                  SubTopic1  \
# 236  Health: Universal Health Coverage  Health  Universal Health Coverage
# 237  Health: Universal Health Coverage  Health  Universal Health Coverage
# 238  Health: Universal Health Coverage  Health  Universal Health Coverage
# 239  Health: Universal Health Coverage  Health  Universal Health Coverage
# 240  Health: Universal Health Coverage  Health  Universal Health Coverage
# 241  Health: Universal Health Coverage  Health  Universal Health Coverage
# 242  Health: Universal Health Coverage  Health  Universal Health Coverage
# 243  Health: Universal Health Coverage  Health  Universal Health Coverage
# 244  Health: Universal Health Coverage  Health  Universal Health Coverage
# 245  Health: Universal Health Coverage  Health  Universal Health Coverage
# 246  Health: Universal Health Coverage  Health  Universal Health Coverage
# 247  Health: Universal Health Coverage  Health  Universal Health Coverage
#
#     SubTopic2                      SubTopic3
# 236      None                           None
# 237      None                  Out-of-pocket
# 238      None                  Out-of-pocket
# 239      None                           None
# 240      None                           None
# 241      None                           None
# 242      None                           None
# 243      None                           None
# 244      None                           None
# 245      None  Number of poor at $3.10 a day
# 246      None  Number of poor at $1.90 a day
# 247      None                       Services

# %%
health.loc[health["Code"] == "SH.UHC.SRVS.CV.XD", ["SubTopic2", "SubTopic3"]] = ["Service Coverage", "Index"]

# %%
health.loc[health["Code"] == "SH.UHC.NOP2.ZS",  "SubTopic3"] = ["3.65(2017 PPP) poverty line"]
health.loc[health["Code"] == "SH.UHC.NOP1.ZS",  "SubTopic3"] = ["2.15(2017 PPP) poverty line"]
health.loc[health["Code"] == "SH.UHC.OOPC.10.ZS",  "SubTopic3"] = ["10% of household consumption or income"]
health.loc[health["Code"] == "SH.UHC.OOPC.25.ZS",  "SubTopic3"] = ["25% of household consumption or income"]

# %%
health.loc[health['Code'].str.startswith('SH.UHC') & 
           health['Code'].str.contains('NOP1|NOP2|NOPR', regex=True), "SubTopic2"] = "Poverty Line (pushed below)"

health.loc[health['Code'].str.startswith('SH.UHC') & 
           health['Code'].str.contains('FBP1|FBP2|FBPR', regex=True), "SubTopic2"] = "Poverty Line (pushed further below)"

health.loc[health['Code'].str.startswith('SH.UHC') & 
           health['Code'].str.contains('TOT1|TOT2|TOTR', regex=True), "SubTopic2"] = "Poverty Line (pushed or further pushed below)"

health.loc[health['Code'].str.startswith('SH.UHC') & 
           health['Code'].str.contains('OOPC', regex=True), "SubTopic2"] = "Poverty Line (spending more)"

# %%
health_subtopic3_mapping = {
    "NOPR": "60% median consumption poverty line",
    "FBP1": "2.15(2017 PPP) poverty line",
    "FBP2": "3.65(2017 PPP) poverty line",
    "TOT1": "2.15(2017 PPP) poverty line",
    "TOT2": "3.65(2017 PPP) poverty line",
    "TOTR": "60% median consumption poverty line",
    "FBPR": "60% median consumption poverty line"
}
health.loc[health["SubTopic3"].isna(), "SubTopic3"] = (
    health["Code"].str.split(".").str[2].map(health_subtopic3_mapping)
)

# %%
health[health['Code'].str.startswith('SH.UHC')]
# Out:
#                   Code                                     Indicator Name  \
# 236     SH.UHC.FBPR.ZS  Proportion of population pushed further below ...
# 237  SH.UHC.OOPC.25.ZS  Proportion of population spending more than 25...
# 238  SH.UHC.OOPC.10.ZS  Proportion of population spending more than 10...
# 239     SH.UHC.TOTR.ZS  Proportion of population pushed or further pus...
# 240     SH.UHC.TOT2.ZS  Proportion of population pushed or further pus...
# 241     SH.UHC.TOT1.ZS  Proportion of population pushed or further pus...
# 242     SH.UHC.FBP2.ZS  Proportion of population pushed further below ...
# 243     SH.UHC.FBP1.ZS  Proportion of population pushed further below ...
# 244     SH.UHC.NOPR.ZS  Proportion of population pushed below the 60% ...
# 245     SH.UHC.NOP2.ZS  Proportion of population pushed below the $3.6...
# 246     SH.UHC.NOP1.ZS  Proportion of population pushed below the $2.1...
# 247  SH.UHC.SRVS.CV.XD                         UHC service coverage index
#
#                          General Topic   Topic                  SubTopic1  \
# 236  Health: Universal Health Coverage  Health  Universal Health Coverage
# 237  Health: Universal Health Coverage  Health  Universal Health Coverage
# 238  Health: Universal Health Coverage  Health  Universal Health Coverage
# 239  Health: Universal Health Coverage  Health  Universal Health Coverage
# 240  Health: Universal Health Coverage  Health  Universal Health Coverage
# 241  Health: Universal Health Coverage  Health  Universal Health Coverage
# 242  Health: Universal Health Coverage  Health  Universal Health Coverage
# 243  Health: Universal Health Coverage  Health  Universal Health Coverage
# 244  Health: Universal Health Coverage  Health  Universal Health Coverage
# 245  Health: Universal Health Coverage  Health  Universal Health Coverage
# 246  Health: Universal Health Coverage  Health  Universal Health Coverage
# 247  Health: Universal Health Coverage  Health  Universal Health Coverage
#
#                                          SubTopic2  \
# 236            Poverty Line (pushed further below)
# 237                   Poverty Line (spending more)
# 238                   Poverty Line (spending more)
# 239  Poverty Line (pushed or further pushed below)
# 240  Poverty Line (pushed or further pushed below)
# 241  Poverty Line (pushed or further pushed below)
# 242            Poverty Line (pushed further below)
# 243            Poverty Line (pushed further below)
# 244                    Poverty Line (pushed below)
# 245                    Poverty Line (pushed below)
# 246                    Poverty Line (pushed below)
# 247                               Service Coverage
#
#                                   SubTopic3
# 236     60% median consumption poverty line
# 237  25% of household consumption or income
# 238  10% of household consumption or income
# 239     60% median consumption poverty line
# 240             3.65(2017 PPP) poverty line
# 241             2.15(2017 PPP) poverty line
# 242             3.65(2017 PPP) poverty line
# 243             2.15(2017 PPP) poverty line
# 244     60% median consumption poverty line
# 245             3.65(2017 PPP) poverty line
# 246             2.15(2017 PPP) poverty line
# 247                                   Index

# %%
with pd.option_context('display.max_colwidth', 200):

    display(health[health['SubTopic3'].isna()])
# Out:
#                   Code  \
# 2       SH.STA.BASS.ZS
# 3    SH.STA.BASS.RU.ZS
# 4    SH.STA.BASS.UR.ZS
# 5       SH.H2O.SMDW.ZS
# 6    SH.H2O.SMDW.RU.ZS
# 7       SH.STA.SMSS.ZS
# 8    SH.STA.SMSS.RU.ZS
# 9    SH.STA.SMSS.UR.ZS
# 10   SH.H2O.SMDW.UR.ZS
# 11   SH.H2O.BASW.UR.ZS
# 12      SH.H2O.BASW.ZS
# 13   SH.H2O.BASW.RU.ZS
# 14      SH.STA.HYGN.ZS
# 15   SH.STA.HYGN.UR.ZS
# 17   SH.STA.HYGN.RU.ZS
# 34   SH.XPD.EHEX.PP.CD
# 35   SH.XPD.CHEX.PP.CD
# 36   SH.XPD.CHEX.PC.CD
# 37   SH.XPD.CHEX.GD.ZS
# 39   SH.XPD.EHEX.PC.CD
# 40   SH.XPD.PVTD.PP.CD
# 41   SH.XPD.PVTD.PC.CD
# 42   SH.XPD.PVTD.CH.ZS
# 43   SH.XPD.GHED.PP.CD
# 44   SH.XPD.GHED.PC.CD
# 45   SH.XPD.GHED.GE.ZS
# 46   SH.XPD.EHEX.CH.ZS
# 47   SH.XPD.GHED.GD.ZS
# 48   SH.XPD.GHED.CH.ZS
# 72      SH.STA.AIRP.P5
# 73   SH.STA.AIRP.FE.P5
# 74   SH.STA.AIRP.MA.P5
# 75      SH.STA.POIS.P5
# 76   SH.STA.POIS.P5.FE
# 77   SH.STA.POIS.P5.MA
# 86      SH.STA.WASH.P5
# 95      SN.ITK.MSFI.ZS
# 100     SN.ITK.SVFI.ZS
#
#                                                                                                                  Indicator Name  \
# 2                                                             People using at least basic sanitation services (% of population)
# 3                                                People using at least basic sanitation services, rural (% of rural population)
# 4                                                People using at least basic sanitation services, urban (% of urban population)
# 5                                                         People using safely managed drinking water services (% of population)
# 6                                            People using safely managed drinking water services, rural (% of rural population)
# 7                                                             People using safely managed sanitation services (% of population)
# 8                                                People using safely managed sanitation services, rural (% of rural population)
# 9                                                People using safely managed sanitation services, urban (% of urban population)
# 10                                           People using safely managed drinking water services, urban (% of urban population)
# 11                                           People using at least basic drinking water services, urban (% of urban population)
# 12                                                        People using at least basic drinking water services (% of population)
# 13                                           People using at least basic drinking water services, rural (% of rural population)
# 14                                          People with basic handwashing facilities including soap and water (% of population)
# 15                             People with basic handwashing facilities including soap and water, urban (% of urban population)
# 17                             People with basic handwashing facilities including soap and water, rural (% of rural population)
# 34                                                        External health expenditure per capita, PPP (current international $)
# 35                                                         Current health expenditure per capita, PPP (current international $)
# 36                                                                          Current health expenditure per capita (current US$)
# 37                                                                                        Current health expenditure (% of GDP)
# 39                                                                         External health expenditure per capita (current US$)
# 40                                                Domestic private health expenditure per capita, PPP (current international $)
# 41                                                                 Domestic private health expenditure per capita (current US$)
# 42                                                        Domestic private health expenditure (% of current health expenditure)
# 43                                     Domestic general government health expenditure per capita, PPP (current international $)
# 44                                                      Domestic general government health expenditure per capita (current US$)
# 45                                         Domestic general government health expenditure (% of general government expenditure)
# 46                                                                External health expenditure (% of current health expenditure)
# 47                                                                    Domestic general government health expenditure (% of GDP)
# 48                                             Domestic general government health expenditure (% of current health expenditure)
# 72                  Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)
# 73   Mortality rate attributed to household and ambient air pollution, age-standardized, female (per 100,000 female population)
# 74       Mortality rate attributed to household and ambient air pollution, age-standardized, male (per 100,000 male population)
# 75                                                Mortality rate attributed to unintentional poisoning (per 100,000 population)
# 76                                 Mortality rate attributed to unintentional poisoning, female (per 100,000 female population)
# 77                                     Mortality rate attributed to unintentional poisoning, male (per 100,000 male population)
# 86                    Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)
# 95                                                       Prevalence of moderate or severe food insecurity in the population (%)
# 100                                                                  Prevalence of severe food insecurity in the population (%)
#
#                   General Topic   Topic           SubTopic1    SubTopic2  \
# 2    Health: Disease prevention  Health  Disease prevention   Stationary
# 3    Health: Disease prevention  Health  Disease prevention   Stationary
# 4    Health: Disease prevention  Health  Disease prevention   Stationary
# 5    Health: Disease prevention  Health  Disease prevention        Water
# 6    Health: Disease prevention  Health  Disease prevention        Water
# 7    Health: Disease prevention  Health  Disease prevention   Stationary
# 8    Health: Disease prevention  Health  Disease prevention   Stationary
# 9    Health: Disease prevention  Health  Disease prevention   Stationary
# 10   Health: Disease prevention  Health  Disease prevention        Water
# 11   Health: Disease prevention  Health  Disease prevention        Water
# 12   Health: Disease prevention  Health  Disease prevention        Water
# 13   Health: Disease prevention  Health  Disease prevention        Water
# 14   Health: Disease prevention  Health  Disease prevention   Stationary
# 15   Health: Disease prevention  Health  Disease prevention   Stationary
# 17   Health: Disease prevention  Health  Disease prevention   Stationary
# 34       Health: Health systems  Health      Health systems  Expenditure
# 35       Health: Health systems  Health      Health systems  Expenditure
# 36       Health: Health systems  Health      Health systems  Expenditure
# 37       Health: Health systems  Health      Health systems  Expenditure
# 39       Health: Health systems  Health      Health systems  Expenditure
# 40       Health: Health systems  Health      Health systems  Expenditure
# 41       Health: Health systems  Health      Health systems  Expenditure
# 42       Health: Health systems  Health      Health systems  Expenditure
# 43       Health: Health systems  Health      Health systems  Expenditure
# 44       Health: Health systems  Health      Health systems  Expenditure
# 45       Health: Health systems  Health      Health systems  Expenditure
# 46       Health: Health systems  Health      Health systems  Expenditure
# 47       Health: Health systems  Health      Health systems  Expenditure
# 48       Health: Health systems  Health      Health systems  Expenditure
# 72            Health: Mortality  Health           Mortality   Stationary
# 73            Health: Mortality  Health           Mortality   Stationary
# 74            Health: Mortality  Health           Mortality   Stationary
# 75            Health: Mortality  Health           Mortality   Stationary
# 76            Health: Mortality  Health           Mortality   Stationary
# 77            Health: Mortality  Health           Mortality   Stationary
# 86            Health: Mortality  Health           Mortality   Stationary
# 95            Health: Nutrition  Health           Nutrition       Intake
# 100           Health: Nutrition  Health           Nutrition       Intake
#
#     SubTopic3
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 17        NaN
# 34        NaN
# 35        NaN
# 36        NaN
# 37        NaN
# 39        NaN
# 40        NaN
# 41        NaN
# 42        NaN
# 43        NaN
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN
# 72        NaN
# 73        NaN
# 74        NaN
# 75        NaN
# 76        NaN
# 77        NaN
# 86        NaN
# 95        NaN
# 100       NaN

# %%
health.loc[health['Code'].str.startswith('SH.STA') & 
           health['Code'].str.contains('SMSS', regex=True), "SubTopic3"] = "Safely Managed Sanitation Services"

health.loc[health['Code'].str.startswith('SH.STA') & 
           health['Code'].str.contains('SMDW', regex=True), "SubTopic3"] = "Safely Managed Drinking Water Services"

health.loc[health['Code'].str.startswith('SH.STA') & 
           health['Code'].str.contains('BASS', regex=True), "SubTopic3"] = "Basic Sanitation Services"

health.loc[health['Code'].str.startswith('SH.STA') & 
           health['Code'].str.contains('HYGN', regex=True), "SubTopic3"] = "Handwashing Facilities Including Soap and Water"

health.loc[health['Code'].str.startswith('SH.STA') & 
           health['Code'].str.contains('POIS', regex=True), "SubTopic3"] = "Unintentional Poisoning"

health.loc[health['Code'].str.startswith('SH.STA') & 
           health['Code'].str.contains('AIRP', regex=True), "SubTopic3"] = "Household and Ambient Air Pollution"


health.loc[health['Code'].str.startswith('SH.STA') & 
           health['Code'].str.contains('WASH', regex=True), "SubTopic3"] = "Unsafe Water, Unsafe Sanitation and Lack of Hygiene"

# H2O

health.loc[health['Code'].str.startswith('SH.H2O') & 
           health['Code'].str.contains('BASW', regex=True), "SubTopic3"] = "Basic Drinking Water Services"

health.loc[health['Code'].str.startswith('SH.H2O') & 
           health['Code'].str.contains('HYGN', regex=True), "SubTopic3"] = "Basic Handwashing Facilities Including Soap and Water"

health.loc[health['Code'].str.startswith('SH.H2O') & 
           health['Code'].str.contains('SMDW', regex=True), "SubTopic3"] = "Safely Managed Drinking Water Services"

# XPD

health.loc[health['Code'].str.startswith('SH.XPD') & 
           health['Code'].str.contains('PVTD', regex=True), "SubTopic3"] = "Domestic Private Health Expenditure"

health.loc[health['Code'].str.startswith('SH.XPD') & 
           health['Code'].str.contains('GHED', regex=True), "SubTopic3"] = "Domestic General Government Health Expenditure"

health.loc[health['Code'].str.startswith('SH.XPD') & 
           health['Code'].str.contains('EHEX', regex=True), "SubTopic3"] = "Current Health Expenditure"

health.loc[health['Code'].str.startswith('SH.XPD') & 
           health['Code'].str.contains('CHEX', regex=True), "SubTopic3"] = "Current Health Expenditure per capita "


# ITK

health.loc[health['Code'].str.startswith('SN.ITK') & 
           health['Code'].str.contains('SVFI', regex=True), "SubTopic3"] = "Severe Food Insecurity"

health.loc[health['Code'].str.startswith('SN.ITK') & 
           health['Code'].str.contains('MSFI', regex=True), "SubTopic3"] = "Moderate or Severe Food Insecurity"

# %%
with pd.option_context('display.max_colwidth', 200):

    display(health[health['SubTopic3'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
has_list = health.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


health_with_lists = health[has_list]
health_with_lists
# Out:
#                   Code                                     Indicator Name  \
# 117     SP.DYN.CDRT.IN               Death rate, crude (per 1,000 people)
# 118     SP.HOU.FEMA.ZS  Female headed households (% of households with...
# 119     SP.REG.BRTH.ZS             Completeness of birth registration (%)
# 120  SP.REG.BRTH.MA.ZS       Completeness of birth registration, male (%)
# 121  SP.REG.BRTH.RU.ZS      Completeness of birth registration, rural (%)
# ..                 ...                                                ...
# 183  SP.POP.0004.FE.5Y  Population ages 00-04, female (% of female pop...
# 184  SP.POP.0004.MA.5Y  Population ages 00-04, male (% of male populat...
# 185  SP.POP.0014.TO.ZS       Population ages 0-14 (% of total population)
# 186  SP.POP.0014.FE.IN                       Population ages 0-14, female
# 187        SP.POP.TOTL                                  Population, total
#
#                      General Topic   Topic   SubTopic1  \
# 117   Health: Population: Dynamics  Health  Population
# 118   Health: Population: Dynamics  Health  Population
# 119   Health: Population: Dynamics  Health  Population
# 120   Health: Population: Dynamics  Health  Population
# 121   Health: Population: Dynamics  Health  Population
# ..                             ...     ...         ...
# 183  Health: Population: Structure  Health  Population
# 184  Health: Population: Structure  Health  Population
# 185  Health: Population: Structure  Health  Population
# 186  Health: Population: Structure  Health  Population
# 187  Health: Population: Structure  Health  Population
#
#                                     SubTopic2         SubTopic3
# 117                       [Dynamics, Dynamic]  Crude death rate
# 118                     [Dynamics, Household]            Female
# 119  [Dynamics, Registration (or regulatory)]             Birth
# 120  [Dynamics, Registration (or regulatory)]             Birth
# 121  [Dynamics, Registration (or regulatory)]             Birth
# ..                                        ...               ...
# 183                   [Structure, Population]           Age 0-4
# 184                   [Structure, Population]           Age 0-4
# 185                   [Structure, Population]          Age 0-14
# 186                   [Structure, Population]          Age 0-14
# 187                   [Structure, Population]             Total
#
# [71 rows x 7 columns]

# %%
health["SubTopic2"] = health["SubTopic2"].apply(select_first_item)

# %%
has_list = health.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


health_with_lists = health[has_list]
health_with_lists
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(health[health['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
#                   Code  \
# 25   SH.CON.1524.MA.ZS
# 26   SH.CON.1524.FE.ZS
# 109     SH.ANM.CHLD.ZS
# 110     SH.ANM.NPRG.ZS
# 112     SH.ANM.ALLW.ZS
#
#                                                                    Indicator Name  \
# 25                Condom use, population ages 15-24, male (% of males ages 15-24)
# 26            Condom use, population ages 15-24, female (% of females ages 15-24)
# 109          Prevalence of anemia among children (% of children ages 6-59 months)
# 110         Prevalence of anemia among non-pregnant women (% of women ages 15-49)
# 112  Prevalence of anemia among women of reproductive age (% of women ages 15-49)
#
#                   General Topic   Topic           SubTopic1  \
# 25   Health: Disease prevention  Health  Disease prevention
# 26   Health: Disease prevention  Health  Disease prevention
# 109           Health: Nutrition  Health           Nutrition
# 110           Health: Nutrition  Health           Nutrition
# 112           Health: Nutrition  Health           Nutrition
#
#                    SubTopic2     SubTopic3
# 25   Consumption (or condom)     Age 15-24
# 26   Consumption (or condom)     Age 15-24
# 109       Anemia (or animal)         Child
# 110       Anemia (or animal)  Non-pregnant
# 112       Anemia (or animal)     All women

# %%
health.loc[health['Code'].str.startswith('SH.CON') , "SubTopic2"] = "Condom"
health.loc[health['Code'].str.startswith('SH.ANM') , "SubTopic2"] = "Anemia"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(health[health['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Infrastructure

# %%
infrastructure   = dfs["infrastructure"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(infrastructure)
# Out:
#                  Code  \
# 0   IT.NET.USER.MA.ZS
# 1      IT.NET.USER.ZS
# 2         IT.MLT.MAIN
# 3      IT.MLT.MAIN.P2
# 4      BX.GSR.CCIS.CD
# 5      BX.GSR.CCIS.ZS
# 6   TM.VAL.ICTG.ZS.UN
# 7   TX.VAL.ICTG.ZS.UN
# 8         IT.NET.BBND
# 9   IT.NET.USER.FE.ZS
# 10     IT.NET.BBND.P2
# 11     IT.NET.SECR.P6
# 12        IT.NET.SECR
# 13        IT.CEL.SETS
# 14     IT.CEL.SETS.P2
# 15        IP.IDS.NRCT
# 16  SP.POP.TECH.RD.P6
# 17        IP.TMK.NRCT
# 18        IP.TMK.RSCT
# 19  SP.POP.SCIE.RD.P6
# 20     TX.VAL.TECH.CD
# 21        IP.IDS.RSCT
# 22        IP.PAT.RESD
# 23  GB.XPD.RSDV.GD.ZS
# 24     IP.JRN.ARTC.SC
# 25  TX.VAL.TECH.MF.ZS
# 26  TX.MNF.TECH.ZS.UN
# 27        IP.PAT.NRES
# 28        IS.AIR.PSGR
# 29  IS.AIR.GOOD.MT.K1
# 30        IS.AIR.DPRT
# 31     IS.RRS.PASG.KM
# 32  IS.RRS.GOOD.MT.K6
# 33     IS.RRS.TOTL.KM
# 34     IS.SHP.GCNW.XQ
# 35     IS.SHP.GOOD.TU
#
#                                                      Indicator Name  \
# 0       Individuals using the Internet, male (% of male population)
# 1                  Individuals using the Internet (% of population)
# 2                                     Fixed telephone subscriptions
# 3                    Fixed telephone subscriptions (per 100 people)
# 4                            ICT service exports (BoP, current US$)
# 5                   ICT service exports (% of service exports, BoP)
# 6                         ICT goods imports (% total goods imports)
# 7                      ICT goods exports (% of total goods exports)
# 8                                     Fixed broadband subscriptions
# 9   Individuals using the Internet, female (% of female population)
# 10                   Fixed broadband subscriptions (per 100 people)
# 11                   Secure Internet servers (per 1 million people)
# 12                                          Secure Internet servers
# 13                                    Mobile cellular subscriptions
# 14                   Mobile cellular subscriptions (per 100 people)
# 15            Industrial design applications, nonresident, by count
# 16                          Technicians in R&D (per million people)
# 17                    Trademark applications, nonresident, by count
# 18                       Trademark applications, resident, by count
# 19                          Researchers in R&D (per million people)
# 20                            High-technology exports (current US$)
# 21               Industrial design applications, resident, by count
# 22                                   Patent applications, residents
# 23                  Research and development expenditure (% of GDP)
# 24                        Scientific and technical journal articles
# 25              High-technology exports (% of manufactured exports)
# 26            Medium and high-tech exports (% manufactured exports)
# 27                                Patent applications, nonresidents
# 28                                Air transport, passengers carried
# 29                          Air transport, freight (million ton-km)
# 30           Air transport, registered carrier departures worldwide
# 31              Railways, passengers carried (million passenger-km)
# 32                     Railways, goods transported (million ton-km)
# 33                                      Rail lines (total route-km)
# 34  Liner shipping connectivity index (maximum value in 2004 = 100)
# 35           Container port traffic (TEU: 20 foot equivalent units)
#
#                      General Topic           Topic       SubTopic1  \
# 0   Infrastructure: Communications  Infrastructure  Communications
# 1   Infrastructure: Communications  Infrastructure  Communications
# 2   Infrastructure: Communications  Infrastructure  Communications
# 3   Infrastructure: Communications  Infrastructure  Communications
# 4   Infrastructure: Communications  Infrastructure  Communications
# 5   Infrastructure: Communications  Infrastructure  Communications
# 6   Infrastructure: Communications  Infrastructure  Communications
# 7   Infrastructure: Communications  Infrastructure  Communications
# 8   Infrastructure: Communications  Infrastructure  Communications
# 9   Infrastructure: Communications  Infrastructure  Communications
# 10  Infrastructure: Communications  Infrastructure  Communications
# 11  Infrastructure: Communications  Infrastructure  Communications
# 12  Infrastructure: Communications  Infrastructure  Communications
# 13  Infrastructure: Communications  Infrastructure  Communications
# 14  Infrastructure: Communications  Infrastructure  Communications
# 15      Infrastructure: Technology  Infrastructure      Technology
# 16      Infrastructure: Technology  Infrastructure      Technology
# 17      Infrastructure: Technology  Infrastructure      Technology
# 18      Infrastructure: Technology  Infrastructure      Technology
# 19      Infrastructure: Technology  Infrastructure      Technology
# 20      Infrastructure: Technology  Infrastructure      Technology
# 21      Infrastructure: Technology  Infrastructure      Technology
# 22      Infrastructure: Technology  Infrastructure      Technology
# 23      Infrastructure: Technology  Infrastructure      Technology
# 24      Infrastructure: Technology  Infrastructure      Technology
# 25      Infrastructure: Technology  Infrastructure      Technology
# 26      Infrastructure: Technology  Infrastructure      Technology
# 27      Infrastructure: Technology  Infrastructure      Technology
# 28  Infrastructure: Transportation  Infrastructure  Transportation
# 29  Infrastructure: Transportation  Infrastructure  Transportation
# 30  Infrastructure: Transportation  Infrastructure  Transportation
# 31  Infrastructure: Transportation  Infrastructure  Transportation
# 32  Infrastructure: Transportation  Infrastructure  Transportation
# 33  Infrastructure: Transportation  Infrastructure  Transportation
# 34  Infrastructure: Transportation  Infrastructure  Transportation
# 35  Infrastructure: Transportation  Infrastructure  Transportation
#
#                SubTopic2  \
# 0               Internet
# 1               Internet
# 2    Mainline telephones
# 3    Mainline telephones
# 4     Goods and services
# 5     Goods and services
# 6                  Value
# 7                  Value
# 8               Internet
# 9               Internet
# 10              Internet
# 11              Internet
# 12              Internet
# 13  Mobile (cell) phones
# 14  Mobile (cell) phones
# 15     Industrial design
# 16            Population
# 17             Trademark
# 18             Trademark
# 19            Population
# 20                 Value
# 21     Industrial design
# 22                Patent
# 23           Expenditure
# 24               Journal
# 25                 Value
# 26         Manufacturing
# 27                Patent
# 28         Air transport
# 29         Air transport
# 30         Air transport
# 31              Railroad
# 32              Railroad
# 33              Railroad
# 34        Ship transport
# 35        Ship transport
#
#                                                                  SubTopic3
# 0                                                                    Users
# 1                                                                    Users
# 2                                                     Telephone main lines
# 3                                                     Telephone main lines
# 4                                         Computer and information systems
# 5                                         Computer and information systems
# 6                                                                ICT goods
# 7                                                                ICT goods
# 8                                                                Broadband
# 9                                                                    Users
# 10                                                               Broadband
# 11                                                                  Secure
# 12                                                                  Secure
# 13                               Subscriptions (e.g., cell phone handsets)
# 14                               Subscriptions (e.g., cell phone handsets)
# 15  Nonresidents (by count) (refers to intellectual property applications)
# 16                                                               Technical
# 17  Nonresidents (by count) (refers to intellectual property applications)
# 18     Residents (by count) (refers to intellectual property applications)
# 19                                                Scientists (researchers)
# 20                                                               Technical
# 21     Residents (by count) (refers to intellectual property applications)
# 22                                                               Residents
# 23                                                Research and development
# 24                                                                 Article
# 25                                                               Technical
# 26                                                               Technical
# 27                                                            Nonresidents
# 28                                                              Passengers
# 29                                                                   Goods
# 30                                                              Departures
# 31                                                              Passengers
# 32                                                                   Goods
# 33                                                                   Total
# 34                                             Liner shipping connectivity
# 35                                                                   Goods

# %%
with pd.option_context('display.max_colwidth', 200):

    display(infrastructure[infrastructure['SubTopic2'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
with pd.option_context('display.max_colwidth', 200):

    display(infrastructure[infrastructure['SubTopic3'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
has_list = infrastructure.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


infrastructure_with_lists = infrastructure[has_list]
print(infrastructure_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(infrastructure[infrastructure['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
with pd.option_context('display.max_colwidth', 200):
    display(infrastructure[infrastructure['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Poverty

# %%
poverty   = dfs["poverty"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(poverty)
# Out:
#               Code  \
# 0      SI.DST.50MD
# 1   SI.DST.05TH.20
# 2   SI.DST.02ND.20
# 3   SI.DST.FRST.10
# 4   SI.DST.10TH.10
# 5   SI.DST.04TH.20
# 6   SI.DST.FRST.20
# 7   SI.DST.03RD.20
# 8      SI.POV.GINI
# 9   SI.POV.LMIC.GP
# 10     SI.POV.GAPS
# 11  SI.POV.UMIC.GP
# 12     SI.POV.MPUN
# 13     SI.POV.MPWB
# 14     SI.POV.LMIC
# 15     SI.POV.DDAY
# 16     SI.POV.UMIC
# 17     SI.POV.SOPO
# 18     SI.POV.NAHC
# 19     SI.SPR.PGAP
# 20     SI.SPR.PC40
# 21  SI.SPR.PC40.ZG
# 22  SI.SPR.PCAP.ZG
# 23     SI.SPR.PCAP
#
#                                                                                                        Indicator Name  \
# 0                                                   Proportion of people living below 50 percent of median income (%)
# 1                                                                                    Income share held by highest 20%
# 2                                                                                     Income share held by second 20%
# 3                                                                                     Income share held by lowest 10%
# 4                                                                                    Income share held by highest 10%
# 5                                                                                     Income share held by fourth 20%
# 6                                                                                     Income share held by lowest 20%
# 7                                                                                      Income share held by third 20%
# 8                                                                                                          Gini index
# 9                                                                           Poverty gap at $3.65 a day (2017 PPP) (%)
# 10                                                                          Poverty gap at $2.15 a day (2017 PPP) (%)
# 11                                                                          Poverty gap at $6.85 a day (2017 PPP) (%)
# 12                                                  Multidimensional poverty headcount ratio (UNDP) (% of population)
# 13                                            Multidimensional poverty headcount ratio (World Bank) (% of population)
# 14                                                Poverty headcount ratio at $3.65 a day (2017 PPP) (% of population)
# 15                                                Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)
# 16                                                Poverty headcount ratio at $6.85 a day (2017 PPP) (% of population)
# 17                                                 Poverty headcount ratio at societal poverty line (% of population)
# 18                                                Poverty headcount ratio at national poverty lines (% of population)
# 19                                           Prosperity gap (average shortfall from a prosperity standard of $25/day)
# 20                        Survey mean consumption or income per capita, bottom 40% of population (2017 PPP $ per day)
# 21  Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)
# 22          Annualized average growth rate in per capita real survey mean consumption or income, total population (%)
# 23                                Survey mean consumption or income per capita, total population (2017 PPP $ per day)
#
#                    General Topic    Topic            SubTopic1  \
# 0   Poverty: Income distribution  Poverty  Income distribution
# 1   Poverty: Income distribution  Poverty  Income distribution
# 2   Poverty: Income distribution  Poverty  Income distribution
# 3   Poverty: Income distribution  Poverty  Income distribution
# 4   Poverty: Income distribution  Poverty  Income distribution
# 5   Poverty: Income distribution  Poverty  Income distribution
# 6   Poverty: Income distribution  Poverty  Income distribution
# 7   Poverty: Income distribution  Poverty  Income distribution
# 8   Poverty: Income distribution  Poverty  Income distribution
# 9         Poverty: Poverty rates  Poverty        Poverty rates
# 10        Poverty: Poverty rates  Poverty        Poverty rates
# 11        Poverty: Poverty rates  Poverty        Poverty rates
# 12        Poverty: Poverty rates  Poverty        Poverty rates
# 13        Poverty: Poverty rates  Poverty        Poverty rates
# 14        Poverty: Poverty rates  Poverty        Poverty rates
# 15        Poverty: Poverty rates  Poverty        Poverty rates
# 16        Poverty: Poverty rates  Poverty        Poverty rates
# 17        Poverty: Poverty rates  Poverty        Poverty rates
# 18        Poverty: Poverty rates  Poverty        Poverty rates
# 19    Poverty: Shared prosperity  Poverty    Shared prosperity
# 20    Poverty: Shared prosperity  Poverty    Shared prosperity
# 21    Poverty: Shared prosperity  Poverty    Shared prosperity
# 22    Poverty: Shared prosperity  Poverty    Shared prosperity
# 23    Poverty: Shared prosperity  Poverty    Shared prosperity
#
#             SubTopic2                    SubTopic3
# 0        Distribution                         None
# 1        Distribution     Fifth (highest) quintile
# 2        Distribution                       Second
# 3        Distribution  First, lowest (also Forest)
# 4        Distribution               Highest decile
# 5        Distribution                       Fourth
# 6        Distribution  First, lowest (also Forest)
# 7        Distribution                        Third
# 8             Poverty                   GINI index
# 9             Poverty                         None
# 10            Poverty   Poverty gap at $1.25 a day
# 11            Poverty                         None
# 12            Poverty                         None
# 13            Poverty                         None
# 14            Poverty                         None
# 15            Poverty                  $1.25 a day
# 16            Poverty                         None
# 17            Poverty                         None
# 18            Poverty   National poverty headcount
# 19  Shared prosperity                         None
# 20  Shared prosperity     Bottom 40% of population
# 21  Shared prosperity     Bottom 40% of population
# 22  Shared prosperity                   Per capita
# 23  Shared prosperity                   Per capita

# %%
with pd.option_context('display.max_colwidth', 200):

    display(poverty[poverty['SubTopic2'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
with pd.option_context('display.max_colwidth', 200):

    display(poverty[poverty['SubTopic3'].isna()])
# Out:
#               Code  \
# 0      SI.DST.50MD
# 9   SI.POV.LMIC.GP
# 11  SI.POV.UMIC.GP
# 12     SI.POV.MPUN
# 13     SI.POV.MPWB
# 14     SI.POV.LMIC
# 16     SI.POV.UMIC
# 17     SI.POV.SOPO
# 19     SI.SPR.PGAP
#
#                                                               Indicator Name  \
# 0          Proportion of people living below 50 percent of median income (%)
# 9                                  Poverty gap at $3.65 a day (2017 PPP) (%)
# 11                                 Poverty gap at $6.85 a day (2017 PPP) (%)
# 12         Multidimensional poverty headcount ratio (UNDP) (% of population)
# 13   Multidimensional poverty headcount ratio (World Bank) (% of population)
# 14       Poverty headcount ratio at $3.65 a day (2017 PPP) (% of population)
# 16       Poverty headcount ratio at $6.85 a day (2017 PPP) (% of population)
# 17        Poverty headcount ratio at societal poverty line (% of population)
# 19  Prosperity gap (average shortfall from a prosperity standard of $25/day)
#
#                    General Topic    Topic            SubTopic1  \
# 0   Poverty: Income distribution  Poverty  Income distribution
# 9         Poverty: Poverty rates  Poverty        Poverty rates
# 11        Poverty: Poverty rates  Poverty        Poverty rates
# 12        Poverty: Poverty rates  Poverty        Poverty rates
# 13        Poverty: Poverty rates  Poverty        Poverty rates
# 14        Poverty: Poverty rates  Poverty        Poverty rates
# 16        Poverty: Poverty rates  Poverty        Poverty rates
# 17        Poverty: Poverty rates  Poverty        Poverty rates
# 19    Poverty: Shared prosperity  Poverty    Shared prosperity
#
#             SubTopic2 SubTopic3
# 0        Distribution      None
# 9             Poverty      None
# 11            Poverty      None
# 12            Poverty      None
# 13            Poverty      None
# 14            Poverty      None
# 16            Poverty      None
# 17            Poverty      None
# 19  Shared prosperity      None

# %%
with pd.option_context('display.max_colwidth', 200):
    display(poverty[poverty['Code'].str.startswith('SI.DST')])
# Out:
#              Code  \
# 0     SI.DST.50MD
# 1  SI.DST.05TH.20
# 2  SI.DST.02ND.20
# 3  SI.DST.FRST.10
# 4  SI.DST.10TH.10
# 5  SI.DST.04TH.20
# 6  SI.DST.FRST.20
# 7  SI.DST.03RD.20
#
#                                                       Indicator Name  \
# 0  Proportion of people living below 50 percent of median income (%)
# 1                                   Income share held by highest 20%
# 2                                    Income share held by second 20%
# 3                                    Income share held by lowest 10%
# 4                                   Income share held by highest 10%
# 5                                    Income share held by fourth 20%
# 6                                    Income share held by lowest 20%
# 7                                     Income share held by third 20%
#
#                   General Topic    Topic            SubTopic1     SubTopic2  \
# 0  Poverty: Income distribution  Poverty  Income distribution  Distribution
# 1  Poverty: Income distribution  Poverty  Income distribution  Distribution
# 2  Poverty: Income distribution  Poverty  Income distribution  Distribution
# 3  Poverty: Income distribution  Poverty  Income distribution  Distribution
# 4  Poverty: Income distribution  Poverty  Income distribution  Distribution
# 5  Poverty: Income distribution  Poverty  Income distribution  Distribution
# 6  Poverty: Income distribution  Poverty  Income distribution  Distribution
# 7  Poverty: Income distribution  Poverty  Income distribution  Distribution
#
#                      SubTopic3
# 0                         None
# 1     Fifth (highest) quintile
# 2                       Second
# 3  First, lowest (also Forest)
# 4               Highest decile
# 5                       Fourth
# 6  First, lowest (also Forest)
# 7                        Third

# %%
poverty.loc[poverty["Code"] == "SI.DST.50MD",  "SubTopic3"] = "Below 50% Median Income"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(poverty[poverty['Code'].str.startswith('SI.POV')])
# Out:
#               Code  \
# 8      SI.POV.GINI
# 9   SI.POV.LMIC.GP
# 10     SI.POV.GAPS
# 11  SI.POV.UMIC.GP
# 12     SI.POV.MPUN
# 13     SI.POV.MPWB
# 14     SI.POV.LMIC
# 15     SI.POV.DDAY
# 16     SI.POV.UMIC
# 17     SI.POV.SOPO
# 18     SI.POV.NAHC
#
#                                                              Indicator Name  \
# 8                                                                Gini index
# 9                                 Poverty gap at $3.65 a day (2017 PPP) (%)
# 10                                Poverty gap at $2.15 a day (2017 PPP) (%)
# 11                                Poverty gap at $6.85 a day (2017 PPP) (%)
# 12        Multidimensional poverty headcount ratio (UNDP) (% of population)
# 13  Multidimensional poverty headcount ratio (World Bank) (% of population)
# 14      Poverty headcount ratio at $3.65 a day (2017 PPP) (% of population)
# 15      Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)
# 16      Poverty headcount ratio at $6.85 a day (2017 PPP) (% of population)
# 17       Poverty headcount ratio at societal poverty line (% of population)
# 18      Poverty headcount ratio at national poverty lines (% of population)
#
#                    General Topic    Topic            SubTopic1 SubTopic2  \
# 8   Poverty: Income distribution  Poverty  Income distribution   Poverty
# 9         Poverty: Poverty rates  Poverty        Poverty rates   Poverty
# 10        Poverty: Poverty rates  Poverty        Poverty rates   Poverty
# 11        Poverty: Poverty rates  Poverty        Poverty rates   Poverty
# 12        Poverty: Poverty rates  Poverty        Poverty rates   Poverty
# 13        Poverty: Poverty rates  Poverty        Poverty rates   Poverty
# 14        Poverty: Poverty rates  Poverty        Poverty rates   Poverty
# 15        Poverty: Poverty rates  Poverty        Poverty rates   Poverty
# 16        Poverty: Poverty rates  Poverty        Poverty rates   Poverty
# 17        Poverty: Poverty rates  Poverty        Poverty rates   Poverty
# 18        Poverty: Poverty rates  Poverty        Poverty rates   Poverty
#
#                      SubTopic3
# 8                   GINI index
# 9                         None
# 10  Poverty gap at $1.25 a day
# 11                        None
# 12                        None
# 13                        None
# 14                        None
# 15                 $1.25 a day
# 16                        None
# 17                        None
# 18  National poverty headcount

# %%
poverty.loc[poverty["Code"] == "SI.POV.LMIC.GP", "SubTopic3"] = ["Poverty gap at $3.65 a day"]
poverty.loc[poverty["Code"] == "SI.POV.SOPO", "SubTopic3"] = ["Societal poverty headcount"]
poverty.loc[poverty["Code"] == "SI.POV.UMIC", "SubTopic3"] = ["Poverty headcount at $6.85 a day"]
poverty.loc[poverty["Code"] == "SI.POV.DDAY", "SubTopic3"] = ["$2.15 a day"]
poverty.loc[poverty["Code"] == "SI.POV.MPUN", "SubTopic3"] = ["Multidimensional poverty (UNDP)"]
poverty.loc[poverty["Code"] == "SI.POV.MPWB", "SubTopic3"] = ["Multidimensional poverty (World Bank)"]
poverty.loc[poverty["Code"] == "SI.POV.UMIC.GP", "SubTopic3"] = ["Poverty gap at $6.85 a day"]
poverty.loc[poverty["Code"] == "SI.POV.GAPS", "SubTopic3"] = ["Poverty gap at $2.15 a day"]
poverty.loc[poverty["Code"] == "SI.POV.LMIC", "SubTopic3"] = ["Poverty headcount at $3.65 a day"]
poverty.loc[poverty["Code"] == "SI.POV.DDAY", "SubTopic3"] = ["Poverty headcount at $2.15 a day"]

# %%
with pd.option_context('display.max_colwidth', 200):
    display(poverty[poverty['Code'].str.startswith('SI.SPR')])
# Out:
#               Code  \
# 19     SI.SPR.PGAP
# 20     SI.SPR.PC40
# 21  SI.SPR.PC40.ZG
# 22  SI.SPR.PCAP.ZG
# 23     SI.SPR.PCAP
#
#                                                                                                        Indicator Name  \
# 19                                           Prosperity gap (average shortfall from a prosperity standard of $25/day)
# 20                        Survey mean consumption or income per capita, bottom 40% of population (2017 PPP $ per day)
# 21  Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)
# 22          Annualized average growth rate in per capita real survey mean consumption or income, total population (%)
# 23                                Survey mean consumption or income per capita, total population (2017 PPP $ per day)
#
#                  General Topic    Topic          SubTopic1          SubTopic2  \
# 19  Poverty: Shared prosperity  Poverty  Shared prosperity  Shared prosperity
# 20  Poverty: Shared prosperity  Poverty  Shared prosperity  Shared prosperity
# 21  Poverty: Shared prosperity  Poverty  Shared prosperity  Shared prosperity
# 22  Poverty: Shared prosperity  Poverty  Shared prosperity  Shared prosperity
# 23  Poverty: Shared prosperity  Poverty  Shared prosperity  Shared prosperity
#
#                    SubTopic3
# 19                      None
# 20  Bottom 40% of population
# 21  Bottom 40% of population
# 22                Per capita
# 23                Per capita

# %%
poverty.loc[poverty["Code"] == "SI.SPR.PCAP.ZG", "SubTopic3"] = ["Total"]
poverty.loc[poverty["Code"] == "SI.SPR.PGAP", "SubTopic3"] = ["Prosperity gap at $25/day"]
poverty.loc[poverty["Code"] == "SI.SPR.PCAP", "SubTopic3"] = ["Total"]

# %%
has_list = poverty.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


poverty_with_lists = poverty[has_list]
poverty_with_lists
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(poverty[poverty['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
with pd.option_context('display.max_colwidth', 200):
    display(poverty[poverty['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Private

# %%
private  = dfs["private"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(private)
# Out:
#                   Code  \
# 0       IC.FRM.FEMO.ZS
# 1       IC.FRM.METG.ZS
# 2    IC.TAX.PRFT.CP.ZS
# 3       IC.FRM.FEMM.ZS
# 4       IC.LGL.CRED.XQ
# ..                 ...
# 133        ST.INT.DPRT
# 134     ST.INT.TVLR.CD
# 135  ST.INT.RCPT.XP.ZS
# 136     ST.INT.TRNR.CD
# 137     ST.INT.RCPT.CD
#
#                                                                   Indicator Name  \
# 0                      Firms with female participation in ownership (% of firms)
# 1             Firms visited or required meetings with tax officials (% of firms)
# 2                                           Profit tax (% of commercial profits)
# 3                                     Firms with female top manager (% of firms)
# 4                           Strength of legal rights index (0=weak to 12=strong)
# ..                                                                           ...
# 133                                  International tourism, number of departures
# 134               International tourism, receipts for travel items (current US$)
# 135                         International tourism, receipts (% of total exports)
# 136  International tourism, receipts for passenger transport items (current US$)
# 137                                International tourism, receipts (current US$)
#
#                                     General Topic                   Topic  \
# 0    Private Sector & Trade: Business environment  Private Sector & Trade
# 1    Private Sector & Trade: Business environment  Private Sector & Trade
# 2    Private Sector & Trade: Business environment  Private Sector & Trade
# 3    Private Sector & Trade: Business environment  Private Sector & Trade
# 4    Private Sector & Trade: Business environment  Private Sector & Trade
# ..                                            ...                     ...
# 133      Private Sector & Trade: Travel & tourism  Private Sector & Trade
# 134      Private Sector & Trade: Travel & tourism  Private Sector & Trade
# 135      Private Sector & Trade: Travel & tourism  Private Sector & Trade
# 136      Private Sector & Trade: Travel & tourism  Private Sector & Trade
# 137      Private Sector & Trade: Travel & tourism  Private Sector & Trade
#
#                 SubTopic1                                 SubTopic2  \
# 0    Business environment                                     Firms
# 1    Business environment                                     Firms
# 2    Business environment  Tax revenue (or tariff) (or tax related)
# 3    Business environment                                     Firms
# 4    Business environment                                     Legal
# ..                    ...                                       ...
# 133      Travel & tourism      Interest payments (or international)
# 134      Travel & tourism      Interest payments (or international)
# 135      Travel & tourism      Interest payments (or international)
# 136      Travel & tourism      Interest payments (or international)
# 137      Travel & tourism      Interest payments (or international)
#
#                                   SubTopic3
# 0                          Female ownership
# 1                                  Meetings
# 2                                    Profit
# 3                            Female manager
# 4                                    Credit
# ..                                      ...
# 133                              Departures
# 134                         Travel receipts
# 135                                Receipts
# 136  Transport receipts (or Turnover ratio)
# 137                                Receipts
#
# [138 rows x 7 columns]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(private[private['SubTopic2'].isna()])
# Out:
#                   Code  \
# 100     IE.PPN.ENGY.CD
# 101     IE.PPN.ICTI.CD
# 102     IE.PPN.TRAN.CD
# 103     IE.PPN.WATR.CD
# 126  TX.UVI.MRCH.XD.WD
# 127  TM.UVI.MRCH.XD.WD
#
#                                                                    Indicator Name  \
# 100                Public private partnerships investment in energy (current US$)
# 101                   Public private partnerships investment in ICT (current US$)
# 102             Public private partnerships investment in transport (current US$)
# 103  Public private partnerships investment in water and sanitation (current US$)
# 126                                          Export unit value index (2015 = 100)
# 127                                          Import unit value index (2015 = 100)
#
#                                                  General Topic  \
# 100  Private Sector & Trade: Private infrastructure investment
# 101  Private Sector & Trade: Private infrastructure investment
# 102  Private Sector & Trade: Private infrastructure investment
# 103  Private Sector & Trade: Private infrastructure investment
# 126                Private Sector & Trade: Trade price indices
# 127                Private Sector & Trade: Trade price indices
#
#                       Topic                          SubTopic1 SubTopic2  \
# 100  Private Sector & Trade  Private infrastructure investment      None
# 101  Private Sector & Trade  Private infrastructure investment      None
# 102  Private Sector & Trade  Private infrastructure investment      None
# 103  Private Sector & Trade  Private infrastructure investment      None
# 126  Private Sector & Trade                Trade price indices      None
# 127  Private Sector & Trade                Trade price indices      None
#
#                 SubTopic3
# 100                Energy
# 101        ICT investment
# 102             Transport
# 103  Water and sanitation
# 126   Goods (merchandise)
# 127   Goods (merchandise)

# %%
private.loc[private['Code'].str.startswith('IE.PPN'), "SubTopic2"] = "Public-Private Partnerships (PPP) Investments"
private.loc[private['Code'].str.startswith('TX.UVI') | private['Code'].str.startswith('TM.UVI'), "SubTopic2"] = "Unit Value Index "

# %%
private[private['Code'].str.startswith('TX.UVI') | private['Code'].str.startswith('TM.UVI')| private['Code'].str.startswith('IE.PPN')]
# Out:
#                   Code                                     Indicator Name  \
# 100     IE.PPN.ENGY.CD  Public private partnerships investment in ener...
# 101     IE.PPN.ICTI.CD  Public private partnerships investment in ICT ...
# 102     IE.PPN.TRAN.CD  Public private partnerships investment in tran...
# 103     IE.PPN.WATR.CD  Public private partnerships investment in wate...
# 126  TX.UVI.MRCH.XD.WD               Export unit value index (2015 = 100)
# 127  TM.UVI.MRCH.XD.WD               Import unit value index (2015 = 100)
#
#                                          General Topic  \
# 100  Private Sector & Trade: Private infrastructure...
# 101  Private Sector & Trade: Private infrastructure...
# 102  Private Sector & Trade: Private infrastructure...
# 103  Private Sector & Trade: Private infrastructure...
# 126        Private Sector & Trade: Trade price indices
# 127        Private Sector & Trade: Trade price indices
#
#                       Topic                          SubTopic1  \
# 100  Private Sector & Trade  Private infrastructure investment
# 101  Private Sector & Trade  Private infrastructure investment
# 102  Private Sector & Trade  Private infrastructure investment
# 103  Private Sector & Trade  Private infrastructure investment
# 126  Private Sector & Trade                Trade price indices
# 127  Private Sector & Trade                Trade price indices
#
#                                          SubTopic2             SubTopic3
# 100  Public-Private Partnerships (PPP) Investments                Energy
# 101  Public-Private Partnerships (PPP) Investments        ICT investment
# 102  Public-Private Partnerships (PPP) Investments             Transport
# 103  Public-Private Partnerships (PPP) Investments  Water and sanitation
# 126                              Unit Value Index    Goods (merchandise)
# 127                              Unit Value Index    Goods (merchandise)

# %%
with pd.option_context('display.max_colwidth', 200):

    display(private[private['SubTopic3'].isna()])
# Out:
#               Code  \
# 29  IC.FRM.THEV.ZS
#
#                                                        Indicator Name  \
# 29  Firms experiencing losses due to theft and vandalism (% of firms)
#
#                                    General Topic                   Topic  \
# 29  Private Sector & Trade: Business environment  Private Sector & Trade
#
#                SubTopic1 SubTopic2 SubTopic3
# 29  Business environment     Firms      None

# %%
private[private['Code'].str.startswith('IC.FRM')]
# Out:
#               Code                                     Indicator Name  \
# 0   IC.FRM.FEMO.ZS  Firms with female participation in ownership (...
# 1   IC.FRM.METG.ZS  Firms visited or required meetings with tax of...
# 3   IC.FRM.FEMM.ZS         Firms with female top manager (% of firms)
# 6   IC.FRM.BKWC.ZS  Firms using banks to finance working capital (...
# 7   IC.FRM.BNKS.ZS  Firms using banks to finance investment (% of ...
# 8   IC.FRM.RSDV.ZS               Firms that spend on R&D (% of firms)
# 15  IC.FRM.TRNG.ZS        Firms offering formal training (% of firms)
# 16  IC.FRM.INFM.ZS  Firms that do not report all sales for tax pur...
# 18  IC.FRM.CMPU.ZS  Firms competing against unregistered firms (% ...
# 23  IC.FRM.FREG.ZS  Firms formally registered when operations star...
# 29  IC.FRM.THEV.ZS  Firms experiencing losses due to theft and van...
# 31  IC.FRM.CRIM.ZS  Losses due to theft and vandalism (% of annual...
# 37  IC.FRM.OUTG.ZS  Value lost due to electrical outages (% of sal...
# 39     IC.FRM.DURS  Time required to obtain an operating license (...
# 44  IC.FRM.CORR.ZS  Informal payments to public officials (% of fi...
# 51  IC.FRM.BRIB.ZS  Bribery incidence (% of firms experiencing at ...
#
#                                    General Topic                   Topic  \
# 0   Private Sector & Trade: Business environment  Private Sector & Trade
# 1   Private Sector & Trade: Business environment  Private Sector & Trade
# 3   Private Sector & Trade: Business environment  Private Sector & Trade
# 6   Private Sector & Trade: Business environment  Private Sector & Trade
# 7   Private Sector & Trade: Business environment  Private Sector & Trade
# 8   Private Sector & Trade: Business environment  Private Sector & Trade
# 15  Private Sector & Trade: Business environment  Private Sector & Trade
# 16  Private Sector & Trade: Business environment  Private Sector & Trade
# 18  Private Sector & Trade: Business environment  Private Sector & Trade
# 23  Private Sector & Trade: Business environment  Private Sector & Trade
# 29  Private Sector & Trade: Business environment  Private Sector & Trade
# 31  Private Sector & Trade: Business environment  Private Sector & Trade
# 37  Private Sector & Trade: Business environment  Private Sector & Trade
# 39  Private Sector & Trade: Business environment  Private Sector & Trade
# 44  Private Sector & Trade: Business environment  Private Sector & Trade
# 51  Private Sector & Trade: Business environment  Private Sector & Trade
#
#                SubTopic1 SubTopic2                  SubTopic3
# 0   Business environment     Firms           Female ownership
# 1   Business environment     Firms                   Meetings
# 3   Business environment     Firms             Female manager
# 6   Business environment     Firms     Bank's working capital
# 7   Business environment     Firms                      Banks
# 8   Business environment     Firms   Research and development
# 15  Business environment     Firms                   Training
# 16  Business environment     Firms                   Informal
# 18  Business environment     Firms   Unregistered competition
# 23  Business environment     Firms  Firms formally registered
# 29  Business environment     Firms                       None
# 31  Business environment     Firms                      Crime
# 37  Business environment     Firms                    Outages
# 39  Business environment     Firms                   Duration
# 44  Business environment     Firms                 Corruption
# 51  Business environment     Firms                    Bribery

# %%
private.loc[private["Code"] == "IC.FRM.THEV.ZS", "SubTopic3"] = ["Theft and Vandalism"]

# %%
has_list = private.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


private_with_lists = private[has_list]
private_with_lists
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(private[private['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
#                      Code  \
# 2       IC.TAX.PRFT.CP.ZS
# 5    IC.REG.COST.PC.MA.ZS
# 9          IC.REG.PROC.FE
# 10            IC.REG.PROC
# 13         IC.REG.PROC.MA
# 14   IC.REG.COST.PC.FE.ZS
# 21         IC.TAX.GIFT.ZS
# 25            IC.TAX.PAYM
# 28      IC.REG.COST.PC.ZS
# 30            IC.REG.DURS
# 34      IC.TAX.LABR.CP.ZS
# 35            IC.TAX.METG
# 36      IC.TAX.OTHR.CP.ZS
# 41         IC.REG.DURS.FE
# 42         IC.REG.DURS.MA
# 45      IC.TAX.TOTL.CP.ZS
# 46            IC.ISV.DURS
# 47            IC.TAX.DURS
# 104        IE.PPI.WATR.CD
# 105        IE.PPI.TRAN.CD
# 106        IE.PPI.ICTI.CD
# 107        IE.PPI.ENGY.CD
# 128           ST.INT.ARVL
# 129        ST.INT.TVLX.CD
# 130        ST.INT.TRNX.CD
# 131        ST.INT.XPND.CD
# 132     ST.INT.XPND.MP.ZS
# 133           ST.INT.DPRT
# 134        ST.INT.TVLR.CD
# 135     ST.INT.RCPT.XP.ZS
# 136        ST.INT.TRNR.CD
# 137        ST.INT.RCPT.CD
#
#                                                                             Indicator Name  \
# 2                                                     Profit tax (% of commercial profits)
# 5                         Cost of business start-up procedures, male (% of GNI per capita)
# 9                              Start-up procedures to register a business, female (number)
# 10                                     Start-up procedures to register a business (number)
# 13                               Start-up procedures to register a business, male (number)
# 14                      Cost of business start-up procedures, female (% of GNI per capita)
# 21                Firms expected to give gifts in meetings with tax officials (% of firms)
# 25                                                                   Tax payments (number)
# 28                              Cost of business start-up procedures (% of GNI per capita)
# 30                                                Time required to start a business (days)
# 34                                   Labor tax and contributions (% of commercial profits)
# 35   Number of visits or required meetings with tax officials (average for affected firms)
# 36                             Other taxes payable by businesses (% of commercial profits)
# 41                                        Time required to start a business, female (days)
# 42                                          Time required to start a business, male (days)
# 45                                           Total tax and contribution rate (% of profit)
# 46                                                      Time to resolve insolvency (years)
# 47                                                   Time to prepare and pay taxes (hours)
# 104            Investment in water and sanitation with private participation (current US$)
# 105                       Investment in transport with private participation (current US$)
# 106                             Investment in ICT with private participation (current US$)
# 107                          Investment in energy with private participation (current US$)
# 128                                              International tourism, number of arrivals
# 129                     International tourism, expenditures for travel items (current US$)
# 130        International tourism, expenditures for passenger transport items (current US$)
# 131                                      International tourism, expenditures (current US$)
# 132                               International tourism, expenditures (% of total imports)
# 133                                            International tourism, number of departures
# 134                         International tourism, receipts for travel items (current US$)
# 135                                   International tourism, receipts (% of total exports)
# 136            International tourism, receipts for passenger transport items (current US$)
# 137                                          International tourism, receipts (current US$)
#
#                                                  General Topic  \
# 2                 Private Sector & Trade: Business environment
# 5                 Private Sector & Trade: Business environment
# 9                 Private Sector & Trade: Business environment
# 10                Private Sector & Trade: Business environment
# 13                Private Sector & Trade: Business environment
# 14                Private Sector & Trade: Business environment
# 21                Private Sector & Trade: Business environment
# 25                Private Sector & Trade: Business environment
# 28                Private Sector & Trade: Business environment
# 30                Private Sector & Trade: Business environment
# 34                Private Sector & Trade: Business environment
# 35                Private Sector & Trade: Business environment
# 36                Private Sector & Trade: Business environment
# 41                Private Sector & Trade: Business environment
# 42                Private Sector & Trade: Business environment
# 45                Private Sector & Trade: Business environment
# 46                Private Sector & Trade: Business environment
# 47                Private Sector & Trade: Business environment
# 104  Private Sector & Trade: Private infrastructure investment
# 105  Private Sector & Trade: Private infrastructure investment
# 106  Private Sector & Trade: Private infrastructure investment
# 107  Private Sector & Trade: Private infrastructure investment
# 128                   Private Sector & Trade: Travel & tourism
# 129                   Private Sector & Trade: Travel & tourism
# 130                   Private Sector & Trade: Travel & tourism
# 131                   Private Sector & Trade: Travel & tourism
# 132                   Private Sector & Trade: Travel & tourism
# 133                   Private Sector & Trade: Travel & tourism
# 134                   Private Sector & Trade: Travel & tourism
# 135                   Private Sector & Trade: Travel & tourism
# 136                   Private Sector & Trade: Travel & tourism
# 137                   Private Sector & Trade: Travel & tourism
#
#                       Topic                          SubTopic1  \
# 2    Private Sector & Trade               Business environment
# 5    Private Sector & Trade               Business environment
# 9    Private Sector & Trade               Business environment
# 10   Private Sector & Trade               Business environment
# 13   Private Sector & Trade               Business environment
# 14   Private Sector & Trade               Business environment
# 21   Private Sector & Trade               Business environment
# 25   Private Sector & Trade               Business environment
# 28   Private Sector & Trade               Business environment
# 30   Private Sector & Trade               Business environment
# 34   Private Sector & Trade               Business environment
# 35   Private Sector & Trade               Business environment
# 36   Private Sector & Trade               Business environment
# 41   Private Sector & Trade               Business environment
# 42   Private Sector & Trade               Business environment
# 45   Private Sector & Trade               Business environment
# 46   Private Sector & Trade               Business environment
# 47   Private Sector & Trade               Business environment
# 104  Private Sector & Trade  Private infrastructure investment
# 105  Private Sector & Trade  Private infrastructure investment
# 106  Private Sector & Trade  Private infrastructure investment
# 107  Private Sector & Trade  Private infrastructure investment
# 128  Private Sector & Trade                   Travel & tourism
# 129  Private Sector & Trade                   Travel & tourism
# 130  Private Sector & Trade                   Travel & tourism
# 131  Private Sector & Trade                   Travel & tourism
# 132  Private Sector & Trade                   Travel & tourism
# 133  Private Sector & Trade                   Travel & tourism
# 134  Private Sector & Trade                   Travel & tourism
# 135  Private Sector & Trade                   Travel & tourism
# 136  Private Sector & Trade                   Travel & tourism
# 137  Private Sector & Trade                   Travel & tourism
#
#                                                              SubTopic2  \
# 2                             Tax revenue (or tariff) (or tax related)
# 5                                         Registration (or regulatory)
# 9                                         Registration (or regulatory)
# 10                                        Registration (or regulatory)
# 13                                        Registration (or regulatory)
# 14                                        Registration (or regulatory)
# 21                            Tax revenue (or tariff) (or tax related)
# 25                            Tax revenue (or tariff) (or tax related)
# 28                                        Registration (or regulatory)
# 30                                        Registration (or regulatory)
# 34                            Tax revenue (or tariff) (or tax related)
# 35                            Tax revenue (or tariff) (or tax related)
# 36                            Tax revenue (or tariff) (or tax related)
# 41                                        Registration (or regulatory)
# 42                                        Registration (or regulatory)
# 45                            Tax revenue (or tariff) (or tax related)
# 46                              Insolvency (or industry plus services)
# 47                            Tax revenue (or tariff) (or tax related)
# 104  Private participation in infrastructure (or producer price index)
# 105  Private participation in infrastructure (or producer price index)
# 106  Private participation in infrastructure (or producer price index)
# 107  Private participation in infrastructure (or producer price index)
# 128                               Interest payments (or international)
# 129                               Interest payments (or international)
# 130                               Interest payments (or international)
# 131                               Interest payments (or international)
# 132                               Interest payments (or international)
# 133                               Interest payments (or international)
# 134                               Interest payments (or international)
# 135                               Interest payments (or international)
# 136                               Interest payments (or international)
# 137                               Interest payments (or international)
#
#                                                       SubTopic3
# 2                                                        Profit
# 5                                                          Cost
# 9                                                    Procedures
# 10                                                   Procedures
# 13                                                   Procedures
# 14                                                         Cost
# 21                                                        Gifts
# 25                                                     Payments
# 28                                                         Cost
# 30                                                     Duration
# 34                                                        Labor
# 35                                                     Meetings
# 36   Water pollution, other industry (% of total BOD emissions)
# 41                                                     Duration
# 42                                                     Duration
# 45                                                        Total
# 46                                                     Duration
# 47                                                     Duration
# 104                                        Water and sanitation
# 105                                                   Transport
# 106                                              ICT investment
# 107                                                      Energy
# 128                                                     Arrival
# 129                                         Travel expenditures
# 130                                      Transport expenditures
# 131                                                 Expenditure
# 132                                                 Expenditure
# 133                                                  Departures
# 134                                             Travel receipts
# 135                                                    Receipts
# 136                      Transport receipts (or Turnover ratio)
# 137                                                    Receipts

# %%
private.loc[private['Code'].str.startswith('IC.TAX') , "SubTopic2"] = "Tax revenue (or tax related)"
private.loc[private['Code'].str.startswith('IC.REG') , "SubTopic2"] = "Registration "
private.loc[private['Code'].str.startswith('IC.ISV') , "SubTopic2"] = "Insolvency"
private.loc[private['Code'].str.startswith('IE.PPI') , "SubTopic2"] = "Private participation in infrastructure"
private.loc[private['Code'].str.startswith('ST.INT') , "SubTopic2"] = "International"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(private[private['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
#                Code  \
# 114  LP.LPI.INFR.XQ
# 136  ST.INT.TRNR.CD
#
#                                                                                            Indicator Name  \
# 114  Logistics performance index: Quality of trade and transport-related infrastructure (1=low to 5=high)
# 136                           International tourism, receipts for passenger transport items (current US$)
#
#                                   General Topic                   Topic  \
# 114  Private Sector & Trade: Trade facilitation  Private Sector & Trade
# 136    Private Sector & Trade: Travel & tourism  Private Sector & Trade
#
#               SubTopic1                    SubTopic2  \
# 114  Trade facilitation  Logistics performance index
# 136    Travel & tourism                International
#
#                                   SubTopic3
# 114     Infrastructure (or infant reported)
# 136  Transport receipts (or Turnover ratio)

# %%
private.loc[private['Code'].str.startswith('LP.LPI.INFR') , "SubTopic3"] = "Infrastructure"
private.loc[private['Code'].str.startswith('ST.INT.TRNR') , "SubTopic3"] = "Transport receipts"

# %% [markdown]
# # Public

# %%
public  = dfs["public"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(public)
# Out:
#                   Code  \
# 0          VC.BTL.DETH
# 1       VC.IHR.PSRC.P5
# 2    VC.IHR.PSRC.FE.P5
# 3    VC.IHR.PSRC.MA.P5
# 4          VC.IDP.NWCV
# ..                 ...
# 128     IQ.CPA.SOCI.XQ
# 129     IQ.CPA.FISP.XQ
# 130     IQ.CPA.REVN.XQ
# 131         RQ.STD.ERR
# 132     IQ.CPA.MACR.XQ
#
#                                                                                              Indicator Name  \
# 0                                                                  Battle-related deaths (number of people)
# 1                                                                Intentional homicides (per 100,000 people)
# 2                                                        Intentional homicides, female (per 100,000 female)
# 3                                                            Intentional homicides, male (per 100,000 male)
# 4    Internally displaced persons, new displacement associated with conflict and violence (number of cases)
# ..                                                                                                      ...
# 128                             CPIA policies for social inclusion/equity cluster average (1=low to 6=high)
# 129                                                             CPIA fiscal policy rating (1=low to 6=high)
# 130                                        CPIA efficiency of revenue mobilization rating (1=low to 6=high)
# 131                                                                      Regulatory Quality: Standard Error
# 132                                                  CPIA macroeconomic management rating (1=low to 6=high)
#
#                             General Topic          Topic  \
# 0     Public Sector: Conflict & fragility  Public Sector
# 1     Public Sector: Conflict & fragility  Public Sector
# 2     Public Sector: Conflict & fragility  Public Sector
# 3     Public Sector: Conflict & fragility  Public Sector
# 4     Public Sector: Conflict & fragility  Public Sector
# ..                                    ...            ...
# 128  Public Sector: Policy & institutions  Public Sector
# 129  Public Sector: Policy & institutions  Public Sector
# 130  Public Sector: Policy & institutions  Public Sector
# 131  Public Sector: Policy & institutions  Public Sector
# 132  Public Sector: Policy & institutions  Public Sector
#
#                  SubTopic1                                    SubTopic2  \
# 0     Conflict & fragility                                       Battle
# 1     Conflict & fragility                        Intentional homicides
# 2     Conflict & fragility                        Intentional homicides
# 3     Conflict & fragility                        Intentional homicides
# 4     Conflict & fragility                 Internally displaced persons
# ..                     ...                                          ...
# 128  Policy & institutions  Country Policy and Institutional Assessment
# 129  Policy & institutions  Country Policy and Institutional Assessment
# 130  Policy & institutions  Country Policy and Institutional Assessment
# 131  Policy & institutions                                         None
# 132  Policy & institutions  Country Policy and Institutional Assessment
#
#                             SubTopic3
# 0                              Deaths
# 1               Primary and secondary
# 2               Primary and secondary
# 3               Primary and secondary
# 4    New conflict and violence (IDPs)
# ..                                ...
# 128           Social inclusion/equity
# 129                     Fiscal policy
# 130              Revenue mobilization
# 131                              None
# 132                     Macroeconomic
#
# [133 rows x 7 columns]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(public[public['SubTopic2'].isna()])
# Out:
#                   Code  \
# 61    RL.PER.RNK.LOWER
# 62              RL.EST
# 63           RL.NO.SRC
# 64          RL.PER.RNK
# 65    RL.PER.RNK.UPPER
# 66          CC.STD.ERR
# 67          RL.STD.ERR
# 68           CC.NO.SRC
# 69          CC.PER.RNK
# 70    CC.PER.RNK.UPPER
# 71              CC.EST
# 72    CC.PER.RNK.LOWER
# 73         IQ.SPI.OVRL
# 74         IQ.SPI.PIL1
# 75         IQ.SPI.PIL2
# 76         IQ.SPI.PIL3
# 77         IQ.SPI.PIL4
# 78         IQ.SPI.PIL5
# 79              VA.EST
# 80          VA.PER.RNK
# 81    VA.PER.RNK.LOWER
# 82    VA.PER.RNK.UPPER
# 83          VA.STD.ERR
# 84           VA.NO.SRC
# 86           PV.NO.SRC
# 87              PV.EST
# 88          PV.PER.RNK
# 89      HD.HCI.OVRL.FE
# 92    PV.PER.RNK.LOWER
# 93          PV.STD.ERR
# 94         HD.HCI.OVRL
# 95   HD.HCI.OVRL.UB.FE
# 96      HD.HCI.OVRL.LB
# 97          GE.STD.ERR
# 98    GE.PER.RNK.UPPER
# 99    GE.PER.RNK.LOWER
# 100         GE.PER.RNK
# 101   PV.PER.RNK.UPPER
# 102          GE.NO.SRC
# 103     HD.HCI.OVRL.MA
# 104  HD.HCI.OVRL.LB.MA
# 105  HD.HCI.OVRL.UB.MA
# 106     HD.HCI.OVRL.UB
# 108             GE.EST
# 110  HD.HCI.OVRL.LB.FE
# 118             RQ.EST
# 119          RQ.NO.SRC
# 120         RQ.PER.RNK
# 121   RQ.PER.RNK.LOWER
# 123   RQ.PER.RNK.UPPER
# 131         RQ.STD.ERR
#
#                                                                                                      Indicator Name  \
# 61                                             Rule of Law: Percentile Rank, Lower Bound of 90% Confidence Interval
# 62                                                                                            Rule of Law: Estimate
# 63                                                                                   Rule of Law: Number of Sources
# 64                                                                                     Rule of Law: Percentile Rank
# 65                                             Rule of Law: Percentile Rank, Upper Bound of 90% Confidence Interval
# 66                                                                            Control of Corruption: Standard Error
# 67                                                                                      Rule of Law: Standard Error
# 68                                                                         Control of Corruption: Number of Sources
# 69                                                                           Control of Corruption: Percentile Rank
# 70                                   Control of Corruption: Percentile Rank, Upper Bound of 90% Confidence Interval
# 71                                                                                  Control of Corruption: Estimate
# 72                                   Control of Corruption: Percentile Rank, Lower Bound of 90% Confidence Interval
# 73                                            Statistical performance indicators (SPI): Overall score (scale 0-100)
# 74                                  Statistical performance indicators (SPI): Pillar 1 data use score (scale 0-100)
# 75                             Statistical performance indicators (SPI): Pillar 2 data services score (scale 0-100)
# 76                             Statistical performance indicators (SPI): Pillar 3 data products score (scale 0-100)
# 77                              Statistical performance indicators (SPI): Pillar 4 data sources score (scale 0-100)
# 78                       Statistical performance indicators (SPI): Pillar 5 data infrastructure score (scale 0-100)
# 79                                                                               Voice and Accountability: Estimate
# 80                                                                        Voice and Accountability: Percentile Rank
# 81                                Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval
# 82                                Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval
# 83                                                                         Voice and Accountability: Standard Error
# 84                                                                      Voice and Accountability: Number of Sources
# 86                                         Political Stability and Absence of Violence/Terrorism: Number of Sources
# 87                                                  Political Stability and Absence of Violence/Terrorism: Estimate
# 88                                           Political Stability and Absence of Violence/Terrorism: Percentile Rank
# 89                                                                    Human capital index (HCI), female (scale 0-1)
# 92   Political Stability and Absence of Violence/Terrorism: Percentile Rank, Lower Bound of 90% Confidence Interval
# 93                                            Political Stability and Absence of Violence/Terrorism: Standard Error
# 94                                                                            Human capital index (HCI) (scale 0-1)
# 95                                                       Human capital index (HCI), female, upper bound (scale 0-1)
# 96                                                               Human capital index (HCI), lower bound (scale 0-1)
# 97                                                                         Government Effectiveness: Standard Error
# 98                                Government Effectiveness: Percentile Rank, Upper Bound of 90% Confidence Interval
# 99                                Government Effectiveness: Percentile Rank, Lower Bound of 90% Confidence Interval
# 100                                                                       Government Effectiveness: Percentile Rank
# 101  Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval
# 102                                                                     Government Effectiveness: Number of Sources
# 103                                                                     Human capital index (HCI), male (scale 0-1)
# 104                                                        Human capital index (HCI), male, lower bound (scale 0-1)
# 105                                                        Human capital index (HCI), male, upper bound (scale 0-1)
# 106                                                              Human capital index (HCI), upper bound (scale 0-1)
# 108                                                                              Government Effectiveness: Estimate
# 110                                                      Human capital index (HCI), female, lower bound (scale 0-1)
# 118                                                                                    Regulatory Quality: Estimate
# 119                                                                           Regulatory Quality: Number of Sources
# 120                                                                             Regulatory Quality: Percentile Rank
# 121                                     Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval
# 123                                     Regulatory Quality: Percentile Rank, Upper Bound of 90% Confidence Interval
# 131                                                                              Regulatory Quality: Standard Error
#
#                             General Topic          Topic  \
# 61   Public Sector: Policy & institutions  Public Sector
# 62   Public Sector: Policy & institutions  Public Sector
# 63   Public Sector: Policy & institutions  Public Sector
# 64   Public Sector: Policy & institutions  Public Sector
# 65   Public Sector: Policy & institutions  Public Sector
# 66   Public Sector: Policy & institutions  Public Sector
# 67   Public Sector: Policy & institutions  Public Sector
# 68   Public Sector: Policy & institutions  Public Sector
# 69   Public Sector: Policy & institutions  Public Sector
# 70   Public Sector: Policy & institutions  Public Sector
# 71   Public Sector: Policy & institutions  Public Sector
# 72   Public Sector: Policy & institutions  Public Sector
# 73   Public Sector: Policy & institutions  Public Sector
# 74   Public Sector: Policy & institutions  Public Sector
# 75   Public Sector: Policy & institutions  Public Sector
# 76   Public Sector: Policy & institutions  Public Sector
# 77   Public Sector: Policy & institutions  Public Sector
# 78   Public Sector: Policy & institutions  Public Sector
# 79   Public Sector: Policy & institutions  Public Sector
# 80   Public Sector: Policy & institutions  Public Sector
# 81   Public Sector: Policy & institutions  Public Sector
# 82   Public Sector: Policy & institutions  Public Sector
# 83   Public Sector: Policy & institutions  Public Sector
# 84   Public Sector: Policy & institutions  Public Sector
# 86   Public Sector: Policy & institutions  Public Sector
# 87   Public Sector: Policy & institutions  Public Sector
# 88   Public Sector: Policy & institutions  Public Sector
# 89   Public Sector: Policy & institutions  Public Sector
# 92   Public Sector: Policy & institutions  Public Sector
# 93   Public Sector: Policy & institutions  Public Sector
# 94   Public Sector: Policy & institutions  Public Sector
# 95   Public Sector: Policy & institutions  Public Sector
# 96   Public Sector: Policy & institutions  Public Sector
# 97   Public Sector: Policy & institutions  Public Sector
# 98   Public Sector: Policy & institutions  Public Sector
# 99   Public Sector: Policy & institutions  Public Sector
# 100  Public Sector: Policy & institutions  Public Sector
# 101  Public Sector: Policy & institutions  Public Sector
# 102  Public Sector: Policy & institutions  Public Sector
# 103  Public Sector: Policy & institutions  Public Sector
# 104  Public Sector: Policy & institutions  Public Sector
# 105  Public Sector: Policy & institutions  Public Sector
# 106  Public Sector: Policy & institutions  Public Sector
# 108  Public Sector: Policy & institutions  Public Sector
# 110  Public Sector: Policy & institutions  Public Sector
# 118  Public Sector: Policy & institutions  Public Sector
# 119  Public Sector: Policy & institutions  Public Sector
# 120  Public Sector: Policy & institutions  Public Sector
# 121  Public Sector: Policy & institutions  Public Sector
# 123  Public Sector: Policy & institutions  Public Sector
# 131  Public Sector: Policy & institutions  Public Sector
#
#                  SubTopic1 SubTopic2 SubTopic3
# 61   Policy & institutions      None      None
# 62   Policy & institutions      None      None
# 63   Policy & institutions      None      None
# 64   Policy & institutions      None      None
# 65   Policy & institutions      None      None
# 66   Policy & institutions      None      None
# 67   Policy & institutions      None      None
# 68   Policy & institutions      None      None
# 69   Policy & institutions      None      None
# 70   Policy & institutions      None      None
# 71   Policy & institutions      None      None
# 72   Policy & institutions      None      None
# 73   Policy & institutions      None   Overall
# 74   Policy & institutions      None      None
# 75   Policy & institutions      None      None
# 76   Policy & institutions      None      None
# 77   Policy & institutions      None      None
# 78   Policy & institutions      None      None
# 79   Policy & institutions      None      None
# 80   Policy & institutions      None      None
# 81   Policy & institutions      None      None
# 82   Policy & institutions      None      None
# 83   Policy & institutions      None      None
# 84   Policy & institutions      None      None
# 86   Policy & institutions      None      None
# 87   Policy & institutions      None      None
# 88   Policy & institutions      None      None
# 89   Policy & institutions      None   Overall
# 92   Policy & institutions      None      None
# 93   Policy & institutions      None      None
# 94   Policy & institutions      None   Overall
# 95   Policy & institutions      None   Overall
# 96   Policy & institutions      None   Overall
# 97   Policy & institutions      None      None
# 98   Policy & institutions      None      None
# 99   Policy & institutions      None      None
# 100  Policy & institutions      None      None
# 101  Policy & institutions      None      None
# 102  Policy & institutions      None      None
# 103  Policy & institutions      None   Overall
# 104  Policy & institutions      None   Overall
# 105  Policy & institutions      None   Overall
# 106  Policy & institutions      None   Overall
# 108  Policy & institutions      None      None
# 110  Policy & institutions      None   Overall
# 118  Policy & institutions      None      None
# 119  Policy & institutions      None      None
# 120  Policy & institutions      None      None
# 121  Policy & institutions      None      None
# 123  Policy & institutions      None      None
# 131  Policy & institutions      None      None

# %%
a = public[public['SubTopic2'].isna()].copy()
a["Code_Prefix"] = a["Code"].str.split(".").str[1]


unique_prefixes = a["Code_Prefix"].unique()
print(unique_prefixes)
# Out:
# ['PER' 'EST' 'NO' 'STD' 'SPI' 'HCI']

# %%
public[public['Code'].str.contains('SPI')]
# Out:
#            Code                                     Indicator Name  \
# 73  IQ.SPI.OVRL  Statistical performance indicators (SPI): Over...
# 74  IQ.SPI.PIL1  Statistical performance indicators (SPI): Pill...
# 75  IQ.SPI.PIL2  Statistical performance indicators (SPI): Pill...
# 76  IQ.SPI.PIL3  Statistical performance indicators (SPI): Pill...
# 77  IQ.SPI.PIL4  Statistical performance indicators (SPI): Pill...
# 78  IQ.SPI.PIL5  Statistical performance indicators (SPI): Pill...
#
#                            General Topic          Topic  \
# 73  Public Sector: Policy & institutions  Public Sector
# 74  Public Sector: Policy & institutions  Public Sector
# 75  Public Sector: Policy & institutions  Public Sector
# 76  Public Sector: Policy & institutions  Public Sector
# 77  Public Sector: Policy & institutions  Public Sector
# 78  Public Sector: Policy & institutions  Public Sector
#
#                 SubTopic1 SubTopic2 SubTopic3
# 73  Policy & institutions      None   Overall
# 74  Policy & institutions      None      None
# 75  Policy & institutions      None      None
# 76  Policy & institutions      None      None
# 77  Policy & institutions      None      None
# 78  Policy & institutions      None      None

# %%
public[public['Code'].str.contains('EST')]
# Out:
#        Code                                     Indicator Name  \
# 62   RL.EST                              Rule of Law: Estimate
# 71   CC.EST                    Control of Corruption: Estimate
# 79   VA.EST                 Voice and Accountability: Estimate
# 87   PV.EST  Political Stability and Absence of Violence/Te...
# 108  GE.EST                 Government Effectiveness: Estimate
# 118  RQ.EST                       Regulatory Quality: Estimate
#
#                             General Topic          Topic  \
# 62   Public Sector: Policy & institutions  Public Sector
# 71   Public Sector: Policy & institutions  Public Sector
# 79   Public Sector: Policy & institutions  Public Sector
# 87   Public Sector: Policy & institutions  Public Sector
# 108  Public Sector: Policy & institutions  Public Sector
# 118  Public Sector: Policy & institutions  Public Sector
#
#                  SubTopic1 SubTopic2 SubTopic3
# 62   Policy & institutions      None      None
# 71   Policy & institutions      None      None
# 79   Policy & institutions      None      None
# 87   Policy & institutions      None      None
# 108  Policy & institutions      None      None
# 118  Policy & institutions      None      None

# %%
public[public['Code'].str.contains('PER')]
# Out:
#                  Code                                     Indicator Name  \
# 61   RL.PER.RNK.LOWER  Rule of Law: Percentile Rank, Lower Bound of 9...
# 64         RL.PER.RNK                       Rule of Law: Percentile Rank
# 65   RL.PER.RNK.UPPER  Rule of Law: Percentile Rank, Upper Bound of 9...
# 69         CC.PER.RNK             Control of Corruption: Percentile Rank
# 70   CC.PER.RNK.UPPER  Control of Corruption: Percentile Rank, Upper ...
# 72   CC.PER.RNK.LOWER  Control of Corruption: Percentile Rank, Lower ...
# 80         VA.PER.RNK          Voice and Accountability: Percentile Rank
# 81   VA.PER.RNK.LOWER  Voice and Accountability: Percentile Rank, Low...
# 82   VA.PER.RNK.UPPER  Voice and Accountability: Percentile Rank, Upp...
# 88         PV.PER.RNK  Political Stability and Absence of Violence/Te...
# 92   PV.PER.RNK.LOWER  Political Stability and Absence of Violence/Te...
# 98   GE.PER.RNK.UPPER  Government Effectiveness: Percentile Rank, Upp...
# 99   GE.PER.RNK.LOWER  Government Effectiveness: Percentile Rank, Low...
# 100        GE.PER.RNK          Government Effectiveness: Percentile Rank
# 101  PV.PER.RNK.UPPER  Political Stability and Absence of Violence/Te...
# 120        RQ.PER.RNK                Regulatory Quality: Percentile Rank
# 121  RQ.PER.RNK.LOWER  Regulatory Quality: Percentile Rank, Lower Bou...
# 123  RQ.PER.RNK.UPPER  Regulatory Quality: Percentile Rank, Upper Bou...
#
#                             General Topic          Topic  \
# 61   Public Sector: Policy & institutions  Public Sector
# 64   Public Sector: Policy & institutions  Public Sector
# 65   Public Sector: Policy & institutions  Public Sector
# 69   Public Sector: Policy & institutions  Public Sector
# 70   Public Sector: Policy & institutions  Public Sector
# 72   Public Sector: Policy & institutions  Public Sector
# 80   Public Sector: Policy & institutions  Public Sector
# 81   Public Sector: Policy & institutions  Public Sector
# 82   Public Sector: Policy & institutions  Public Sector
# 88   Public Sector: Policy & institutions  Public Sector
# 92   Public Sector: Policy & institutions  Public Sector
# 98   Public Sector: Policy & institutions  Public Sector
# 99   Public Sector: Policy & institutions  Public Sector
# 100  Public Sector: Policy & institutions  Public Sector
# 101  Public Sector: Policy & institutions  Public Sector
# 120  Public Sector: Policy & institutions  Public Sector
# 121  Public Sector: Policy & institutions  Public Sector
# 123  Public Sector: Policy & institutions  Public Sector
#
#                  SubTopic1 SubTopic2 SubTopic3
# 61   Policy & institutions      None      None
# 64   Policy & institutions      None      None
# 65   Policy & institutions      None      None
# 69   Policy & institutions      None      None
# 70   Policy & institutions      None      None
# 72   Policy & institutions      None      None
# 80   Policy & institutions      None      None
# 81   Policy & institutions      None      None
# 82   Policy & institutions      None      None
# 88   Policy & institutions      None      None
# 92   Policy & institutions      None      None
# 98   Policy & institutions      None      None
# 99   Policy & institutions      None      None
# 100  Policy & institutions      None      None
# 101  Policy & institutions      None      None
# 120  Policy & institutions      None      None
# 121  Policy & institutions      None      None
# 123  Policy & institutions      None      None

# %% [markdown]
# # for PER This is a good example where we need to further add a new column to add more informations like in this case (LOWER , UPPER)

# %%
public[public['Code'].str.contains('STD')]
# Out:
#            Code                                     Indicator Name  \
# 66   CC.STD.ERR              Control of Corruption: Standard Error
# 67   RL.STD.ERR                        Rule of Law: Standard Error
# 83   VA.STD.ERR           Voice and Accountability: Standard Error
# 93   PV.STD.ERR  Political Stability and Absence of Violence/Te...
# 97   GE.STD.ERR           Government Effectiveness: Standard Error
# 131  RQ.STD.ERR                 Regulatory Quality: Standard Error
#
#                             General Topic          Topic  \
# 66   Public Sector: Policy & institutions  Public Sector
# 67   Public Sector: Policy & institutions  Public Sector
# 83   Public Sector: Policy & institutions  Public Sector
# 93   Public Sector: Policy & institutions  Public Sector
# 97   Public Sector: Policy & institutions  Public Sector
# 131  Public Sector: Policy & institutions  Public Sector
#
#                  SubTopic1 SubTopic2 SubTopic3
# 66   Policy & institutions      None      None
# 67   Policy & institutions      None      None
# 83   Policy & institutions      None      None
# 93   Policy & institutions      None      None
# 97   Policy & institutions      None      None
# 131  Policy & institutions      None      None

# %%
public.loc[public['Code'].str.startswith('HD.HCI'), "SubTopic2"] = "Human capital index"


public.loc[public['Code'].str.startswith('RQ'), "SubTopic2"] = "Regulatory Quality"
public.loc[public['Code'].str.startswith('GE'), "SubTopic2"] = "Government Effectiveness"
public.loc[public['Code'].str.startswith('RL'), "SubTopic2"] = "Rule of Law"
public.loc[public['Code'].str.startswith('CC'), "SubTopic2"] = "Control of Corruption"
public.loc[public['Code'].str.startswith('PV'), "SubTopic2"] = "Political Stability and Absence of Violence/Terrorism"
public.loc[public['Code'].str.startswith('VA.'), "SubTopic2"] = "Voice and Accountability"
public.loc[public['Code'].str.startswith('IQ.'), "SubTopic2"] = "Statistical performance indicators"

public.loc[public['Code'].str.contains('PER'), "SubTopic3"] = "Percentile Rank"
public.loc[public["Code"].str.contains("EST"), "SubTopic3"] = "Estimate"
public.loc[public["Code"].str.contains("STD.ERR"), "SubTopic3"] = "Standard Error"
public.loc[public["Code"].str.contains("NO") , "SubTopic3"] = "Number of Sources"


public.loc[public["Code"].str.contains("PIL1") , "SubTopic3"] = "Data use score"
public.loc[public["Code"].str.contains("PIL2") , "SubTopic3"] = "Data services score"
public.loc[public["Code"].str.contains("PIL3") , "SubTopic3"] = "Data products score"
public.loc[public["Code"].str.contains("PIL4") , "SubTopic3"] = "Data sources score"
public.loc[public["Code"].str.contains("PIL5") , "SubTopic3"] = "Data infrastructure score"
public.loc[public["Code"].str.contains("OVRL") , "SubTopic3"] = "Overall score"

# %%
with pd.option_context('display.max_colwidth', 200):

    display(public[public['SubTopic3'].isna()])
# Out:
#               Code  \
# 60  GF.XPD.BUDG.ZS
#
#                                                                      Indicator Name  \
# 60  Primary government expenditures as a proportion of original approved budget (%)
#
#                         General Topic          Topic           SubTopic1  \
# 60  Public Sector: Government finance  Public Sector  Government finance
#
#       SubTopic2 SubTopic3
# 60  Expenditure      None

# %%
public.loc[public["Code"] == "GF.XPD.BUDG.ZS", "SubTopic3"] = ["Budget"]

# %%
has_list = public.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


public_with_lists = public[has_list]
with pd.option_context('display.max_colwidth', 200):
    display(public_with_lists)
# Out:
#                  Code  \
# 15     GC.DOD.TOTL.CN
# 16  GC.DOD.TOTL.GD.ZS
# 17  GC.AST.TOTL.GD.ZS
# 18     GC.NLD.TOTL.CN
# 19  GC.LBL.TOTL.GD.ZS
# 20  GC.NLD.TOTL.GD.ZS
# 21  GC.NFN.TOTL.GD.ZS
# 22     GC.NFN.TOTL.CN
# 23     GC.LBL.TOTL.CN
# 24     GC.AST.TOTL.CN
# 38     GC.TAX.YPKG.CN
# 40     GC.TAX.GSRV.CN
# 41  GC.TAX.INTT.RV.ZS
# 42     GC.TAX.INTT.CN
# 45     GC.TAX.YPKG.ZS
# 46  GC.TAX.TOTL.GD.ZS
# 48     GC.TAX.TOTL.CN
# 49     GC.TAX.EXPT.ZS
# 50     GC.TAX.EXPT.CN
# 51  GC.TAX.GSRV.RV.ZS
# 52  GC.TAX.GSRV.VA.ZS
# 53  GC.TAX.YPKG.RV.ZS
# 54     GC.TAX.OTHR.CN
# 55  GC.TAX.OTHR.RV.ZS
# 56     GC.TAX.IMPT.CN
# 57     GC.TAX.IMPT.ZS
#
#                                                           Indicator Name  \
# 15                          Central government debt, total (current LCU)
# 16                             Central government debt, total (% of GDP)
# 17                        Net acquisition of financial assets (% of GDP)
# 18                     Net lending (+) / net borrowing (-) (current LCU)
# 19                       Net incurrence of liabilities, total (% of GDP)
# 20                        Net lending (+) / net borrowing (-) (% of GDP)
# 21                      Net investment in nonfinancial assets (% of GDP)
# 22                   Net investment in nonfinancial assets (current LCU)
# 23                    Net incurrence of liabilities, total (current LCU)
# 24                     Net acquisition of financial assets (current LCU)
# 38              Taxes on income, profits and capital gains (current LCU)
# 40                             Taxes on goods and services (current LCU)
# 41                           Taxes on international trade (% of revenue)
# 42                            Taxes on international trade (current LCU)
# 45         Taxes on income, profits and capital gains (% of total taxes)
# 46                                                Tax revenue (% of GDP)
# 48                                             Tax revenue (current LCU)
# 49                                   Taxes on exports (% of tax revenue)
# 50                                        Taxes on exports (current LCU)
# 51                            Taxes on goods and services (% of revenue)
# 52  Taxes on goods and services (% value added of industry and services)
# 53             Taxes on income, profits and capital gains (% of revenue)
# 54                                             Other taxes (current LCU)
# 55                                            Other taxes (% of revenue)
# 56                         Customs and other import duties (current LCU)
# 57                    Customs and other import duties (% of tax revenue)
#
#                                              General Topic          Topic  \
# 15  Public Sector: Government finance: Deficit & financing  Public Sector
# 16  Public Sector: Government finance: Deficit & financing  Public Sector
# 17  Public Sector: Government finance: Deficit & financing  Public Sector
# 18  Public Sector: Government finance: Deficit & financing  Public Sector
# 19  Public Sector: Government finance: Deficit & financing  Public Sector
# 20  Public Sector: Government finance: Deficit & financing  Public Sector
# 21  Public Sector: Government finance: Deficit & financing  Public Sector
# 22  Public Sector: Government finance: Deficit & financing  Public Sector
# 23  Public Sector: Government finance: Deficit & financing  Public Sector
# 24  Public Sector: Government finance: Deficit & financing  Public Sector
# 38              Public Sector: Government finance: Revenue  Public Sector
# 40              Public Sector: Government finance: Revenue  Public Sector
# 41              Public Sector: Government finance: Revenue  Public Sector
# 42              Public Sector: Government finance: Revenue  Public Sector
# 45              Public Sector: Government finance: Revenue  Public Sector
# 46              Public Sector: Government finance: Revenue  Public Sector
# 48              Public Sector: Government finance: Revenue  Public Sector
# 49              Public Sector: Government finance: Revenue  Public Sector
# 50              Public Sector: Government finance: Revenue  Public Sector
# 51              Public Sector: Government finance: Revenue  Public Sector
# 52              Public Sector: Government finance: Revenue  Public Sector
# 53              Public Sector: Government finance: Revenue  Public Sector
# 54              Public Sector: Government finance: Revenue  Public Sector
# 55              Public Sector: Government finance: Revenue  Public Sector
# 56              Public Sector: Government finance: Revenue  Public Sector
# 57              Public Sector: Government finance: Revenue  Public Sector
#
#              SubTopic1                                              SubTopic2  \
# 15  Government finance  [Deficit & financing, Debt outstanding and disbursed]
# 16  Government finance  [Deficit & financing, Debt outstanding and disbursed]
# 17  Government finance                           [Deficit & financing, Asset]
# 18  Government finance       [Deficit & financing, Net lending/net borrowing]
# 19  Government finance                       [Deficit & financing, Liability]
# 20  Government finance       [Deficit & financing, Net lending/net borrowing]
# 21  Government finance             [Deficit & financing, Nonfinancial assets]
# 22  Government finance             [Deficit & financing, Nonfinancial assets]
# 23  Government finance                       [Deficit & financing, Liability]
# 24  Government finance                           [Deficit & financing, Asset]
# 38  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 40  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 41  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 42  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 45  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 46  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 48  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 49  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 50  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 51  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 52  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 53  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 54  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 55  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 56  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 57  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
#
#                                                      SubTopic3
# 15                                                       Total
# 16                                                       Total
# 17                                                       Total
# 18                                                       Total
# 19                                                       Total
# 20                                                       Total
# 21                                                       Total
# 22                                                       Total
# 23                                                       Total
# 24                                                       Total
# 38                           Income, profits and capital gains
# 40                                          Goods and services
# 41                                         International trade
# 42                                         International trade
# 45                           Income, profits and capital gains
# 46                                                       Total
# 48                                                       Total
# 49                                                     Exports
# 50                                                     Exports
# 51                                          Goods and services
# 52                                          Goods and services
# 53                           Income, profits and capital gains
# 54  Water pollution, other industry (% of total BOD emissions)
# 55  Water pollution, other industry (% of total BOD emissions)
# 56                             Customs and other import duties
# 57                             Customs and other import duties

# %%
with pd.option_context('display.max_colwidth', 200):

    display(public[public['Code'].str.startswith('GC')])
# Out:
#                  Code  \
# 15     GC.DOD.TOTL.CN
# 16  GC.DOD.TOTL.GD.ZS
# 17  GC.AST.TOTL.GD.ZS
# 18     GC.NLD.TOTL.CN
# 19  GC.LBL.TOTL.GD.ZS
# 20  GC.NLD.TOTL.GD.ZS
# 21  GC.NFN.TOTL.GD.ZS
# 22     GC.NFN.TOTL.CN
# 23     GC.LBL.TOTL.CN
# 24     GC.AST.TOTL.CN
# 25     GC.XPN.TRFT.ZS
# 26     GC.XPN.TRFT.CN
# 27     GC.XPN.COMP.ZS
# 28     GC.XPN.COMP.CN
# 29     GC.XPN.INTP.ZS
# 30  GC.XPN.INTP.RV.ZS
# 31     GC.XPN.INTP.CN
# 32     GC.XPN.OTHR.CN
# 33     GC.XPN.OTHR.ZS
# 34     GC.XPN.GSRV.CN
# 35     GC.XPN.GSRV.ZS
# 36     GC.XPN.TOTL.CN
# 37  GC.XPN.TOTL.GD.ZS
# 38     GC.TAX.YPKG.CN
# 39     GC.REV.XGRT.CN
# 40     GC.TAX.GSRV.CN
# 41  GC.TAX.INTT.RV.ZS
# 42     GC.TAX.INTT.CN
# 43     GC.REV.SOCL.CN
# 44     GC.REV.SOCL.ZS
# 45     GC.TAX.YPKG.ZS
# 46  GC.TAX.TOTL.GD.ZS
# 47  GC.REV.XGRT.GD.ZS
# 48     GC.TAX.TOTL.CN
# 49     GC.TAX.EXPT.ZS
# 50     GC.TAX.EXPT.CN
# 51  GC.TAX.GSRV.RV.ZS
# 52  GC.TAX.GSRV.VA.ZS
# 53  GC.TAX.YPKG.RV.ZS
# 54     GC.TAX.OTHR.CN
# 55  GC.TAX.OTHR.RV.ZS
# 56     GC.TAX.IMPT.CN
# 57     GC.TAX.IMPT.ZS
# 58     GC.REV.GOTR.CN
# 59     GC.REV.GOTR.ZS
#
#                                                           Indicator Name  \
# 15                          Central government debt, total (current LCU)
# 16                             Central government debt, total (% of GDP)
# 17                        Net acquisition of financial assets (% of GDP)
# 18                     Net lending (+) / net borrowing (-) (current LCU)
# 19                       Net incurrence of liabilities, total (% of GDP)
# 20                        Net lending (+) / net borrowing (-) (% of GDP)
# 21                      Net investment in nonfinancial assets (% of GDP)
# 22                   Net investment in nonfinancial assets (current LCU)
# 23                    Net incurrence of liabilities, total (current LCU)
# 24                     Net acquisition of financial assets (current LCU)
# 25                          Subsidies and other transfers (% of expense)
# 26                           Subsidies and other transfers (current LCU)
# 27                              Compensation of employees (% of expense)
# 28                               Compensation of employees (current LCU)
# 29                                      Interest payments (% of expense)
# 30                                      Interest payments (% of revenue)
# 31                                       Interest payments (current LCU)
# 32                                           Other expense (current LCU)
# 33                                          Other expense (% of expense)
# 34                              Goods and services expense (current LCU)
# 35                             Goods and services expense (% of expense)
# 36                                                 Expense (current LCU)
# 37                                                    Expense (% of GDP)
# 38              Taxes on income, profits and capital gains (current LCU)
# 39                               Revenue, excluding grants (current LCU)
# 40                             Taxes on goods and services (current LCU)
# 41                           Taxes on international trade (% of revenue)
# 42                            Taxes on international trade (current LCU)
# 43                                    Social contributions (current LCU)
# 44                                   Social contributions (% of revenue)
# 45         Taxes on income, profits and capital gains (% of total taxes)
# 46                                                Tax revenue (% of GDP)
# 47                                  Revenue, excluding grants (% of GDP)
# 48                                             Tax revenue (current LCU)
# 49                                   Taxes on exports (% of tax revenue)
# 50                                        Taxes on exports (current LCU)
# 51                            Taxes on goods and services (% of revenue)
# 52  Taxes on goods and services (% value added of industry and services)
# 53             Taxes on income, profits and capital gains (% of revenue)
# 54                                             Other taxes (current LCU)
# 55                                            Other taxes (% of revenue)
# 56                         Customs and other import duties (current LCU)
# 57                    Customs and other import duties (% of tax revenue)
# 58                                Grants and other revenue (current LCU)
# 59                               Grants and other revenue (% of revenue)
#
#                                              General Topic          Topic  \
# 15  Public Sector: Government finance: Deficit & financing  Public Sector
# 16  Public Sector: Government finance: Deficit & financing  Public Sector
# 17  Public Sector: Government finance: Deficit & financing  Public Sector
# 18  Public Sector: Government finance: Deficit & financing  Public Sector
# 19  Public Sector: Government finance: Deficit & financing  Public Sector
# 20  Public Sector: Government finance: Deficit & financing  Public Sector
# 21  Public Sector: Government finance: Deficit & financing  Public Sector
# 22  Public Sector: Government finance: Deficit & financing  Public Sector
# 23  Public Sector: Government finance: Deficit & financing  Public Sector
# 24  Public Sector: Government finance: Deficit & financing  Public Sector
# 25              Public Sector: Government finance: Expense  Public Sector
# 26              Public Sector: Government finance: Expense  Public Sector
# 27              Public Sector: Government finance: Expense  Public Sector
# 28              Public Sector: Government finance: Expense  Public Sector
# 29              Public Sector: Government finance: Expense  Public Sector
# 30              Public Sector: Government finance: Expense  Public Sector
# 31              Public Sector: Government finance: Expense  Public Sector
# 32              Public Sector: Government finance: Expense  Public Sector
# 33              Public Sector: Government finance: Expense  Public Sector
# 34              Public Sector: Government finance: Expense  Public Sector
# 35              Public Sector: Government finance: Expense  Public Sector
# 36              Public Sector: Government finance: Expense  Public Sector
# 37              Public Sector: Government finance: Expense  Public Sector
# 38              Public Sector: Government finance: Revenue  Public Sector
# 39              Public Sector: Government finance: Revenue  Public Sector
# 40              Public Sector: Government finance: Revenue  Public Sector
# 41              Public Sector: Government finance: Revenue  Public Sector
# 42              Public Sector: Government finance: Revenue  Public Sector
# 43              Public Sector: Government finance: Revenue  Public Sector
# 44              Public Sector: Government finance: Revenue  Public Sector
# 45              Public Sector: Government finance: Revenue  Public Sector
# 46              Public Sector: Government finance: Revenue  Public Sector
# 47              Public Sector: Government finance: Revenue  Public Sector
# 48              Public Sector: Government finance: Revenue  Public Sector
# 49              Public Sector: Government finance: Revenue  Public Sector
# 50              Public Sector: Government finance: Revenue  Public Sector
# 51              Public Sector: Government finance: Revenue  Public Sector
# 52              Public Sector: Government finance: Revenue  Public Sector
# 53              Public Sector: Government finance: Revenue  Public Sector
# 54              Public Sector: Government finance: Revenue  Public Sector
# 55              Public Sector: Government finance: Revenue  Public Sector
# 56              Public Sector: Government finance: Revenue  Public Sector
# 57              Public Sector: Government finance: Revenue  Public Sector
# 58              Public Sector: Government finance: Revenue  Public Sector
# 59              Public Sector: Government finance: Revenue  Public Sector
#
#              SubTopic1                                              SubTopic2  \
# 15  Government finance  [Deficit & financing, Debt outstanding and disbursed]
# 16  Government finance  [Deficit & financing, Debt outstanding and disbursed]
# 17  Government finance                           [Deficit & financing, Asset]
# 18  Government finance       [Deficit & financing, Net lending/net borrowing]
# 19  Government finance                       [Deficit & financing, Liability]
# 20  Government finance       [Deficit & financing, Net lending/net borrowing]
# 21  Government finance             [Deficit & financing, Nonfinancial assets]
# 22  Government finance             [Deficit & financing, Nonfinancial assets]
# 23  Government finance                       [Deficit & financing, Liability]
# 24  Government finance                           [Deficit & financing, Asset]
# 25  Government finance                                                Expense
# 26  Government finance                                                Expense
# 27  Government finance                                                Expense
# 28  Government finance                                                Expense
# 29  Government finance                                                Expense
# 30  Government finance                                                Expense
# 31  Government finance                                                Expense
# 32  Government finance                                                Expense
# 33  Government finance                                                Expense
# 34  Government finance                                                Expense
# 35  Government finance                                                Expense
# 36  Government finance                                                Expense
# 37  Government finance                                                Expense
# 38  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 39  Government finance                                                Revenue
# 40  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 41  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 42  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 43  Government finance                                                Revenue
# 44  Government finance                                                Revenue
# 45  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 46  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 47  Government finance                                                Revenue
# 48  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 49  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 50  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 51  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 52  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 53  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 54  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 55  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 56  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 57  Government finance    [Revenue, Tax revenue (or tariff) (or tax related)]
# 58  Government finance                                                Revenue
# 59  Government finance                                                Revenue
#
#                                                      SubTopic3
# 15                                                       Total
# 16                                                       Total
# 17                                                       Total
# 18                                                       Total
# 19                                                       Total
# 20                                                       Total
# 21                                                       Total
# 22                                                       Total
# 23                                                       Total
# 24                                                       Total
# 25                               Subsidies and other transfers
# 26                               Subsidies and other transfers
# 27                                                Compensation
# 28                                                Compensation
# 29                                           Interest payments
# 30                                           Interest payments
# 31                                           Interest payments
# 32  Water pollution, other industry (% of total BOD emissions)
# 33  Water pollution, other industry (% of total BOD emissions)
# 34                                          Goods and services
# 35                                          Goods and services
# 36                                                       Total
# 37                                                       Total
# 38                           Income, profits and capital gains
# 39                                            Excluding grants
# 40                                          Goods and services
# 41                                         International trade
# 42                                         International trade
# 43                                                      Social
# 44                                                      Social
# 45                           Income, profits and capital gains
# 46                                                       Total
# 47                                            Excluding grants
# 48                                                       Total
# 49                                                     Exports
# 50                                                     Exports
# 51                                          Goods and services
# 52                                          Goods and services
# 53                           Income, profits and capital gains
# 54  Water pollution, other industry (% of total BOD emissions)
# 55  Water pollution, other industry (% of total BOD emissions)
# 56                             Customs and other import duties
# 57                             Customs and other import duties
# 58                                    Grants and other revenue
# 59                                    Grants and other revenue

# %%
public["SubTopic2"] = public["SubTopic2"].apply(select_second_item)

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(public[public['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
#                  Code  \
# 38     GC.TAX.YPKG.CN
# 40     GC.TAX.GSRV.CN
# 41  GC.TAX.INTT.RV.ZS
# 42     GC.TAX.INTT.CN
# 45     GC.TAX.YPKG.ZS
# 46  GC.TAX.TOTL.GD.ZS
# 48     GC.TAX.TOTL.CN
# 49     GC.TAX.EXPT.ZS
# 50     GC.TAX.EXPT.CN
# 51  GC.TAX.GSRV.RV.ZS
# 52  GC.TAX.GSRV.VA.ZS
# 53  GC.TAX.YPKG.RV.ZS
# 54     GC.TAX.OTHR.CN
# 55  GC.TAX.OTHR.RV.ZS
# 56     GC.TAX.IMPT.CN
# 57     GC.TAX.IMPT.ZS
#
#                                                           Indicator Name  \
# 38              Taxes on income, profits and capital gains (current LCU)
# 40                             Taxes on goods and services (current LCU)
# 41                           Taxes on international trade (% of revenue)
# 42                            Taxes on international trade (current LCU)
# 45         Taxes on income, profits and capital gains (% of total taxes)
# 46                                                Tax revenue (% of GDP)
# 48                                             Tax revenue (current LCU)
# 49                                   Taxes on exports (% of tax revenue)
# 50                                        Taxes on exports (current LCU)
# 51                            Taxes on goods and services (% of revenue)
# 52  Taxes on goods and services (% value added of industry and services)
# 53             Taxes on income, profits and capital gains (% of revenue)
# 54                                             Other taxes (current LCU)
# 55                                            Other taxes (% of revenue)
# 56                         Customs and other import duties (current LCU)
# 57                    Customs and other import duties (% of tax revenue)
#
#                                  General Topic          Topic  \
# 38  Public Sector: Government finance: Revenue  Public Sector
# 40  Public Sector: Government finance: Revenue  Public Sector
# 41  Public Sector: Government finance: Revenue  Public Sector
# 42  Public Sector: Government finance: Revenue  Public Sector
# 45  Public Sector: Government finance: Revenue  Public Sector
# 46  Public Sector: Government finance: Revenue  Public Sector
# 48  Public Sector: Government finance: Revenue  Public Sector
# 49  Public Sector: Government finance: Revenue  Public Sector
# 50  Public Sector: Government finance: Revenue  Public Sector
# 51  Public Sector: Government finance: Revenue  Public Sector
# 52  Public Sector: Government finance: Revenue  Public Sector
# 53  Public Sector: Government finance: Revenue  Public Sector
# 54  Public Sector: Government finance: Revenue  Public Sector
# 55  Public Sector: Government finance: Revenue  Public Sector
# 56  Public Sector: Government finance: Revenue  Public Sector
# 57  Public Sector: Government finance: Revenue  Public Sector
#
#              SubTopic1                                 SubTopic2  \
# 38  Government finance  Tax revenue (or tariff) (or tax related)
# 40  Government finance  Tax revenue (or tariff) (or tax related)
# 41  Government finance  Tax revenue (or tariff) (or tax related)
# 42  Government finance  Tax revenue (or tariff) (or tax related)
# 45  Government finance  Tax revenue (or tariff) (or tax related)
# 46  Government finance  Tax revenue (or tariff) (or tax related)
# 48  Government finance  Tax revenue (or tariff) (or tax related)
# 49  Government finance  Tax revenue (or tariff) (or tax related)
# 50  Government finance  Tax revenue (or tariff) (or tax related)
# 51  Government finance  Tax revenue (or tariff) (or tax related)
# 52  Government finance  Tax revenue (or tariff) (or tax related)
# 53  Government finance  Tax revenue (or tariff) (or tax related)
# 54  Government finance  Tax revenue (or tariff) (or tax related)
# 55  Government finance  Tax revenue (or tariff) (or tax related)
# 56  Government finance  Tax revenue (or tariff) (or tax related)
# 57  Government finance  Tax revenue (or tariff) (or tax related)
#
#                                                      SubTopic3
# 38                           Income, profits and capital gains
# 40                                          Goods and services
# 41                                         International trade
# 42                                         International trade
# 45                           Income, profits and capital gains
# 46                                                       Total
# 48                                                       Total
# 49                                                     Exports
# 50                                                     Exports
# 51                                          Goods and services
# 52                                          Goods and services
# 53                           Income, profits and capital gains
# 54  Water pollution, other industry (% of total BOD emissions)
# 55  Water pollution, other industry (% of total BOD emissions)
# 56                             Customs and other import duties
# 57                             Customs and other import duties

# %%
public.loc[public['Code'].str.startswith('GC.TAX') , "SubTopic2"] = "Tax revenue (or tax related)"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(public[public['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Social

# %%
social  = dfs["social"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(social)
# Out:
#                      Code  \
# 0       SL.TLF.0714.WK.TM
# 1       SL.TLF.0714.SW.TM
# 2    SL.TLF.0714.SW.FE.TM
# 3    SL.TLF.0714.SW.MA.TM
# 4    SL.TLF.0714.WK.FE.TM
# ..                    ...
# 156     SL.UEM.NEET.FE.ZS
# 157  SL.UEM.NEET.FE.ME.ZS
# 158     SL.UEM.NEET.MA.ZS
# 159        SL.UEM.NEET.ZS
# 160     SL.UEM.NEET.ME.ZS
#
#                                                                                                             Indicator Name  \
# 0                                              Average working hours of children, working only, ages 7-14 (hours per week)
# 1                                            Average working hours of children, study and work, ages 7-14 (hours per week)
# 2                                    Average working hours of children, study and work, female, ages 7-14 (hours per week)
# 3                                      Average working hours of children, study and work, male, ages 7-14 (hours per week)
# 4                                      Average working hours of children, working only, female, ages 7-14 (hours per week)
# ..                                                                                                                     ...
# 156                         Share of youth not in education, employment or training, female (% of female youth population)
# 157  Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate)
# 158                             Share of youth not in education, employment or training, male (% of male youth population)
# 159                                 Share of youth not in education, employment or training, total (% of youth population)
# 160          Share of youth not in education, employment or training, total (% of youth population) (modeled ILO estimate)
#
#                                     General Topic                      Topic  \
# 0    Social Protection & Labor: Economic activity  Social Protection & Labor
# 1    Social Protection & Labor: Economic activity  Social Protection & Labor
# 2    Social Protection & Labor: Economic activity  Social Protection & Labor
# 3    Social Protection & Labor: Economic activity  Social Protection & Labor
# 4    Social Protection & Labor: Economic activity  Social Protection & Labor
# ..                                            ...                        ...
# 156       Social Protection & Labor: Unemployment  Social Protection & Labor
# 157       Social Protection & Labor: Unemployment  Social Protection & Labor
# 158       Social Protection & Labor: Unemployment  Social Protection & Labor
# 159       Social Protection & Labor: Unemployment  Social Protection & Labor
# 160       Social Protection & Labor: Unemployment  Social Protection & Labor
#
#              SubTopic1          SubTopic2                     SubTopic3
# 0    Economic activity  Total labor force                      Age 7-14
# 1    Economic activity  Total labor force                      Age 7-14
# 2    Economic activity  Total labor force                      Age 7-14
# 3    Economic activity  Total labor force                      Age 7-14
# 4    Economic activity  Total labor force                      Age 7-14
# ..                 ...                ...                           ...
# 156       Unemployment       Unemployment  Not in education or training
# 157       Unemployment       Unemployment  Not in education or training
# 158       Unemployment       Unemployment  Not in education or training
# 159       Unemployment       Unemployment  Not in education or training
# 160       Unemployment       Unemployment  Not in education or training
#
# [161 rows x 7 columns]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(social[social['SubTopic2'].isna()])
# Out:
#                          Code  \
# 107   per_si_allsi.ben_q1_tot
# 108   per_sa_allsa.ben_q1_tot
# 109   per_lm_alllm.ben_q1_tot
# 110      per_allsp.ben_q1_tot
# 111     per_allsp.adq_pop_tot
# 112  per_si_allsi.adq_pop_tot
# 113  per_lm_alllm.adq_pop_tot
# 114  per_sa_allsa.adq_pop_tot
# 115   per_sa_allsa.cov_q2_tot
# 116   per_lm_alllm.cov_q5_tot
# 117   per_lm_alllm.cov_q1_tot
# 118   per_lm_alllm.cov_q4_tot
# 119   per_sa_allsa.cov_q4_tot
# 120  per_si_allsi.cov_pop_tot
# 121   per_si_allsi.cov_q2_tot
# 122   per_si_allsi.cov_q3_tot
# 123   per_si_allsi.cov_q4_tot
# 124   per_si_allsi.cov_q1_tot
# 125   per_sa_allsa.cov_q1_tot
# 126   per_si_allsi.cov_q5_tot
# 127     per_allsp.cov_pop_tot
# 128   per_sa_allsa.cov_q3_tot
# 129  per_sa_allsa.cov_pop_tot
# 130   per_sa_allsa.cov_q5_tot
# 131   per_lm_alllm.cov_q3_tot
# 132   per_lm_alllm.cov_q2_tot
# 133  per_lm_alllm.cov_pop_tot
#
#                                                                                                 Indicator Name  \
# 107  Benefit incidence of social insurance programs to poorest quintile (% of total social insurance benefits)
# 108       Benefit incidence of social safety net programs to poorest quintile (% of total safety net benefits)
# 109       Benefit incidence of unemployment benefits and ALMP to poorest quintile (% of total U/ALMP benefits)
# 110    Benefit incidence of social protection and labor programs to poorest quintile (% of total SPL benefits)
# 111            Adequacy of social protection and labor programs (% of total welfare of beneficiary households)
# 112                       Adequacy of social insurance programs (% of total welfare of beneficiary households)
# 113                  Adequacy of unemployment benefits and ALMP (% of total welfare of beneficiary households)
# 114                      Adequacy of social safety net programs (% of total welfare of beneficiary households)
# 115                                   Coverage of social safety net programs in 2nd quintile (% of population)
# 116                           Coverage of unemployment benefits and ALMP in richest quintile (% of population)
# 117                           Coverage of unemployment benefits and ALMP in poorest quintile (% of population)
# 118                               Coverage of unemployment benefits and ALMP in 4th quintile (% of population)
# 119                                   Coverage of social safety net programs in 4th quintile (% of population)
# 120                                                    Coverage of social insurance programs (% of population)
# 121                                    Coverage of social insurance programs in 2nd quintile (% of population)
# 122                                    Coverage of social insurance programs in 3rd quintile (% of population)
# 123                                    Coverage of social insurance programs in 4th quintile (% of population)
# 124                                Coverage of social insurance programs in poorest quintile (% of population)
# 125                               Coverage of social safety net programs in poorest quintile (% of population)
# 126                                Coverage of social insurance programs in richest quintile (% of population)
# 127                                         Coverage of social protection and labor programs (% of population)
# 128                                   Coverage of social safety net programs in 3rd quintile (% of population)
# 129                                                   Coverage of social safety net programs (% of population)
# 130                               Coverage of social safety net programs in richest quintile (% of population)
# 131                               Coverage of unemployment benefits and ALMP in 3rd quintile (% of population)
# 132                               Coverage of unemployment benefits and ALMP in 2nd quintile (% of population)
# 133                                               Coverage of unemployment benefits and ALMP (% of population)
#
#                               General Topic                      Topic  \
# 107  Social Protection & Labor: Performance  Social Protection & Labor
# 108  Social Protection & Labor: Performance  Social Protection & Labor
# 109  Social Protection & Labor: Performance  Social Protection & Labor
# 110  Social Protection & Labor: Performance  Social Protection & Labor
# 111  Social Protection & Labor: Performance  Social Protection & Labor
# 112  Social Protection & Labor: Performance  Social Protection & Labor
# 113  Social Protection & Labor: Performance  Social Protection & Labor
# 114  Social Protection & Labor: Performance  Social Protection & Labor
# 115  Social Protection & Labor: Performance  Social Protection & Labor
# 116  Social Protection & Labor: Performance  Social Protection & Labor
# 117  Social Protection & Labor: Performance  Social Protection & Labor
# 118  Social Protection & Labor: Performance  Social Protection & Labor
# 119  Social Protection & Labor: Performance  Social Protection & Labor
# 120  Social Protection & Labor: Performance  Social Protection & Labor
# 121  Social Protection & Labor: Performance  Social Protection & Labor
# 122  Social Protection & Labor: Performance  Social Protection & Labor
# 123  Social Protection & Labor: Performance  Social Protection & Labor
# 124  Social Protection & Labor: Performance  Social Protection & Labor
# 125  Social Protection & Labor: Performance  Social Protection & Labor
# 126  Social Protection & Labor: Performance  Social Protection & Labor
# 127  Social Protection & Labor: Performance  Social Protection & Labor
# 128  Social Protection & Labor: Performance  Social Protection & Labor
# 129  Social Protection & Labor: Performance  Social Protection & Labor
# 130  Social Protection & Labor: Performance  Social Protection & Labor
# 131  Social Protection & Labor: Performance  Social Protection & Labor
# 132  Social Protection & Labor: Performance  Social Protection & Labor
# 133  Social Protection & Labor: Performance  Social Protection & Labor
#
#        SubTopic1 SubTopic2 SubTopic3
# 107  Performance      None      None
# 108  Performance      None      None
# 109  Performance      None      None
# 110  Performance      None      None
# 111  Performance      None      None
# 112  Performance      None      None
# 113  Performance      None      None
# 114  Performance      None      None
# 115  Performance      None      None
# 116  Performance      None      None
# 117  Performance      None      None
# 118  Performance      None      None
# 119  Performance      None      None
# 120  Performance      None      None
# 121  Performance      None      None
# 122  Performance      None      None
# 123  Performance      None      None
# 124  Performance      None      None
# 125  Performance      None      None
# 126  Performance      None      None
# 127  Performance      None      None
# 128  Performance      None      None
# 129  Performance      None      None
# 130  Performance      None      None
# 131  Performance      None      None
# 132  Performance      None      None
# 133  Performance      None      None

# %% [markdown]
# # These are unexpected type of codes that are found  in the wdi metadata so for better work we will convert them to more suitable structure and we will store them into list

# %%
# SP = Social Protection and Labor Programs

def transform_code(code):
    if code.startswith("per_"):  
        parts = code.replace('.', '_').split('_') 
        if parts[1] == "allsp":  # Special case for "SP"
            return "SP" + '.' + parts[2].upper() + '.' + parts[3].upper() + '.' + parts[4].upper()
        else:
            return parts[1].upper() + '.' + parts[3].upper() + '.' + parts[4].upper() + '.' + parts[5].upper()
    return code

# %% [markdown]
# ## For Storing the new codes

# %%
changes = social[social['SubTopic2'].isna()]["Code"]
changes = changes.to_frame(name="Old Code")
changes.reset_index(drop=True, inplace=True)

# %%
changes["Code"] = changes["Old Code"].apply(transform_code)
changes.to_excel("../data/hierarchy/changed_codes_social.xlsx", index=False)

# %%
social["Code"] = social["Code"].apply(transform_code)

# %%
with pd.option_context('display.max_colwidth', 200):

    display(social[social['SubTopic2'].isna()])
# Out:
#                Code  \
# 107   SI.BEN.Q1.TOT
# 108   SA.BEN.Q1.TOT
# 109   LM.BEN.Q1.TOT
# 110   SP.BEN.Q1.TOT
# 111  SP.ADQ.POP.TOT
# 112  SI.ADQ.POP.TOT
# 113  LM.ADQ.POP.TOT
# 114  SA.ADQ.POP.TOT
# 115   SA.COV.Q2.TOT
# 116   LM.COV.Q5.TOT
# 117   LM.COV.Q1.TOT
# 118   LM.COV.Q4.TOT
# 119   SA.COV.Q4.TOT
# 120  SI.COV.POP.TOT
# 121   SI.COV.Q2.TOT
# 122   SI.COV.Q3.TOT
# 123   SI.COV.Q4.TOT
# 124   SI.COV.Q1.TOT
# 125   SA.COV.Q1.TOT
# 126   SI.COV.Q5.TOT
# 127  SP.COV.POP.TOT
# 128   SA.COV.Q3.TOT
# 129  SA.COV.POP.TOT
# 130   SA.COV.Q5.TOT
# 131   LM.COV.Q3.TOT
# 132   LM.COV.Q2.TOT
# 133  LM.COV.POP.TOT
#
#                                                                                                 Indicator Name  \
# 107  Benefit incidence of social insurance programs to poorest quintile (% of total social insurance benefits)
# 108       Benefit incidence of social safety net programs to poorest quintile (% of total safety net benefits)
# 109       Benefit incidence of unemployment benefits and ALMP to poorest quintile (% of total U/ALMP benefits)
# 110    Benefit incidence of social protection and labor programs to poorest quintile (% of total SPL benefits)
# 111            Adequacy of social protection and labor programs (% of total welfare of beneficiary households)
# 112                       Adequacy of social insurance programs (% of total welfare of beneficiary households)
# 113                  Adequacy of unemployment benefits and ALMP (% of total welfare of beneficiary households)
# 114                      Adequacy of social safety net programs (% of total welfare of beneficiary households)
# 115                                   Coverage of social safety net programs in 2nd quintile (% of population)
# 116                           Coverage of unemployment benefits and ALMP in richest quintile (% of population)
# 117                           Coverage of unemployment benefits and ALMP in poorest quintile (% of population)
# 118                               Coverage of unemployment benefits and ALMP in 4th quintile (% of population)
# 119                                   Coverage of social safety net programs in 4th quintile (% of population)
# 120                                                    Coverage of social insurance programs (% of population)
# 121                                    Coverage of social insurance programs in 2nd quintile (% of population)
# 122                                    Coverage of social insurance programs in 3rd quintile (% of population)
# 123                                    Coverage of social insurance programs in 4th quintile (% of population)
# 124                                Coverage of social insurance programs in poorest quintile (% of population)
# 125                               Coverage of social safety net programs in poorest quintile (% of population)
# 126                                Coverage of social insurance programs in richest quintile (% of population)
# 127                                         Coverage of social protection and labor programs (% of population)
# 128                                   Coverage of social safety net programs in 3rd quintile (% of population)
# 129                                                   Coverage of social safety net programs (% of population)
# 130                               Coverage of social safety net programs in richest quintile (% of population)
# 131                               Coverage of unemployment benefits and ALMP in 3rd quintile (% of population)
# 132                               Coverage of unemployment benefits and ALMP in 2nd quintile (% of population)
# 133                                               Coverage of unemployment benefits and ALMP (% of population)
#
#                               General Topic                      Topic  \
# 107  Social Protection & Labor: Performance  Social Protection & Labor
# 108  Social Protection & Labor: Performance  Social Protection & Labor
# 109  Social Protection & Labor: Performance  Social Protection & Labor
# 110  Social Protection & Labor: Performance  Social Protection & Labor
# 111  Social Protection & Labor: Performance  Social Protection & Labor
# 112  Social Protection & Labor: Performance  Social Protection & Labor
# 113  Social Protection & Labor: Performance  Social Protection & Labor
# 114  Social Protection & Labor: Performance  Social Protection & Labor
# 115  Social Protection & Labor: Performance  Social Protection & Labor
# 116  Social Protection & Labor: Performance  Social Protection & Labor
# 117  Social Protection & Labor: Performance  Social Protection & Labor
# 118  Social Protection & Labor: Performance  Social Protection & Labor
# 119  Social Protection & Labor: Performance  Social Protection & Labor
# 120  Social Protection & Labor: Performance  Social Protection & Labor
# 121  Social Protection & Labor: Performance  Social Protection & Labor
# 122  Social Protection & Labor: Performance  Social Protection & Labor
# 123  Social Protection & Labor: Performance  Social Protection & Labor
# 124  Social Protection & Labor: Performance  Social Protection & Labor
# 125  Social Protection & Labor: Performance  Social Protection & Labor
# 126  Social Protection & Labor: Performance  Social Protection & Labor
# 127  Social Protection & Labor: Performance  Social Protection & Labor
# 128  Social Protection & Labor: Performance  Social Protection & Labor
# 129  Social Protection & Labor: Performance  Social Protection & Labor
# 130  Social Protection & Labor: Performance  Social Protection & Labor
# 131  Social Protection & Labor: Performance  Social Protection & Labor
# 132  Social Protection & Labor: Performance  Social Protection & Labor
# 133  Social Protection & Labor: Performance  Social Protection & Labor
#
#        SubTopic1 SubTopic2 SubTopic3
# 107  Performance      None      None
# 108  Performance      None      None
# 109  Performance      None      None
# 110  Performance      None      None
# 111  Performance      None      None
# 112  Performance      None      None
# 113  Performance      None      None
# 114  Performance      None      None
# 115  Performance      None      None
# 116  Performance      None      None
# 117  Performance      None      None
# 118  Performance      None      None
# 119  Performance      None      None
# 120  Performance      None      None
# 121  Performance      None      None
# 122  Performance      None      None
# 123  Performance      None      None
# 124  Performance      None      None
# 125  Performance      None      None
# 126  Performance      None      None
# 127  Performance      None      None
# 128  Performance      None      None
# 129  Performance      None      None
# 130  Performance      None      None
# 131  Performance      None      None
# 132  Performance      None      None
# 133  Performance      None      None

# %%
social.loc[social['Code'].str.startswith('SI'), "SubTopic2"] = "Social insurance programs"
social.loc[social['Code'].str.startswith('SA'), "SubTopic2"] = "Social safety net programs"
social.loc[social['Code'].str.startswith('LM'), "SubTopic2"] = "Unemployment benefits and ALMP"
social.loc[social['Code'].str.startswith('SP'), "SubTopic2"] = "Social protection and labor programs"


social.loc[social['Code'].str.contains('COV'), "SubTopic3"] = "Coverage"
social.loc[social["Code"].str.contains("ADQ"), "SubTopic3"] = "Adequacy"
social.loc[social["Code"].str.contains("BEN") , "SubTopic3"] = "Benefit incidence"

# %%
social.loc[social['Code'].str.startswith('SI') |social['Code'].str.startswith('SA')|social['Code'].str.startswith('LM')|social['Code'].str.startswith('SP')]
# Out:
#                Code                                     Indicator Name  \
# 107   SI.BEN.Q1.TOT  Benefit incidence of social insurance programs...
# 108   SA.BEN.Q1.TOT  Benefit incidence of social safety net program...
# 109   LM.BEN.Q1.TOT  Benefit incidence of unemployment benefits and...
# 110   SP.BEN.Q1.TOT  Benefit incidence of social protection and lab...
# 111  SP.ADQ.POP.TOT  Adequacy of social protection and labor progra...
# 112  SI.ADQ.POP.TOT  Adequacy of social insurance programs (% of to...
# 113  LM.ADQ.POP.TOT  Adequacy of unemployment benefits and ALMP (% ...
# 114  SA.ADQ.POP.TOT  Adequacy of social safety net programs (% of t...
# 115   SA.COV.Q2.TOT  Coverage of social safety net programs in 2nd ...
# 116   LM.COV.Q5.TOT  Coverage of unemployment benefits and ALMP in ...
# 117   LM.COV.Q1.TOT  Coverage of unemployment benefits and ALMP in ...
# 118   LM.COV.Q4.TOT  Coverage of unemployment benefits and ALMP in ...
# 119   SA.COV.Q4.TOT  Coverage of social safety net programs in 4th ...
# 120  SI.COV.POP.TOT  Coverage of social insurance programs (% of po...
# 121   SI.COV.Q2.TOT  Coverage of social insurance programs in 2nd q...
# 122   SI.COV.Q3.TOT  Coverage of social insurance programs in 3rd q...
# 123   SI.COV.Q4.TOT  Coverage of social insurance programs in 4th q...
# 124   SI.COV.Q1.TOT  Coverage of social insurance programs in poore...
# 125   SA.COV.Q1.TOT  Coverage of social safety net programs in poor...
# 126   SI.COV.Q5.TOT  Coverage of social insurance programs in riche...
# 127  SP.COV.POP.TOT  Coverage of social protection and labor progra...
# 128   SA.COV.Q3.TOT  Coverage of social safety net programs in 3rd ...
# 129  SA.COV.POP.TOT  Coverage of social safety net programs (% of p...
# 130   SA.COV.Q5.TOT  Coverage of social safety net programs in rich...
# 131   LM.COV.Q3.TOT  Coverage of unemployment benefits and ALMP in ...
# 132   LM.COV.Q2.TOT  Coverage of unemployment benefits and ALMP in ...
# 133  LM.COV.POP.TOT  Coverage of unemployment benefits and ALMP (% ...
#
#                               General Topic                      Topic  \
# 107  Social Protection & Labor: Performance  Social Protection & Labor
# 108  Social Protection & Labor: Performance  Social Protection & Labor
# 109  Social Protection & Labor: Performance  Social Protection & Labor
# 110  Social Protection & Labor: Performance  Social Protection & Labor
# 111  Social Protection & Labor: Performance  Social Protection & Labor
# 112  Social Protection & Labor: Performance  Social Protection & Labor
# 113  Social Protection & Labor: Performance  Social Protection & Labor
# 114  Social Protection & Labor: Performance  Social Protection & Labor
# 115  Social Protection & Labor: Performance  Social Protection & Labor
# 116  Social Protection & Labor: Performance  Social Protection & Labor
# 117  Social Protection & Labor: Performance  Social Protection & Labor
# 118  Social Protection & Labor: Performance  Social Protection & Labor
# 119  Social Protection & Labor: Performance  Social Protection & Labor
# 120  Social Protection & Labor: Performance  Social Protection & Labor
# 121  Social Protection & Labor: Performance  Social Protection & Labor
# 122  Social Protection & Labor: Performance  Social Protection & Labor
# 123  Social Protection & Labor: Performance  Social Protection & Labor
# 124  Social Protection & Labor: Performance  Social Protection & Labor
# 125  Social Protection & Labor: Performance  Social Protection & Labor
# 126  Social Protection & Labor: Performance  Social Protection & Labor
# 127  Social Protection & Labor: Performance  Social Protection & Labor
# 128  Social Protection & Labor: Performance  Social Protection & Labor
# 129  Social Protection & Labor: Performance  Social Protection & Labor
# 130  Social Protection & Labor: Performance  Social Protection & Labor
# 131  Social Protection & Labor: Performance  Social Protection & Labor
# 132  Social Protection & Labor: Performance  Social Protection & Labor
# 133  Social Protection & Labor: Performance  Social Protection & Labor
#
#        SubTopic1                             SubTopic2          SubTopic3
# 107  Performance             Social insurance programs  Benefit incidence
# 108  Performance            Social safety net programs  Benefit incidence
# 109  Performance        Unemployment benefits and ALMP  Benefit incidence
# 110  Performance  Social protection and labor programs  Benefit incidence
# 111  Performance  Social protection and labor programs           Adequacy
# 112  Performance             Social insurance programs           Adequacy
# 113  Performance        Unemployment benefits and ALMP           Adequacy
# 114  Performance            Social safety net programs           Adequacy
# 115  Performance            Social safety net programs           Coverage
# 116  Performance        Unemployment benefits and ALMP           Coverage
# 117  Performance        Unemployment benefits and ALMP           Coverage
# 118  Performance        Unemployment benefits and ALMP           Coverage
# 119  Performance            Social safety net programs           Coverage
# 120  Performance             Social insurance programs           Coverage
# 121  Performance             Social insurance programs           Coverage
# 122  Performance             Social insurance programs           Coverage
# 123  Performance             Social insurance programs           Coverage
# 124  Performance             Social insurance programs           Coverage
# 125  Performance            Social safety net programs           Coverage
# 126  Performance             Social insurance programs           Coverage
# 127  Performance  Social protection and labor programs           Coverage
# 128  Performance            Social safety net programs           Coverage
# 129  Performance            Social safety net programs           Coverage
# 130  Performance            Social safety net programs           Coverage
# 131  Performance        Unemployment benefits and ALMP           Coverage
# 132  Performance        Unemployment benefits and ALMP           Coverage
# 133  Performance        Unemployment benefits and ALMP           Coverage

# %%
with pd.option_context('display.max_colwidth', 200):

    display(social[social['SubTopic3'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
has_list = social.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


social_with_lists = social[has_list]
with pd.option_context('display.max_colwidth', 200):
    display(social_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(social[social['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
#                  Code  \
# 22     SL.IND.EMPL.ZS
# 23  SL.IND.EMPL.FE.ZS
# 24  SL.IND.EMPL.MA.ZS
#
#                                                                     Indicator Name  \
# 22           Employment in industry (% of total employment) (modeled ILO estimate)
# 23  Employment in industry, female (% of female employment) (modeled ILO estimate)
# 24      Employment in industry, male (% of male employment) (modeled ILO estimate)
#
#                                    General Topic                      Topic  \
# 22  Social Protection & Labor: Economic activity  Social Protection & Labor
# 23  Social Protection & Labor: Economic activity  Social Protection & Labor
# 24  Social Protection & Labor: Economic activity  Social Protection & Labor
#
#             SubTopic1                              SubTopic2  \
# 22  Economic activity  Industry (or interest due) (or index)
# 23  Economic activity  Industry (or interest due) (or index)
# 24  Economic activity  Industry (or interest due) (or index)
#
#                                      SubTopic3
# 22  Economically active population (employees)
# 23  Economically active population (employees)
# 24  Economically active population (employees)

# %%
social.loc[social['Code'].str.startswith('SL.IND') , "SubTopic2"] = "Industry"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(social[social['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# # Trade

# %%
trade  = dfs["trade"]

# %%
with pd.option_context('display.max_colwidth', 200):

    display(trade)
# Out:
#                     Code  \
# 0      TM.TAX.TCOM.BR.ZS
# 1      TM.TAX.MANF.IP.ZS
# 2      TM.TAX.MRCH.BR.ZS
# 3   TM.TAX.TCOM.WM.FN.ZS
# 4      TM.TAX.TCOM.BC.ZS
# 5      TM.TAX.MANF.BC.ZS
# 6      TM.TAX.MRCH.BC.ZS
# 7   TM.TAX.MANF.WM.FN.ZS
# 8   TM.TAX.MRCH.WM.FN.ZS
# 9   TM.TAX.TCOM.SM.FN.ZS
# 10     TM.TAX.MRCH.IP.ZS
# 11  TM.TAX.MANF.SM.FN.ZS
# 12  TM.TAX.TCOM.WM.AR.ZS
# 13  TM.TAX.MANF.WM.AR.ZS
# 14  TM.TAX.MRCH.WM.AR.ZS
# 15  TM.TAX.TCOM.SM.AR.ZS
# 16  TM.TAX.MANF.SM.AR.ZS
# 17  TM.TAX.MRCH.SM.AR.ZS
# 18     TM.TAX.MANF.BR.ZS
# 19     TM.TAX.TCOM.SR.ZS
# 20     TM.TAX.MANF.SR.ZS
# 21     TM.TAX.MRCH.SR.ZS
# 22     TM.TAX.TCOM.IP.ZS
# 23  TM.TAX.MRCH.SM.FN.ZS
# 24     TT.PRI.MRCH.XD.WD
# 25     TX.QTY.MRCH.XD.WD
# 26     TM.VAL.MRCH.XD.WD
# 27     TM.QTY.MRCH.XD.WD
# 28     TX.VAL.MRCH.XD.WD
#
#                                                                 Indicator Name  \
# 0                                Bound rate, simple mean, primary products (%)
# 1    Share of tariff lines with international peaks, manufactured products (%)
# 2                                    Bound rate, simple mean, all products (%)
# 3        Tariff rate, most favored nation, weighted mean, primary products (%)
# 4                                       Binding coverage, primary products (%)
# 5                                  Binding coverage, manufactured products (%)
# 6                                           Binding coverage, all products (%)
# 7   Tariff rate, most favored nation, weighted mean, manufactured products (%)
# 8            Tariff rate, most favored nation, weighted mean, all products (%)
# 9          Tariff rate, most favored nation, simple mean, primary products (%)
# 10            Share of tariff lines with international peaks, all products (%)
# 11    Tariff rate, most favored nation, simple mean, manufactured products (%)
# 12                   Tariff rate, applied, weighted mean, primary products (%)
# 13              Tariff rate, applied, weighted mean, manufactured products (%)
# 14                       Tariff rate, applied, weighted mean, all products (%)
# 15                     Tariff rate, applied, simple mean, primary products (%)
# 16                Tariff rate, applied, simple mean, manufactured products (%)
# 17                         Tariff rate, applied, simple mean, all products (%)
# 18                          Bound rate, simple mean, manufactured products (%)
# 19             Share of tariff lines with specific rates, primary products (%)
# 20        Share of tariff lines with specific rates, manufactured products (%)
# 21                 Share of tariff lines with specific rates, all products (%)
# 22        Share of tariff lines with international peaks, primary products (%)
# 23             Tariff rate, most favored nation, simple mean, all products (%)
# 24                                Net barter terms of trade index (2015 = 100)
# 25                                            Export volume index (2015 = 100)
# 26                                             Import value index (2015 = 100)
# 27                                            Import volume index (2015 = 100)
# 28                                             Export value index (2015 = 100)
#
#    General Topic  Topic      SubTopic1  \
# 0          Trade  Trade        Tariffs
# 1          Trade  Trade        Tariffs
# 2          Trade  Trade        Tariffs
# 3          Trade  Trade        Tariffs
# 4          Trade  Trade        Tariffs
# 5          Trade  Trade        Tariffs
# 6          Trade  Trade        Tariffs
# 7          Trade  Trade        Tariffs
# 8          Trade  Trade        Tariffs
# 9          Trade  Trade        Tariffs
# 10         Trade  Trade        Tariffs
# 11         Trade  Trade        Tariffs
# 12         Trade  Trade        Tariffs
# 13         Trade  Trade        Tariffs
# 14         Trade  Trade        Tariffs
# 15         Trade  Trade        Tariffs
# 16         Trade  Trade        Tariffs
# 17         Trade  Trade        Tariffs
# 18         Trade  Trade        Tariffs
# 19         Trade  Trade        Tariffs
# 20         Trade  Trade        Tariffs
# 21         Trade  Trade        Tariffs
# 22         Trade  Trade        Tariffs
# 23         Trade  Trade        Tariffs
# 24         Trade  Trade  Trade indexes
# 25         Trade  Trade  Trade indexes
# 26         Trade  Trade  Trade indexes
# 27         Trade  Trade  Trade indexes
# 28         Trade  Trade  Trade indexes
#
#                                    SubTopic2                       SubTopic3
# 0   Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 1   Tax revenue (or tariff) (or tax related)                   Manufacturing
# 2   Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 3   Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 4   Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 5   Tax revenue (or tariff) (or tax related)                   Manufacturing
# 6   Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 7   Tax revenue (or tariff) (or tax related)                   Manufacturing
# 8   Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 9   Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 10  Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 11  Tax revenue (or tariff) (or tax related)                   Manufacturing
# 12  Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 13  Tax revenue (or tariff) (or tax related)                   Manufacturing
# 14  Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 15  Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 16  Tax revenue (or tariff) (or tax related)                   Manufacturing
# 17  Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 18  Tax revenue (or tariff) (or tax related)                   Manufacturing
# 19  Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 20  Tax revenue (or tariff) (or tax related)                   Manufacturing
# 21  Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 22  Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 23  Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 24                                     Price             Goods (merchandise)
# 25                         Quantity (volume)             Goods (merchandise)
# 26                                     Value             Goods (merchandise)
# 27                         Quantity (volume)             Goods (merchandise)
# 28                                     Value             Goods (merchandise)

# %%
with pd.option_context('display.max_colwidth', 200):

    display(trade[trade['SubTopic2'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
with pd.option_context('display.max_colwidth', 200):

    display(trade[trade['SubTopic3'].isna()])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %%
has_list = trade.apply(lambda row: isinstance(row['SubTopic2'], list) or isinstance(row['SubTopic3'], list), axis=1)


trade_with_lists = trade[has_list]
with pd.option_context('display.max_colwidth', 200):
    display(trade_with_lists)
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# ## handling the (text (or text))

# %%
with pd.option_context('display.max_colwidth', 200):
    display(trade[trade['SubTopic2'].str.contains(r'\(or', na=False) ])
# Out:
#                     Code  \
# 0      TM.TAX.TCOM.BR.ZS
# 1      TM.TAX.MANF.IP.ZS
# 2      TM.TAX.MRCH.BR.ZS
# 3   TM.TAX.TCOM.WM.FN.ZS
# 4      TM.TAX.TCOM.BC.ZS
# 5      TM.TAX.MANF.BC.ZS
# 6      TM.TAX.MRCH.BC.ZS
# 7   TM.TAX.MANF.WM.FN.ZS
# 8   TM.TAX.MRCH.WM.FN.ZS
# 9   TM.TAX.TCOM.SM.FN.ZS
# 10     TM.TAX.MRCH.IP.ZS
# 11  TM.TAX.MANF.SM.FN.ZS
# 12  TM.TAX.TCOM.WM.AR.ZS
# 13  TM.TAX.MANF.WM.AR.ZS
# 14  TM.TAX.MRCH.WM.AR.ZS
# 15  TM.TAX.TCOM.SM.AR.ZS
# 16  TM.TAX.MANF.SM.AR.ZS
# 17  TM.TAX.MRCH.SM.AR.ZS
# 18     TM.TAX.MANF.BR.ZS
# 19     TM.TAX.TCOM.SR.ZS
# 20     TM.TAX.MANF.SR.ZS
# 21     TM.TAX.MRCH.SR.ZS
# 22     TM.TAX.TCOM.IP.ZS
# 23  TM.TAX.MRCH.SM.FN.ZS
#
#                                                                 Indicator Name  \
# 0                                Bound rate, simple mean, primary products (%)
# 1    Share of tariff lines with international peaks, manufactured products (%)
# 2                                    Bound rate, simple mean, all products (%)
# 3        Tariff rate, most favored nation, weighted mean, primary products (%)
# 4                                       Binding coverage, primary products (%)
# 5                                  Binding coverage, manufactured products (%)
# 6                                           Binding coverage, all products (%)
# 7   Tariff rate, most favored nation, weighted mean, manufactured products (%)
# 8            Tariff rate, most favored nation, weighted mean, all products (%)
# 9          Tariff rate, most favored nation, simple mean, primary products (%)
# 10            Share of tariff lines with international peaks, all products (%)
# 11    Tariff rate, most favored nation, simple mean, manufactured products (%)
# 12                   Tariff rate, applied, weighted mean, primary products (%)
# 13              Tariff rate, applied, weighted mean, manufactured products (%)
# 14                       Tariff rate, applied, weighted mean, all products (%)
# 15                     Tariff rate, applied, simple mean, primary products (%)
# 16                Tariff rate, applied, simple mean, manufactured products (%)
# 17                         Tariff rate, applied, simple mean, all products (%)
# 18                          Bound rate, simple mean, manufactured products (%)
# 19             Share of tariff lines with specific rates, primary products (%)
# 20        Share of tariff lines with specific rates, manufactured products (%)
# 21                 Share of tariff lines with specific rates, all products (%)
# 22        Share of tariff lines with international peaks, primary products (%)
# 23             Tariff rate, most favored nation, simple mean, all products (%)
#
#    General Topic  Topic SubTopic1                                 SubTopic2  \
# 0          Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 1          Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 2          Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 3          Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 4          Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 5          Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 6          Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 7          Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 8          Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 9          Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 10         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 11         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 12         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 13         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 14         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 15         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 16         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 17         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 18         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 19         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 20         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 21         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 22         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
# 23         Trade  Trade   Tariffs  Tax revenue (or tariff) (or tax related)
#
#                          SubTopic3
# 0   Primary products (commodities)
# 1                    Manufacturing
# 2              Goods (merchandise)
# 3   Primary products (commodities)
# 4   Primary products (commodities)
# 5                    Manufacturing
# 6              Goods (merchandise)
# 7                    Manufacturing
# 8              Goods (merchandise)
# 9   Primary products (commodities)
# 10             Goods (merchandise)
# 11                   Manufacturing
# 12  Primary products (commodities)
# 13                   Manufacturing
# 14             Goods (merchandise)
# 15  Primary products (commodities)
# 16                   Manufacturing
# 17             Goods (merchandise)
# 18                   Manufacturing
# 19  Primary products (commodities)
# 20                   Manufacturing
# 21             Goods (merchandise)
# 22  Primary products (commodities)
# 23             Goods (merchandise)

# %% [markdown]
# # As we can see here both subtopic1 and 2 will have tarrif as value after further anlysing the best way is to change the values of subtopic1 as the wdi indicates  TM => imports and TX => Exports

# %%
trade
# Out:
#                     Code                                     Indicator Name  \
# 0      TM.TAX.TCOM.BR.ZS      Bound rate, simple mean, primary products (%)
# 1      TM.TAX.MANF.IP.ZS  Share of tariff lines with international peaks...
# 2      TM.TAX.MRCH.BR.ZS          Bound rate, simple mean, all products (%)
# 3   TM.TAX.TCOM.WM.FN.ZS  Tariff rate, most favored nation, weighted mea...
# 4      TM.TAX.TCOM.BC.ZS             Binding coverage, primary products (%)
# 5      TM.TAX.MANF.BC.ZS        Binding coverage, manufactured products (%)
# 6      TM.TAX.MRCH.BC.ZS                 Binding coverage, all products (%)
# 7   TM.TAX.MANF.WM.FN.ZS  Tariff rate, most favored nation, weighted mea...
# 8   TM.TAX.MRCH.WM.FN.ZS  Tariff rate, most favored nation, weighted mea...
# 9   TM.TAX.TCOM.SM.FN.ZS  Tariff rate, most favored nation, simple mean,...
# 10     TM.TAX.MRCH.IP.ZS  Share of tariff lines with international peaks...
# 11  TM.TAX.MANF.SM.FN.ZS  Tariff rate, most favored nation, simple mean,...
# 12  TM.TAX.TCOM.WM.AR.ZS  Tariff rate, applied, weighted mean, primary p...
# 13  TM.TAX.MANF.WM.AR.ZS  Tariff rate, applied, weighted mean, manufactu...
# 14  TM.TAX.MRCH.WM.AR.ZS  Tariff rate, applied, weighted mean, all produ...
# 15  TM.TAX.TCOM.SM.AR.ZS  Tariff rate, applied, simple mean, primary pro...
# 16  TM.TAX.MANF.SM.AR.ZS  Tariff rate, applied, simple mean, manufacture...
# 17  TM.TAX.MRCH.SM.AR.ZS  Tariff rate, applied, simple mean, all product...
# 18     TM.TAX.MANF.BR.ZS  Bound rate, simple mean, manufactured products...
# 19     TM.TAX.TCOM.SR.ZS  Share of tariff lines with specific rates, pri...
# 20     TM.TAX.MANF.SR.ZS  Share of tariff lines with specific rates, man...
# 21     TM.TAX.MRCH.SR.ZS  Share of tariff lines with specific rates, all...
# 22     TM.TAX.TCOM.IP.ZS  Share of tariff lines with international peaks...
# 23  TM.TAX.MRCH.SM.FN.ZS  Tariff rate, most favored nation, simple mean,...
# 24     TT.PRI.MRCH.XD.WD       Net barter terms of trade index (2015 = 100)
# 25     TX.QTY.MRCH.XD.WD                   Export volume index (2015 = 100)
# 26     TM.VAL.MRCH.XD.WD                    Import value index (2015 = 100)
# 27     TM.QTY.MRCH.XD.WD                   Import volume index (2015 = 100)
# 28     TX.VAL.MRCH.XD.WD                    Export value index (2015 = 100)
#
#    General Topic  Topic      SubTopic1  \
# 0          Trade  Trade        Tariffs
# 1          Trade  Trade        Tariffs
# 2          Trade  Trade        Tariffs
# 3          Trade  Trade        Tariffs
# 4          Trade  Trade        Tariffs
# 5          Trade  Trade        Tariffs
# 6          Trade  Trade        Tariffs
# 7          Trade  Trade        Tariffs
# 8          Trade  Trade        Tariffs
# 9          Trade  Trade        Tariffs
# 10         Trade  Trade        Tariffs
# 11         Trade  Trade        Tariffs
# 12         Trade  Trade        Tariffs
# 13         Trade  Trade        Tariffs
# 14         Trade  Trade        Tariffs
# 15         Trade  Trade        Tariffs
# 16         Trade  Trade        Tariffs
# 17         Trade  Trade        Tariffs
# 18         Trade  Trade        Tariffs
# 19         Trade  Trade        Tariffs
# 20         Trade  Trade        Tariffs
# 21         Trade  Trade        Tariffs
# 22         Trade  Trade        Tariffs
# 23         Trade  Trade        Tariffs
# 24         Trade  Trade  Trade indexes
# 25         Trade  Trade  Trade indexes
# 26         Trade  Trade  Trade indexes
# 27         Trade  Trade  Trade indexes
# 28         Trade  Trade  Trade indexes
#
#                                    SubTopic2                       SubTopic3
# 0   Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 1   Tax revenue (or tariff) (or tax related)                   Manufacturing
# 2   Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 3   Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 4   Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 5   Tax revenue (or tariff) (or tax related)                   Manufacturing
# 6   Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 7   Tax revenue (or tariff) (or tax related)                   Manufacturing
# 8   Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 9   Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 10  Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 11  Tax revenue (or tariff) (or tax related)                   Manufacturing
# 12  Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 13  Tax revenue (or tariff) (or tax related)                   Manufacturing
# 14  Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 15  Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 16  Tax revenue (or tariff) (or tax related)                   Manufacturing
# 17  Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 18  Tax revenue (or tariff) (or tax related)                   Manufacturing
# 19  Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 20  Tax revenue (or tariff) (or tax related)                   Manufacturing
# 21  Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 22  Tax revenue (or tariff) (or tax related)  Primary products (commodities)
# 23  Tax revenue (or tariff) (or tax related)             Goods (merchandise)
# 24                                     Price             Goods (merchandise)
# 25                         Quantity (volume)             Goods (merchandise)
# 26                                     Value             Goods (merchandise)
# 27                         Quantity (volume)             Goods (merchandise)
# 28                                     Value             Goods (merchandise)

# %%
trade.loc[trade['Code'].str.startswith('TM') , "SubTopic1"] = "Imports"
trade.loc[trade['Code'].str.startswith('TX') , "SubTopic1"] = "Exports"
trade.loc[trade['Code'].str.startswith('TT') , "SubTopic1"] = "Terms of trade"


trade.loc[trade['Code'].str.startswith('TM.TAX') , "SubTopic2"] = "Tariff"

# %%
with pd.option_context('display.max_colwidth', 200):
    display(trade[trade['SubTopic3'].str.contains(r'\(or', na=False) ])
# Out:
# Empty DataFrame
# Columns: [Code, Indicator Name, General Topic, Topic, SubTopic1, SubTopic2, SubTopic3]
# Index: []

# %% [markdown]
# ## Save to Excel

# %%
with pd.ExcelWriter('../data/hierarchy/hierarchy_code_by_sheet.xlsx') as writer:
    for sheet_name, df in dfs.items():
        topic_value = df['Topic'].iloc[0] 
        df = df.sort_values(['SubTopic1', 'SubTopic2', 'SubTopic3'])
        df.to_excel(writer, sheet_name=str(topic_value), index=False)

# %% [markdown]
# ### Combine into one

# %%
combined_df = pd.concat(dfs.values(), ignore_index=True)
combined_df = combined_df.sort_values(['Topic','SubTopic1', 'SubTopic2', 'SubTopic3'])
combined_df.to_excel('../data/hierarchy/hierarchy_code.xlsx', index=False)

# %%
combined_df
# Out:
#                       Code                                     Indicator Name  \
# 0           BN.KAC.EOMS.CD        Net errors and omissions (BoP, current US$)
# 1        BM.KLT.DINV.CD.WD  Foreign direct investment, net outflows (BoP, ...
# 2     BM.KLT.DINV.WD.GD.ZS  Foreign direct investment, net outflows (% of ...
# 3     BX.KLT.DINV.WD.GD.ZS  Foreign direct investment, net inflows (% of GDP)
# 4           BN.KLT.DINV.CD  Foreign direct investment, net (BoP, current US$)
# ...                    ...                                                ...
# 1482  TM.TAX.TCOM.SM.AR.ZS  Tariff rate, applied, simple mean, primary pro...
# 1486     TM.TAX.TCOM.SR.ZS  Share of tariff lines with specific rates, pri...
# 1489     TM.TAX.TCOM.IP.ZS  Share of tariff lines with international peaks...
# 1493     TM.VAL.MRCH.XD.WD                    Import value index (2015 = 100)
# 1491     TT.PRI.MRCH.XD.WD       Net barter terms of trade index (2015 = 100)
#
#                                           General Topic  \
# 0     Economic Policy & Debt: Balance of payments: C...
# 1     Economic Policy & Debt: Balance of payments: C...
# 2     Economic Policy & Debt: Balance of payments: C...
# 3     Economic Policy & Debt: Balance of payments: C...
# 4     Economic Policy & Debt: Balance of payments: C...
# ...                                                 ...
# 1482                                              Trade
# 1486                                              Trade
# 1489                                              Trade
# 1493                                              Trade
# 1491                                              Trade
#
#                        Topic            SubTopic1  \
# 0     Economic Policy & Debt  Balance of payments
# 1     Economic Policy & Debt  Balance of payments
# 2     Economic Policy & Debt  Balance of payments
# 3     Economic Policy & Debt  Balance of payments
# 4     Economic Policy & Debt  Balance of payments
# ...                      ...                  ...
# 1482                   Trade              Imports
# 1486                   Trade              Imports
# 1489                   Trade              Imports
# 1493                   Trade              Imports
# 1491                   Trade       Terms of trade
#
#                                SubTopic2                       SubTopic3
# 0                        Capital account            Errors and omissions
# 1     Capital account: long term capital               Direct investment
# 2     Capital account: long term capital               Direct investment
# 3     Capital account: long term capital               Direct investment
# 4     Capital account: long term capital               Direct investment
# ...                                  ...                             ...
# 1482                              Tariff  Primary products (commodities)
# 1486                              Tariff  Primary products (commodities)
# 1489                              Tariff  Primary products (commodities)
# 1493                               Value             Goods (merchandise)
# 1491                               Price             Goods (merchandise)
#
# [1496 rows x 7 columns]

# %% [markdown]
# # Add the new values to the metada

# %%
metadata_code = pd.read_excel('../data/metadata/metadata_topic.xlsx', sheet_name=0)
metadata_code
# Out:
#                       Code                                     Indicator Name  \
# 0        BX.KLT.DINV.CD.WD  Foreign direct investment, net inflows (BoP, c...
# 1           BN.KLT.DINV.CD  Foreign direct investment, net (BoP, current US$)
# 2     BX.KLT.DINV.WD.GD.ZS  Foreign direct investment, net inflows (% of GDP)
# 3     BM.KLT.DINV.WD.GD.ZS  Foreign direct investment, net outflows (% of ...
# 4        BM.KLT.DINV.CD.WD  Foreign direct investment, net outflows (BoP, ...
# ...                    ...                                                ...
# 1491     TT.PRI.MRCH.XD.WD       Net barter terms of trade index (2015 = 100)
# 1492     TX.VAL.MRCH.XD.WD                    Export value index (2015 = 100)
# 1493     TX.QTY.MRCH.XD.WD                   Export volume index (2015 = 100)
# 1494     TM.VAL.MRCH.XD.WD                    Import value index (2015 = 100)
# 1495     TM.QTY.MRCH.XD.WD                   Import volume index (2015 = 100)
#
#                                           General Topic  \
# 0     Economic Policy & Debt: Balance of payments: C...
# 1     Economic Policy & Debt: Balance of payments: C...
# 2     Economic Policy & Debt: Balance of payments: C...
# 3     Economic Policy & Debt: Balance of payments: C...
# 4     Economic Policy & Debt: Balance of payments: C...
# ...                                                 ...
# 1491                                              Trade
# 1492                                              Trade
# 1493                                              Trade
# 1494                                              Trade
# 1495                                              Trade
#
#                        Topic            SubTopic1  \
# 0     Economic Policy & Debt  Balance of payments
# 1     Economic Policy & Debt  Balance of payments
# 2     Economic Policy & Debt  Balance of payments
# 3     Economic Policy & Debt  Balance of payments
# 4     Economic Policy & Debt  Balance of payments
# ...                      ...                  ...
# 1491                   Trade        Trade indexes
# 1492                   Trade        Trade indexes
# 1493                   Trade        Trade indexes
# 1494                   Trade        Trade indexes
# 1495                   Trade        Trade indexes
#
#                         SubTopic2 SubTopic3  \
# 0     Capital & financial account       NaN
# 1     Capital & financial account       NaN
# 2     Capital & financial account       NaN
# 3     Capital & financial account       NaN
# 4     Capital & financial account       NaN
# ...                           ...       ...
# 1491                          NaN       NaN
# 1492                          NaN       NaN
# 1493                          NaN       NaN
# 1494                          NaN       NaN
# 1495                          NaN       NaN
#
#                                        Short definition  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1491  Net barter terms of trade index is calculated ...
# 1492  Export values are the current value of exports...
# 1493  Export volume indexes are derived from UNCTAD'...
# 1494  Import value indexes are the current value of ...
# 1495  Import volume indexes are derived from UNCTAD'...
#
#                                         Long definition License Type  ...  \
# 0     Foreign direct investment refers to direct inv...    CC BY-4.0  ...
# 1     Foreign direct investment are the net inflows ...    CC BY-4.0  ...
# 2     Foreign direct investment are the net inflows ...    CC BY-4.0  ...
# 3     Foreign direct investment refers to direct inv...    CC BY-4.0  ...
# 4     Foreign direct investment refers to direct inv...    CC BY-4.0  ...
# ...                                                 ...          ...  ...
# 1491  Net barter terms of trade index is calculated ...    CC BY-4.0  ...
# 1492  Export values are the current value of exports...    CC BY-4.0  ...
# 1493  Export volume indexes are derived from UNCTAD'...    CC BY-4.0  ...
# 1494  Import value indexes are the current value of ...    CC BY-4.0  ...
# 1495  Import volume indexes are derived from UNCTAD'...    CC BY-4.0  ...
#
#                     Statistical concept and methodology  \
# 0     Data on equity flows are based on balance of p...
# 1                                                   NaN
# 2     Data on equity flows are based on balance of p...
# 3     Data on equity flows are based on balance of p...
# 4     Data on equity flows are based on balance of p...
# ...                                                 ...
# 1491                                                NaN
# 1492                                                NaN
# 1493                                                NaN
# 1494                                                NaN
# 1495                                                NaN
#
#                                   Development relevance  \
# 0     Private financial flows - equity and debt - ac...
# 1                                                   NaN
# 2     Private financial flows - equity and debt - ac...
# 3     Private financial flows - equity and debt - ac...
# 4     Private financial flows - equity and debt - ac...
# ...                                                 ...
# 1491                                                NaN
# 1492                                                NaN
# 1493                                                NaN
# 1494                                                NaN
# 1495                                                NaN
#
#                              Limitations and exceptions  \
# 0     FDI data do not give a complete picture of int...
# 1                                                   NaN
# 2     FDI data do not give a complete picture of int...
# 3     FDI data do not give a complete picture of int...
# 4     FDI data do not give a complete picture of int...
# ...                                                 ...
# 1491                                                NaN
# 1492                                                NaN
# 1493                                                NaN
# 1494                                                NaN
# 1495                                                NaN
#
#                                        General comments Other notes  \
# 0     Note: Data starting from 2005 are based on the...         NaN
# 1     Note: Data are based on the sixth edition of t...         NaN
# 2     Note: Data starting from 2005 are based on the...         NaN
# 3     Note: Data starting from 2005 are based on the...         NaN
# 4     Note: Data starting from 2005 are based on the...         NaN
# ...                                                 ...         ...
# 1491                                                NaN         NaN
# 1492                                                NaN         NaN
# 1493                                                NaN         NaN
# 1494                                                NaN         NaN
# 1495                                                NaN         NaN
#
#      Notes from original source Related source links Other web links  \
# 0                           NaN                  NaN             NaN
# 1                           NaN                  NaN             NaN
# 2                           NaN                  NaN             NaN
# 3                           NaN                  NaN             NaN
# 4                           NaN                  NaN             NaN
# ...                         ...                  ...             ...
# 1491                        NaN                  NaN             NaN
# 1492                        NaN                  NaN             NaN
# 1493                        NaN                  NaN             NaN
# 1494                        NaN                  NaN             NaN
# 1495                        NaN                  NaN             NaN
#
#      Related indicators                                        License URL
# 0                   NaN  https://datacatalog.worldbank.org/public-licen...
# 1                   NaN  https://datacatalog.worldbank.org/public-licen...
# 2                   NaN  https://datacatalog.worldbank.org/public-licen...
# 3                   NaN  https://datacatalog.worldbank.org/public-licen...
# 4                   NaN  https://datacatalog.worldbank.org/public-licen...
# ...                 ...                                                ...
# 1491                NaN  https://datacatalog.worldbank.org/public-licen...
# 1492                NaN  https://datacatalog.worldbank.org/public-licen...
# 1493                NaN  https://datacatalog.worldbank.org/public-licen...
# 1494                NaN  https://datacatalog.worldbank.org/public-licen...
# 1495                NaN  https://datacatalog.worldbank.org/public-licen...
#
# [1496 rows x 27 columns]

# %%
# We can use the function update to replace the valeus of the topics data as they have the same column names
metadata_code.update(combined_df)

metadata_code
# Out:
#                       Code                                     Indicator Name  \
# 0           BN.KAC.EOMS.CD        Net errors and omissions (BoP, current US$)
# 1        BM.KLT.DINV.CD.WD  Foreign direct investment, net outflows (BoP, ...
# 2     BM.KLT.DINV.WD.GD.ZS  Foreign direct investment, net outflows (% of ...
# 3     BX.KLT.DINV.WD.GD.ZS  Foreign direct investment, net inflows (% of GDP)
# 4           BN.KLT.DINV.CD  Foreign direct investment, net (BoP, current US$)
# ...                    ...                                                ...
# 1491     TT.PRI.MRCH.XD.WD       Net barter terms of trade index (2015 = 100)
# 1492     TX.QTY.MRCH.XD.WD                   Export volume index (2015 = 100)
# 1493     TM.VAL.MRCH.XD.WD                    Import value index (2015 = 100)
# 1494     TM.QTY.MRCH.XD.WD                   Import volume index (2015 = 100)
# 1495     TX.VAL.MRCH.XD.WD                    Export value index (2015 = 100)
#
#                                           General Topic  \
# 0     Economic Policy & Debt: Balance of payments: C...
# 1     Economic Policy & Debt: Balance of payments: C...
# 2     Economic Policy & Debt: Balance of payments: C...
# 3     Economic Policy & Debt: Balance of payments: C...
# 4     Economic Policy & Debt: Balance of payments: C...
# ...                                                 ...
# 1491                                              Trade
# 1492                                              Trade
# 1493                                              Trade
# 1494                                              Trade
# 1495                                              Trade
#
#                        Topic            SubTopic1  \
# 0     Economic Policy & Debt  Balance of payments
# 1     Economic Policy & Debt  Balance of payments
# 2     Economic Policy & Debt  Balance of payments
# 3     Economic Policy & Debt  Balance of payments
# 4     Economic Policy & Debt  Balance of payments
# ...                      ...                  ...
# 1491                   Trade       Terms of trade
# 1492                   Trade              Exports
# 1493                   Trade              Imports
# 1494                   Trade              Imports
# 1495                   Trade              Exports
#
#                                SubTopic2             SubTopic3  \
# 0                        Capital account  Errors and omissions
# 1     Capital account: long term capital     Direct investment
# 2     Capital account: long term capital     Direct investment
# 3     Capital account: long term capital     Direct investment
# 4     Capital account: long term capital     Direct investment
# ...                                  ...                   ...
# 1491                               Price   Goods (merchandise)
# 1492                   Quantity (volume)   Goods (merchandise)
# 1493                               Value   Goods (merchandise)
# 1494                   Quantity (volume)   Goods (merchandise)
# 1495                               Value   Goods (merchandise)
#
#                                        Short definition  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1491  Net barter terms of trade index is calculated ...
# 1492  Export values are the current value of exports...
# 1493  Export volume indexes are derived from UNCTAD'...
# 1494  Import value indexes are the current value of ...
# 1495  Import volume indexes are derived from UNCTAD'...
#
#                                         Long definition License Type  ...  \
# 0     Foreign direct investment refers to direct inv...    CC BY-4.0  ...
# 1     Foreign direct investment are the net inflows ...    CC BY-4.0  ...
# 2     Foreign direct investment are the net inflows ...    CC BY-4.0  ...
# 3     Foreign direct investment refers to direct inv...    CC BY-4.0  ...
# 4     Foreign direct investment refers to direct inv...    CC BY-4.0  ...
# ...                                                 ...          ...  ...
# 1491  Net barter terms of trade index is calculated ...    CC BY-4.0  ...
# 1492  Export values are the current value of exports...    CC BY-4.0  ...
# 1493  Export volume indexes are derived from UNCTAD'...    CC BY-4.0  ...
# 1494  Import value indexes are the current value of ...    CC BY-4.0  ...
# 1495  Import volume indexes are derived from UNCTAD'...    CC BY-4.0  ...
#
#                     Statistical concept and methodology  \
# 0     Data on equity flows are based on balance of p...
# 1                                                   NaN
# 2     Data on equity flows are based on balance of p...
# 3     Data on equity flows are based on balance of p...
# 4     Data on equity flows are based on balance of p...
# ...                                                 ...
# 1491                                                NaN
# 1492                                                NaN
# 1493                                                NaN
# 1494                                                NaN
# 1495                                                NaN
#
#                                   Development relevance  \
# 0     Private financial flows - equity and debt - ac...
# 1                                                   NaN
# 2     Private financial flows - equity and debt - ac...
# 3     Private financial flows - equity and debt - ac...
# 4     Private financial flows - equity and debt - ac...
# ...                                                 ...
# 1491                                                NaN
# 1492                                                NaN
# 1493                                                NaN
# 1494                                                NaN
# 1495                                                NaN
#
#                              Limitations and exceptions  \
# 0     FDI data do not give a complete picture of int...
# 1                                                   NaN
# 2     FDI data do not give a complete picture of int...
# 3     FDI data do not give a complete picture of int...
# 4     FDI data do not give a complete picture of int...
# ...                                                 ...
# 1491                                                NaN
# 1492                                                NaN
# 1493                                                NaN
# 1494                                                NaN
# 1495                                                NaN
#
#                                        General comments Other notes  \
# 0     Note: Data starting from 2005 are based on the...         NaN
# 1     Note: Data are based on the sixth edition of t...         NaN
# 2     Note: Data starting from 2005 are based on the...         NaN
# 3     Note: Data starting from 2005 are based on the...         NaN
# 4     Note: Data starting from 2005 are based on the...         NaN
# ...                                                 ...         ...
# 1491                                                NaN         NaN
# 1492                                                NaN         NaN
# 1493                                                NaN         NaN
# 1494                                                NaN         NaN
# 1495                                                NaN         NaN
#
#      Notes from original source Related source links Other web links  \
# 0                           NaN                  NaN             NaN
# 1                           NaN                  NaN             NaN
# 2                           NaN                  NaN             NaN
# 3                           NaN                  NaN             NaN
# 4                           NaN                  NaN             NaN
# ...                         ...                  ...             ...
# 1491                        NaN                  NaN             NaN
# 1492                        NaN                  NaN             NaN
# 1493                        NaN                  NaN             NaN
# 1494                        NaN                  NaN             NaN
# 1495                        NaN                  NaN             NaN
#
#      Related indicators                                        License URL
# 0                   NaN  https://datacatalog.worldbank.org/public-licen...
# 1                   NaN  https://datacatalog.worldbank.org/public-licen...
# 2                   NaN  https://datacatalog.worldbank.org/public-licen...
# 3                   NaN  https://datacatalog.worldbank.org/public-licen...
# 4                   NaN  https://datacatalog.worldbank.org/public-licen...
# ...                 ...                                                ...
# 1491                NaN  https://datacatalog.worldbank.org/public-licen...
# 1492                NaN  https://datacatalog.worldbank.org/public-licen...
# 1493                NaN  https://datacatalog.worldbank.org/public-licen...
# 1494                NaN  https://datacatalog.worldbank.org/public-licen...
# 1495                NaN  https://datacatalog.worldbank.org/public-licen...
#
# [1496 rows x 27 columns]

# %%
summary(metadata_code).style.background_gradient(cmap='Blues')
# Out:
# data shape: (1496, 27)
# <style type="text/css">
# #T_0d781_row0_col1, #T_0d781_row0_col2, #T_0d781_row1_col1, #T_0d781_row1_col2, #T_0d781_row2_col1, #T_0d781_row2_col2, #T_0d781_row3_col1, #T_0d781_row3_col2, #T_0d781_row4_col1, #T_0d781_row4_col2, #T_0d781_row5_col1, #T_0d781_row5_col2, #T_0d781_row6_col1, #T_0d781_row6_col2, #T_0d781_row8_col1, #T_0d781_row8_col2, #T_0d781_row9_col1, #T_0d781_row9_col2, #T_0d781_row9_col3, #T_0d781_row10_col1, #T_0d781_row10_col2, #T_0d781_row11_col3, #T_0d781_row13_col3, #T_0d781_row14_col3, #T_0d781_row15_col3, #T_0d781_row23_col3, #T_0d781_row24_col3, #T_0d781_row25_col3, #T_0d781_row26_col1, #T_0d781_row26_col2, #T_0d781_row26_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0d781_row0_col3, #T_0d781_row1_col3, #T_0d781_row15_col1, #T_0d781_row15_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0d781_row2_col3 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_0d781_row3_col3, #T_0d781_row16_col3, #T_0d781_row21_col3 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_0d781_row4_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_0d781_row5_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_0d781_row6_col3 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_0d781_row7_col1, #T_0d781_row7_col2 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_0d781_row7_col3 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_0d781_row8_col3 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_0d781_row10_col3 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_0d781_row11_col1, #T_0d781_row11_col2, #T_0d781_row14_col1, #T_0d781_row14_col2 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_0d781_row12_col1, #T_0d781_row12_col2 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_0d781_row12_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_0d781_row13_col1, #T_0d781_row13_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_0d781_row16_col1, #T_0d781_row16_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_0d781_row17_col1, #T_0d781_row17_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_0d781_row17_col3 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_0d781_row18_col1, #T_0d781_row18_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_0d781_row18_col3 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_0d781_row19_col1, #T_0d781_row19_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_0d781_row19_col3 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_0d781_row20_col1, #T_0d781_row20_col2 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_0d781_row20_col3 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_0d781_row21_col1, #T_0d781_row21_col2, #T_0d781_row23_col1, #T_0d781_row23_col2 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_0d781_row22_col1, #T_0d781_row22_col2 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_0d781_row22_col3 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_0d781_row24_col1, #T_0d781_row24_col2 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_0d781_row25_col1, #T_0d781_row25_col2 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0d781">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d781_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_0d781_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_0d781_level0_col2" class="col_heading level0 col2" >%missing</th>
#       <th id="T_0d781_level0_col3" class="col_heading level0 col3" >#unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d781_level0_row0" class="row_heading level0 row0" >Code</th>
#       <td id="T_0d781_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_0d781_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_0d781_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_0d781_row0_col3" class="data row0 col3" >1496</td>
#     </tr>
#     <tr>
#       <th id="T_0d781_level0_row1" class="row_heading level0 row1" >Indicator Name</th>
#       <td id="T_0d781_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_0d781_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_0d781_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_0d781_row1_col3" class="data row1 col3" >1496</td>
#     </tr>
#     <tr>
#       <th id="T_0d781_level0_row2" class="row_heading level0 row2" >General Topic</th>
#       <td id="T_0d781_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_0d781_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_0d781_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_0d781_row2_col3" class="data row2 col3" >87</td>
#     </tr>
#     <tr>
#       <th id="T_0d781_level0_row3" class="row_heading level0 row3" >Topic</th>
#       <td id="T_0d781_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_0d781_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_0d781_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_0d781_row3_col3" class="data row3 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_0d781_level0_row4" class="row_heading level0 row4" >SubTopic1</th>
#       <td id="T_0d781_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_0d781_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_0d781_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_0d781_row4_col3" class="data row4 col3" >60</td>
#     </tr>
#     <tr>
#       <th id="T_0d781_level0_row5" class="row_heading level0 row5" >SubTopic2</th>
#       <td id="T_0d781_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_0d781_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_0d781_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_0d781_row5_col3" class="data row5 col3" >178</td>
#     </tr>
#     <tr>
#       <th id="T_0d781_level0_row6" class="row_heading level0 row6" >SubTopic3</th>
#       <td id="T_0d781_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_0d781_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_0d781_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_0d781_row6_col3" class="data row6 col3" >515</td>
#     </tr>
#     <tr>
#       <th id="T_0d781_level0_row7" class="row_heading level0 row7" >Short definition</th>
#       <td id="T_0d781_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_0d781_row7_col1" class="data row7 col1" >1289</td>
#       <td id="T_0d781_row7_col2" class="data row7 col2" >0.861631</td>
#       <td id="T_0d781_row7_col3" class="data row7 col3" >176</td>
#     </tr>
#     <tr>
#       <th id="T_0d781_level0_row8" class="row_heading level0 row8" >Long definition</th>
#       <td id="T_0d781_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_0d781_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_0d781_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_0d781_row8_col3" class="data row8 col3" >1130</td>
#     </tr>
#     <tr>
#       <th id="T_0d781_level0_row9" class="row_heading level0 row9" >License Type</th>
#       <td id="T_0d781_row9_col0" class="data row9 col0" >object</td>
#       <td id="T_0d781_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_0d781_row9_col2" class="data row9 col2" >0.001337</td>
#       <td id="T_0d781_row9_col3" class="data row9 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_0d781_level0_row10" class="row_heading level0 row10" >Source</th>
#       <td id="T_0d781_row10_col0" class="data row10 col0" >object</td>
#       <td id="T_0d781_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_0d781_row10_col2" class="data row10 col2" >0.000668</td>
#       <td id="T_0d781_row10_col3" class="data row10 col3" >204</td>
#     </tr>
#     <tr>
#       <th id="T_0d781_level0_row11" class="row_heading level0 row11" >Dataset</th>
#       <td id="T_0d781_row11_col0" class="data row11 col0" >object</td>
#       <td id="T_0d781_row11_col1" class="data row11 col1" >1417</td>
#       <td id="T_0d781_row11_col2" class="data row11 col

# %%
metadata_code = metadata_code.sort_values(['Topic','SubTopic1', 'SubTopic2', 'SubTopic3'])
with pd.ExcelWriter('../data/metadata/metadata_code.xlsx') as writer:
    metadata_code.to_excel(writer, index=False)

# %% [markdown]
# ## Orgonize into different sheets for metadata

# %%
metadata_code = metadata_code.groupby('Topic')

# %%
with pd.ExcelWriter('../data/metadata/metadata_code_by_sheet.xlsx') as writer:
    for topic, group in metadata_code:
        sheet_name = str(topic)[:50] 
        group = group.sort_values(['SubTopic1', 'SubTopic2', 'SubTopic3'])
        group.to_excel(writer, sheet_name=sheet_name, index=False)
